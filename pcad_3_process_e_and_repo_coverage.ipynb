# %% [markdown]
# # PCAD notebook 3
#
# This notebook processes electronic inventory data from Alma, merging electronic collection IDs and portfolio data into the main dataframe. It also loads, cleans, and merges data from BTAA SPR and Portico (the trusted repositories) into the main dataframe. Finally, it produces a list of MMS IDs for print records in Alma that are candidates for withdrawal based on preliminary matching to PCA and the trusted repositories.
#
# This notebook requires an Alma Analytics report of PCA-eligible portfolios. To produce this report in Alma Analytics:
# 1. Edit the Analytics report `/shared/University of Minnesota/Twin Cities/PCAD/PCAD-collection-IDs-to-title-info`
# 2. In the report, change the electronic collection IDs filter to match the e-collection IDs from the current version of the PCA spreadsheet provided by ERM or CMCC.
# 3. Run the report, save it, and export it as CSV.
# 4. If the first report is 400000 lines, run the report twice -- once with RCOUNT(1) is less than or equal to 400000 and once where greater than 400000 to get around export limits.
# 5. There will likely be character encoding issues. The easiest workaround for this is to open the exported csv files in Notebook++ and change the encoding to UTF-8 under the 'Encoding' menu tab, then save the files.
#
# Required files/inputs:
# - `mmsids_with_ecollids_all_{date}.pkl` file produced by `get_ecoll_ids.py` script
# - Alma Analytics report of PCA portfolios created based on the spreadsheet of PCA-eligible collections
# - `p_and_e_{date}.pkl` produced by PCAD notebook 2
# - Excel files showing coverage overlap for each trusted repository (BTAA SPR and Portico)
#
# Outputs:
# - `all_groups_{date}.pkl` file of main dataframe
# - Tab-delimited file `all_p_mms_ids-pcad-preserved_{date}.txt` to create itemized set in Alma of candidate print records
# - Various other `.pkl` files to save progress and review (if needed)

# %%
import ast
import math
import re
import pandas as pd
import numpy as np
from os.path import splitext
from io import BytesIO
from datetime import date
today = str(date.today()).replace('-','')

# %%
#change filename
ecolls = pd.read_pickle('mmsids_with_ecollids_all_20201109.pkl')
ecolls
# Out:
#               MMS ID          E Coll ID
# 0   9976741105001701  61781897120001701
# 0   9974069275901701  61809184890001701
# 0   9974069275901701  61781433670001701
# 0   9974069275901701  61726636620001701
# 0   9974069275901701  61692584080001701
# ..               ...                ...
# 0   9968274140001701  61535210660001701
# 0   9969007820001701  61620731210001701
# 0   9968320030001701  61789849490001701
# 0   9968320030001701  61645309830001701
# 0   9968320030001701  61549770130001701
#
# [81175 rows x 2 columns]

# %%
#change filename
p_and_e_data = pd.read_pickle('p_and_e_20201109.pkl')
p_and_e_data
# Out:
#         record_index            MMS_ID                       Title  \
# 0              87349  9935224330001701          Publishers' world.
# 1             105258  9967008940001701           Publishers weekly
# 2              58136  9913446020001701  Publishers weekly yearbook
# 3              60626  9934112930001701           Publishers weekly
# 4              52478  9937257820001701  The Book publishing annual
# ...              ...               ...                         ...
# 129003          2519  9939323230001701    UNLV gaming law journal.
# 129020         21367  9935136780001701            Northern history
# 129021        105065  9969162920001701           Northern history.
# 129074        114862  9977101571201701            Oriental insects
# 129075         14688  9933514930001701            Oriental insects
#
#                  OCN         ISSN                   Related_OCNs  \
# 0           [988619]  [0555-6384]  [2489456, 567791231, 1695359]
# 1         [37309426]  [2150-4008]                             []
# 2          [9604938]  [0000-0469]                             []
# 3          [2489456]  [0000-0019]            [37309426, 9604938]
# 4       [1114932096]  [0000-0787]                             []
# ...              ...          ...                            ...
# 129003   [666937502]           []                             []
# 129020     [1760664]  [0078-172X]                             []
# 129021   [679734406]  [1745-8706]                             []
# 129074   [668436876]  [2157-8745]                             []
# 129075     [1761507]  [0030-5316]                             []
#
#                                        Related_ISSNs Vol_nos Gov_doc_nos  \
# 0                                        [0000-0019]      []          []
# 1                                        [0000-0019]      []          []
# 2                                        [0000-0019]      []          []
# 3       [0000-0019, 000--0019, 0000-0469, 2150-4008]      []          []
# 4                                        [0000-0019]      []          []
# ...                                              ...     ...         ...
# 129003                                            []      []          []
# 129020                                            []      []          []
# 129021                                   [0078-172X]      []          []
# 129074                                   [0030-5316]      []          []
# 129075                                            []      []          []
#
#                                   OCN_cluster  \
# 0       [567791231, 1695359, 988619, 2489456]
# 1                                  [37309426]
# 2                                   [9604938]
# 3                [37309426, 9604938, 2489456]
# 4                                [1114932096]
# ...                                       ...
# 129003                            [666937502]
# 129020                              [1760664]
# 129021                            [679734406]
# 129074                            [668436876]
# 129075                              [1761507]
#
#                              ISSN_cluster p_or_e ISSN_group_id OCN_group_id  \
# 0                  [0000-0019, 0555-6384]      p          [0i]     [35959o]
# 1                  [2150-4008, 0000-0019]      e          [0i]     [35959o]
# 2                  [0000-0469, 0000-0019]      p          [0i]     [35959o]
# 3       [2150-4008, 0000-0469, 0000-0019]      p          [0i]     [35959o]
# 4                  [0000-0787, 0000-0019]      p          [0i]      [9122o]
# ...                                   ...    ...           ...          ...
# 129003                                 []      p      [48442i]     [99928o]
# 129020                        [0078-172X]      p       [9994i]     [40621o]
# 129021             [0078-172X, 1745-8706]      e       [9994i]    [100478o]
# 129074             [0030-5316, 2157-8745]      e       [5104i]     [99982o]
# 129075                        [0030-5316]      p       [5104i]     [40822o]
#
#              both_groups  matches_group_id ISSN_to_match
# 0           [0i, 35959o]                 0     0555-6384
# 1           [0i, 35959o]                 0     2150-4008
# 2           [0i, 35959o]                 0     0000-0469
# 3           [0i, 35959o]                 0     0000-0019
# 4            [0i, 9122o]                 0     0000-0787
# ...                  ...               ...           ...
# 129003  [48442i, 99928o]            101650
# 129020   [9994i, 40621o]            101667     0078-172X
# 129021  [9994i, 100478o]            101667     1745-8706
# 129074   [5104i, 99982o]            101697     2157-8745
# 129075   [5104i, 40822o]            101697     0030-5316
#
# [40379 rows x 17 columns]

# %%
edf2 = pd.merge(p_and_e_data,ecolls,how='left',left_on='MMS_ID',right_on='MMS ID')
edf2
# Out:
#         record_index            MMS_ID               Title          OCN  \
# 0              87349  9935224330001701  Publishers' world.     [988619]
# 1             105258  9967008940001701   Publishers weekly   [37309426]
# 2             105258  9967008940001701   Publishers weekly   [37309426]
# 3             105258  9967008940001701   Publishers weekly   [37309426]
# 4             105258  9967008940001701   Publishers weekly   [37309426]
# ...              ...               ...                 ...          ...
# 102032        105065  9969162920001701   Northern history.  [679734406]
# 102033        105065  9969162920001701   Northern history.  [679734406]
# 102034        114862  9977101571201701    Oriental insects  [668436876]
# 102035        114862  9977101571201701    Oriental insects  [668436876]
# 102036         14688  9933514930001701    Oriental insects    [1761507]
#
#                ISSN                   Related_OCNs Related_ISSNs Vol_nos  \
# 0       [0555-6384]  [2489456, 567791231, 1695359]   [0000-0019]      []
# 1       [2150-4008]                             []   [0000-0019]      []
# 2       [2150-4008]                             []   [0000-0019]      []
# 3       [2150-4008]                             []   [0000-0019]      []
# 4       [2150-4008]                             []   [0000-0019]      []
# ...             ...                            ...           ...     ...
# 102032  [1745-8706]                             []   [0078-172X]      []
# 102033  [1745-8706]                             []   [0078-172X]      []
# 102034  [2157-8745]                             []   [0030-5316]      []
# 102035  [2157-8745]                             []   [0030-5316]      []
# 102036  [0030-5316]                             []            []      []
#
#        Gov_doc_nos                            OCN_cluster  \
# 0               []  [567791231, 1695359, 988619, 2489456]
# 1               []                             [37309426]
# 2               []                             [37309426]
# 3               []                             [37309426]
# 4               []                             [37309426]
# ...            ...                                    ...
# 102032          []                            [679734406]
# 102033          []                            [679734406]
# 102034          []                            [668436876]
# 102035          []                            [668436876]
# 102036          []                              [1761507]
#
#                   ISSN_cluster p_or_e ISSN_group_id OCN_group_id  \
# 0       [0000-0019, 0555-6384]      p          [0i]     [35959o]
# 1       [2150-4008, 0000-0019]      e          [0i]     [35959o]
# 2       [2150-4008, 0000-0019]      e          [0i]     [35959o]
# 3       [2150-4008, 0000-0019]      e          [0i]     [35959o]
# 4       [2150-4008, 0000-0019]      e          [0i]     [35959o]
# ...                        ...    ...           ...          ...
# 102032  [0078-172X, 1745-8706]      e       [9994i]    [100478o]
# 102033  [0078-172X, 1745-8706]      e       [9994i]    [100478o]
# 102034  [0030-5316, 2157-8745]      e       [5104i]     [99982o]
# 102035  [0030-5316, 2157-8745]      e       [5104i]     [99982o]
# 102036             [0030-5316]      p       [5104i]     [40822o]
#
#              both_groups  matches_group_id ISSN_to_match            MMS ID  \
# 0           [0i, 35959o]                 0     0555-6384               NaN
# 1           [0i, 35959o]                 0     2150-4008  9967008940001701
# 2           [0i, 35959o]                 0     2150-4008  9967008940001701
# 3           [0i, 35959o]                 0     2150-4008  9967008940001701
# 4           [0i, 35959o]                 0     2150-4008  9967008940001701
# ...                  ...               ...           ...               ...
# 102032  [9994i, 100478o]            101667     1745-8706  9969162920001701
# 102033  [9994i, 100478o]            101667     1745-8706  9969162920001701
# 102034   [5104i, 99982o]            101697     2157-8745  9977101571201701
# 102035   [5104i, 99982o]            101697     2157-8745  9977101571201701
# 102036   [5104i, 40822o]            101697     0030-5316               NaN
#
#                 E Coll ID
# 0                     NaN
# 1       61821822470001701
# 2       61816638400001701
# 3       61816608130001701
# 4       61815504800001701
# ...                   ...
# 102032  61549770130001701
# 102033  61535213430001701
# 102034  61808527020001701
# 102035  61808506700001701
# 102036                NaN
#
# [102037 rows x 19 columns]

# %% [markdown]
# ### Merge pcad data from Analytics into e df

# %%
#change filename
pcad0 = pd.read_csv('PCAD-collection-IDs-to-title-info-1.csv',sep=',',dtype=str)
pcad0
# Out:
#       Electronic Collection Id       Electronic Collection Public Name  \
# 0            61535209430001701  American Medical Association Backfiles
# 1            61535209430001701  American Medical Association Backfiles
# 2            61535209430001701  American Medical Association Backfiles
# 3            61535209430001701  American Medical Association Backfiles
# 4            61535209430001701  American Medical Association Backfiles
# ...                        ...                                     ...
# 42466        61816118310001701    Mary Ann Liebert Publishers Journals
# 42467        61816118310001701    Mary Ann Liebert Publishers Journals
# 42468        61816118310001701    Mary Ann Liebert Publishers Journals
# 42469        61816598280001701  Wiley Online Library Surgery Backfiles
# 42470        61817087960001701                   Time Magazine Archive
#
#       Electronic Collection Public Name (override)            MMS Id  \
# 0                                              NaN  9966629010001701
# 1                                              NaN  9966757510001701
# 2                                              NaN  9966759170001701
# 3                                              NaN  9966774590001701
# 4                                              NaN  9966774910001701
# ...                                            ...               ...
# 42466                    Mary Ann Liebert Backfile  9977118809701701
# 42467                    Mary Ann Liebert Backfile  9977118809801701
# 42468                    Mary Ann Liebert Backfile  9977118809901701
# 42469                                          NaN  9966956150001701
# 42470                                          NaN  9969180100001701
#
#                                            Title Begin Publication Date  \
# 0                     Archives of ophthalmology.                   1879
# 1                           Archives of surgery.                   1920
# 2             The archives of internal medicine.                   1908
# 3                    Archives of otolaryngology.                   1960
# 4      American journal of diseases of children.                   1960
# ...                                          ...                    ...
# 42466             Central nervous system trauma.                   1984
# 42467              CyberPsychology and behavior.                   1998
# 42468                         AIDS patient care.                   1987
# 42469                British journal of surgery.                   1913
# 42470                                      Time.                   1923
#
#       End Publication Date                  ISSN  \
# 0                     1950  2375-057X; 0093-0326
# 1                     1950  2376-3590; 0272-5533
# 2                     1950             0730-188X
# 3                     1985  2376-3817; 0003-9977
# 4                     1993  2374-3018; 0002-922X
# ...                    ...                   ...
# 42466                 1987             0737-5999
# 42467                 2009  1557-8364; 1094-9313
# 42468                 1995  0893-5068; 0893-5068
# 42469                 9999  1365-2168; 0007-1323
# 42470                 9999  2169-1665; 0040-781X
#
#                            Coverage Information Combined Coverage Statement  \
# 0       Available from 1929 volume: 1 issue: 1 until ...        Only global
# 1       Available from 1920 volume: 1 issue: 1 until ...        Only global
# 2       Available from 1908 volume: 1 issue: 1 until ...        Only global
# 3       Available from 1960 volume: 72 issue: 1 until...        Only global
# 4       Available from 1960 volume: 100 issue: 1 unti...        Only global
# ...                                                  ...                ...
# 42466   Available from 1984 volume: 1 issue: 1 until ...        Only global
# 42467   Available from 1998 volume: 1 issue: 1 until ...        Only global
# 42468   Available from 1987 volume: 1 issue: 1 until ...        Only global
# 42469   Available from 1913 volume: 1 issue: 1 until ...         Only local
# 42470                    Available from 1923 until 2000;        Only global
#
#             Portfolio Id      Lifecycle Embargo Operator Embargo Months  \
# 0      53536123280001701  In Repository              NaN            NaN
# 1      53536420410001701  In Repository              NaN            NaN
# 2      53536407060001701  In Repository              NaN            NaN
# 3      53536464550001701  In Repository              NaN            NaN
# 4      53536464180001701  In Repository              NaN            NaN
# ...                  ...            ...              ...            ...
# 42466  53816118110001701  In Repository              NaN            NaN
# 42467  53816118140001701  In Repository              NaN            NaN
# 42468  53816118210001701  In Repository              NaN            NaN
# 42469  53816598250001701  In Repository              NaN            NaN
# 42470  53817087930001701  In Repository              NaN            NaN
#
#       Embargo Years Status (Active)
# 0               NaN            None
# 1               NaN            None
# 2               NaN            None
# 3               NaN            None
# 4               NaN            None
# ...             ...             ...
# 42466           NaN            None
# 42467           NaN            None
# 42468           NaN            None
# 42469           NaN            None
# 42470           NaN            None
#
# [42471 rows x 16 columns]

# %%
'''Run this cell only if Analytics report exceeded 40000 lines
pcad1 = pd.read_csv('PCAD-collection-IDs-to-title-info-1-20180809.csv',sep='\t',dtype=str)
pcad = pd.concat([pcad0,pcad1],ignore_index=True)
pcad.drop_duplicates(inplace=True)
pcad'''

# %% [markdown]
# #### Remove rows where electronic lifecycle is "Deleted"

# %%
pcad = pcad0
pcad = pcad[pcad['Lifecycle'] != 'Deleted']
pcad
# Out:
#       Electronic Collection Id       Electronic Collection Public Name  \
# 0            61535209430001701  American Medical Association Backfiles
# 1            61535209430001701  American Medical Association Backfiles
# 2            61535209430001701  American Medical Association Backfiles
# 3            61535209430001701  American Medical Association Backfiles
# 4            61535209430001701  American Medical Association Backfiles
# ...                        ...                                     ...
# 42466        61816118310001701    Mary Ann Liebert Publishers Journals
# 42467        61816118310001701    Mary Ann Liebert Publishers Journals
# 42468        61816118310001701    Mary Ann Liebert Publishers Journals
# 42469        61816598280001701  Wiley Online Library Surgery Backfiles
# 42470        61817087960001701                   Time Magazine Archive
#
#       Electronic Collection Public Name (override)            MMS Id  \
# 0                                              NaN  9966629010001701
# 1                                              NaN  9966757510001701
# 2                                              NaN  9966759170001701
# 3                                              NaN  9966774590001701
# 4                                              NaN  9966774910001701
# ...                                            ...               ...
# 42466                    Mary Ann Liebert Backfile  9977118809701701
# 42467                    Mary Ann Liebert Backfile  9977118809801701
# 42468                    Mary Ann Liebert Backfile  9977118809901701
# 42469                                          NaN  9966956150001701
# 42470                                          NaN  9969180100001701
#
#                                            Title Begin Publication Date  \
# 0                     Archives of ophthalmology.                   1879
# 1                           Archives of surgery.                   1920
# 2             The archives of internal medicine.                   1908
# 3                    Archives of otolaryngology.                   1960
# 4      American journal of diseases of children.                   1960
# ...                                          ...                    ...
# 42466             Central nervous system trauma.                   1984
# 42467              CyberPsychology and behavior.                   1998
# 42468                         AIDS patient care.                   1987
# 42469                British journal of surgery.                   1913
# 42470                                      Time.                   1923
#
#       End Publication Date                  ISSN  \
# 0                     1950  2375-057X; 0093-0326
# 1                     1950  2376-3590; 0272-5533
# 2                     1950             0730-188X
# 3                     1985  2376-3817; 0003-9977
# 4                     1993  2374-3018; 0002-922X
# ...                    ...                   ...
# 42466                 1987             0737-5999
# 42467                 2009  1557-8364; 1094-9313
# 42468                 1995  0893-5068; 0893-5068
# 42469                 9999  1365-2168; 0007-1323
# 42470                 9999  2169-1665; 0040-781X
#
#                            Coverage Information Combined Coverage Statement  \
# 0       Available from 1929 volume: 1 issue: 1 until ...        Only global
# 1       Available from 1920 volume: 1 issue: 1 until ...        Only global
# 2       Available from 1908 volume: 1 issue: 1 until ...        Only global
# 3       Available from 1960 volume: 72 issue: 1 until...        Only global
# 4       Available from 1960 volume: 100 issue: 1 unti...        Only global
# ...                                                  ...                ...
# 42466   Available from 1984 volume: 1 issue: 1 until ...        Only global
# 42467   Available from 1998 volume: 1 issue: 1 until ...        Only global
# 42468   Available from 1987 volume: 1 issue: 1 until ...        Only global
# 42469   Available from 1913 volume: 1 issue: 1 until ...         Only local
# 42470                    Available from 1923 until 2000;        Only global
#
#             Portfolio Id      Lifecycle Embargo Operator Embargo Months  \
# 0      53536123280001701  In Repository              NaN            NaN
# 1      53536420410001701  In Repository              NaN            NaN
# 2      53536407060001701  In Repository              NaN            NaN
# 3      53536464550001701  In Repository              NaN            NaN
# 4      53536464180001701  In Repository              NaN            NaN
# ...                  ...            ...              ...            ...
# 42466  53816118110001701  In Repository              NaN            NaN
# 42467  53816118140001701  In Repository              NaN            NaN
# 42468  53816118210001701  In Repository              NaN            NaN
# 42469  53816598250001701  In Repository              NaN            NaN
# 42470  53817087930001701  In Repository              NaN            NaN
#
#       Embargo Years Status (Active)
# 0               NaN            None
# 1               NaN            None
# 2               NaN            None
# 3               NaN            None
# 4               NaN            None
# ...             ...             ...
# 42466           NaN            None
# 42467           NaN            None
# 42468           NaN            None
# 42469           NaN            None
# 42470           NaN            None
#
# [32057 rows x 16 columns]

# %% [markdown]
# #### Read in PCAD collections data from spreadsheet

# %%
#change filename; may need to add or remove renaming pairs depending on headers in PCAD collections spreadsheet
pcad_ynm = pd.read_excel('PCAD II Final_summary.xlsx',dtype=str)
pcad_ynm.rename(columns={'Collection ID':'Electronic Collection Id', 'PCA&ILL': 'PCAD?'},inplace=True)
pcad_ynm
# Out:
#     Electronic Collection Id                     Collection Public Name PCAD?
# 0          61757894800001701                     ACSESS Digital Library   Yes
# 1          61647584340001701   AIAA Aerospace Research Central Journals   Yes
# 2          61549768600001701                        AIP Digital Archive   Yes
# 3          61535215970001701   American Chemical Society Legacy Archive   Yes
# 4          61535209430001701     American Medical Association Backfiles   Yes
# ..                       ...                                        ...   ...
# 195        61816598280001701     Wiley Online Library Surgery Backfiles   Yes
# 196        61535213310001701  Wiley Online Library Veterinary Backfiles   Yes
# 197        61644185620001701                Women''s Magazine Archive I   Yes
# 198        61618810070001701                Women''s Wear Daily Archive   Yes
# 199        61624535360001701                  World Scientific Archives   Yes
#
# [200 rows x 3 columns]

# %%
pcad_ynm = pcad_ynm[['Electronic Collection Id','Collection Public Name','PCAD?']]
pcad_ynm
# Out:
#     Electronic Collection Id                     Collection Public Name PCAD?
# 0          61757894800001701                     ACSESS Digital Library   Yes
# 1          61647584340001701   AIAA Aerospace Research Central Journals   Yes
# 2          61549768600001701                        AIP Digital Archive   Yes
# 3          61535215970001701   American Chemical Society Legacy Archive   Yes
# 4          61535209430001701     American Medical Association Backfiles   Yes
# ..                       ...                                        ...   ...
# 195        61816598280001701     Wiley Online Library Surgery Backfiles   Yes
# 196        61535213310001701  Wiley Online Library Veterinary Backfiles   Yes
# 197        61644185620001701                Women''s Magazine Archive I   Yes
# 198        61618810070001701                Women''s Wear Daily Archive   Yes
# 199        61624535360001701                  World Scientific Archives   Yes
#
# [200 rows x 3 columns]

# %%
def code_vendor (collection_public_name):
    x = collection_public_name.lower()
    if 'wiley' in x:
        return 'Wiley'
    elif 'elsevier' in x:
        return 'Elsevier'
    elif 'jstor' in x:
        return 'JSTOR'
    elif 'sage' in x:
        return 'SAGE'
    elif 'springer' in x:
        return 'Springer'
    elif 'taylor & francis' in x:
        return 'Taylor & Francis'
    else:
        return 'other'

# %%
pcad_ynm['Vendor_key'] = pcad_ynm['Collection Public Name'].apply(lambda x: code_vendor(x))
pcad_ynm
# Out:
#     Electronic Collection Id                     Collection Public Name PCAD?  \
# 0          61757894800001701                     ACSESS Digital Library   Yes
# 1          61647584340001701   AIAA Aerospace Research Central Journals   Yes
# 2          61549768600001701                        AIP Digital Archive   Yes
# 3          61535215970001701   American Chemical Society Legacy Archive   Yes
# 4          61535209430001701     American Medical Association Backfiles   Yes
# ..                       ...                                        ...   ...
# 195        61816598280001701     Wiley Online Library Surgery Backfiles   Yes
# 196        61535213310001701  Wiley Online Library Veterinary Backfiles   Yes
# 197        61644185620001701                Women''s Magazine Archive I   Yes
# 198        61618810070001701                Women''s Wear Daily Archive   Yes
# 199        61624535360001701                  World Scientific Archives   Yes
#
#     Vendor_key
# 0        other
# 1        other
# 2        other
# 3        other
# 4        other
# ..         ...
# 195      Wiley
# 196      Wiley
# 197      other
# 198      other
# 199      other
#
# [200 rows x 4 columns]

# %%
pcad_ynm['Vendor_key'].value_counts()
# Out:
# other               75
# Wiley               52
# JSTOR               23
# Taylor & Francis    18
# SAGE                14
# Springer            13
# Elsevier             5
# Name: Vendor_key, dtype: int64

# %%
pcad = pd.merge(pcad,pcad_ynm,how='inner',left_on='Electronic Collection Id',right_on='Electronic Collection Id')
pcad
# Out:
#       Electronic Collection Id       Electronic Collection Public Name  \
# 0            61535209430001701  American Medical Association Backfiles
# 1            61535209430001701  American Medical Association Backfiles
# 2            61535209430001701  American Medical Association Backfiles
# 3            61535209430001701  American Medical Association Backfiles
# 4            61535209430001701  American Medical Association Backfiles
# ...                        ...                                     ...
# 32664        61816118310001701    Mary Ann Liebert Publishers Journals
# 32665        61816118310001701    Mary Ann Liebert Publishers Journals
# 32666        61816118310001701    Mary Ann Liebert Publishers Journals
# 32667        61816598280001701  Wiley Online Library Surgery Backfiles
# 32668        61817087960001701                   Time Magazine Archive
#
#       Electronic Collection Public Name (override)            MMS Id  \
# 0                                              NaN  9966629010001701
# 1                                              NaN  9966757510001701
# 2                                              NaN  9966759170001701
# 3                                              NaN  9966774590001701
# 4                                              NaN  9966774910001701
# ...                                            ...               ...
# 32664                    Mary Ann Liebert Backfile  9977118809701701
# 32665                    Mary Ann Liebert Backfile  9977118809801701
# 32666                    Mary Ann Liebert Backfile  9977118809901701
# 32667                                          NaN  9966956150001701
# 32668                                          NaN  9969180100001701
#
#                                            Title Begin Publication Date  \
# 0                     Archives of ophthalmology.                   1879
# 1                           Archives of surgery.                   1920
# 2             The archives of internal medicine.                   1908
# 3                    Archives of otolaryngology.                   1960
# 4      American journal of diseases of children.                   1960
# ...                                          ...                    ...
# 32664             Central nervous system trauma.                   1984
# 32665              CyberPsychology and behavior.                   1998
# 32666                         AIDS patient care.                   1987
# 32667                British journal of surgery.                   1913
# 32668                                      Time.                   1923
#
#       End Publication Date                  ISSN  \
# 0                     1950  2375-057X; 0093-0326
# 1                     1950  2376-3590; 0272-5533
# 2                     1950             0730-188X
# 3                     1985  2376-3817; 0003-9977
# 4                     1993  2374-3018; 0002-922X
# ...                    ...                   ...
# 32664                 1987             0737-5999
# 32665                 2009  1557-8364; 1094-9313
# 32666                 1995  0893-5068; 0893-5068
# 32667                 9999  1365-2168; 0007-1323
# 32668                 9999  2169-1665; 0040-781X
#
#                            Coverage Information Combined Coverage Statement  \
# 0       Available from 1929 volume: 1 issue: 1 until ...        Only global
# 1       Available from 1920 volume: 1 issue: 1 until ...        Only global
# 2       Available from 1908 volume: 1 issue: 1 until ...        Only global
# 3       Available from 1960 volume: 72 issue: 1 until...        Only global
# 4       Available from 1960 volume: 100 issue: 1 unti...        Only global
# ...                                                  ...                ...
# 32664   Available from 1984 volume: 1 issue: 1 until ...        Only global
# 32665   Available from 1998 volume: 1 issue: 1 until ...        Only global
# 32666   Available from 1987 volume: 1 issue: 1 until ...        Only global
# 32667   Available from 1913 volume: 1 issue: 1 until ...         Only local
# 32668                    Available from 1923 until 2000;        Only global
#
#             Portfolio Id      Lifecycle Embargo Operator Embargo Months  \
# 0      53536123280001701  In Repository              NaN            NaN
# 1      53536420410001701  In Repository              NaN            NaN
# 2      53536407060001701  In Repository              NaN            NaN
# 3      53536464550001701  In Repository              NaN            NaN
# 4      53536464180001701  In Repository              NaN            NaN
# ...                  ...            ...              ...            ...
# 32664  53816118110001701  In Repository              NaN            NaN
# 32665  53816118140001701  In Repository              NaN            NaN
# 32666  53816118210001701  In Repository              NaN            NaN
# 32667  53816598250001701  In Repository              NaN            NaN
# 32668  53817087930001701  In Repository              NaN            NaN
#
#       Embargo Years Status (Active)                  Collection Public Name  \
# 0               NaN            None  American Medical Association Backfiles
# 1               NaN            None  American Medical Association Backfiles
# 2               NaN            None  American Medical Association Backfiles
# 3               NaN            None  American Medical Association Backfiles
# 4               NaN            None  American Medical Association Backfiles
# ...             ...             ...                                     ...
# 32664           NaN            None    Mary Ann Liebert Publishers Journals
# 32665           NaN            None    Mary Ann Liebert Publishers Journals
# 32666           NaN            None    Mary Ann Liebert Publishers Journals
# 32667           NaN            None  Wiley Online Library Surgery Backfiles
# 32668           NaN            None                   Time Magazine Archive
#
#       PCAD? Vendor_key
# 0       Yes      other
# 1       Yes      other
# 2       Yes      other
# 3       Yes      other
# 4       Yes      other
# ...     ...        ...
# 32664   Yes      other
# 32665   Yes      other
# 32666   Yes      other
# 32667   Yes      Wiley
# 32668   Yes      other
#
# [32669 rows x 19 columns]

# %%
df_pcad = pd.merge(edf2, pcad, how='left', left_on=['MMS_ID','E Coll ID'],
                   right_on=['MMS Id','Electronic Collection Id'],suffixes=['_bib','_portfolio'])
df_pcad
# Out:
#         record_index            MMS_ID           Title_bib          OCN  \
# 0              87349  9935224330001701  Publishers' world.     [988619]
# 1             105258  9967008940001701   Publishers weekly   [37309426]
# 2             105258  9967008940001701   Publishers weekly   [37309426]
# 3             105258  9967008940001701   Publishers weekly   [37309426]
# 4             105258  9967008940001701   Publishers weekly   [37309426]
# ...              ...               ...                 ...          ...
# 102154        105065  9969162920001701   Northern history.  [679734406]
# 102155        105065  9969162920001701   Northern history.  [679734406]
# 102156        114862  9977101571201701    Oriental insects  [668436876]
# 102157        114862  9977101571201701    Oriental insects  [668436876]
# 102158         14688  9933514930001701    Oriental insects    [1761507]
#
#            ISSN_bib                   Related_OCNs Related_ISSNs Vol_nos  \
# 0       [0555-6384]  [2489456, 567791231, 1695359]   [0000-0019]      []
# 1       [2150-4008]                             []   [0000-0019]      []
# 2       [2150-4008]                             []   [0000-0019]      []
# 3       [2150-4008]                             []   [0000-0019]      []
# 4       [2150-4008]                             []   [0000-0019]      []
# ...             ...                            ...           ...     ...
# 102154  [1745-8706]                             []   [0078-172X]      []
# 102155  [1745-8706]                             []   [0078-172X]      []
# 102156  [2157-8745]                             []   [0030-5316]      []
# 102157  [2157-8745]                             []   [0030-5316]      []
# 102158  [0030-5316]                             []            []      []
#
#        Gov_doc_nos                            OCN_cluster  ...  \
# 0               []  [567791231, 1695359, 988619, 2489456]  ...
# 1               []                             [37309426]  ...
# 2               []                             [37309426]  ...
# 3               []                             [37309426]  ...
# 4               []                             [37309426]  ...
# ...            ...                                    ...  ...
# 102154          []                            [679734406]  ...
# 102155          []                            [679734406]  ...
# 102156          []                            [668436876]  ...
# 102157          []                            [668436876]  ...
# 102158          []                              [1761507]  ...
#
#        Coverage Statement       Portfolio Id      Lifecycle Embargo Operator  \
# 0                     NaN                NaN            NaN              NaN
# 1                     NaN                NaN            NaN              NaN
# 2                     NaN                NaN            NaN              NaN
# 3                     NaN                NaN            NaN              NaN
# 4                     NaN                NaN            NaN              NaN
# ...                   ...                ...            ...              ...
# 102154                NaN                NaN            NaN              NaN
# 102155                NaN                NaN            NaN              NaN
# 102156        Only global  53815435190001701  In Repository              NaN
# 102157         Only local  53815442430001701  In Repository              NaN
# 102158                NaN                NaN            NaN              NaN
#
#        Embargo Months  Embargo Years Status (Active)  \
# 0                 NaN            NaN             NaN
# 1                 NaN            NaN             NaN
# 2                 NaN            NaN             NaN
# 3                 NaN            NaN             NaN
# 4                 NaN            NaN             NaN
# ...               ...            ...             ...
# 102154            NaN            NaN             NaN
# 102155            NaN            NaN             NaN
# 102156            NaN            NaN            None
# 102157            NaN            NaN            None
# 102158            NaN            NaN             NaN
#
#                                    Collection Public Name PCAD?  \
# 0                                                     NaN   NaN
# 1                                                     NaN   NaN
# 2                                                     NaN   NaN
# 3                                                     NaN   NaN
# 4                                                     NaN   NaN
# ...                                                   ...   ...
# 102154                                                NaN   NaN
# 102155                                                NaN   NaN
# 102156  Taylor & Francis Biological, Earth & Environme...   Yes
# 102157  Taylor & Francis Biological, Earth, Environmen...   Yes
# 102158                                                NaN   NaN
#
#               Vendor_key
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 102154               NaN
# 102155               NaN
# 102156  Taylor & Francis
# 102157  Taylor & Francis
# 102158               NaN
#
# [102159 rows x 38 columns]

# %%
df_pcad['Vendor_key'].value_counts()
# Out:
# Wiley               5404
# other               2075
# JSTOR               1966
# Elsevier            1372
# SAGE                1020
# Taylor & Francis     921
# Springer             581
# Name: Vendor_key, dtype: int64

# %% [markdown]
# #### Filter for rows with some kind of PCAD indicator

# %%
edf_pcad = df_pcad[(df_pcad['p_or_e'] == 'e') & (df_pcad['PCAD?'].isin(['Yes','Maybe']))]
edf_pcad
# Out:
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib          OCN  \
# 24                      The Wilson journal of ornithology   [66901429]
# 27           IEEE transactions on ultrasonics engineering   [66903667]
# 34             Journal of the University Film Association  [560253122]
# 37      Journal of the University Film and Video Assoc...  [669053443]
# 51                  Journal of the Institute of Actuaries  [669212538]
# ...                                                   ...          ...
# 102066  Proceedings and addresses of the American Phil...   [58839985]
# 102111  The Americas - Academy of American Franciscan ...   [45202766]
# 102114    International journal of adhesion and adhesives   [38995556]
# 102156                                   Oriental insects  [668436876]
# 102157                                   Oriental insects  [668436876]
#
#            ISSN_bib Related_OCNs Related_ISSNs Vol_nos Gov_doc_nos  \
# 24      [1938-5447]           []   [1559-4491]      []          []
# 27      [2162-1373]           []   [0893-6706]      []          []
# 34      [2328-1944]           []   [0041-9311]      []          []
# 37      [2328-1936]           []   [0734-919X]      []          []
# 51      [2058-1009]           []   [0020-2681]      []          []
# ...             ...          ...           ...     ...         ...
# 102066  [2325-9248]           []   [0065-972X]      []          []
# 102111  [1533-6247]           []   [0003-1615]      []          []
# 102114  [1879-0127]           []   [0143-7496]      []          []
# 102156  [2157-8745]           []   [0030-5316]      []          []
# 102157  [2157-8745]           []   [0030-5316]      []          []
#
#         OCN_cluster  ... Coverage Statement       Portfolio Id      Lifecycle  \
# 24       [66901429]  ...        Only global  53588425000001701  In Repository
# 27       [66903667]  ...        Only global  53620359120001701  In Repository
# 34      [560253122]  ...        Only global  53538633520001701  In Repository
# 37      [669053443]  ...        Only global  53537295580001701  In Repository
# 51      [669212538]  ...        Only global  53747073660001701  In Repository
# ...             ...  ...                ...                ...            ...
# 102066   [58839985]  ...        Only global  53540700110001701  In Repository
# 102111   [45202766]  ...        Only global  53539160390001701  In Repository
# 102114   [38995556]  ...         Only local  53624617390001701  In Repository
# 102156  [668436876]  ...        Only global  53815435190001701  In Repository
# 102157  [668436876]  ...         Only local  53815442430001701  In Repository
#
#        Embargo Operator Embargo Months  Embargo Years      Status (Active)  \
# 24                   >=            NaN              4  Waiting for Renewal
# 27                  NaN            NaN            NaN                 None
# 34                  NaN            NaN            NaN  Waiting for Renewal
# 37                  NaN            NaN            NaN  Waiting for Renewal
# 51                  NaN            NaN            NaN                 None
# ...                 ...            ...            ...                  ...
# 102066               >=            NaN              4  Waiting for Renewal
# 102111               >=            NaN              6  Waiting for Renewal
# 102114              NaN            NaN            NaN                 None
# 102156              NaN            NaN            NaN                 None
# 102157              NaN            NaN            NaN                 None
#
#                                    Collection Public Name PCAD?  \
# 24                         JSTOR Life Sciences Collection   Yes
# 27             IEEE/IET Electronic Library (IEL) Journals   Yes
# 34                              JSTOR Arts and Sciences V   Yes
# 37                              JSTOR Arts and Sciences V   Yes
# 51                              JSTOR Arts and Sciences X   Yes
# ...                                                   ...   ...
# 102066                        JSTOR Arts and Sciences VII   Yes
# 102111                        JSTOR Arts and Sciences VII   Yes
# 102114           Elsevier ScienceDirect Journals Complete   Yes
# 102156  Taylor & Francis Biological, Earth & Environme...   Yes
# 102157  Taylor & Francis Biological, Earth, Environmen...   Yes
#
#               Vendor_key
# 24                 JSTOR
# 27                 other
# 34                 JSTOR
# 37                 JSTOR
# 51                 JSTOR
# ...                  ...
# 102066             JSTOR
# 102111             JSTOR
# 102114          Elsevier
# 102156  Taylor & Francis
# 102157  Taylor & Francis
#
# [13339 rows x 38 columns]

# %%
edf_pcad.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'OCN', 'ISSN_bib',
#        'Related_OCNs', 'Related_ISSNs', 'Vol_nos', 'Gov_doc_nos',
#        'OCN_cluster', 'ISSN_cluster', 'p_or_e', 'ISSN_group_id',
#        'OCN_group_id', 'both_groups', 'matches_group_id', 'ISSN_to_match',
#        'MMS ID', 'E Coll ID', 'Electronic Collection Id',
#        'Electronic Collection Public Name',
#        'Electronic Collection Public Name (override)', 'MMS Id',
#        'Title_portfolio', 'Begin Publication Date', 'End Publication Date',
#        'ISSN_portfolio', 'Coverage Information Combined', 'Coverage Statement',
#        'Portfolio Id', 'Lifecycle', 'Embargo Operator', 'Embargo Months',
#        'Embargo Years', 'Status (Active)', 'Collection Public Name', 'PCAD?',
#        'Vendor_key'],
#       dtype='object')

# %%
epcad_groups = list(edf_pcad['matches_group_id'])
print(len(epcad_groups))
epcad_groups
# Out:
# 13339
# [2,
#  5,
#  7,
#  7,
#  12,
#  12,
#  20,
#  77,
#  83,
#  92,
#  92,
#  202,
#  213,
#  213,
#  213,
#  213,
#  213,
#  252,
#  254,
#  259,
#  267,
#  267,
#  273,
#  273,
#  277,
#  284,
#  292,
#  315,
#  340,
#  340,
#  477,
#  496,
#  511,
#  513,
#  513,
#  537,
#  660,
#  686,
#  686,
#  707,
#  739,
#  739,
#  744,
#  747,
#  764,
#  803,
#  803,
#  803,
#  819,
#  877,
#  877,
#  895,
#  895,
#  895,
#  895,
#  895,
#  895,
#  914,
#  1001,
#  1005,
#  1005,
#  1005,
#  1005,
#  1005,
#  1005,
#  1005,
#  1038,
#  1066,
#  1086,
#  1086,
#  1087,
#  1204,
#  1208,
#  1245,
#  1245,
#  1345,
#  1475,
#  1526,
#  1526,
#  1527,
#  1534,
#  1547,
#  1606,
#  1725,
#  1745,
#  1745,
#  1772,
#  1809,
#  1812,
#  1846,
#  1857,
#  1857,
#  1869,
#  1920,
#  1960,
#  2059,
#  2059,
#  2059,
#  2059,
#  2065,
#  2067,
#  2067,
#  2078,
#  2308,
#  2308,
#  2308,
#  2337,
#  2356,
#  2364,
#  2365,
#  2394,
#  2435,
#  2471,
#  2492,
#  2492,
#  2492,
#  2492,
#  2492,
#  2492,
#  2492,
#  2492,
#  2505,
#  2529,
#  2537,
#  2557,
#  2561,
#  2561,
#  2571,
#  2592,
#  2592,
#  2592,
#  2603,
#  2603,
#  2604,
#  2619,
#  2701,
#  2701,
#  2725,
#  2725,
#  2734,
#  2734,
#  2734,
#  2734,
#  2734,
#  2734,
#  2775,
#  2808,
#  2908,
#  2951,
#  2961,
#  2990,
#  2990,
#  2993,
#  3023,
#  3095,
#  3156,
#  3156,
#  3156,
#  3156,
#  3156,
#  3156,
#  3399,
#  3399,
#  3401,
#  3401,
#  3434,
#  3434,
#  3443,
#  3447,
#  3448,
#  3475,
#  3475,
#  3478,
#  3483,
#  3489,
#  3489,
#  3513,
#  3513,
#  3513,
#  3513,
#  3513,
#  3513,
#  3513,
#  3513,
#  3518,
#  3518,
#  3544,
#  3544,
#  3561,
#  3563,
#  3564,
#  3571,
#  3573,
#  3592,
#  3592,
#  3674,
#  3674,
#  3682,
#  3682,
#  3682,
#  3686,
#  3698,
#  3698,
#  3702,
#  3716,
#  3724,
#  3740,
#  3740,
#  3740,
#  3740,
#  3794,
#  3806,
#  3818,
#  3828,
#  3840,
#  3861,
#  3861,
#  3875,
#  3875,
#  3875,
#  3875,
#  3875,
#  3896,
#  3899,
#  3919,
#  3928,
#  3928,
#  3960,
#  3960,
#  3960,
#  3960,
#  3960,
#  3960,
#  3960,
#  4013,
#  4029,
#  4029,
#  4035,
#  4058,
#  4105,
#  4117,
#  4136,
#  4188,
#  4188,
#  4188,
#  4188,
#  4188,
#  4188,
#  4201,
#  4219,
#  4237,
#  4237,
#  4258,
#  4265,
#  4273,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4300,
#  4319,
#  4319,
#  4321,
#  4322,
#  4322,
#  4325,
#  4325,
#  4325,
#  4325,
#  4337,
#  4338,
#  4344,
#  4361,
#  4368,
#  4376,
#  4380,
#  4381,
#  4381,
#  4381,
#  4393,
#  4401,
#  4401,
#  4401,
#  4420,
#  4420,
#  4420,
#  4420,
#  4422,
#  4431,
#  4468,
#  4468,
#  4468,
#  4468,
#  4468,
#  4468,
#  4468,
#  4494,
#  4494,
#  4495,
#  4495,
#  4508,
#  4511,
#  4513,
#  4542,
#  4588,
#  4618,
#  4618,
#  4618,
#  4618,
#  4618,
#  4618,
#  4626,
#  4675,
#  4690,
#  4690,
#  4690,
#  4690,
#  4690,
#  4690,
#  4690,
#  4707,
#  4714,
#  4789,
#  4851,
#  4851,
#  4904,
#  4907,
#  4909,
#  4909,
#  4909,
#  4909,
#  4909,
#  4909,
#  4909,
#  4920,
#  4938,
#  4938,
#  4938,
#  4938,
#  4938,
#  4938,
#  4938,
#  4954,
#  4954,
#  4961,
#  5013,
#  5052,
#  5052,
#  5053,
#  5057,
#  5058,
#  5087,
#  5087,
#  5087,
#  5087,
#  5088,
#  5093,
#  5093,
#  5098,
#  5110,
#  5110,
#  5110,
#  5136,
#  5136,
#  5136,
#  5136,
#  5145,
#  5186,
#  5225,
#  5367,
#  5367,
#  5371,
#  5371,
#  5371,
#  5371,
#  5371,
#  5371,
#  5371,
#  5387,
#  5387,
#  5413,
#  5413,
#  5420,
#  5433,
#  5472,
#  5472,
#  5472,
#  5600,
#  5620,
#  5660,
#  5660,
#  5660,
#  5660,
#  5660,
#  5660,
#  5665,
#  5695,
#  5699,
#  5699,
#  5700,
#  5700,
#  5704,
#  5712,
#  5712,
#  5714,
#  5757,
#  5795,
#  5857,
#  5912,
#  5913,
#  5913,
#  5989,
#  5997,
#  6012,
#  6017,
#  6022,
#  6100,
#  6126,
#  6141,
#  6141,
#  6141,
#  6181,
#  6195,
#  6195,
#  6213,
#  6213,
#  6213,
#  6213,
#  6213,
#  6213,
#  6228,
#  6240,
#  6252,
#  6252,
#  6252,
#  6252,
#  6252,
#  6252,
#  6294,
#  6298,
#  6311,
#  6311,
#  6326,
#  6326,
#  6326,
#  6326,
#  6333,
#  6333,
#  6333,
#  6333,
#  6333,
#  6333,
#  6333,
#  6346,
#  6346,
#  6352,
#  6352,
#  6367,
#  6367,
#  6367,
#  6371,
#  6419,
#  6419,
#  6419,
#  6419,
#  6419,
#  6419,
#  6419,
#  6421,
#  6421,
#  6426,
#  6428,
#  6428,
#  6429,
#  6433,
#  6434,
#  6468,
#  6468,
#  6475,
#  6475,
#  6475,
#  6476,
#  6476,
#  6531,
#  6531,
#  6531,
#  6531,
#  6543,
#  6543,
#  6550,
#  6550,
#  6596,
#  6596,
#  6596,
#  6619,
#  6627,
#  6637,
#  6637,
#  6687,
#  6728,
#  6783,
#  6797,
#  6825,
#  6826,
#  6841,
#  6841,
#  6841,
#  6841,
#  6841,
#  6841,
#  6851,
#  6851,
#  6851,
#  6851,
#  6851,
#  6851,
#  6857,
#  6894,
#  6921,
#  6928,
#  6935,
#  6937,
#  6959,
#  6959,
#  7000,
#  7012,
#  7020,
#  7020,
#  7020,
#  7020,
#  7020,
#  7020,
#  7020,
#  7060,
#  7060,
#  7120,
#  7120,
#  7129,
#  7141,
#  7148,
#  7152,
#  7152,
#  7152,
#  7199,
#  7220,
#  7220,
#  7242,
#  7254,
#  7254,
#  7254,
#  7254,
#  7254,
#  7254,
#  7257,
#  7268,
#  7268,
#  7339,
#  7339,
#  7339,
#  7340,
#  7341,
#  7352,
#  7356,
#  7399,
#  7399,
#  7440,
#  7505,
#  7505,
#  7515,
#  7520,
#  7600,
#  7618,
#  7618,
#  7618,
#  7636,
#  7636,
#  7669,
#  7687,
#  7692,
#  7701,
#  7721,
#  7721,
#  7721,
#  7721,
#  7721,
#  7762,
#  7762,
#  7768,
#  7786,
#  7808,
#  7808,
#  7808,
#  7809,
#  7809,
#  7869,
#  7899,
#  7899,
#  7906,
#  7906,
#  7907,
#  7907,
#  7907,
#  7907,
#  7907,
#  7907,
#  7930,
#  7962,
#  8061,
#  8085,
#  8085,
#  8088,
#  8088,
#  8090,
#  8109,
#  8110,
#  8166,
#  8213,
#  8213,
#  8213,
#  8213,
#  8249,
#  8255,
#  8255,
#  8255,
#  8263,
#  8284,
#  8323,
#  8323,
#  8329,
#  8329,
#  8329,
#  8329,
#  8343,
#  8361,
#  8371,
#  8404,
#  8409,
#  8412,
#  8438,
#  8438,
#  8438,
#  8439,
#  8442,
#  8442,
#  8442,
#  8442,
#  8442,
#  8442,
#  8445,
#  8445,
#  8445,
#  8446,
#  8492,
#  8492,
#  8551,
#  8551,
#  8574,
#  8577,
#  8600,
#  8600,
#  8600,
#  8614,
#  8616,
#  8620,
#  8620,
#  8677,
#  8677,
#  8677,
#  8677,
#  8677,
#  8677,
#  8677,
#  8693,
#  8712,
#  8719,
#  8773,
#  8773,
#  8773,
#  8773,
#  8773,
#  8773,
#  8786,
#  8786,
#  8786,
#  8786,
#  8786,
#  8786,
#  8786,
#  8797,
#  8800,
#  8805,
#  8812,
#  8812,
#  8874,
#  8874,
#  9041,
#  9041,
#  9048,
#  9074,
#  9075,
#  9075,
#  9093,
#  9106,
#  9117,
#  9117,
#  9167,
#  9171,
#  9171,
#  9171,
#  9171,
#  9171,
#  9171,
#  9175,
#  9189,
#  9189,
#  9189,
#  9189,
#  9189,
#  9189,
#  9189,
#  9192,
#  9192,
#  9192,
#  9192,
#  9192,
#  9192,
#  9192,
#  9193,
#  9194,
#  9207,
#  9211,
#  9223,
#  9237,
#  9255,
#  9259,
#  9291,
#  9310,
#  9314,
#  9317,
#  9331,
#  9333,
#  9338,
#  9338,
#  9393,
#  9393,
#  9393,
#  9402,
#  9405,
#  9411,
#  9411,
#  9411,
#  9411,
#  9411,
#  9411,
#  9411,
#  9420,
#  9423,
#  9423,
#  9445,
#  9446,
#  9446,
#  9447,
#  9488,
#  9562,
#  9562,
#  9581,
#  9603,
#  9614,
#  9614,
#  9623,
#  9642,
#  9651,
#  9656,
#  9682,
#  9682,
#  9698,
#  9726,
#  9782,
#  9804,
#  9806,
#  9818,
#  9839,
#  9887,
#  9887,
#  9903,
#  9903,
#  9910,
#  9921,
#  9930,
#  9933,
#  9933,
#  9933,
#  9933,
#  9933,
#  9933,
#  9947,
#  9956,
#  9956,
#  9964,
#  9992,
#  9992,
#  9992,
#  9992,
#  9992,
#  9992,
#  9992,
#  10098,
#  10098,
#  10106,
#  10106,
#  10108,
#  10124,
#  10155,
#  10155,
#  10155,
#  10155,
#  10155,
#  10155,
#  10160,
#  10167,
#  10174,
#  10185,
#  10201,
#  10202,
#  10203,
#  10203,
#  10204,
#  10204,
#  10204,
#  10204,
#  10204,
#  10207,
#  10207,
#  10207,
#  10207,
#  10207,
#  10207,
#  10207,
#  10208,
#  10208,
#  10214,
#  10263,
#  10266,
#  10272,
#  10272,
#  10274,
#  10277,
#  10281,
#  10302,
#  10302,
#  10302,
#  10302,
#  10302,
#  10302,
#  10305,
#  10313,
#  10328,
#  10328,
#  10347,
#  10353,
#  10353,
#  10353,
#  10353,
#  10353,
#  10353,
#  10353,
#  10378,
#  10378,
#  10384,
#  10400,
#  10400,
#  10423,
#  10431,
#  10445,
#  10449,
#  10449,
#  10456,
#  10456,
#  10456,
#  10461,
#  10479,
#  10479,
#  10479,
#  10488,
#  10488,
#  10491,
#  10495,
#  10518,
#  10523,
#  10539,
#  10539,
#  10553,
#  10553,
#  10573,
#  10588,
#  10588,
#  10588,
#  10588,
#  10588,
#  10589,
#  10589,
#  10589,
#  10589,
#  10589,
#  10589,
#  10590,
#  10590,
#  10590,
#  10590,
#  10590,
#  10590,
#  10591,
#  10595,
#  10596,
#  10602,
#  10610,
#  10624,
#  10624,
#  10630,
#  10630,
#  10638,
#  10638,
#  10638,
#  10638,
#  10638,
#  10638,
#  10638,
#  10654,
#  10654,
#  10654,
#  10658,
#  10662,
#  10667,
#  10667,
#  10681,
#  10687,
#  10690,
#  10693,
#  10693,
#  10694,
#  10694,
#  10694,
#  10694,
#  10694,
#  10712,
#  10721,
#  10725,
#  10726,
#  10727,
#  10729,
#  10730,
#  10731,
#  10751,
#  10857,
#  10857,
#  10875,
#  10875,
#  10879,
#  10880,
#  10880,
#  10889,
#  10892,
#  10892,
#  10906,
#  10910,
#  10910,
#  10929,
#  10929,
#  10931,
#  10966,
#  10981,
#  10988,
#  11002,
#  11055,
#  11093,
#  11102,
#  11109,
#  11113,
#  11113,
#  11125,
#  11144,
#  11163,
#  11164,
#  11179,
#  11181,
#  11185,
#  11201,
#  11201,
#  11222,
#  11225,
#  11234,
#  11252,
#  11252,
#  ...]

# %%
epcad_data = df_pcad[df_pcad['matches_group_id'].isin(epcad_groups)]
epcad_data
# Out:
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 16            113344  9968879310001701
# 17            113344  9968879310001701
# 18            113344  9968879310001701
# ...              ...               ...
# 102118        125537  9968947900001701
# 102119        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib          OCN  \
# 14                   The Wilson journal of ornithology.   [62791211]
# 15                    The Wilson journal of ornithology   [66901429]
# 16                    The Wilson journal of ornithology   [66901429]
# 17                    The Wilson journal of ornithology   [66901429]
# 18                    The Wilson journal of ornithology   [66901429]
# ...                                                 ...          ...
# 102118  International journal of adhesion and adhesives   [38995556]
# 102119  International journal of adhesion and adhesives   [38995556]
# 102156                                 Oriental insects  [668436876]
# 102157                                 Oriental insects  [668436876]
# 102158                                 Oriental insects    [1761507]
#
#            ISSN_bib Related_OCNs Related_ISSNs Vol_nos Gov_doc_nos  \
# 14      [1559-4491]           []            []      []          []
# 15      [1938-5447]           []   [1559-4491]      []          []
# 16      [1938-5447]           []   [1559-4491]      []          []
# 17      [1938-5447]           []   [1559-4491]      []          []
# 18      [1938-5447]           []   [1559-4491]      []          []
# ...             ...          ...           ...     ...         ...
# 102118  [1879-0127]           []   [0143-7496]      []          []
# 102119  [1879-0127]           []   [0143-7496]      []          []
# 102156  [2157-8745]           []   [0030-5316]      []          []
# 102157  [2157-8745]           []   [0030-5316]      []          []
# 102158  [0030-5316]           []            []      []          []
#
#         OCN_cluster  ... Coverage Statement       Portfolio Id      Lifecycle  \
# 14       [62791211]  ...                NaN                NaN            NaN
# 15       [66901429]  ...                NaN                NaN            NaN
# 16       [66901429]  ...                NaN                NaN            NaN
# 17       [66901429]  ...                NaN                NaN            NaN
# 18       [66901429]  ...                NaN                NaN            NaN
# ...             ...  ...                ...                ...            ...
# 102118   [38995556]  ...                NaN                NaN            NaN
# 102119   [38995556]  ...                NaN                NaN            NaN
# 102156  [668436876]  ...        Only global  53815435190001701  In Repository
# 102157  [668436876]  ...         Only local  53815442430001701  In Repository
# 102158    [1761507]  ...                NaN                NaN            NaN
#
#        Embargo Operator Embargo Months  Embargo Years Status (Active)  \
# 14                  NaN            NaN            NaN             NaN
# 15                  NaN            NaN            NaN             NaN
# 16                  NaN            NaN            NaN             NaN
# 17                  NaN            NaN            NaN             NaN
# 18                  NaN            NaN            NaN             NaN
# ...                 ...            ...            ...             ...
# 102118              NaN            NaN            NaN             NaN
# 102119              NaN            NaN            NaN             NaN
# 102156              NaN            NaN            NaN            None
# 102157              NaN            NaN            NaN            None
# 102158              NaN            NaN            NaN             NaN
#
#                                    Collection Public Name PCAD?  \
# 14                                                    NaN   NaN
# 15                                                    NaN   NaN
# 16                                                    NaN   NaN
# 17                                                    NaN   NaN
# 18                                                    NaN   NaN
# ...                                                   ...   ...
# 102118                                                NaN   NaN
# 102119                                                NaN   NaN
# 102156  Taylor & Francis Biological, Earth & Environme...   Yes
# 102157  Taylor & Francis Biological, Earth, Environmen...   Yes
# 102158                                                NaN   NaN
#
#               Vendor_key
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# ...                  ...
# 102118               NaN
# 102119               NaN
# 102156  Taylor & Francis
# 102157  Taylor & Francis
# 102158               NaN
#
# [52265 rows x 38 columns]

# %%
no_pcad_data = df_pcad[df_pcad['matches_group_id'].isin(epcad_groups) == False]
no_pcad_data
# Out:
#         record_index            MMS_ID           Title_bib          OCN  \
# 0              87349  9935224330001701  Publishers' world.     [988619]
# 1             105258  9967008940001701   Publishers weekly   [37309426]
# 2             105258  9967008940001701   Publishers weekly   [37309426]
# 3             105258  9967008940001701   Publishers weekly   [37309426]
# 4             105258  9967008940001701   Publishers weekly   [37309426]
# ...              ...               ...                 ...          ...
# 102151         21367  9935136780001701    Northern history    [1760664]
# 102152        105065  9969162920001701   Northern history.  [679734406]
# 102153        105065  9969162920001701   Northern history.  [679734406]
# 102154        105065  9969162920001701   Northern history.  [679734406]
# 102155        105065  9969162920001701   Northern history.  [679734406]
#
#            ISSN_bib                   Related_OCNs Related_ISSNs Vol_nos  \
# 0       [0555-6384]  [2489456, 567791231, 1695359]   [0000-0019]      []
# 1       [2150-4008]                             []   [0000-0019]      []
# 2       [2150-4008]                             []   [0000-0019]      []
# 3       [2150-4008]                             []   [0000-0019]      []
# 4       [2150-4008]                             []   [0000-0019]      []
# ...             ...                            ...           ...     ...
# 102151  [0078-172X]                             []            []      []
# 102152  [1745-8706]                             []   [0078-172X]      []
# 102153  [1745-8706]                             []   [0078-172X]      []
# 102154  [1745-8706]                             []   [0078-172X]      []
# 102155  [1745-8706]                             []   [0078-172X]      []
#
#        Gov_doc_nos                            OCN_cluster  ...  \
# 0               []  [567791231, 1695359, 988619, 2489456]  ...
# 1               []                             [37309426]  ...
# 2               []                             [37309426]  ...
# 3               []                             [37309426]  ...
# 4               []                             [37309426]  ...
# ...            ...                                    ...  ...
# 102151          []                              [1760664]  ...
# 102152          []                            [679734406]  ...
# 102153          []                            [679734406]  ...
# 102154          []                            [679734406]  ...
# 102155          []                            [679734406]  ...
#
#        Coverage Statement Portfolio Id Lifecycle Embargo Operator  \
# 0                     NaN          NaN       NaN              NaN
# 1                     NaN          NaN       NaN              NaN
# 2                     NaN          NaN       NaN              NaN
# 3                     NaN          NaN       NaN              NaN
# 4                     NaN          NaN       NaN              NaN
# ...                   ...          ...       ...              ...
# 102151                NaN          NaN       NaN              NaN
# 102152                NaN          NaN       NaN              NaN
# 102153                NaN          NaN       NaN              NaN
# 102154                NaN          NaN       NaN              NaN
# 102155                NaN          NaN       NaN              NaN
#
#        Embargo Months  Embargo Years Status (Active) Collection Public Name  \
# 0                 NaN            NaN             NaN                    NaN
# 1                 NaN            NaN             NaN                    NaN
# 2                 NaN            NaN             NaN                    NaN
# 3                 NaN            NaN             NaN                    NaN
# 4                 NaN            NaN             NaN                    NaN
# ...               ...            ...             ...                    ...
# 102151            NaN            NaN             NaN                    NaN
# 102152            NaN            NaN             NaN                    NaN
# 102153            NaN            NaN             NaN                    NaN
# 102154            NaN            NaN             NaN                    NaN
# 102155            NaN            NaN             NaN                    NaN
#
#        PCAD? Vendor_key
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# ...      ...        ...
# 102151   NaN        NaN
# 102152   NaN        NaN
# 102153   NaN        NaN
# 102154   NaN        NaN
# 102155   NaN        NaN
#
# [49894 rows x 38 columns]

# %%
no_pcad_data['matches_group_id'].nunique()
# Out:
# 10280

# %%
df_epcad = epcad_data

# %%
df_epcad[df_epcad['PCAD?'] == 'nan']
# Out:
# Empty DataFrame
# Columns: [record_index, MMS_ID, Title_bib, OCN, ISSN_bib, Related_OCNs, Related_ISSNs, Vol_nos, Gov_doc_nos, OCN_cluster, ISSN_cluster, p_or_e, ISSN_group_id, OCN_group_id, both_groups, matches_group_id, ISSN_to_match, MMS ID, E Coll ID, Electronic Collection Id, Electronic Collection Public Name, Electronic Collection Public Name (override), MMS Id, Title_portfolio, Begin Publication Date, End Publication Date, ISSN_portfolio, Coverage Information Combined, Coverage Statement, Portfolio Id, Lifecycle, Embargo Operator, Embargo Months, Embargo Years, Status (Active), Collection Public Name, PCAD?, Vendor_key]
# Index: []
#
# [0 rows x 38 columns]

# %%
df_epcad = df_epcad[df_epcad['PCAD?'] != 'nan']
df_epcad
# Out:
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 16            113344  9968879310001701
# 17            113344  9968879310001701
# 18            113344  9968879310001701
# ...              ...               ...
# 102118        125537  9968947900001701
# 102119        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib          OCN  \
# 14                   The Wilson journal of ornithology.   [62791211]
# 15                    The Wilson journal of ornithology   [66901429]
# 16                    The Wilson journal of ornithology   [66901429]
# 17                    The Wilson journal of ornithology   [66901429]
# 18                    The Wilson journal of ornithology   [66901429]
# ...                                                 ...          ...
# 102118  International journal of adhesion and adhesives   [38995556]
# 102119  International journal of adhesion and adhesives   [38995556]
# 102156                                 Oriental insects  [668436876]
# 102157                                 Oriental insects  [668436876]
# 102158                                 Oriental insects    [1761507]
#
#            ISSN_bib Related_OCNs Related_ISSNs Vol_nos Gov_doc_nos  \
# 14      [1559-4491]           []            []      []          []
# 15      [1938-5447]           []   [1559-4491]      []          []
# 16      [1938-5447]           []   [1559-4491]      []          []
# 17      [1938-5447]           []   [1559-4491]      []          []
# 18      [1938-5447]           []   [1559-4491]      []          []
# ...             ...          ...           ...     ...         ...
# 102118  [1879-0127]           []   [0143-7496]      []          []
# 102119  [1879-0127]           []   [0143-7496]      []          []
# 102156  [2157-8745]           []   [0030-5316]      []          []
# 102157  [2157-8745]           []   [0030-5316]      []          []
# 102158  [0030-5316]           []            []      []          []
#
#         OCN_cluster  ... Coverage Statement       Portfolio Id      Lifecycle  \
# 14       [62791211]  ...                NaN                NaN            NaN
# 15       [66901429]  ...                NaN                NaN            NaN
# 16       [66901429]  ...                NaN                NaN            NaN
# 17       [66901429]  ...                NaN                NaN            NaN
# 18       [66901429]  ...                NaN                NaN            NaN
# ...             ...  ...                ...                ...            ...
# 102118   [38995556]  ...                NaN                NaN            NaN
# 102119   [38995556]  ...                NaN                NaN            NaN
# 102156  [668436876]  ...        Only global  53815435190001701  In Repository
# 102157  [668436876]  ...         Only local  53815442430001701  In Repository
# 102158    [1761507]  ...                NaN                NaN            NaN
#
#        Embargo Operator Embargo Months  Embargo Years Status (Active)  \
# 14                  NaN            NaN            NaN             NaN
# 15                  NaN            NaN            NaN             NaN
# 16                  NaN            NaN            NaN             NaN
# 17                  NaN            NaN            NaN             NaN
# 18                  NaN            NaN            NaN             NaN
# ...                 ...            ...            ...             ...
# 102118              NaN            NaN            NaN             NaN
# 102119              NaN            NaN            NaN             NaN
# 102156              NaN            NaN            NaN            None
# 102157              NaN            NaN            NaN            None
# 102158              NaN            NaN            NaN             NaN
#
#                                    Collection Public Name PCAD?  \
# 14                                                    NaN   NaN
# 15                                                    NaN   NaN
# 16                                                    NaN   NaN
# 17                                                    NaN   NaN
# 18                                                    NaN   NaN
# ...                                                   ...   ...
# 102118                                                NaN   NaN
# 102119                                                NaN   NaN
# 102156  Taylor & Francis Biological, Earth & Environme...   Yes
# 102157  Taylor & Francis Biological, Earth, Environmen...   Yes
# 102158                                                NaN   NaN
#
#               Vendor_key
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# ...                  ...
# 102118               NaN
# 102119               NaN
# 102156  Taylor & Francis
# 102157  Taylor & Francis
# 102158               NaN
#
# [52265 rows x 38 columns]

# %% [markdown]
# #### Find groups with p and e, p only, and e only

# %%
find_only_p_or_e = df_epcad[['record_index','matches_group_id','p_or_e','MMS_ID','Title_bib']]
find_only_p_or_e
# Out:
#         record_index  matches_group_id p_or_e            MMS_ID  \
# 14             69875                 2      p  9939153590001701
# 15            113344                 2      e  9968879310001701
# 16            113344                 2      e  9968879310001701
# 17            113344                 2      e  9968879310001701
# 18            113344                 2      e  9968879310001701
# ...              ...               ...    ...               ...
# 102118        125537            101582      e  9968947900001701
# 102119        125537            101582      e  9968947900001701
# 102156        114862            101697      e  9977101571201701
# 102157        114862            101697      e  9977101571201701
# 102158         14688            101697      p  9933514930001701
#
#                                               Title_bib
# 14                   The Wilson journal of ornithology.
# 15                    The Wilson journal of ornithology
# 16                    The Wilson journal of ornithology
# 17                    The Wilson journal of ornithology
# 18                    The Wilson journal of ornithology
# ...                                                 ...
# 102118  International journal of adhesion and adhesives
# 102119  International journal of adhesion and adhesives
# 102156                                 Oriental insects
# 102157                                 Oriental insects
# 102158                                 Oriental insects
#
# [52265 rows x 5 columns]

# %%
find_only_p_or_e.drop_duplicates(inplace=True)
find_only_p_or_e
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         record_index  matches_group_id p_or_e            MMS_ID  \
# 14             69875                 2      p  9939153590001701
# 15            113344                 2      e  9968879310001701
# 25             57684                 5      p  9963550760001701
# 26            128733                 5      e  9968441380001701
# 32            112352                 7      e  9967759560001701
# ...              ...               ...    ...               ...
# 102112        124654            101581      e  9924328340001701
# 102113         31683            101582      p  9957960200001701
# 102114        125537            101582      e  9968947900001701
# 102156        114862            101697      e  9977101571201701
# 102158         14688            101697      p  9933514930001701
#
#                                               Title_bib
# 14                   The Wilson journal of ornithology.
# 15                    The Wilson journal of ornithology
# 25         IEEE transactions on ultrasonics engineering
# 26         IEEE transactions on ultrasonics engineering
# 32           Journal of the University Film Association
# ...                                                 ...
# 102112                                Americas (Online)
# 102113  International journal of adhesion and adhesives
# 102114  International journal of adhesion and adhesives
# 102156                                 Oriental insects
# 102158                                 Oriental insects
#
# [15659 rows x 5 columns]

# %%
find_only_p_or_e = find_only_p_or_e.groupby(['matches_group_id']).agg(lambda x: list(set(x))).reset_index()
find_only_p_or_e
# Out:
#       matches_group_id                                       record_index  \
# 0                    2                                    [113344, 69875]
# 1                    5                                    [57684, 128733]
# 2                    7                            [112352, 78492, 107439]
# 3                   12                                    [88618, 111951]
# 4                   20                                    [122066, 89596]
# ...                ...                                                ...
# 6652            101504                                     [113874, 3295]
# 6653            101522  [41280, 26122, 118219, 61904, 18706, 123828, 8...
# 6654            101581                            [17960, 124654, 117510]
# 6655            101582                                    [125537, 31683]
# 6656            101697                                    [14688, 114862]
#
#       p_or_e                                             MMS_ID  \
# 0     [e, p]               [9939153590001701, 9968879310001701]
# 1     [e, p]               [9963550760001701, 9968441380001701]
# 2     [e, p]  [9967759560001701, 9933370000001701, 996714552...
# 3     [e, p]               [9939481760001701, 9968429800001701]
# 4     [e, p]               [9963135560001701, 9975966292301701]
# ...      ...                                                ...
# 6652  [e, p]               [9974799725001701, 9953296770001701]
# 6653  [e, p]  [9959156260001701, 9967988520001701, 991429894...
# 6654  [e, p]  [9924328340001701, 9946768760001701, 996798786...
# 6655  [e, p]               [9957960200001701, 9968947900001701]
# 6656  [e, p]               [9977101571201701, 9933514930001701]
#
#                                               Title_bib
# 0     [The Wilson journal of ornithology, The Wilson...
# 1        [IEEE transactions on ultrasonics engineering]
# 2     [Journal of the University Film Association, J...
# 3               [Journal of the Institute of Actuaries]
# 4     [Journal of tissue culture methods., Journal o...
# ...                                                 ...
# 6652                                            [Nomos]
# 6653  [Year book - American Philosophical Society, P...
# 6654  [The Americas - Academy of American Franciscan...
# 6655  [International journal of adhesion and adhesives]
# 6656                                 [Oriental insects]
#
# [6657 rows x 5 columns]

# %%
find_only_p_or_e['p_or_e'] = find_only_p_or_e['p_or_e'].apply(lambda x: sorted(x))
find_only_p_or_e
# Out:
#       matches_group_id                                       record_index  \
# 0                    2                                    [113344, 69875]
# 1                    5                                    [57684, 128733]
# 2                    7                            [112352, 78492, 107439]
# 3                   12                                    [88618, 111951]
# 4                   20                                    [122066, 89596]
# ...                ...                                                ...
# 6652            101504                                     [113874, 3295]
# 6653            101522  [41280, 26122, 118219, 61904, 18706, 123828, 8...
# 6654            101581                            [17960, 124654, 117510]
# 6655            101582                                    [125537, 31683]
# 6656            101697                                    [14688, 114862]
#
#       p_or_e                                             MMS_ID  \
# 0     [e, p]               [9939153590001701, 9968879310001701]
# 1     [e, p]               [9963550760001701, 9968441380001701]
# 2     [e, p]  [9967759560001701, 9933370000001701, 996714552...
# 3     [e, p]               [9939481760001701, 9968429800001701]
# 4     [e, p]               [9963135560001701, 9975966292301701]
# ...      ...                                                ...
# 6652  [e, p]               [9974799725001701, 9953296770001701]
# 6653  [e, p]  [9959156260001701, 9967988520001701, 991429894...
# 6654  [e, p]  [9924328340001701, 9946768760001701, 996798786...
# 6655  [e, p]               [9957960200001701, 9968947900001701]
# 6656  [e, p]               [9977101571201701, 9933514930001701]
#
#                                               Title_bib
# 0     [The Wilson journal of ornithology, The Wilson...
# 1        [IEEE transactions on ultrasonics engineering]
# 2     [Journal of the University Film Association, J...
# 3               [Journal of the Institute of Actuaries]
# 4     [Journal of tissue culture methods., Journal o...
# ...                                                 ...
# 6652                                            [Nomos]
# 6653  [Year book - American Philosophical Society, P...
# 6654  [The Americas - Academy of American Franciscan...
# 6655  [International journal of adhesion and adhesives]
# 6656                                 [Oriental insects]
#
# [6657 rows x 5 columns]

# %%
find_only_p_or_e['pore'] = find_only_p_or_e['p_or_e'].apply(lambda x: ' '.join(x))
find_only_p_or_e
# Out:
#       matches_group_id                                       record_index  \
# 0                    2                                    [113344, 69875]
# 1                    5                                    [57684, 128733]
# 2                    7                            [112352, 78492, 107439]
# 3                   12                                    [88618, 111951]
# 4                   20                                    [122066, 89596]
# ...                ...                                                ...
# 6652            101504                                     [113874, 3295]
# 6653            101522  [41280, 26122, 118219, 61904, 18706, 123828, 8...
# 6654            101581                            [17960, 124654, 117510]
# 6655            101582                                    [125537, 31683]
# 6656            101697                                    [14688, 114862]
#
#       p_or_e                                             MMS_ID  \
# 0     [e, p]               [9939153590001701, 9968879310001701]
# 1     [e, p]               [9963550760001701, 9968441380001701]
# 2     [e, p]  [9967759560001701, 9933370000001701, 996714552...
# 3     [e, p]               [9939481760001701, 9968429800001701]
# 4     [e, p]               [9963135560001701, 9975966292301701]
# ...      ...                                                ...
# 6652  [e, p]               [9974799725001701, 9953296770001701]
# 6653  [e, p]  [9959156260001701, 9967988520001701, 991429894...
# 6654  [e, p]  [9924328340001701, 9946768760001701, 996798786...
# 6655  [e, p]               [9957960200001701, 9968947900001701]
# 6656  [e, p]               [9977101571201701, 9933514930001701]
#
#                                               Title_bib pore
# 0     [The Wilson journal of ornithology, The Wilson...  e p
# 1        [IEEE transactions on ultrasonics engineering]  e p
# 2     [Journal of the University Film Association, J...  e p
# 3               [Journal of the Institute of Actuaries]  e p
# 4     [Journal of tissue culture methods., Journal o...  e p
# ...                                                 ...  ...
# 6652                                            [Nomos]  e p
# 6653  [Year book - American Philosophical Society, P...  e p
# 6654  [The Americas - Academy of American Franciscan...  e p
# 6655  [International journal of adhesion and adhesives]  e p
# 6656                                 [Oriental insects]  e p
#
# [6657 rows x 6 columns]

# %%
find_only_p_or_e['pore'].value_counts()
# Out:
# e p    6657
# Name: pore, dtype: int64

# %%
only_p = find_only_p_or_e[find_only_p_or_e['pore'] == 'p']
only_p
# Out:
# Empty DataFrame
# Columns: [matches_group_id, record_index, p_or_e, MMS_ID, Title_bib, pore]
# Index: []

# %%
only_p_groups = list(only_p['matches_group_id'])
print(len(only_p_groups))
only_p_groups
# Out:
# 0
# []

# %%
p_only_data = df_epcad[df_epcad['matches_group_id'].isin(only_p_groups)]
p_only_data
# Out:
# Empty DataFrame
# Columns: [record_index, MMS_ID, Title_bib, OCN, ISSN_bib, Related_OCNs, Related_ISSNs, Vol_nos, Gov_doc_nos, OCN_cluster, ISSN_cluster, p_or_e, ISSN_group_id, OCN_group_id, both_groups, matches_group_id, ISSN_to_match, MMS ID, E Coll ID, Electronic Collection Id, Electronic Collection Public Name, Electronic Collection Public Name (override), MMS Id, Title_portfolio, Begin Publication Date, End Publication Date, ISSN_portfolio, Coverage Information Combined, Coverage Statement, Portfolio Id, Lifecycle, Embargo Operator, Embargo Months, Embargo Years, Status (Active), Collection Public Name, PCAD?, Vendor_key]
# Index: []
#
# [0 rows x 38 columns]

# %%
#if p_only_data is not empty
p_only_data.to_pickle('p_e_no_pcad.pkl')

# %%
only_e = find_only_p_or_e[find_only_p_or_e['pore'] == 'e']
only_e
# Out:
# Empty DataFrame
# Columns: [matches_group_id, record_index, p_or_e, MMS_ID, Title_bib, pore]
# Index: []

# %%
only_e_groups = list(only_e['matches_group_id'])
only_e_groups
# Out:
# []

# %%
e_only_data = df_epcad[df_epcad['matches_group_id'].isin(only_e_groups)]
e_only_data
# Out:
# Empty DataFrame
# Columns: [record_index, MMS_ID, Title_bib, OCN, ISSN_bib, Related_OCNs, Related_ISSNs, Vol_nos, Gov_doc_nos, OCN_cluster, ISSN_cluster, p_or_e, ISSN_group_id, OCN_group_id, both_groups, matches_group_id, ISSN_to_match, MMS ID, E Coll ID, Electronic Collection Id, Electronic Collection Public Name, Electronic Collection Public Name (override), MMS Id, Title_portfolio, Begin Publication Date, End Publication Date, ISSN_portfolio, Coverage Information Combined, Coverage Statement, Portfolio Id, Lifecycle, Embargo Operator, Embargo Months, Embargo Years, Status (Active), Collection Public Name, PCAD?, Vendor_key]
# Index: []
#
# [0 rows x 38 columns]

# %%
#if e_only_data is not empty
e_only_data.to_pickle('pe_e_no_pcad.pkl')

# %%
p_and_e = find_only_p_or_e[find_only_p_or_e['pore'] == 'e p']
p_and_e
# Out:
#       matches_group_id                                       record_index  \
# 0                    2                                    [113344, 69875]
# 1                    5                                    [57684, 128733]
# 2                    7                            [112352, 78492, 107439]
# 3                   12                                    [88618, 111951]
# 4                   20                                    [122066, 89596]
# ...                ...                                                ...
# 6652            101504                                     [113874, 3295]
# 6653            101522  [41280, 26122, 118219, 61904, 18706, 123828, 8...
# 6654            101581                            [17960, 124654, 117510]
# 6655            101582                                    [125537, 31683]
# 6656            101697                                    [14688, 114862]
#
#       p_or_e                                             MMS_ID  \
# 0     [e, p]               [9939153590001701, 9968879310001701]
# 1     [e, p]               [9963550760001701, 9968441380001701]
# 2     [e, p]  [9967759560001701, 9933370000001701, 996714552...
# 3     [e, p]               [9939481760001701, 9968429800001701]
# 4     [e, p]               [9963135560001701, 9975966292301701]
# ...      ...                                                ...
# 6652  [e, p]               [9974799725001701, 9953296770001701]
# 6653  [e, p]  [9959156260001701, 9967988520001701, 991429894...
# 6654  [e, p]  [9924328340001701, 9946768760001701, 996798786...
# 6655  [e, p]               [9957960200001701, 9968947900001701]
# 6656  [e, p]               [9977101571201701, 9933514930001701]
#
#                                               Title_bib pore
# 0     [The Wilson journal of ornithology, The Wilson...  e p
# 1        [IEEE transactions on ultrasonics engineering]  e p
# 2     [Journal of the University Film Association, J...  e p
# 3               [Journal of the Institute of Actuaries]  e p
# 4     [Journal of tissue culture methods., Journal o...  e p
# ...                                                 ...  ...
# 6652                                            [Nomos]  e p
# 6653  [Year book - American Philosophical Society, P...  e p
# 6654  [The Americas - Academy of American Franciscan...  e p
# 6655  [International journal of adhesion and adhesives]  e p
# 6656                                 [Oriental insects]  e p
#
# [6657 rows x 6 columns]

# %%
pe_groups = list(p_and_e['matches_group_id'])
print(len(pe_groups))
pe_groups
# Out:
# 6657
# [2,
#  5,
#  7,
#  12,
#  20,
#  77,
#  83,
#  92,
#  202,
#  213,
#  252,
#  254,
#  259,
#  267,
#  273,
#  277,
#  284,
#  292,
#  315,
#  340,
#  477,
#  496,
#  511,
#  513,
#  537,
#  660,
#  686,
#  707,
#  739,
#  744,
#  747,
#  764,
#  803,
#  819,
#  877,
#  895,
#  914,
#  1001,
#  1005,
#  1038,
#  1066,
#  1086,
#  1087,
#  1204,
#  1208,
#  1245,
#  1345,
#  1475,
#  1526,
#  1527,
#  1534,
#  1547,
#  1606,
#  1725,
#  1745,
#  1772,
#  1809,
#  1812,
#  1846,
#  1857,
#  1869,
#  1920,
#  1960,
#  2059,
#  2065,
#  2067,
#  2078,
#  2308,
#  2337,
#  2356,
#  2364,
#  2365,
#  2394,
#  2435,
#  2471,
#  2492,
#  2505,
#  2529,
#  2537,
#  2557,
#  2561,
#  2571,
#  2592,
#  2603,
#  2604,
#  2619,
#  2701,
#  2725,
#  2734,
#  2775,
#  2808,
#  2908,
#  2951,
#  2961,
#  2990,
#  2993,
#  3023,
#  3095,
#  3156,
#  3399,
#  3401,
#  3434,
#  3443,
#  3447,
#  3448,
#  3475,
#  3478,
#  3483,
#  3489,
#  3513,
#  3518,
#  3544,
#  3561,
#  3563,
#  3564,
#  3571,
#  3573,
#  3592,
#  3674,
#  3682,
#  3686,
#  3698,
#  3702,
#  3716,
#  3724,
#  3740,
#  3794,
#  3806,
#  3818,
#  3828,
#  3840,
#  3861,
#  3875,
#  3896,
#  3899,
#  3919,
#  3928,
#  3960,
#  4013,
#  4029,
#  4035,
#  4058,
#  4105,
#  4117,
#  4136,
#  4188,
#  4201,
#  4219,
#  4237,
#  4258,
#  4265,
#  4273,
#  4300,
#  4319,
#  4321,
#  4322,
#  4325,
#  4337,
#  4338,
#  4344,
#  4361,
#  4368,
#  4376,
#  4380,
#  4381,
#  4393,
#  4401,
#  4420,
#  4422,
#  4431,
#  4468,
#  4494,
#  4495,
#  4508,
#  4511,
#  4513,
#  4542,
#  4588,
#  4618,
#  4626,
#  4675,
#  4690,
#  4707,
#  4714,
#  4789,
#  4851,
#  4904,
#  4907,
#  4909,
#  4920,
#  4938,
#  4954,
#  4961,
#  5013,
#  5052,
#  5053,
#  5057,
#  5058,
#  5087,
#  5088,
#  5093,
#  5098,
#  5110,
#  5136,
#  5145,
#  5186,
#  5225,
#  5367,
#  5371,
#  5387,
#  5413,
#  5420,
#  5433,
#  5472,
#  5600,
#  5620,
#  5660,
#  5665,
#  5695,
#  5699,
#  5700,
#  5704,
#  5712,
#  5714,
#  5757,
#  5795,
#  5857,
#  5912,
#  5913,
#  5989,
#  5997,
#  6012,
#  6017,
#  6022,
#  6100,
#  6126,
#  6141,
#  6181,
#  6195,
#  6213,
#  6228,
#  6240,
#  6252,
#  6294,
#  6298,
#  6311,
#  6326,
#  6333,
#  6346,
#  6352,
#  6367,
#  6371,
#  6419,
#  6421,
#  6426,
#  6428,
#  6429,
#  6433,
#  6434,
#  6468,
#  6475,
#  6476,
#  6531,
#  6543,
#  6550,
#  6596,
#  6619,
#  6627,
#  6637,
#  6687,
#  6728,
#  6783,
#  6797,
#  6825,
#  6826,
#  6841,
#  6851,
#  6857,
#  6894,
#  6921,
#  6928,
#  6935,
#  6937,
#  6959,
#  7000,
#  7012,
#  7020,
#  7060,
#  7120,
#  7129,
#  7141,
#  7148,
#  7152,
#  7199,
#  7220,
#  7242,
#  7254,
#  7257,
#  7268,
#  7339,
#  7340,
#  7341,
#  7352,
#  7356,
#  7399,
#  7440,
#  7505,
#  7515,
#  7520,
#  7600,
#  7618,
#  7636,
#  7669,
#  7687,
#  7692,
#  7701,
#  7721,
#  7762,
#  7768,
#  7786,
#  7808,
#  7809,
#  7869,
#  7899,
#  7906,
#  7907,
#  7930,
#  7962,
#  8061,
#  8085,
#  8088,
#  8090,
#  8109,
#  8110,
#  8166,
#  8213,
#  8249,
#  8255,
#  8263,
#  8284,
#  8323,
#  8329,
#  8343,
#  8361,
#  8371,
#  8404,
#  8409,
#  8412,
#  8438,
#  8439,
#  8442,
#  8445,
#  8446,
#  8492,
#  8551,
#  8574,
#  8577,
#  8600,
#  8614,
#  8616,
#  8620,
#  8677,
#  8693,
#  8712,
#  8719,
#  8773,
#  8786,
#  8797,
#  8800,
#  8805,
#  8812,
#  8874,
#  9041,
#  9048,
#  9074,
#  9075,
#  9093,
#  9106,
#  9117,
#  9167,
#  9171,
#  9175,
#  9189,
#  9192,
#  9193,
#  9194,
#  9207,
#  9211,
#  9223,
#  9237,
#  9255,
#  9259,
#  9291,
#  9310,
#  9314,
#  9317,
#  9331,
#  9333,
#  9338,
#  9393,
#  9402,
#  9405,
#  9411,
#  9420,
#  9423,
#  9445,
#  9446,
#  9447,
#  9488,
#  9562,
#  9581,
#  9603,
#  9614,
#  9623,
#  9642,
#  9651,
#  9656,
#  9682,
#  9698,
#  9726,
#  9782,
#  9804,
#  9806,
#  9818,
#  9839,
#  9887,
#  9903,
#  9910,
#  9921,
#  9930,
#  9933,
#  9947,
#  9956,
#  9964,
#  9992,
#  10098,
#  10106,
#  10108,
#  10124,
#  10155,
#  10160,
#  10167,
#  10174,
#  10185,
#  10201,
#  10202,
#  10203,
#  10204,
#  10207,
#  10208,
#  10214,
#  10263,
#  10266,
#  10272,
#  10274,
#  10277,
#  10281,
#  10302,
#  10305,
#  10313,
#  10328,
#  10347,
#  10353,
#  10378,
#  10384,
#  10400,
#  10423,
#  10431,
#  10445,
#  10449,
#  10456,
#  10461,
#  10479,
#  10488,
#  10491,
#  10495,
#  10518,
#  10523,
#  10539,
#  10553,
#  10573,
#  10588,
#  10589,
#  10590,
#  10591,
#  10595,
#  10596,
#  10602,
#  10610,
#  10624,
#  10630,
#  10638,
#  10654,
#  10658,
#  10662,
#  10667,
#  10681,
#  10687,
#  10690,
#  10693,
#  10694,
#  10712,
#  10721,
#  10725,
#  10726,
#  10727,
#  10729,
#  10730,
#  10731,
#  10751,
#  10857,
#  10875,
#  10879,
#  10880,
#  10889,
#  10892,
#  10906,
#  10910,
#  10929,
#  10931,
#  10966,
#  10981,
#  10988,
#  11002,
#  11055,
#  11093,
#  11102,
#  11109,
#  11113,
#  11125,
#  11144,
#  11163,
#  11164,
#  11179,
#  11181,
#  11185,
#  11201,
#  11222,
#  11225,
#  11234,
#  11252,
#  11261,
#  11263,
#  11264,
#  11267,
#  11270,
#  11280,
#  11282,
#  11287,
#  11289,
#  11305,
#  11347,
#  11362,
#  11367,
#  11369,
#  11371,
#  11373,
#  11376,
#  11384,
#  11394,
#  11395,
#  11420,
#  11421,
#  11426,
#  11429,
#  11454,
#  11468,
#  11472,
#  11475,
#  11480,
#  11497,
#  11501,
#  11510,
#  11550,
#  11559,
#  11562,
#  11566,
#  11570,
#  11575,
#  11592,
#  11593,
#  11600,
#  11601,
#  11612,
#  11639,
#  11643,
#  11653,
#  11655,
#  11680,
#  11689,
#  11719,
#  11731,
#  11753,
#  11778,
#  11817,
#  11827,
#  11861,
#  11872,
#  11971,
#  11978,
#  11990,
#  12007,
#  12024,
#  12029,
#  12030,
#  12044,
#  12084,
#  12086,
#  12091,
#  12098,
#  12114,
#  12123,
#  12126,
#  12129,
#  12138,
#  12151,
#  12158,
#  12190,
#  12196,
#  12206,
#  12227,
#  12238,
#  12244,
#  12256,
#  12258,
#  12279,
#  12285,
#  12319,
#  12340,
#  12362,
#  12375,
#  12390,
#  12450,
#  12484,
#  12512,
#  12513,
#  12524,
#  12578,
#  12593,
#  12646,
#  12673,
#  12747,
#  12759,
#  12781,
#  12789,
#  12793,
#  12797,
#  12804,
#  12808,
#  12822,
#  12828,
#  12832,
#  12836,
#  12841,
#  12847,
#  12860,
#  12866,
#  12871,
#  12878,
#  12909,
#  12923,
#  12925,
#  12930,
#  12935,
#  12951,
#  12953,
#  12970,
#  12972,
#  12979,
#  13001,
#  13010,
#  13035,
#  13074,
#  13075,
#  13078,
#  13083,
#  13104,
#  13119,
#  13121,
#  13138,
#  13151,
#  13177,
#  13204,
#  13211,
#  13221,
#  13229,
#  13243,
#  13249,
#  13253,
#  13256,
#  13277,
#  13327,
#  13353,
#  13358,
#  13382,
#  13384,
#  13424,
#  13425,
#  13439,
#  13468,
#  13470,
#  13482,
#  13490,
#  13502,
#  13555,
#  13570,
#  13595,
#  13596,
#  13612,
#  13633,
#  13641,
#  13643,
#  13648,
#  13654,
#  13659,
#  13677,
#  13718,
#  13737,
#  13744,
#  13746,
#  13751,
#  13775,
#  13795,
#  13803,
#  13812,
#  13817,
#  13819,
#  13864,
#  13878,
#  13881,
#  13885,
#  13892,
#  13919,
#  13920,
#  13929,
#  13935,
#  13939,
#  14009,
#  14016,
#  14023,
#  14028,
#  14035,
#  14036,
#  14042,
#  14047,
#  14053,
#  14055,
#  14060,
#  14079,
#  14085,
#  14086,
#  14097,
#  14106,
#  14109,
#  14113,
#  14126,
#  14166,
#  14174,
#  14175,
#  14200,
#  14269,
#  14287,
#  14297,
#  14316,
#  14317,
#  14337,
#  14374,
#  14378,
#  14403,
#  14433,
#  14434,
#  14436,
#  14437,
#  14441,
#  14442,
#  14457,
#  14471,
#  14475,
#  14483,
#  14485,
#  14503,
#  14513,
#  14531,
#  14537,
#  14538,
#  14540,
#  14541,
#  14545,
#  14551,
#  14556,
#  14558,
#  14566,
#  14569,
#  14575,
#  14578,
#  14580,
#  14581,
#  14583,
#  14598,
#  14602,
#  14620,
#  14629,
#  14631,
#  14632,
#  14636,
#  14637,
#  14649,
#  14660,
#  14662,
#  14666,
#  14703,
#  14713,
#  14756,
#  14781,
#  14796,
#  14797,
#  14800,
#  14801,
#  14803,
#  14815,
#  14829,
#  14851,
#  14858,
#  14871,
#  14901,
#  14902,
#  14903,
#  14908,
#  14916,
#  14929,
#  14954,
#  14955,
#  14966,
#  15004,
#  15022,
#  15039,
#  15041,
#  15042,
#  15084,
#  15145,
#  15244,
#  15246,
#  15248,
#  15252,
#  15283,
#  15303,
#  15306,
#  15314,
#  15335,
#  15342,
#  15376,
#  15395,
#  15411,
#  15413,
#  15419,
#  15466,
#  15479,
#  15520,
#  15531,
#  15543,
#  15554,
#  15575,
#  15591,
#  15596,
#  15601,
#  15636,
#  15641,
#  15642,
#  15643,
#  15646,
#  15659,
#  15665,
#  15678,
#  15714,
#  15726,
#  15739,
#  15787,
#  15790,
#  15795,
#  15805,
#  15817,
#  15820,
#  15821,
#  15822,
#  15848,
#  15867,
#  15882,
#  15910,
#  15912,
#  15921,
#  15922,
#  15934,
#  15945,
#  15957,
#  15966,
#  15986,
#  16032,
#  16061,
#  16064,
#  16071,
#  16081,
#  16100,
#  16123,
#  16152,
#  16165,
#  16171,
#  16186,
#  16350,
#  16352,
#  16360,
#  16393,
#  16397,
#  16425,
#  16426,
#  16431,
#  16501,
#  16515,
#  16540,
#  16560,
#  16622,
#  16656,
#  16681,
#  16682,
#  16685,
#  16718,
#  16742,
#  16751,
#  16786,
#  16801,
#  16838,
#  16912,
#  16915,
#  16927,
#  16929,
#  16938,
#  16947,
#  16948,
#  16958,
#  16962,
#  16969,
#  16972,
#  16975,
#  16978,
#  16987,
#  17002,
#  17003,
#  17019,
#  17022,
#  17033,
#  17036,
#  17037,
#  17043,
#  17053,
#  17072,
#  17083,
#  17085,
#  17088,
#  17090,
#  17096,
#  17103,
#  17120,
#  17126,
#  17140,
#  17169,
#  17170,
#  17178,
#  17183,
#  17185,
#  17188,
#  17210,
#  17212,
#  17213,
#  17224,
#  17229,
#  17232,
#  17234,
#  17237,
#  17250,
#  17269,
#  17275,
#  17300,
#  17304,
#  17305,
#  17309,
#  17375,
#  17376,
#  17377,
#  17384,
#  17395,
#  17407,
#  17424,
#  17425,
#  17433,
#  17438,
#  17445,
#  17455,
#  17498,
#  17503,
#  17522,
#  17547,
#  ...]

# %%
p_and_e_data = df_epcad[df_epcad['matches_group_id'].isin(pe_groups)]
p_and_e_data
# Out:
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 16            113344  9968879310001701
# 17            113344  9968879310001701
# 18            113344  9968879310001701
# ...              ...               ...
# 102118        125537  9968947900001701
# 102119        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib          OCN  \
# 14                   The Wilson journal of ornithology.   [62791211]
# 15                    The Wilson journal of ornithology   [66901429]
# 16                    The Wilson journal of ornithology   [66901429]
# 17                    The Wilson journal of ornithology   [66901429]
# 18                    The Wilson journal of ornithology   [66901429]
# ...                                                 ...          ...
# 102118  International journal of adhesion and adhesives   [38995556]
# 102119  International journal of adhesion and adhesives   [38995556]
# 102156                                 Oriental insects  [668436876]
# 102157                                 Oriental insects  [668436876]
# 102158                                 Oriental insects    [1761507]
#
#            ISSN_bib Related_OCNs Related_ISSNs Vol_nos Gov_doc_nos  \
# 14      [1559-4491]           []            []      []          []
# 15      [1938-5447]           []   [1559-4491]      []          []
# 16      [1938-5447]           []   [1559-4491]      []          []
# 17      [1938-5447]           []   [1559-4491]      []          []
# 18      [1938-5447]           []   [1559-4491]      []          []
# ...             ...          ...           ...     ...         ...
# 102118  [1879-0127]           []   [0143-7496]      []          []
# 102119  [1879-0127]           []   [0143-7496]      []          []
# 102156  [2157-8745]           []   [0030-5316]      []          []
# 102157  [2157-8745]           []   [0030-5316]      []          []
# 102158  [0030-5316]           []            []      []          []
#
#         OCN_cluster  ... Coverage Statement       Portfolio Id      Lifecycle  \
# 14       [62791211]  ...                NaN                NaN            NaN
# 15       [66901429]  ...                NaN                NaN            NaN
# 16       [66901429]  ...                NaN                NaN            NaN
# 17       [66901429]  ...                NaN                NaN            NaN
# 18       [66901429]  ...                NaN                NaN            NaN
# ...             ...  ...                ...                ...            ...
# 102118   [38995556]  ...                NaN                NaN            NaN
# 102119   [38995556]  ...                NaN                NaN            NaN
# 102156  [668436876]  ...        Only global  53815435190001701  In Repository
# 102157  [668436876]  ...         Only local  53815442430001701  In Repository
# 102158    [1761507]  ...                NaN                NaN            NaN
#
#        Embargo Operator Embargo Months  Embargo Years Status (Active)  \
# 14                  NaN            NaN            NaN             NaN
# 15                  NaN            NaN            NaN             NaN
# 16                  NaN            NaN            NaN             NaN
# 17                  NaN            NaN            NaN             NaN
# 18                  NaN            NaN            NaN             NaN
# ...                 ...            ...            ...             ...
# 102118              NaN            NaN            NaN             NaN
# 102119              NaN            NaN            NaN             NaN
# 102156              NaN            NaN            NaN            None
# 102157              NaN            NaN            NaN            None
# 102158              NaN            NaN            NaN             NaN
#
#                                    Collection Public Name PCAD?  \
# 14                                                    NaN   NaN
# 15                                                    NaN   NaN
# 16                                                    NaN   NaN
# 17                                                    NaN   NaN
# 18                                                    NaN   NaN
# ...                                                   ...   ...
# 102118                                                NaN   NaN
# 102119                                                NaN   NaN
# 102156  Taylor & Francis Biological, Earth & Environme...   Yes
# 102157  Taylor & Francis Biological, Earth, Environmen...   Yes
# 102158                                                NaN   NaN
#
#               Vendor_key
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# ...                  ...
# 102118               NaN
# 102119               NaN
# 102156  Taylor & Francis
# 102157  Taylor & Francis
# 102158               NaN
#
# [52265 rows x 38 columns]

# %%
p_and_e_data.to_pickle(f'p_and_e_pcad_{today}.pkl')

# %%
p_and_e_data['PCAD?'].value_counts()
# Out:
# Yes    13339
# Name: PCAD?, dtype: int64

# %%
p = p_and_e_data[p_and_e_data['p_or_e']=='e']
p['PCAD?'].value_counts()
# Out:
# Yes    13339
# Name: PCAD?, dtype: int64

# %%
df = p_and_e_data
df.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'OCN', 'ISSN_bib',
#        'Related_OCNs', 'Related_ISSNs', 'Vol_nos', 'Gov_doc_nos',
#        'OCN_cluster', 'ISSN_cluster', 'p_or_e', 'ISSN_group_id',
#        'OCN_group_id', 'both_groups', 'matches_group_id', 'ISSN_to_match',
#        'MMS ID', 'E Coll ID', 'Electronic Collection Id',
#        'Electronic Collection Public Name',
#        'Electronic Collection Public Name (override)', 'MMS Id',
#        'Title_portfolio', 'Begin Publication Date', 'End Publication Date',
#        'ISSN_portfolio', 'Coverage Information Combined', 'Coverage Statement',
#        'Portfolio Id', 'Lifecycle', 'Embargo Operator', 'Embargo Months',
#        'Embargo Years', 'Status (Active)', 'Collection Public Name', 'PCAD?',
#        'Vendor_key'],
#       dtype='object')

# %%
df = df[['record_index', 'MMS_ID', 'Title_bib', 'p_or_e', 'ISSN_bib','ISSN_cluster',
         'matches_group_id', 'Electronic Collection Id', 'Electronic Collection Public Name',
         'Electronic Collection Public Name (override)', 'Title_portfolio', 
         'ISSN_portfolio', 'Coverage Information Combined', 'Coverage Statement',
         'Portfolio Id', 'Collection Public Name', 'PCAD?','Vendor_key']]
df
# Out:
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 16            113344  9968879310001701
# 17            113344  9968879310001701
# 18            113344  9968879310001701
# ...              ...               ...
# 102118        125537  9968947900001701
# 102119        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib p_or_e     ISSN_bib  \
# 14                   The Wilson journal of ornithology.      p  [1559-4491]
# 15                    The Wilson journal of ornithology      e  [1938-5447]
# 16                    The Wilson journal of ornithology      e  [1938-5447]
# 17                    The Wilson journal of ornithology      e  [1938-5447]
# 18                    The Wilson journal of ornithology      e  [1938-5447]
# ...                                                 ...    ...          ...
# 102118  International journal of adhesion and adhesives      e  [1879-0127]
# 102119  International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                 Oriental insects      e  [2157-8745]
# 102157                                 Oriental insects      e  [2157-8745]
# 102158                                 Oriental insects      p  [0030-5316]
#
#                   ISSN_cluster  matches_group_id Electronic Collection Id  \
# 14                 [1559-4491]                 2                      NaN
# 15      [1559-4491, 1938-5447]                 2                      NaN
# 16      [1559-4491, 1938-5447]                 2                      NaN
# 17      [1559-4491, 1938-5447]                 2                      NaN
# 18      [1559-4491, 1938-5447]                 2                      NaN
# ...                        ...               ...                      ...
# 102118  [0143-7496, 1879-0127]            101582                      NaN
# 102119  [0143-7496, 1879-0127]            101582                      NaN
# 102156  [0030-5316, 2157-8745]            101697        61808527020001701
# 102157  [0030-5316, 2157-8745]            101697        61808506700001701
# 102158             [0030-5316]            101697                      NaN
#
#                         Electronic Collection Public Name  \
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# ...                                                   ...
# 102118                                                NaN
# 102119                                                NaN
# 102156  Taylor & Francis Biological, Earth & Environme...
# 102157  Taylor & Francis Biological, Earth, Environmen...
# 102158                                                NaN
#
#              Electronic Collection Public Name (override)   Title_portfolio  \
# 14                                                    NaN               NaN
# 15                                                    NaN               NaN
# 16                                                    NaN               NaN
# 17                                                    NaN               NaN
# 18                                                    NaN               NaN
# ...                                                   ...               ...
# 102118                                                NaN               NaN
# 102119                                                NaN               NaN
# 102156  Taylor & Francis Biological, Earth, Environmen...  Oriental insects
# 102157  Taylor & Francis Biological, Earth, Environmen...  Oriental insects
# 102158                                                NaN               NaN
#
#               ISSN_portfolio  \
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# ...                      ...
# 102118                   NaN
# 102119                   NaN
# 102156  2157-8745; 0030-5316
# 102157  2157-8745; 0030-5316
# 102158                   NaN
#
#                             Coverage Information Combined Coverage Statement  \
# 14                                                    NaN                NaN
# 15                                                    NaN                NaN
# 16                                                    NaN                NaN
# 17                                                    NaN                NaN
# 18                                                    NaN                NaN
# ...                                                   ...                ...
# 102118                                                NaN                NaN
# 102119                                                NaN                NaN
# 102156   Available from 1967 volume: 1 until 1996 volu...        Only global
# 102157   Available from 1997 volume: 31 issue: 1 until...         Only local
# 102158                                                NaN                NaN
#
#              Portfolio Id                             Collection Public Name  \
# 14                    NaN                                                NaN
# 15                    NaN                                                NaN
# 16                    NaN                                                NaN
# 17                    NaN                                                NaN
# 18                    NaN                                                NaN
# ...                   ...                                                ...
# 102118                NaN                                                NaN
# 102119                NaN                                                NaN
# 102156  53815435190001701  Taylor & Francis Biological, Earth & Environme...
# 102157  53815442430001701  Taylor & Francis Biological, Earth, Environmen...
# 102158                NaN                                                NaN
#
#        PCAD?        Vendor_key
# 14       NaN               NaN
# 15       NaN               NaN
# 16       NaN               NaN
# 17       NaN               NaN
# 18       NaN               NaN
# ...      ...               ...
# 102118   NaN               NaN
# 102119   NaN               NaN
# 102156   Yes  Taylor & Francis
# 102157   Yes  Taylor & Francis
# 102158   NaN               NaN
#
# [52265 rows x 18 columns]

# %%
df_e_trunc = df[df['PCAD?'].notnull()]
df_e_trunc
# Out:
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib p_or_e     ISSN_bib  \
# 24                      The Wilson journal of ornithology      e  [1938-5447]
# 27           IEEE transactions on ultrasonics engineering      e  [2162-1373]
# 34             Journal of the University Film Association      e  [2328-1944]
# 37      Journal of the University Film and Video Assoc...      e  [2328-1936]
# 51                  Journal of the Institute of Actuaries      e  [2058-1009]
# ...                                                   ...    ...          ...
# 102066  Proceedings and addresses of the American Phil...      e  [2325-9248]
# 102111  The Americas - Academy of American Franciscan ...      e  [1533-6247]
# 102114    International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                   Oriental insects      e  [2157-8745]
# 102157                                   Oriental insects      e  [2157-8745]
#
#                   ISSN_cluster  matches_group_id Electronic Collection Id  \
# 24      [1559-4491, 1938-5447]                 2        61588428410001701
# 27      [0893-6706, 2162-1373]                 5        61619505660001701
# 34      [0041-9311, 2328-1944]                 7        61535210810001701
# 37      [2328-1936, 0734-919X]                 7        61535210810001701
# 51      [0020-2681, 2058-1009]                12        61746266290001701
# ...                        ...               ...                      ...
# 102066  [2325-9248, 0065-972X]            101522        61535211010001701
# 102111  [1533-6247, 0003-1615]            101581        61535211010001701
# 102114  [0143-7496, 1879-0127]            101582        61624504590001701
# 102156  [0030-5316, 2157-8745]            101697        61808527020001701
# 102157  [0030-5316, 2157-8745]            101697        61808506700001701
#
#                         Electronic Collection Public Name  \
# 24                         JSTOR Life Sciences Collection
# 27             IEEE/IET Electronic Library (IEL) Journals
# 34                              JSTOR Arts and Sciences V
# 37                              JSTOR Arts and Sciences V
# 51                              JSTOR Arts and Sciences X
# ...                                                   ...
# 102066                        JSTOR Arts and Sciences VII
# 102111                        JSTOR Arts and Sciences VII
# 102114           Elsevier ScienceDirect Journals Complete
# 102156  Taylor & Francis Biological, Earth & Environme...
# 102157  Taylor & Francis Biological, Earth, Environmen...
#
#              Electronic Collection Public Name (override)  \
# 24                                                    NaN
# 27                         IEEE Journal Archive 1884-1999
# 34                                                    NaN
# 37                                                    NaN
# 51                                                    NaN
# ...                                                   ...
# 102066                                                NaN
# 102111                                                NaN
# 102114                                                NaN
# 102156  Taylor & Francis Biological, Earth, Environmen...
# 102157  Taylor & Francis Biological, Earth, Environmen...
#
#                                           Title_portfolio  \
# 24                     The Wilson journal of ornithology.
# 27          IEEE transactions on ultrasonics engineering.
# 34            Journal of the University Film Association.
# 37      Journal of the University Film and Video Assoc...
# 51                 Journal of the Institute of Actuaries.
# ...                                                   ...
# 102066  Proceedings and addresses of the American Phil...
# 102111                                      The Americas.
# 102114      International journal of adhesion & adhesives
# 102156                                   Oriental insects
# 102157                                   Oriental insects
#
#               ISSN_portfolio  \
# 24      1938-5447; 1559-4491
# 27      2162-1373; 0893-6706
# 34      2328-1944; 0041-9311
# 37      2328-1936; 0734-919X
# 51      2058-1009; 0020-2681
# ...                      ...
# 102066  2325-9248; 0065-972X
# 102111  1533-6247; 0003-1615
# 102114  1879-0127; 0143-7496
# 102156  2157-8745; 0030-5316
# 102157  2157-8745; 0030-5316
#
#                             Coverage Information Combined Coverage Statement  \
# 24              Available from 2006 volume: 118 issue: 1;        Only global
# 27       Available from 1963 volume: 10 issue: 1 until...        Only global
# 34       Available from 1968 volume: 20 issue: 1 until...        Only global
# 37       Available from 1982 volume: 34 issue: 1 until...        Only global
# 51       Available from 1886 volume: 25 issue: 5 until...        Only global
# ...                                                   ...                ...
# 102066                     Available from 1927 volume: 1;        Only global
# 102111            Available from 1944 volume: 1 issue: 1;        Only global
# 102114        Available from 1980-07- volume: 1 issue: 1;         Only local
# 102156   Available from 1967 volume: 1 until 1996 volu...        Only global
# 102157   Available from 1997 volume: 31 issue: 1 until...         Only local
#
#              Portfolio Id                             Collection Public Name  \
# 24      53588425000001701                     JSTOR Life Sciences Collection
# 27      53620359120001701         IEEE/IET Electronic Library (IEL) Journals
# 34      53538633520001701                          JSTOR Arts and Sciences V
# 37      53537295580001701                          JSTOR Arts and Sciences V
# 51      53747073660001701                          JSTOR Arts and Sciences X
# ...                   ...                                                ...
# 102066  53540700110001701                        JSTOR Arts and Sciences VII
# 102111  53539160390001701                        JSTOR Arts and Sciences VII
# 102114  53624617390001701           Elsevier ScienceDirect Journals Complete
# 102156  53815435190001701  Taylor & Francis Biological, Earth & Environme...
# 102157  53815442430001701  Taylor & Francis Biological, Earth, Environmen...
#
#        PCAD?        Vendor_key
# 24       Yes             JSTOR
# 27       Yes             other
# 34       Yes             JSTOR
# 37       Yes             JSTOR
# 51       Yes             JSTOR
# ...      ...               ...
# 102066   Yes             JSTOR
# 102111   Yes             JSTOR
# 102114   Yes          Elsevier
# 102156   Yes  Taylor & Francis
# 102157   Yes  Taylor & Francis
#
# [13339 rows x 18 columns]

# %%
df_e_trunc['Electronic Collection Id'].fillna('',inplace=True)
df_e_trunc['Electronic Collection Public Name (override)'].fillna('',inplace=True)
df_e_trunc
# Out:
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib p_or_e     ISSN_bib  \
# 24                      The Wilson journal of ornithology      e  [1938-5447]
# 27           IEEE transactions on ultrasonics engineering      e  [2162-1373]
# 34             Journal of the University Film Association      e  [2328-1944]
# 37      Journal of the University Film and Video Assoc...      e  [2328-1936]
# 51                  Journal of the Institute of Actuaries      e  [2058-1009]
# ...                                                   ...    ...          ...
# 102066  Proceedings and addresses of the American Phil...      e  [2325-9248]
# 102111  The Americas - Academy of American Franciscan ...      e  [1533-6247]
# 102114    International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                   Oriental insects      e  [2157-8745]
# 102157                                   Oriental insects      e  [2157-8745]
#
#                   ISSN_cluster  matches_group_id Electronic Collection Id  \
# 24      [1559-4491, 1938-5447]                 2        61588428410001701
# 27      [0893-6706, 2162-1373]                 5        61619505660001701
# 34      [0041-9311, 2328-1944]                 7        61535210810001701
# 37      [2328-1936, 0734-919X]                 7        61535210810001701
# 51      [0020-2681, 2058-1009]                12        61746266290001701
# ...                        ...               ...                      ...
# 102066  [2325-9248, 0065-972X]            101522        61535211010001701
# 102111  [1533-6247, 0003-1615]            101581        61535211010001701
# 102114  [0143-7496, 1879-0127]            101582        61624504590001701
# 102156  [0030-5316, 2157-8745]            101697        61808527020001701
# 102157  [0030-5316, 2157-8745]            101697        61808506700001701
#
#                         Electronic Collection Public Name  \
# 24                         JSTOR Life Sciences Collection
# 27             IEEE/IET Electronic Library (IEL) Journals
# 34                              JSTOR Arts and Sciences V
# 37                              JSTOR Arts and Sciences V
# 51                              JSTOR Arts and Sciences X
# ...                                                   ...
# 102066                        JSTOR Arts and Sciences VII
# 102111                        JSTOR Arts and Sciences VII
# 102114           Elsevier ScienceDirect Journals Complete
# 102156  Taylor & Francis Biological, Earth & Environme...
# 102157  Taylor & Francis Biological, Earth, Environmen...
#
#              Electronic Collection Public Name (override)  \
# 24
# 27                         IEEE Journal Archive 1884-1999
# 34
# 37
# 51
# ...                                                   ...
# 102066
# 102111
# 102114
# 102156  Taylor & Francis Biological, Earth, Environmen...
# 102157  Taylor & Francis Biological, Earth, Environmen...
#
#                                           Title_portfolio  \
# 24                     The Wilson journal of ornithology.
# 27          IEEE transactions on ultrasonics engineering.
# 34            Journal of the University Film Association.
# 37      Journal of the University Film and Video Assoc...
# 51                 Journal of the Institute of Actuaries.
# ...                                                   ...
# 102066  Proceedings and addresses of the American Phil...
# 102111                                      The Americas.
# 102114      International journal of adhesion & adhesives
# 102156                                   Oriental insects
# 102157                                   Oriental insects
#
#               ISSN_portfolio  \
# 24      1938-5447; 1559-4491
# 27      2162-1373; 0893-6706
# 34      2328-1944; 0041-9311
# 37      2328-1936; 0734-919X
# 51      2058-1009; 0020-2681
# ...                      ...
# 102066  2325-9248; 0065-972X
# 102111  1533-6247; 0003-1615
# 102114  1879-0127; 0143-7496
# 102156  2157-8745; 0030-5316
# 102157  2157-8745; 0030-5316
#
#                             Coverage Information Combined Coverage Statement  \
# 24              Available from 2006 volume: 118 issue: 1;        Only global
# 27       Available from 1963 volume: 10 issue: 1 until...        Only global
# 34       Available from 1968 volume: 20 issue: 1 until...        Only global
# 37       Available from 1982 volume: 34 issue: 1 until...        Only global
# 51       Available from 1886 volume: 25 issue: 5 until...        Only global
# ...                                                   ...                ...
# 102066                     Available from 1927 volume: 1;        Only global
# 102111            Available from 1944 volume: 1 issue: 1;        Only global
# 102114        Available from 1980-07- volume: 1 issue: 1;         Only local
# 102156   Available from 1967 volume: 1 until 1996 volu...        Only global
# 102157   Available from 1997 volume: 31 issue: 1 until...         Only local
#
#              Portfolio Id                             Collection Public Name  \
# 24      53588425000001701                     JSTOR Life Sciences Collection
# 27      53620359120001701         IEEE/IET Electronic Library (IEL) Journals
# 34      53538633520001701                          JSTOR Arts and Sciences V
# 37      53537295580001701                          JSTOR Arts and Sciences V
# 51      53747073660001701                          JSTOR Arts and Sciences X
# ...                   ...                                                ...
# 102066  53540700110001701                        JSTOR Arts and Sciences VII
# 102111  53539160390001701                        JSTOR Arts and Sciences VII
# 102114  53624617390001701           Elsevier ScienceDirect Journals Complete
# 102156  53815435190001701  Taylor & Francis Biological, Earth & Environme...
# 102157  53815442430001701  Taylor & Francis Biological, Earth, Environmen...
#
#        PCAD?        Vendor_key
# 24       Yes             JSTOR
# 27       Yes             other
# 34       Yes             JSTOR
# 37       Yes             JSTOR
# 51       Yes             JSTOR
# ...      ...               ...
# 102066   Yes             JSTOR
# 102111   Yes             JSTOR
# 102114   Yes          Elsevier
# 102156   Yes  Taylor & Francis
# 102157   Yes  Taylor & Francis
#
# [13339 rows x 18 columns]

# %%
df_e_trunc['e_coll_info'] = df_e_trunc.apply(lambda x: str([x['Electronic Collection Id'],x['Electronic Collection Public Name'],x['Electronic Collection Public Name (override)'],x['Coverage Information Combined']]), 
                                                   axis = 1)
df_e_trunc
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib p_or_e     ISSN_bib  \
# 24                      The Wilson journal of ornithology      e  [1938-5447]
# 27           IEEE transactions on ultrasonics engineering      e  [2162-1373]
# 34             Journal of the University Film Association      e  [2328-1944]
# 37      Journal of the University Film and Video Assoc...      e  [2328-1936]
# 51                  Journal of the Institute of Actuaries      e  [2058-1009]
# ...                                                   ...    ...          ...
# 102066  Proceedings and addresses of the American Phil...      e  [2325-9248]
# 102111  The Americas - Academy of American Franciscan ...      e  [1533-6247]
# 102114    International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                   Oriental insects      e  [2157-8745]
# 102157                                   Oriental insects      e  [2157-8745]
#
#                   ISSN_cluster  matches_group_id Electronic Collection Id  \
# 24      [1559-4491, 1938-5447]                 2        61588428410001701
# 27      [0893-6706, 2162-1373]                 5        61619505660001701
# 34      [0041-9311, 2328-1944]                 7        61535210810001701
# 37      [2328-1936, 0734-919X]                 7        61535210810001701
# 51      [0020-2681, 2058-1009]                12        61746266290001701
# ...                        ...               ...                      ...
# 102066  [2325-9248, 0065-972X]            101522        61535211010001701
# 102111  [1533-6247, 0003-1615]            101581        61535211010001701
# 102114  [0143-7496, 1879-0127]            101582        61624504590001701
# 102156  [0030-5316, 2157-8745]            101697        61808527020001701
# 102157  [0030-5316, 2157-8745]            101697        61808506700001701
#
#                         Electronic Collection Public Name  \
# 24                         JSTOR Life Sciences Collection
# 27             IEEE/IET Electronic Library (IEL) Journals
# 34                              JSTOR Arts and Sciences V
# 37                              JSTOR Arts and Sciences V
# 51                              JSTOR Arts and Sciences X
# ...                                                   ...
# 102066                        JSTOR Arts and Sciences VII
# 102111                        JSTOR Arts and Sciences VII
# 102114           Elsevier ScienceDirect Journals Complete
# 102156  Taylor & Francis Biological, Earth & Environme...
# 102157  Taylor & Francis Biological, Earth, Environmen...
#
#              Electronic Collection Public Name (override)  \
# 24
# 27                         IEEE Journal Archive 1884-1999
# 34
# 37
# 51
# ...                                                   ...
# 102066
# 102111
# 102114
# 102156  Taylor & Francis Biological, Earth, Environmen...
# 102157  Taylor & Francis Biological, Earth, Environmen...
#
#                                           Title_portfolio  \
# 24                     The Wilson journal of ornithology.
# 27          IEEE transactions on ultrasonics engineering.
# 34            Journal of the University Film Association.
# 37      Journal of the University Film and Video Assoc...
# 51                 Journal of the Institute of Actuaries.
# ...                                                   ...
# 102066  Proceedings and addresses of the American Phil...
# 102111                                      The Americas.
# 102114      International journal of adhesion & adhesives
# 102156                                   Oriental insects
# 102157                                   Oriental insects
#
#               ISSN_portfolio  \
# 24      1938-5447; 1559-4491
# 27      2162-1373; 0893-6706
# 34      2328-1944; 0041-9311
# 37      2328-1936; 0734-919X
# 51      2058-1009; 0020-2681
# ...                      ...
# 102066  2325-9248; 0065-972X
# 102111  1533-6247; 0003-1615
# 102114  1879-0127; 0143-7496
# 102156  2157-8745; 0030-5316
# 102157  2157-8745; 0030-5316
#
#                             Coverage Information Combined Coverage Statement  \
# 24              Available from 2006 volume: 118 issue: 1;        Only global
# 27       Available from 1963 volume: 10 issue: 1 until...        Only global
# 34       Available from 1968 volume: 20 issue: 1 until...        Only global
# 37       Available from 1982 volume: 34 issue: 1 until...        Only global
# 51       Available from 1886 volume: 25 issue: 5 until...        Only global
# ...                                                   ...                ...
# 102066                     Available from 1927 volume: 1;        Only global
# 102111            Available from 1944 volume: 1 issue: 1;        Only global
# 102114        Available from 1980-07- volume: 1 issue: 1;         Only local
# 102156   Available from 1967 volume: 1 until 1996 volu...        Only global
# 102157   Available from 1997 volume: 31 issue: 1 until...         Only local
#
#              Portfolio Id                             Collection Public Name  \
# 24      53588425000001701                     JSTOR Life Sciences Collection
# 27      53620359120001701         IEEE/IET Electronic Library (IEL) Journals
# 34      53538633520001701                          JSTOR Arts and Sciences V
# 37      53537295580001701                          JSTOR Arts and Sciences V
# 51      53747073660001701                          JSTOR Arts and Sciences X
# ...                   ...                                                ...
# 102066  53540700110001701                        JSTOR Arts and Sciences VII
# 102111  53539160390001701                        JSTOR Arts and Sciences VII
# 102114  53624617390001701           Elsevier ScienceDirect Journals Complete
# 102156  53815435190001701  Taylor & Francis Biological, Earth & Environme...
# 102157  53815442430001701  Taylor & Francis Biological, Earth, Environmen...
#
#        PCAD?        Vendor_key  \
# 24       Yes             JSTOR
# 27       Yes             other
# 34       Yes             JSTOR
# 37       Yes             JSTOR
# 51       Yes             JSTOR
# ...      ...               ...
# 102066   Yes             JSTOR
# 102111   Yes             JSTOR
# 102114   Yes          Elsevier
# 102156   Yes  Taylor & Francis
# 102157   Yes  Taylor & Francis
#
#                                               e_coll_info
# 24      ['61588428410001701', 'JSTOR Life Sciences Col...
# 27      ['61619505660001701', 'IEEE/IET Electronic Lib...
# 34      ['61535210810001701', 'JSTOR Arts and Sciences...
# 37      ['61535210810001701', 'JSTOR Arts and Sciences...
# 51      ['61746266290001701', 'JSTOR Arts and Sciences...
# ...                                                   ...
# 102066  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102111  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102114  ['61624504590001701', 'Elsevier ScienceDirect ...
# 102156  ['61808527020001701', 'Taylor & Francis Biolog...
# 102157  ['61808506700001701', 'Taylor & Francis Biolog...
#
# [13339 rows x 19 columns]

# %%
df_e_trunc.drop(['Electronic Collection Id','Electronic Collection Public Name','Electronic Collection Public Name (override)',
                 'Coverage Statement','Collection Public Name'],inplace=True, axis=1)
df_e_trunc
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib p_or_e     ISSN_bib  \
# 24                      The Wilson journal of ornithology      e  [1938-5447]
# 27           IEEE transactions on ultrasonics engineering      e  [2162-1373]
# 34             Journal of the University Film Association      e  [2328-1944]
# 37      Journal of the University Film and Video Assoc...      e  [2328-1936]
# 51                  Journal of the Institute of Actuaries      e  [2058-1009]
# ...                                                   ...    ...          ...
# 102066  Proceedings and addresses of the American Phil...      e  [2325-9248]
# 102111  The Americas - Academy of American Franciscan ...      e  [1533-6247]
# 102114    International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                   Oriental insects      e  [2157-8745]
# 102157                                   Oriental insects      e  [2157-8745]
#
#                   ISSN_cluster  matches_group_id  \
# 24      [1559-4491, 1938-5447]                 2
# 27      [0893-6706, 2162-1373]                 5
# 34      [0041-9311, 2328-1944]                 7
# 37      [2328-1936, 0734-919X]                 7
# 51      [0020-2681, 2058-1009]                12
# ...                        ...               ...
# 102066  [2325-9248, 0065-972X]            101522
# 102111  [1533-6247, 0003-1615]            101581
# 102114  [0143-7496, 1879-0127]            101582
# 102156  [0030-5316, 2157-8745]            101697
# 102157  [0030-5316, 2157-8745]            101697
#
#                                           Title_portfolio  \
# 24                     The Wilson journal of ornithology.
# 27          IEEE transactions on ultrasonics engineering.
# 34            Journal of the University Film Association.
# 37      Journal of the University Film and Video Assoc...
# 51                 Journal of the Institute of Actuaries.
# ...                                                   ...
# 102066  Proceedings and addresses of the American Phil...
# 102111                                      The Americas.
# 102114      International journal of adhesion & adhesives
# 102156                                   Oriental insects
# 102157                                   Oriental insects
#
#               ISSN_portfolio  \
# 24      1938-5447; 1559-4491
# 27      2162-1373; 0893-6706
# 34      2328-1944; 0041-9311
# 37      2328-1936; 0734-919X
# 51      2058-1009; 0020-2681
# ...                      ...
# 102066  2325-9248; 0065-972X
# 102111  1533-6247; 0003-1615
# 102114  1879-0127; 0143-7496
# 102156  2157-8745; 0030-5316
# 102157  2157-8745; 0030-5316
#
#                             Coverage Information Combined       Portfolio Id  \
# 24              Available from 2006 volume: 118 issue: 1;  53588425000001701
# 27       Available from 1963 volume: 10 issue: 1 until...  53620359120001701
# 34       Available from 1968 volume: 20 issue: 1 until...  53538633520001701
# 37       Available from 1982 volume: 34 issue: 1 until...  53537295580001701
# 51       Available from 1886 volume: 25 issue: 5 until...  53747073660001701
# ...                                                   ...                ...
# 102066                     Available from 1927 volume: 1;  53540700110001701
# 102111            Available from 1944 volume: 1 issue: 1;  53539160390001701
# 102114        Available from 1980-07- volume: 1 issue: 1;  53624617390001701
# 102156   Available from 1967 volume: 1 until 1996 volu...  53815435190001701
# 102157   Available from 1997 volume: 31 issue: 1 until...  53815442430001701
#
#        PCAD?        Vendor_key  \
# 24       Yes             JSTOR
# 27       Yes             other
# 34       Yes             JSTOR
# 37       Yes             JSTOR
# 51       Yes             JSTOR
# ...      ...               ...
# 102066   Yes             JSTOR
# 102111   Yes             JSTOR
# 102114   Yes          Elsevier
# 102156   Yes  Taylor & Francis
# 102157   Yes  Taylor & Francis
#
#                                               e_coll_info
# 24      ['61588428410001701', 'JSTOR Life Sciences Col...
# 27      ['61619505660001701', 'IEEE/IET Electronic Lib...
# 34      ['61535210810001701', 'JSTOR Arts and Sciences...
# 37      ['61535210810001701', 'JSTOR Arts and Sciences...
# 51      ['61746266290001701', 'JSTOR Arts and Sciences...
# ...                                                   ...
# 102066  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102111  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102114  ['61624504590001701', 'Elsevier ScienceDirect ...
# 102156  ['61808527020001701', 'Taylor & Francis Biolog...
# 102157  ['61808506700001701', 'Taylor & Francis Biolog...
#
# [13339 rows x 14 columns]

# %%
df_e_trunc['portfolio_info'] = df_e_trunc.apply(lambda x: str([x['Portfolio Id'],x['Title_portfolio']]), 
                                                   axis = 1)
df_e_trunc
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib p_or_e     ISSN_bib  \
# 24                      The Wilson journal of ornithology      e  [1938-5447]
# 27           IEEE transactions on ultrasonics engineering      e  [2162-1373]
# 34             Journal of the University Film Association      e  [2328-1944]
# 37      Journal of the University Film and Video Assoc...      e  [2328-1936]
# 51                  Journal of the Institute of Actuaries      e  [2058-1009]
# ...                                                   ...    ...          ...
# 102066  Proceedings and addresses of the American Phil...      e  [2325-9248]
# 102111  The Americas - Academy of American Franciscan ...      e  [1533-6247]
# 102114    International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                   Oriental insects      e  [2157-8745]
# 102157                                   Oriental insects      e  [2157-8745]
#
#                   ISSN_cluster  matches_group_id  \
# 24      [1559-4491, 1938-5447]                 2
# 27      [0893-6706, 2162-1373]                 5
# 34      [0041-9311, 2328-1944]                 7
# 37      [2328-1936, 0734-919X]                 7
# 51      [0020-2681, 2058-1009]                12
# ...                        ...               ...
# 102066  [2325-9248, 0065-972X]            101522
# 102111  [1533-6247, 0003-1615]            101581
# 102114  [0143-7496, 1879-0127]            101582
# 102156  [0030-5316, 2157-8745]            101697
# 102157  [0030-5316, 2157-8745]            101697
#
#                                           Title_portfolio  \
# 24                     The Wilson journal of ornithology.
# 27          IEEE transactions on ultrasonics engineering.
# 34            Journal of the University Film Association.
# 37      Journal of the University Film and Video Assoc...
# 51                 Journal of the Institute of Actuaries.
# ...                                                   ...
# 102066  Proceedings and addresses of the American Phil...
# 102111                                      The Americas.
# 102114      International journal of adhesion & adhesives
# 102156                                   Oriental insects
# 102157                                   Oriental insects
#
#               ISSN_portfolio  \
# 24      1938-5447; 1559-4491
# 27      2162-1373; 0893-6706
# 34      2328-1944; 0041-9311
# 37      2328-1936; 0734-919X
# 51      2058-1009; 0020-2681
# ...                      ...
# 102066  2325-9248; 0065-972X
# 102111  1533-6247; 0003-1615
# 102114  1879-0127; 0143-7496
# 102156  2157-8745; 0030-5316
# 102157  2157-8745; 0030-5316
#
#                             Coverage Information Combined       Portfolio Id  \
# 24              Available from 2006 volume: 118 issue: 1;  53588425000001701
# 27       Available from 1963 volume: 10 issue: 1 until...  53620359120001701
# 34       Available from 1968 volume: 20 issue: 1 until...  53538633520001701
# 37       Available from 1982 volume: 34 issue: 1 until...  53537295580001701
# 51       Available from 1886 volume: 25 issue: 5 until...  53747073660001701
# ...                                                   ...                ...
# 102066                     Available from 1927 volume: 1;  53540700110001701
# 102111            Available from 1944 volume: 1 issue: 1;  53539160390001701
# 102114        Available from 1980-07- volume: 1 issue: 1;  53624617390001701
# 102156   Available from 1967 volume: 1 until 1996 volu...  53815435190001701
# 102157   Available from 1997 volume: 31 issue: 1 until...  53815442430001701
#
#        PCAD?        Vendor_key  \
# 24       Yes             JSTOR
# 27       Yes             other
# 34       Yes             JSTOR
# 37       Yes             JSTOR
# 51       Yes             JSTOR
# ...      ...               ...
# 102066   Yes             JSTOR
# 102111   Yes             JSTOR
# 102114   Yes          Elsevier
# 102156   Yes  Taylor & Francis
# 102157   Yes  Taylor & Francis
#
#                                               e_coll_info  \
# 24      ['61588428410001701', 'JSTOR Life Sciences Col...
# 27      ['61619505660001701', 'IEEE/IET Electronic Lib...
# 34      ['61535210810001701', 'JSTOR Arts and Sciences...
# 37      ['61535210810001701', 'JSTOR Arts and Sciences...
# 51      ['61746266290001701', 'JSTOR Arts and Sciences...
# ...                                                   ...
# 102066  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102111  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102114  ['61624504590001701', 'Elsevier ScienceDirect ...
# 102156  ['61808527020001701', 'Taylor & Francis Biolog...
# 102157  ['61808506700001701', 'Taylor & Francis Biolog...
#
#                                            portfolio_info
# 24      ['53588425000001701', 'The Wilson journal of o...
# 27      ['53620359120001701', 'IEEE transactions on ul...
# 34      ['53538633520001701', 'Journal of the Universi...
# 37      ['53537295580001701', 'Journal of the Universi...
# 51      ['53747073660001701', 'Journal of the Institut...
# ...                                                   ...
# 102066  ['53540700110001701', 'Proceedings and address...
# 102111             ['53539160390001701', 'The Americas.']
# 102114  ['53624617390001701', 'International journal o...
# 102156          ['53815435190001701', 'Oriental insects']
# 102157          ['53815442430001701', 'Oriental insects']
#
# [13339 rows x 15 columns]

# %%
df_e_trunc.drop(['Portfolio Id','Title_portfolio','ISSN_portfolio'],inplace=True, axis=1)
df_e_trunc
# Out:
#         record_index            MMS_ID  \
# 24            113344  9968879310001701
# 27            128733  9968441380001701
# 34            112352  9967759560001701
# 37            107439  9967145520001701
# 51            111951  9968429800001701
# ...              ...               ...
# 102066        123828  9968665290001701
# 102111        117510  9967987860001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
#
#                                                 Title_bib p_or_e     ISSN_bib  \
# 24                      The Wilson journal of ornithology      e  [1938-5447]
# 27           IEEE transactions on ultrasonics engineering      e  [2162-1373]
# 34             Journal of the University Film Association      e  [2328-1944]
# 37      Journal of the University Film and Video Assoc...      e  [2328-1936]
# 51                  Journal of the Institute of Actuaries      e  [2058-1009]
# ...                                                   ...    ...          ...
# 102066  Proceedings and addresses of the American Phil...      e  [2325-9248]
# 102111  The Americas - Academy of American Franciscan ...      e  [1533-6247]
# 102114    International journal of adhesion and adhesives      e  [1879-0127]
# 102156                                   Oriental insects      e  [2157-8745]
# 102157                                   Oriental insects      e  [2157-8745]
#
#                   ISSN_cluster  matches_group_id  \
# 24      [1559-4491, 1938-5447]                 2
# 27      [0893-6706, 2162-1373]                 5
# 34      [0041-9311, 2328-1944]                 7
# 37      [2328-1936, 0734-919X]                 7
# 51      [0020-2681, 2058-1009]                12
# ...                        ...               ...
# 102066  [2325-9248, 0065-972X]            101522
# 102111  [1533-6247, 0003-1615]            101581
# 102114  [0143-7496, 1879-0127]            101582
# 102156  [0030-5316, 2157-8745]            101697
# 102157  [0030-5316, 2157-8745]            101697
#
#                             Coverage Information Combined PCAD?  \
# 24              Available from 2006 volume: 118 issue: 1;   Yes
# 27       Available from 1963 volume: 10 issue: 1 until...   Yes
# 34       Available from 1968 volume: 20 issue: 1 until...   Yes
# 37       Available from 1982 volume: 34 issue: 1 until...   Yes
# 51       Available from 1886 volume: 25 issue: 5 until...   Yes
# ...                                                   ...   ...
# 102066                     Available from 1927 volume: 1;   Yes
# 102111            Available from 1944 volume: 1 issue: 1;   Yes
# 102114        Available from 1980-07- volume: 1 issue: 1;   Yes
# 102156   Available from 1967 volume: 1 until 1996 volu...   Yes
# 102157   Available from 1997 volume: 31 issue: 1 until...   Yes
#
#               Vendor_key                                        e_coll_info  \
# 24                 JSTOR  ['61588428410001701', 'JSTOR Life Sciences Col...
# 27                 other  ['61619505660001701', 'IEEE/IET Electronic Lib...
# 34                 JSTOR  ['61535210810001701', 'JSTOR Arts and Sciences...
# 37                 JSTOR  ['61535210810001701', 'JSTOR Arts and Sciences...
# 51                 JSTOR  ['61746266290001701', 'JSTOR Arts and Sciences...
# ...                  ...                                                ...
# 102066             JSTOR  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102111             JSTOR  ['61535211010001701', 'JSTOR Arts and Sciences...
# 102114          Elsevier  ['61624504590001701', 'Elsevier ScienceDirect ...
# 102156  Taylor & Francis  ['61808527020001701', 'Taylor & Francis Biolog...
# 102157  Taylor & Francis  ['61808506700001701', 'Taylor & Francis Biolog...
#
#                                            portfolio_info
# 24      ['53588425000001701', 'The Wilson journal of o...
# 27      ['53620359120001701', 'IEEE transactions on ul...
# 34      ['53538633520001701', 'Journal of the Universi...
# 37      ['53537295580001701', 'Journal of the Universi...
# 51      ['53747073660001701', 'Journal of the Institut...
# ...                                                   ...
# 102066  ['53540700110001701', 'Proceedings and address...
# 102111             ['53539160390001701', 'The Americas.']
# 102114  ['53624617390001701', 'International journal o...
# 102156          ['53815435190001701', 'Oriental insects']
# 102157          ['53815442430001701', 'Oriental insects']
#
# [13339 rows x 12 columns]

# %%
dfeg = df_e_trunc[['MMS_ID','e_coll_info','portfolio_info']].groupby(['MMS_ID']).agg(lambda x: list(set([item for item in x]))).reset_index()
dfeg
# Out:
#                 MMS_ID                                        e_coll_info  \
# 0     9966211480001701  [['61624504590001701', 'Elsevier ScienceDirect...
# 1     9966211500001701  [['61535213730001701', 'SpringerLink Historica...
# 2     9966211580001701  [['61624504590001701', 'Elsevier ScienceDirect...
# 3     9966211610001701  [['61624504590001701', 'Elsevier ScienceDirect...
# 4     9966211630001701  [['61535212360001701', 'Elsevier SD Backfile B...
# ...                ...                                                ...
# 7156  9977118809801701  [['61816118310001701', 'Mary Ann Liebert Publi...
# 7157  9977118809901701  [['61816118310001701', 'Mary Ann Liebert Publi...
# 7158  9977242251801701  [['61765175560001701', 'Wiley Online Library D...
# 7159  9977255009801701  [['61789512600001701', 'JSTOR Arts & Sciences ...
# 7160  9977262509801701  [['61535210810001701', 'JSTOR Arts and Science...
#
#                                          portfolio_info
# 0          [['53624689300001701', 'Structural safety']]
# 1     [['53535250720001701', 'Plant molecular biolog...
# 2         [['53624691020001701', 'Solid state ionics']]
# 3     [['53624691280001701', 'Soil & tillage researc...
# 4     [['53535250570001701', 'Regulatory peptides.']...
# ...                                                 ...
# 7156  [['53816118140001701', 'CyberPsychology and be...
# 7157      [['53816118210001701', 'AIDS patient care.']]
# 7158  [['53831074140001701', 'Crop science, soil sci...
# 7159  [['53831868390001701', 'Wiener Zeitschrift fü...
# 7160  [['53833378320001701', 'Beiheft ... der Histor...
#
# [7161 rows x 3 columns]

# %%
dfes = df_e_trunc[['MMS_ID','Coverage Information Combined','PCAD?','Vendor_key']].groupby(['MMS_ID']).agg(lambda x: list(set(x))).reset_index()
dfes
# Out:
#                 MMS_ID                      Coverage Information Combined  \
# 0     9966211480001701    [ Available from 1995-03- volume: 17 issue: 1;]
# 1     9966211500001701  [ Available from 1982 volume: 1 issue: 1 until...
# 2     9966211580001701     [ Available from 1980-04- volume: 1 issue: 1;]
# 3     9966211610001701                  [ Available from 1980 volume: 1;]
# 4     9966211630001701  [ Available from 1980 volume: 1 until 2004-12-...
# ...                ...                                                ...
# 7156  9977118809801701  [ Available from 1998 volume: 1 issue: 1 until...
# 7157  9977118809901701  [ Available from 1987 volume: 1 issue: 1 until...
# 7158  9977242251801701  [ Available from 1999 volume: 44 issue: 1 unti...
# 7159  9977255009801701                 [ Available from 2000 volume: 44;]
# 7160  9977262509801701  [ Available from 1924 volume: 1 until 2006 vol...
#
#       PCAD?  Vendor_key
# 0     [Yes]  [Elsevier]
# 1     [Yes]  [Springer]
# 2     [Yes]  [Elsevier]
# 3     [Yes]  [Elsevier]
# 4     [Yes]  [Elsevier]
# ...     ...         ...
# 7156  [Yes]     [other]
# 7157  [Yes]     [other]
# 7158  [Yes]     [Wiley]
# 7159  [Yes]     [JSTOR]
# 7160  [Yes]     [JSTOR]
#
# [7161 rows x 4 columns]

# %%
df_e_combo = pd.merge(dfeg, dfes, how='left',on='MMS_ID')
df_e_combo
# Out:
#                 MMS_ID                                        e_coll_info  \
# 0     9966211480001701  [['61624504590001701', 'Elsevier ScienceDirect...
# 1     9966211500001701  [['61535213730001701', 'SpringerLink Historica...
# 2     9966211580001701  [['61624504590001701', 'Elsevier ScienceDirect...
# 3     9966211610001701  [['61624504590001701', 'Elsevier ScienceDirect...
# 4     9966211630001701  [['61535212360001701', 'Elsevier SD Backfile B...
# ...                ...                                                ...
# 7156  9977118809801701  [['61816118310001701', 'Mary Ann Liebert Publi...
# 7157  9977118809901701  [['61816118310001701', 'Mary Ann Liebert Publi...
# 7158  9977242251801701  [['61765175560001701', 'Wiley Online Library D...
# 7159  9977255009801701  [['61789512600001701', 'JSTOR Arts & Sciences ...
# 7160  9977262509801701  [['61535210810001701', 'JSTOR Arts and Science...
#
#                                          portfolio_info  \
# 0          [['53624689300001701', 'Structural safety']]
# 1     [['53535250720001701', 'Plant molecular biolog...
# 2         [['53624691020001701', 'Solid state ionics']]
# 3     [['53624691280001701', 'Soil & tillage researc...
# 4     [['53535250570001701', 'Regulatory peptides.']...
# ...                                                 ...
# 7156  [['53816118140001701', 'CyberPsychology and be...
# 7157      [['53816118210001701', 'AIDS patient care.']]
# 7158  [['53831074140001701', 'Crop science, soil sci...
# 7159  [['53831868390001701', 'Wiener Zeitschrift fü...
# 7160  [['53833378320001701', 'Beiheft ... der Histor...
#
#                           Coverage Information Combined  PCAD?  Vendor_key
# 0       [ Available from 1995-03- volume: 17 issue: 1;]  [Yes]  [Elsevier]
# 1     [ Available from 1982 volume: 1 issue: 1 until...  [Yes]  [Springer]
# 2        [ Available from 1980-04- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# 3                     [ Available from 1980 volume: 1;]  [Yes]  [Elsevier]
# 4     [ Available from 1980 volume: 1 until 2004-12-...  [Yes]  [Elsevier]
# ...                                                 ...    ...         ...
# 7156  [ Available from 1998 volume: 1 issue: 1 until...  [Yes]     [other]
# 7157  [ Available from 1987 volume: 1 issue: 1 until...  [Yes]     [other]
# 7158  [ Available from 1999 volume: 44 issue: 1 unti...  [Yes]     [Wiley]
# 7159                 [ Available from 2000 volume: 44;]  [Yes]     [JSTOR]
# 7160  [ Available from 1924 volume: 1 until 2006 vol...  [Yes]     [JSTOR]
#
# [7161 rows x 6 columns]

# %%
p_and_e_data.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'OCN', 'ISSN_bib',
#        'Related_OCNs', 'Related_ISSNs', 'Vol_nos', 'Gov_doc_nos',
#        'OCN_cluster', 'ISSN_cluster', 'p_or_e', 'ISSN_group_id',
#        'OCN_group_id', 'both_groups', 'matches_group_id', 'ISSN_to_match',
#        'MMS ID', 'E Coll ID', 'Electronic Collection Id',
#        'Electronic Collection Public Name',
#        'Electronic Collection Public Name (override)', 'MMS Id',
#        'Title_portfolio', 'Begin Publication Date', 'End Publication Date',
#        'ISSN_portfolio', 'Coverage Information Combined', 'Coverage Statement',
#        'Portfolio Id', 'Lifecycle', 'Embargo Operator', 'Embargo Months',
#        'Embargo Years', 'Status (Active)', 'Collection Public Name', 'PCAD?',
#        'Vendor_key'],
#       dtype='object')

# %%
p_and_e_data = p_and_e_data[['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib','ISSN_cluster',
                             'p_or_e', 'matches_group_id', 'ISSN_to_match']]
p_and_e_data
# Out:
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 16            113344  9968879310001701
# 17            113344  9968879310001701
# 18            113344  9968879310001701
# ...              ...               ...
# 102118        125537  9968947900001701
# 102119        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib     ISSN_bib  \
# 14                   The Wilson journal of ornithology.  [1559-4491]
# 15                    The Wilson journal of ornithology  [1938-5447]
# 16                    The Wilson journal of ornithology  [1938-5447]
# 17                    The Wilson journal of ornithology  [1938-5447]
# 18                    The Wilson journal of ornithology  [1938-5447]
# ...                                                 ...          ...
# 102118  International journal of adhesion and adhesives  [1879-0127]
# 102119  International journal of adhesion and adhesives  [1879-0127]
# 102156                                 Oriental insects  [2157-8745]
# 102157                                 Oriental insects  [2157-8745]
# 102158                                 Oriental insects  [0030-5316]
#
#                   ISSN_cluster p_or_e  matches_group_id ISSN_to_match
# 14                 [1559-4491]      p                 2     1559-4491
# 15      [1559-4491, 1938-5447]      e                 2     1938-5447
# 16      [1559-4491, 1938-5447]      e                 2     1938-5447
# 17      [1559-4491, 1938-5447]      e                 2     1938-5447
# 18      [1559-4491, 1938-5447]      e                 2     1938-5447
# ...                        ...    ...               ...           ...
# 102118  [0143-7496, 1879-0127]      e            101582     1879-0127
# 102119  [0143-7496, 1879-0127]      e            101582     1879-0127
# 102156  [0030-5316, 2157-8745]      e            101697     2157-8745
# 102157  [0030-5316, 2157-8745]      e            101697     2157-8745
# 102158             [0030-5316]      p            101697     0030-5316
#
# [52265 rows x 8 columns]

# %%
p_and_e_data['ISSN_bib'] = p_and_e_data['ISSN_bib'].apply(lambda x: str(x))
p_and_e_data['ISSN_cluster'] = p_and_e_data['ISSN_cluster'].apply(lambda x: str(x))
p_and_e_data
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 16            113344  9968879310001701
# 17            113344  9968879310001701
# 18            113344  9968879310001701
# ...              ...               ...
# 102118        125537  9968947900001701
# 102119        125537  9968947900001701
# 102156        114862  9977101571201701
# 102157        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib       ISSN_bib  \
# 14                   The Wilson journal of ornithology.  ['1559-4491']
# 15                    The Wilson journal of ornithology  ['1938-5447']
# 16                    The Wilson journal of ornithology  ['1938-5447']
# 17                    The Wilson journal of ornithology  ['1938-5447']
# 18                    The Wilson journal of ornithology  ['1938-5447']
# ...                                                 ...            ...
# 102118  International journal of adhesion and adhesives  ['1879-0127']
# 102119  International journal of adhesion and adhesives  ['1879-0127']
# 102156                                 Oriental insects  ['2157-8745']
# 102157                                 Oriental insects  ['2157-8745']
# 102158                                 Oriental insects  ['0030-5316']
#
#                       ISSN_cluster p_or_e  matches_group_id ISSN_to_match
# 14                   ['1559-4491']      p                 2     1559-4491
# 15      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 16      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 17      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 18      ['1559-4491', '1938-5447']      e                 2     1938-5447
# ...                            ...    ...               ...           ...
# 102118  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 102119  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 102156  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 102157  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 102158               ['0030-5316']      p            101697     0030-5316
#
# [52265 rows x 8 columns]

# %%
p_and_e_data.drop_duplicates(inplace=True)
p_and_e_data
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         record_index            MMS_ID  \
# 14             69875  9939153590001701
# 15            113344  9968879310001701
# 25             57684  9963550760001701
# 26            128733  9968441380001701
# 32            112352  9967759560001701
# ...              ...               ...
# 102112        124654  9924328340001701
# 102113         31683  9957960200001701
# 102114        125537  9968947900001701
# 102156        114862  9977101571201701
# 102158         14688  9933514930001701
#
#                                               Title_bib       ISSN_bib  \
# 14                   The Wilson journal of ornithology.  ['1559-4491']
# 15                    The Wilson journal of ornithology  ['1938-5447']
# 25         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 26         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 32           Journal of the University Film Association  ['2328-1944']
# ...                                                 ...            ...
# 102112                                Americas (Online)           ['']
# 102113  International journal of adhesion and adhesives  ['0143-7496']
# 102114  International journal of adhesion and adhesives  ['1879-0127']
# 102156                                 Oriental insects  ['2157-8745']
# 102158                                 Oriental insects  ['0030-5316']
#
#                       ISSN_cluster p_or_e  matches_group_id ISSN_to_match
# 14                   ['1559-4491']      p                 2     1559-4491
# 15      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 25                   ['0893-6706']      p                 5     0893-6706
# 26      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 32      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                            ...    ...               ...           ...
# 102112               ['0003-1615']      e            101581
# 102113               ['0143-7496']      p            101582     0143-7496
# 102114  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 102156  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 102158               ['0030-5316']      p            101697     0030-5316
#
# [15659 rows x 8 columns]

# %%
p_and_e_data['MMS_ID'].nunique()
# Out:
# 15651

# %%
df_combo = pd.merge(p_and_e_data,df_e_combo,how='left',on='MMS_ID')
df_combo
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 4            112352  9967759560001701
# ...             ...               ...
# 15654        124654  9924328340001701
# 15655         31683  9957960200001701
# 15656        125537  9968947900001701
# 15657        114862  9977101571201701
# 15658         14688  9933514930001701
#
#                                              Title_bib       ISSN_bib  \
# 0                   The Wilson journal of ornithology.  ['1559-4491']
# 1                    The Wilson journal of ornithology  ['1938-5447']
# 2         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 4           Journal of the University Film Association  ['2328-1944']
# ...                                                ...            ...
# 15654                                Americas (Online)           ['']
# 15655  International journal of adhesion and adhesives  ['0143-7496']
# 15656  International journal of adhesion and adhesives  ['1879-0127']
# 15657                                 Oriental insects  ['2157-8745']
# 15658                                 Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                           ...    ...               ...           ...
# 15654               ['0003-1615']      e            101581
# 15655               ['0143-7496']      p            101582     0143-7496
# 15656  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 15657  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 15658               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 15654                                                NaN
# 15655                                                NaN
# 15656  [['61624504590001701', 'Elsevier ScienceDirect...
# 15657  [['61808506700001701', 'Taylor & Francis Biolo...
# 15658                                                NaN
#
#                                           portfolio_info  \
# 0                                                    NaN
# 1      [['53588425000001701', 'The Wilson journal of ...
# 2                                                    NaN
# 3      [['53620359120001701', 'IEEE transactions on u...
# 4      [['53538633520001701', 'Journal of the Univers...
# ...                                                  ...
# 15654                                                NaN
# 15655                                                NaN
# 15656  [['53624617390001701', 'International journal ...
# 15657  [['53815442430001701', 'Oriental insects'], ['...
# 15658                                                NaN
#
#                            Coverage Information Combined  PCAD?  \
# 0                                                    NaN    NaN
# 1           [ Available from 2006 volume: 118 issue: 1;]  [Yes]
# 2                                                    NaN    NaN
# 3      [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 4      [ Available from 1968 volume: 20 issue: 1 unti...  [Yes]
# ...                                                  ...    ...
# 15654                                                NaN    NaN
# 15655                                                NaN    NaN
# 15656     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 15657  [ Available from 1997 volume: 31 issue: 1 unti...  [Yes]
# 15658                                                NaN    NaN
#
#                Vendor_key
# 0                     NaN
# 1                 [JSTOR]
# 2                     NaN
# 3                 [other]
# 4                 [JSTOR]
# ...                   ...
# 15654                 NaN
# 15655                 NaN
# 15656          [Elsevier]
# 15657  [Taylor & Francis]
# 15658                 NaN
#
# [15659 rows x 13 columns]

# %%
df_combo.to_pickle(f'p_and_e_with_combined_coverage_{today}.pkl')

# %% [markdown]
# ## Create dataframes of BTAA SPR and PORTICO data

# %% [markdown]
# #### BTAA SPR

# %%
#change filename if necessary
btaa = pd.read_excel('BTAA-SPR.xlsx')
btaa
# Out:
#      ISSN Number                                    Title 1 (Print)  \
# 0      0001-0782                         Communications of the ACM.
# 1      0001-1541                                     AIChE journal.
# 2      0001-2092                                      AORN journal.
# 3      0001-2815                                   Tissue antigens.
# 4      0001-2998                      Seminars in nuclear medicine.
# ...          ...                                                ...
# 9649   8756-7547  Genetic, social, and general psychology monogr...
# 9650   8756-7555                                  College teaching.
# 9651   8756-8225          Journal of college student psychotherapy.
# 9652   8756-9264  Clinical progress in electrophysiology and pac...
# 9653   8756-971X  Journal of the American Mosquito Control Assoc...
#
#                                       Publisher (Print)  \
# 0                   Association for Computing Machinery
# 1                       Wiley Subscription Services Inc
# 2                  Association of Operating Room Nurses
# 3                                            Munksgaard
# 4                                  Grune & Stratton etc
# ...                                                 ...
# 9649                               Heldref Publications
# 9650  Heldref Publications a division of Helen Dwigh...
# 9651                                      Haworth Press
# 9652                                      Futura Pub Co
# 9653              American Mosquito Control Association
#
#                                         Title 2 (Print)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9649                                                NaN
# 9650                                                NaN
# 9651                                                NaN
# 9652                                                NaN
# 9653  Journal of the American Mosquito Control Assoc...
#
#                             Publisher (Print).1 Title 3 (Print)  \
# 0                                           NaN             NaN
# 1                                           NaN             NaN
# 2                                           NaN             NaN
# 3                                           NaN             NaN
# 4                                           NaN             NaN
# ...                                         ...             ...
# 9649                                        NaN             NaN
# 9650                                        NaN             NaN
# 9651                                        NaN             NaN
# 9652                                        NaN             NaN
# 9653  The American Mosquito Control Association             NaN
#
#      Publisher (Print).2 (more bib records?) Match?  \
# 0                    NaN                 NaN    YES
# 1                    NaN                 NaN    YES
# 2                    NaN                 NaN    YES
# 3                    NaN                 NaN    YES
# 4                    NaN                 NaN    YES
# ...                  ...                 ...    ...
# 9649                 NaN                 NaN    NaN
# 9650                 NaN                 NaN    NaN
# 9651                 NaN                 NaN    NaN
# 9652                 NaN                 NaN    NaN
# 9653                 NaN                 NaN    NaN
#
#                                            SPR Holdings  \
# 0     2 (1959)-43 (2000), 45 (2002)-46 (2003), 50 (2...
# 1                         1 (1955)-50 (2004), 52 (2006)
# 2               4 (1966)-48 (1988), 51 (1990)-85 (2007)
# 3                                    1 (1971)-52 (1998)
# 4                                    1 (1971)-35 (2005)
# ...                                                 ...
# 9649                                                NaN
# 9650                                                NaN
# 9651                                                NaN
# 9652                                                NaN
# 9653                                                NaN
#
#                                             SPR Missing
# 0     v.44 (2001), v.47 (2004)-v.49 (2006), v.51 (20...
# 1                             v.51 (2005), v.53 (2007)-
# 2     v.1 (1963)-v.3 (1965),v.49 (1989)-50 (1989),v....
# 3                                          v.53 (1999)-
# 4                                          v.36 (2006)-
# ...                                                 ...
# 9649                                                NaN
# 9650                                                NaN
# 9651                                                NaN
# 9652                                                NaN
# 9653                                                NaN
#
# [9654 rows x 11 columns]

# %%
btaa_cols = list(btaa.columns)
btaa_cols
# Out:
# ['ISSN Number',
#  'Title 1 (Print)',
#  'Publisher (Print)',
#  'Title 2 (Print)',
#  'Publisher (Print).1',
#  'Title 3 (Print)',
#  'Publisher (Print).2',
#  '(more bib records?)',
#  'Match?',
#  'SPR Holdings',
#  'SPR Missing']

# %%
btaa_cols_edit = []
for x in btaa_cols:
    btaa_cols_edit.append(str(x) + '_BTAA-SPR')
btaa_cols_edit
# Out:
# ['ISSN Number_BTAA-SPR',
#  'Title 1 (Print)_BTAA-SPR',
#  'Publisher (Print)_BTAA-SPR',
#  'Title 2 (Print)_BTAA-SPR',
#  'Publisher (Print).1_BTAA-SPR',
#  'Title 3 (Print)_BTAA-SPR',
#  'Publisher (Print).2_BTAA-SPR',
#  '(more bib records?)_BTAA-SPR',
#  'Match?_BTAA-SPR',
#  'SPR Holdings_BTAA-SPR',
#  'SPR Missing_BTAA-SPR']

# %%
btaa_dict = dict(zip(btaa_cols, btaa_cols_edit))
btaa_dict
# Out:
# {'ISSN Number': 'ISSN Number_BTAA-SPR',
#  'Title 1 (Print)': 'Title 1 (Print)_BTAA-SPR',
#  'Publisher (Print)': 'Publisher (Print)_BTAA-SPR',
#  'Title 2 (Print)': 'Title 2 (Print)_BTAA-SPR',
#  'Publisher (Print).1': 'Publisher (Print).1_BTAA-SPR',
#  'Title 3 (Print)': 'Title 3 (Print)_BTAA-SPR',
#  'Publisher (Print).2': 'Publisher (Print).2_BTAA-SPR',
#  '(more bib records?)': '(more bib records?)_BTAA-SPR',
#  'Match?': 'Match?_BTAA-SPR',
#  'SPR Holdings': 'SPR Holdings_BTAA-SPR',
#  'SPR Missing': 'SPR Missing_BTAA-SPR'}

# %%
btaa.rename(index=str, columns = btaa_dict, inplace=True)
btaa
# Out:
#      ISSN Number_BTAA-SPR                           Title 1 (Print)_BTAA-SPR  \
# 0               0001-0782                         Communications of the ACM.
# 1               0001-1541                                     AIChE journal.
# 2               0001-2092                                      AORN journal.
# 3               0001-2815                                   Tissue antigens.
# 4               0001-2998                      Seminars in nuclear medicine.
# ...                   ...                                                ...
# 9649            8756-7547  Genetic, social, and general psychology monogr...
# 9650            8756-7555                                  College teaching.
# 9651            8756-8225          Journal of college student psychotherapy.
# 9652            8756-9264  Clinical progress in electrophysiology and pac...
# 9653            8756-971X  Journal of the American Mosquito Control Assoc...
#
#                              Publisher (Print)_BTAA-SPR  \
# 0                   Association for Computing Machinery
# 1                       Wiley Subscription Services Inc
# 2                  Association of Operating Room Nurses
# 3                                            Munksgaard
# 4                                  Grune & Stratton etc
# ...                                                 ...
# 9649                               Heldref Publications
# 9650  Heldref Publications a division of Helen Dwigh...
# 9651                                      Haworth Press
# 9652                                      Futura Pub Co
# 9653              American Mosquito Control Association
#
#                                Title 2 (Print)_BTAA-SPR  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9649                                                NaN
# 9650                                                NaN
# 9651                                                NaN
# 9652                                                NaN
# 9653  Journal of the American Mosquito Control Assoc...
#
#                    Publisher (Print).1_BTAA-SPR Title 3 (Print)_BTAA-SPR  \
# 0                                           NaN                      NaN
# 1                                           NaN                      NaN
# 2                                           NaN                      NaN
# 3                                           NaN                      NaN
# 4                                           NaN                      NaN
# ...                                         ...                      ...
# 9649                                        NaN                      NaN
# 9650                                        NaN                      NaN
# 9651                                        NaN                      NaN
# 9652                                        NaN                      NaN
# 9653  The American Mosquito Control Association                      NaN
#
#      Publisher (Print).2_BTAA-SPR (more bib records?)_BTAA-SPR  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 9649                          NaN                          NaN
# 9650                          NaN                          NaN
# 9651                          NaN                          NaN
# 9652                          NaN                          NaN
# 9653                          NaN                          NaN
#
#      Match?_BTAA-SPR                              SPR Holdings_BTAA-SPR  \
# 0                YES  2 (1959)-43 (2000), 45 (2002)-46 (2003), 50 (2...
# 1                YES                      1 (1955)-50 (2004), 52 (2006)
# 2                YES            4 (1966)-48 (1988), 51 (1990)-85 (2007)
# 3                YES                                 1 (1971)-52 (1998)
# 4                YES                                 1 (1971)-35 (2005)
# ...              ...                                                ...
# 9649             NaN                                                NaN
# 9650             NaN                                                NaN
# 9651             NaN                                                NaN
# 9652             NaN                                                NaN
# 9653             NaN                                                NaN
#
#                                    SPR Missing_BTAA-SPR
# 0     v.44 (2001), v.47 (2004)-v.49 (2006), v.51 (20...
# 1                             v.51 (2005), v.53 (2007)-
# 2     v.1 (1963)-v.3 (1965),v.49 (1989)-50 (1989),v....
# 3                                          v.53 (1999)-
# 4                                          v.36 (2006)-
# ...                                                 ...
# 9649                                                NaN
# 9650                                                NaN
# 9651                                                NaN
# 9652                                                NaN
# 9653                                                NaN
#
# [9654 rows x 11 columns]

# %% [markdown]
# #### Merge SPR data into df_combo

# %%
df_pcad_btaa = pd.merge(df_combo,btaa,how='left',left_on='ISSN_to_match',right_on='ISSN Number_BTAA-SPR')
df_pcad_btaa
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 4            112352  9967759560001701
# ...             ...               ...
# 15654        124654  9924328340001701
# 15655         31683  9957960200001701
# 15656        125537  9968947900001701
# 15657        114862  9977101571201701
# 15658         14688  9933514930001701
#
#                                              Title_bib       ISSN_bib  \
# 0                   The Wilson journal of ornithology.  ['1559-4491']
# 1                    The Wilson journal of ornithology  ['1938-5447']
# 2         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 4           Journal of the University Film Association  ['2328-1944']
# ...                                                ...            ...
# 15654                                Americas (Online)           ['']
# 15655  International journal of adhesion and adhesives  ['0143-7496']
# 15656  International journal of adhesion and adhesives  ['1879-0127']
# 15657                                 Oriental insects  ['2157-8745']
# 15658                                 Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                           ...    ...               ...           ...
# 15654               ['0003-1615']      e            101581
# 15655               ['0143-7496']      p            101582     0143-7496
# 15656  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 15657  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 15658               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 15654                                                NaN
# 15655                                                NaN
# 15656  [['61624504590001701', 'Elsevier ScienceDirect...
# 15657  [['61808506700001701', 'Taylor & Francis Biolo...
# 15658                                                NaN
#
#                                           portfolio_info  ...  \
# 0                                                    NaN  ...
# 1      [['53588425000001701', 'The Wilson journal of ...  ...
# 2                                                    NaN  ...
# 3      [['53620359120001701', 'IEEE transactions on u...  ...
# 4      [['53538633520001701', 'Journal of the Univers...  ...
# ...                                                  ...  ...
# 15654                                                NaN  ...
# 15655                                                NaN  ...
# 15656  [['53624617390001701', 'International journal ...  ...
# 15657  [['53815442430001701', 'Oriental insects'], ['...  ...
# 15658                                                NaN  ...
#
#                                Title 1 (Print)_BTAA-SPR  \
# 0                                                   NaN
# 1                                                   NaN
# 2         IEEE transactions on ultrasonics engineering.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 15654                                               NaN
# 15655  International journal of adhesion and adhesives.
# 15656                                               NaN
# 15657                                               NaN
# 15658                                               NaN
#
#                               Publisher (Print)_BTAA-SPR  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Institute of Electrical and Electronics Engineers
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15654                                                NaN
# 15655                   IPC Science and Technology Press
# 15656                                                NaN
# 15657                                                NaN
# 15658                                                NaN
#
#       Title 2 (Print)_BTAA-SPR Publisher (Print).1_BTAA-SPR  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ...                        ...                          ...
# 15654                      NaN                          NaN
# 15655                      NaN                          NaN
# 15656                      NaN                          NaN
# 15657                      NaN                          NaN
# 15658                      NaN                          NaN
#
#       Title 3 (Print)_BTAA-SPR Publisher (Print).2_BTAA-SPR  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ...                        ...                          ...
# 15654                      NaN                          NaN
# 15655                      NaN                          NaN
# 15656                      NaN                          NaN
# 15657                      NaN                          NaN
# 15658                      NaN                          NaN
#
#       (more bib records?)_BTAA-SPR Match?_BTAA-SPR SPR Holdings_BTAA-SPR  \
# 0                              NaN             NaN                   NaN
# 1                              NaN             NaN                   NaN
# 2                              NaN             YES             10 (1963)
# 3                              NaN             NaN                   NaN
# 4                              NaN             NaN                   NaN
# ...                            ...             ...                   ...
# 15654                          NaN             NaN                   NaN
# 15655                          NaN             YES   10 (1990)-26 (2006)
# 15656                          NaN             NaN                   NaN
# 15657                          NaN             NaN                   NaN
# 15658                          NaN             NaN                   NaN
#
#                       SPR Missing_BTAA-SPR
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 15654                                  NaN
# 15655  v.1 (1980)-v.9 (1989), v.27 (2007)-
# 15656                                  NaN
# 15657                                  NaN
# 15658                                  NaN
#
# [15659 rows x 24 columns]

# %% [markdown]
# #### Portico

# %%
portico = pd.read_excel('portico_2020-Oct.xlsx')
portico
# Out:
#        Library Input Row  Electronic Collection Id  \
# 0                      1         61535209430001701
# 1                      2         61535209430001701
# 2                      3         61535209430001701
# 3                      4         61535209430001701
# 4                      5         61535209430001701
# ...                  ...                       ...
# 30871              30872         61816118310001701
# 30872              30873         61816118310001701
# 30873              30874         61816118310001701
# 30874              30875         61816598280001701
# 30875              30876         61817087960001701
#
#             Electronic Collection Public Name       Portfolio Id  \
# 0      American Medical Association Backfiles  53536123280001701
# 1      American Medical Association Backfiles  53536407060001701
# 2      American Medical Association Backfiles  53536420410001701
# 3      American Medical Association Backfiles  53536464180001701
# 4      American Medical Association Backfiles  53536464550001701
# ...                                       ...                ...
# 30871    Mary Ann Liebert Publishers Journals  53816118240001701
# 30872    Mary Ann Liebert Publishers Journals  53816118260001701
# 30873    Mary Ann Liebert Publishers Journals  53816118280001701
# 30874  Wiley Online Library Surgery Backfiles  53816598250001701
# 30875                   Time Magazine Archive  53817087930001701
#
#       Available For Group Availability      Lifecycle                  ISSN  \
# 0              TwinCities    Available  In Repository  2375-057X; 0093-0326
# 1              TwinCities    Available  In Repository             0730-188X
# 2              TwinCities    Available  In Repository  2376-3590; 0272-5533
# 3              TwinCities    Available  In Repository  2374-3018; 0002-922X
# 4              TwinCities    Available  In Repository  2376-3817; 0003-9977
# ...                   ...          ...            ...                   ...
# 30871          TwinCities    Available  In Repository             2151-1136
# 30872          TwinCities    Available  In Repository  1937-3392; 1937-3384
# 30873          TwinCities    Available  In Repository  1937-3376; 1937-3368
# 30874          TwinCities    Available  In Repository  1365-2168; 0007-1323
# 30875          TwinCities    Available  In Repository  2169-1665; 0040-781X
#
#                  MMS Id Bibliographic Lifecycle  ...  \
# 0      9966629010001701           In Repository  ...
# 1      9966759170001701           In Repository  ...
# 2      9966757510001701           In Repository  ...
# 3      9966774910001701           In Repository  ...
# 4      9966774590001701           In Repository  ...
# ...                 ...                     ...  ...
# 30871  9975418997301701           In Repository  ...
# 30872  9966973510001701           In Repository  ...
# 30873  9966973540001701           In Repository  ...
# 30874  9966956150001701           In Repository  ...
# 30875  9969180100001701           In Repository  ...
#
#       Earliest Volume Preserved Latest Year Preserved Latest Volume Preserved  \
# 0                             1                1997.0                     115
# 1                           NaN                   NaN                     NaN
# 2                           NaN                   NaN                     NaN
# 3                            91                1997.0                     151
# 4                             1                1997.0                     123
# ...                         ...                   ...                     ...
# 30871                        24                2018.0                      32
# 30872                        14                2019.0                      25
# 30873                        14                2019.0                      25
# 30874                         1                2020.0                     107
# 30875                       NaN                   NaN                     NaN
#
#       Num Preserved Articles Num Preserved Issues Num Preserved Volumes  \
# 0                    29375.0                450.0                  52.0
# 1                        NaN                  NaN                   NaN
# 2                        NaN                  NaN                   NaN
# 3                    16545.0                505.0                  85.0
# 4                    11918.0                311.0                  52.0
# ...                      ...                  ...                   ...
# 30871                  450.0                 52.0                   9.0
# 30872                 1175.0                120.0                  12.0
# 30873                  495.0                 67.0                  12.0
# 30874                35244.0                912.0                 107.0
# 30875                    NaN                  NaN                   NaN
#
#                        URL to Journal in Audit Interface  \
# 0      http://audit.portico.org/stable?cs=ISSN_000399...
# 1                                                    NaN
# 2                                                    NaN
# 3      http://audit.portico.org/stable?cs=ISSN_000292...
# 4      http://audit.portico.org/stable?cs=ISSN_000399...
# ...                                                  ...
# 30871   http://audit.portico.org/stable?cs=ISSN_21511136
# 30872   http://audit.portico.org/stable?cs=ISSN_19373384
# 30873   http://audit.portico.org/stable?cs=ISSN_19373368
# 30874   http://audit.portico.org/stable?cs=ISSN_00071323
# 30875                                                NaN
#
#                           Portico Content Provider  \
# 0      American Medical Association (through 2017)
# 1                                              NaN
# 2                                              NaN
# 3      American Medical Association (through 2017)
# 4      American Medical Association (through 2017)
# ...                                            ...
# 30871                       Mary Ann Liebert, Inc.
# 30872                       Mary Ann Liebert, Inc.
# 30873                       Mary Ann Liebert, Inc.
# 30874                      John Wiley & Sons, Inc.
# 30875                                          NaN
#
#                                         Portico Title ID Notes
# 0          ISSN_00039950 | ISSN_00930326 | ISSN_00966339   NaN
# 1                                                    NaN   NaN
# 2                                                    NaN   NaN
# 3      ISSN_0002922X | ISSN_00966916 | ISSN_00968994 ...   NaN
# 4      ISSN_00039977 | ISSN_00966894 | ISSN_02760673 ...   NaN
# ...                                                  ...   ...
# 30871                                      ISSN_21511136   NaN
# 30872                                      ISSN_19373384   NaN
# 30873                                      ISSN_19373368   NaN
# 30874                                      ISSN_00071323   NaN
# 30875                                                NaN   NaN
#
# [30876 rows x 29 columns]

# %%
portico['Linking ISSN list'] = portico['Linking ISSN'].apply(lambda x: str(x).split('|'))
portico
# Out:
#        Library Input Row  Electronic Collection Id  \
# 0                      1         61535209430001701
# 1                      2         61535209430001701
# 2                      3         61535209430001701
# 3                      4         61535209430001701
# 4                      5         61535209430001701
# ...                  ...                       ...
# 30871              30872         61816118310001701
# 30872              30873         61816118310001701
# 30873              30874         61816118310001701
# 30874              30875         61816598280001701
# 30875              30876         61817087960001701
#
#             Electronic Collection Public Name       Portfolio Id  \
# 0      American Medical Association Backfiles  53536123280001701
# 1      American Medical Association Backfiles  53536407060001701
# 2      American Medical Association Backfiles  53536420410001701
# 3      American Medical Association Backfiles  53536464180001701
# 4      American Medical Association Backfiles  53536464550001701
# ...                                       ...                ...
# 30871    Mary Ann Liebert Publishers Journals  53816118240001701
# 30872    Mary Ann Liebert Publishers Journals  53816118260001701
# 30873    Mary Ann Liebert Publishers Journals  53816118280001701
# 30874  Wiley Online Library Surgery Backfiles  53816598250001701
# 30875                   Time Magazine Archive  53817087930001701
#
#       Available For Group Availability      Lifecycle                  ISSN  \
# 0              TwinCities    Available  In Repository  2375-057X; 0093-0326
# 1              TwinCities    Available  In Repository             0730-188X
# 2              TwinCities    Available  In Repository  2376-3590; 0272-5533
# 3              TwinCities    Available  In Repository  2374-3018; 0002-922X
# 4              TwinCities    Available  In Repository  2376-3817; 0003-9977
# ...                   ...          ...            ...                   ...
# 30871          TwinCities    Available  In Repository             2151-1136
# 30872          TwinCities    Available  In Repository  1937-3392; 1937-3384
# 30873          TwinCities    Available  In Repository  1937-3376; 1937-3368
# 30874          TwinCities    Available  In Repository  1365-2168; 0007-1323
# 30875          TwinCities    Available  In Repository  2169-1665; 0040-781X
#
#                  MMS Id Bibliographic Lifecycle  ... Latest Year Preserved  \
# 0      9966629010001701           In Repository  ...                1997.0
# 1      9966759170001701           In Repository  ...                   NaN
# 2      9966757510001701           In Repository  ...                   NaN
# 3      9966774910001701           In Repository  ...                1997.0
# 4      9966774590001701           In Repository  ...                1997.0
# ...                 ...                     ...  ...                   ...
# 30871  9975418997301701           In Repository  ...                2018.0
# 30872  9966973510001701           In Repository  ...                2019.0
# 30873  9966973540001701           In Repository  ...                2019.0
# 30874  9966956150001701           In Repository  ...                2020.0
# 30875  9969180100001701           In Repository  ...                   NaN
#
#       Latest Volume Preserved Num Preserved Articles Num Preserved Issues  \
# 0                         115                29375.0                450.0
# 1                         NaN                    NaN                  NaN
# 2                         NaN                    NaN                  NaN
# 3                         151                16545.0                505.0
# 4                         123                11918.0                311.0
# ...                       ...                    ...                  ...
# 30871                      32                  450.0                 52.0
# 30872                      25                 1175.0                120.0
# 30873                      25                  495.0                 67.0
# 30874                     107                35244.0                912.0
# 30875                     NaN                    NaN                  NaN
#
#       Num Preserved Volumes  \
# 0                      52.0
# 1                       NaN
# 2                       NaN
# 3                      85.0
# 4                      52.0
# ...                     ...
# 30871                   9.0
# 30872                  12.0
# 30873                  12.0
# 30874                 107.0
# 30875                   NaN
#
#                        URL to Journal in Audit Interface  \
# 0      http://audit.portico.org/stable?cs=ISSN_000399...
# 1                                                    NaN
# 2                                                    NaN
# 3      http://audit.portico.org/stable?cs=ISSN_000292...
# 4      http://audit.portico.org/stable?cs=ISSN_000399...
# ...                                                  ...
# 30871   http://audit.portico.org/stable?cs=ISSN_21511136
# 30872   http://audit.portico.org/stable?cs=ISSN_19373384
# 30873   http://audit.portico.org/stable?cs=ISSN_19373368
# 30874   http://audit.portico.org/stable?cs=ISSN_00071323
# 30875                                                NaN
#
#                           Portico Content Provider  \
# 0      American Medical Association (through 2017)
# 1                                              NaN
# 2                                              NaN
# 3      American Medical Association (through 2017)
# 4      American Medical Association (through 2017)
# ...                                            ...
# 30871                       Mary Ann Liebert, Inc.
# 30872                       Mary Ann Liebert, Inc.
# 30873                       Mary Ann Liebert, Inc.
# 30874                      John Wiley & Sons, Inc.
# 30875                                          NaN
#
#                                         Portico Title ID  Notes  \
# 0          ISSN_00039950 | ISSN_00930326 | ISSN_00966339    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3      ISSN_0002922X | ISSN_00966916 | ISSN_00968994 ...    NaN
# 4      ISSN_00039977 | ISSN_00966894 | ISSN_02760673 ...    NaN
# ...                                                  ...    ...
# 30871                                      ISSN_21511136    NaN
# 30872                                      ISSN_19373384    NaN
# 30873                                      ISSN_19373368    NaN
# 30874                                      ISSN_00071323    NaN
# 30875                                                NaN    NaN
#
#                                        Linking ISSN list
# 0                  [0003-9950 ,  0093-0326 ,  2374-765X]
# 1                                            [0730-188X]
# 2                                            [0272-5533]
# 3      [0002-922X ,  0096-8994 ,  0096-6916 ,  1072-4...
# 4      [2376-3817 ,  0096-6894 ,  0276-0673 ,  1538-3...
# ...                                                  ...
# 30871                                        [2151-1136]
# 30872                                        [1937-3384]
# 30873                                        [1937-3368]
# 30874                                        [1365-2168]
# 30875                                        [2169-1665]
#
# [30876 rows x 30 columns]

# %%
melted_ids = pd.concat([pd.DataFrame(v, index=np.repeat(k,len(v))) for k,v in portico['Linking ISSN list'].to_dict().items()])
melted_ids = melted_ids.rename(columns={0:'Linking ISSN split'})
melted_ids = melted_ids[melted_ids['Linking ISSN split'] != '']
melted_ids
# Out:
#       Linking ISSN split
# 0             0003-9950
# 0             0093-0326
# 0              2374-765X
# 1              0730-188X
# 2              0272-5533
# ...                  ...
# 30871          2151-1136
# 30872          1937-3384
# 30873          1937-3368
# 30874          1365-2168
# 30875          2169-1665
#
# [34863 rows x 1 columns]

# %%
portico_gran = pd.DataFrame()
portico_gran = pd.merge(portico,melted_ids,how="left",left_index=True,right_index=True)
portico_gran
# Out:
#        Library Input Row  Electronic Collection Id  \
# 0                      1         61535209430001701
# 0                      1         61535209430001701
# 0                      1         61535209430001701
# 1                      2         61535209430001701
# 2                      3         61535209430001701
# ...                  ...                       ...
# 30871              30872         61816118310001701
# 30872              30873         61816118310001701
# 30873              30874         61816118310001701
# 30874              30875         61816598280001701
# 30875              30876         61817087960001701
#
#             Electronic Collection Public Name       Portfolio Id  \
# 0      American Medical Association Backfiles  53536123280001701
# 0      American Medical Association Backfiles  53536123280001701
# 0      American Medical Association Backfiles  53536123280001701
# 1      American Medical Association Backfiles  53536407060001701
# 2      American Medical Association Backfiles  53536420410001701
# ...                                       ...                ...
# 30871    Mary Ann Liebert Publishers Journals  53816118240001701
# 30872    Mary Ann Liebert Publishers Journals  53816118260001701
# 30873    Mary Ann Liebert Publishers Journals  53816118280001701
# 30874  Wiley Online Library Surgery Backfiles  53816598250001701
# 30875                   Time Magazine Archive  53817087930001701
#
#       Available For Group Availability      Lifecycle                  ISSN  \
# 0              TwinCities    Available  In Repository  2375-057X; 0093-0326
# 0              TwinCities    Available  In Repository  2375-057X; 0093-0326
# 0              TwinCities    Available  In Repository  2375-057X; 0093-0326
# 1              TwinCities    Available  In Repository             0730-188X
# 2              TwinCities    Available  In Repository  2376-3590; 0272-5533
# ...                   ...          ...            ...                   ...
# 30871          TwinCities    Available  In Repository             2151-1136
# 30872          TwinCities    Available  In Repository  1937-3392; 1937-3384
# 30873          TwinCities    Available  In Repository  1937-3376; 1937-3368
# 30874          TwinCities    Available  In Repository  1365-2168; 0007-1323
# 30875          TwinCities    Available  In Repository  2169-1665; 0040-781X
#
#                  MMS Id Bibliographic Lifecycle  ... Latest Volume Preserved  \
# 0      9966629010001701           In Repository  ...                     115
# 0      9966629010001701           In Repository  ...                     115
# 0      9966629010001701           In Repository  ...                     115
# 1      9966759170001701           In Repository  ...                     NaN
# 2      9966757510001701           In Repository  ...                     NaN
# ...                 ...                     ...  ...                     ...
# 30871  9975418997301701           In Repository  ...                      32
# 30872  9966973510001701           In Repository  ...                      25
# 30873  9966973540001701           In Repository  ...                      25
# 30874  9966956150001701           In Repository  ...                     107
# 30875  9969180100001701           In Repository  ...                     NaN
#
#       Num Preserved Articles Num Preserved Issues Num Preserved Volumes  \
# 0                    29375.0                450.0                  52.0
# 0                    29375.0                450.0                  52.0
# 0                    29375.0                450.0                  52.0
# 1                        NaN                  NaN                   NaN
# 2                        NaN                  NaN                   NaN
# ...                      ...                  ...                   ...
# 30871                  450.0                 52.0                   9.0
# 30872                 1175.0                120.0                  12.0
# 30873                  495.0                 67.0                  12.0
# 30874                35244.0                912.0                 107.0
# 30875                    NaN                  NaN                   NaN
#
#                        URL to Journal in Audit Interface  \
# 0      http://audit.portico.org/stable?cs=ISSN_000399...
# 0      http://audit.portico.org/stable?cs=ISSN_000399...
# 0      http://audit.portico.org/stable?cs=ISSN_000399...
# 1                                                    NaN
# 2                                                    NaN
# ...                                                  ...
# 30871   http://audit.portico.org/stable?cs=ISSN_21511136
# 30872   http://audit.portico.org/stable?cs=ISSN_19373384
# 30873   http://audit.portico.org/stable?cs=ISSN_19373368
# 30874   http://audit.portico.org/stable?cs=ISSN_00071323
# 30875                                                NaN
#
#                           Portico Content Provider  \
# 0      American Medical Association (through 2017)
# 0      American Medical Association (through 2017)
# 0      American Medical Association (through 2017)
# 1                                              NaN
# 2                                              NaN
# ...                                            ...
# 30871                       Mary Ann Liebert, Inc.
# 30872                       Mary Ann Liebert, Inc.
# 30873                       Mary Ann Liebert, Inc.
# 30874                      John Wiley & Sons, Inc.
# 30875                                          NaN
#
#                                     Portico Title ID Notes  \
# 0      ISSN_00039950 | ISSN_00930326 | ISSN_00966339   NaN
# 0      ISSN_00039950 | ISSN_00930326 | ISSN_00966339   NaN
# 0      ISSN_00039950 | ISSN_00930326 | ISSN_00966339   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# ...                                              ...   ...
# 30871                                  ISSN_21511136   NaN
# 30872                                  ISSN_19373384   NaN
# 30873                                  ISSN_19373368   NaN
# 30874                                  ISSN_00071323   NaN
# 30875                                            NaN   NaN
#
#                            Linking ISSN list Linking ISSN split
# 0      [0003-9950 ,  0093-0326 ,  2374-765X]         0003-9950
# 0      [0003-9950 ,  0093-0326 ,  2374-765X]         0093-0326
# 0      [0003-9950 ,  0093-0326 ,  2374-765X]          2374-765X
# 1                                [0730-188X]          0730-188X
# 2                                [0272-5533]          0272-5533
# ...                                      ...                ...
# 30871                            [2151-1136]          2151-1136
# 30872                            [1937-3384]          1937-3384
# 30873                            [1937-3368]          1937-3368
# 30874                            [1365-2168]          1365-2168
# 30875                            [2169-1665]          2169-1665
#
# [34863 rows x 31 columns]

# %% [markdown]
# #### Merge Portico data into df with BTAA data

# %%
portico_gran.columns
# Out:
# Index(['Library Input Row', 'Electronic Collection Id',
#        'Electronic Collection Public Name', 'Portfolio Id',
#        'Available For Group', 'Availability', 'Lifecycle', 'ISSN', 'MMS Id',
#        'Bibliographic Lifecycle', 'Title (Complete)', 'Linking ISSN',
#        'Portico Match', 'Preservation Service', 'Portico Title',
#        'Portico ISSN', 'PCA', 'Status', 'Earliest Year Preserved',
#        'Earliest Volume Preserved', 'Latest Year Preserved',
#        'Latest Volume Preserved', 'Num Preserved Articles',
#        'Num Preserved Issues', 'Num Preserved Volumes',
#        'URL to Journal in Audit Interface', 'Portico Content Provider',
#        'Portico Title ID', 'Notes', 'Linking ISSN list', 'Linking ISSN split'],
#       dtype='object')

# %%
portico_gran = portico_gran[['ISSN','Title (Complete)','Portico Match','Portico Title','PCA',
       'Status', 'Earliest Year Preserved', 'Latest Year Preserved','Linking ISSN list', 'Linking ISSN split']]
portico_gran
# Out:
#                        ISSN                      Title (Complete)  \
# 0      2375-057X; 0093-0326            Archives of ophthalmology.
# 0      2375-057X; 0093-0326            Archives of ophthalmology.
# 0      2375-057X; 0093-0326            Archives of ophthalmology.
# 1                 0730-188X    The archives of internal medicine.
# 2      2376-3590; 0272-5533                  Archives of surgery.
# ...                     ...                                   ...
# 30871             2151-1136                         Videourology.
# 30872  1937-3392; 1937-3384  Tissue engineering. Part C, Methods.
# 30873  1937-3376; 1937-3368  Tissue engineering. Part B, Reviews.
# 30874  1365-2168; 0007-1323           British journal of surgery.
# 30875  2169-1665; 0040-781X                                 Time.
#
#       Portico Match                                      Portico Title  PCA  \
# 0               Yes  Archives of Ophthalmology (1929-1950) | Archiv...   No
# 0               Yes  Archives of Ophthalmology (1929-1950) | Archiv...   No
# 0               Yes  Archives of Ophthalmology (1929-1950) | Archiv...   No
# 1                No                                                NaN  NaN
# 2                No                                                NaN  NaN
# ...             ...                                                ...  ...
# 30871           Yes                                       Videourology  Yes
# 30872           Yes                Tissue Engineering, Part C, Methods  Yes
# 30873           Yes                Tissue Engineering, Part B, Reviews  Yes
# 30874           Yes                         British Journal of Surgery  Yes
# 30875            No                                                NaN  NaN
#
#           Status  Earliest Year Preserved  Latest Year Preserved  \
# 0      Preserved                   1929.0                 1997.0
# 0      Preserved                   1929.0                 1997.0
# 0      Preserved                   1929.0                 1997.0
# 1            NaN                      NaN                    NaN
# 2            NaN                      NaN                    NaN
# ...          ...                      ...                    ...
# 30871  Preserved                   2010.0                 2018.0
# 30872  Preserved                   2008.0                 2019.0
# 30873  Preserved                   2008.0                 2019.0
# 30874  Preserved                   1913.0                 2020.0
# 30875        NaN                      NaN                    NaN
#
#                            Linking ISSN list Linking ISSN split
# 0      [0003-9950 ,  0093-0326 ,  2374-765X]         0003-9950
# 0      [0003-9950 ,  0093-0326 ,  2374-765X]         0093-0326
# 0      [0003-9950 ,  0093-0326 ,  2374-765X]          2374-765X
# 1                                [0730-188X]          0730-188X
# 2                                [0272-5533]          0272-5533
# ...                                      ...                ...
# 30871                            [2151-1136]          2151-1136
# 30872                            [1937-3384]          1937-3384
# 30873                            [1937-3368]          1937-3368
# 30874                            [1365-2168]          1365-2168
# 30875                            [2169-1665]          2169-1665
#
# [34863 rows x 10 columns]

# %%
portico_gran = portico_gran[(portico_gran['Portico Match'] == 'Yes') & (portico_gran['PCA'] == 'Yes') & 
                            (portico_gran['Status'] == 'Preserved')]
portico_gran
# Out:
#                        ISSN                                 Title (Complete)  \
# 30     1553-0795; 0002-9106                     American journal of anatomy.
# 31     1554-527X; 0736-0266                 Journal of orthopaedic research.
# 32     1520-6327; 0739-4462  Archives of insect biochemistry and physiology.
# 33     1097-0029; 1059-910X               Microscopy research and technique.
# 34     1097-4652; 0021-9541                  Journal of cellular physiology.
# ...                     ...                                              ...
# 30870  0893-5068; 0893-5068                               AIDS patient care.
# 30871             2151-1136                                    Videourology.
# 30872  1937-3392; 1937-3384             Tissue engineering. Part C, Methods.
# 30873  1937-3376; 1937-3368             Tissue engineering. Part B, Reviews.
# 30874  1365-2168; 0007-1323                      British journal of surgery.
#
#       Portico Match                                   Portico Title  PCA  \
# 30              Yes                     American Journal of Anatomy  Yes
# 31              Yes                 Journal of Orthopaedic Research  Yes
# 32              Yes  Archives of Insect Biochemistry and Physiology  Yes
# 33              Yes               Microscopy Research and Technique  Yes
# 34              Yes                  Journal of Cellular Physiology  Yes
# ...             ...                                             ...  ...
# 30870           Yes  AIDS Patient Care | AIDS Patient Care and STDs  Yes
# 30871           Yes                                    Videourology  Yes
# 30872           Yes             Tissue Engineering, Part C, Methods  Yes
# 30873           Yes             Tissue Engineering, Part B, Reviews  Yes
# 30874           Yes                      British Journal of Surgery  Yes
#
#           Status  Earliest Year Preserved  Latest Year Preserved  \
# 30     Preserved                   1901.0                 1991.0
# 31     Preserved                   1983.0                 2020.0
# 32     Preserved                   1983.0                 2020.0
# 33     Preserved                   1992.0                 2020.0
# 34     Preserved                   1966.0                 2020.0
# ...          ...                      ...                    ...
# 30870  Preserved                   1987.0                 2019.0
# 30871  Preserved                   2010.0                 2018.0
# 30872  Preserved                   2008.0                 2019.0
# 30873  Preserved                   2008.0                 2019.0
# 30874  Preserved                   1913.0                 2020.0
#
#               Linking ISSN list Linking ISSN split
# 30                  [0002-9106]          0002-9106
# 31                  [1554-527X]          1554-527X
# 32                  [0739-4462]          0739-4462
# 33                  [1097-0029]          1097-0029
# 34                  [0021-9541]          0021-9541
# ...                         ...                ...
# 30870  [2332-4023 ,  1087-2914]          1087-2914
# 30871               [2151-1136]          2151-1136
# 30872               [1937-3384]          1937-3384
# 30873               [1937-3368]          1937-3368
# 30874               [1365-2168]          1365-2168
#
# [26563 rows x 10 columns]

# %%
portico_cols = list(portico_gran.columns)
portico_cols
# Out:
# ['ISSN',
#  'Title (Complete)',
#  'Portico Match',
#  'Portico Title',
#  'PCA',
#  'Status',
#  'Earliest Year Preserved',
#  'Latest Year Preserved',
#  'Linking ISSN list',
#  'Linking ISSN split']

# %%
portico_cols_edit = []
for x in portico_cols:
    portico_cols_edit.append(str(x) + '_PORTICO')
portico_cols_edit
# Out:
# ['ISSN_PORTICO',
#  'Title (Complete)_PORTICO',
#  'Portico Match_PORTICO',
#  'Portico Title_PORTICO',
#  'PCA_PORTICO',
#  'Status_PORTICO',
#  'Earliest Year Preserved_PORTICO',
#  'Latest Year Preserved_PORTICO',
#  'Linking ISSN list_PORTICO',
#  'Linking ISSN split_PORTICO']

# %%
portico_dict = dict(zip(portico_cols, portico_cols_edit))
portico_dict
# Out:
# {'ISSN': 'ISSN_PORTICO',
#  'Title (Complete)': 'Title (Complete)_PORTICO',
#  'Portico Match': 'Portico Match_PORTICO',
#  'Portico Title': 'Portico Title_PORTICO',
#  'PCA': 'PCA_PORTICO',
#  'Status': 'Status_PORTICO',
#  'Earliest Year Preserved': 'Earliest Year Preserved_PORTICO',
#  'Latest Year Preserved': 'Latest Year Preserved_PORTICO',
#  'Linking ISSN list': 'Linking ISSN list_PORTICO',
#  'Linking ISSN split': 'Linking ISSN split_PORTICO'}

# %%
portico_gran.rename(index=str, columns = portico_dict, inplace=True)
portico_gran
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#                ISSN_PORTICO                         Title (Complete)_PORTICO  \
# 30     1553-0795; 0002-9106                     American journal of anatomy.
# 31     1554-527X; 0736-0266                 Journal of orthopaedic research.
# 32     1520-6327; 0739-4462  Archives of insect biochemistry and physiology.
# 33     1097-0029; 1059-910X               Microscopy research and technique.
# 34     1097-4652; 0021-9541                  Journal of cellular physiology.
# ...                     ...                                              ...
# 30870  0893-5068; 0893-5068                               AIDS patient care.
# 30871             2151-1136                                    Videourology.
# 30872  1937-3392; 1937-3384             Tissue engineering. Part C, Methods.
# 30873  1937-3376; 1937-3368             Tissue engineering. Part B, Reviews.
# 30874  1365-2168; 0007-1323                      British journal of surgery.
#
#       Portico Match_PORTICO                           Portico Title_PORTICO  \
# 30                      Yes                     American Journal of Anatomy
# 31                      Yes                 Journal of Orthopaedic Research
# 32                      Yes  Archives of Insect Biochemistry and Physiology
# 33                      Yes               Microscopy Research and Technique
# 34                      Yes                  Journal of Cellular Physiology
# ...                     ...                                             ...
# 30870                   Yes  AIDS Patient Care | AIDS Patient Care and STDs
# 30871                   Yes                                    Videourology
# 30872                   Yes             Tissue Engineering, Part C, Methods
# 30873                   Yes             Tissue Engineering, Part B, Reviews
# 30874                   Yes                      British Journal of Surgery
#
#       PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 30            Yes      Preserved                           1901.0
# 31            Yes      Preserved                           1983.0
# 32            Yes      Preserved                           1983.0
# 33            Yes      Preserved                           1992.0
# 34            Yes      Preserved                           1966.0
# ...           ...            ...                              ...
# 30870         Yes      Preserved                           1987.0
# 30871         Yes      Preserved                           2010.0
# 30872         Yes      Preserved                           2008.0
# 30873         Yes      Preserved                           2008.0
# 30874         Yes      Preserved                           1913.0
#
#        Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 30                            1991.0               [0002-9106]
# 31                            2020.0               [1554-527X]
# 32                            2020.0               [0739-4462]
# 33                            2020.0               [1097-0029]
# 34                            2020.0               [0021-9541]
# ...                              ...                       ...
# 30870                         2019.0  [2332-4023 ,  1087-2914]
# 30871                         2018.0               [2151-1136]
# 30872                         2019.0               [1937-3384]
# 30873                         2019.0               [1937-3368]
# 30874                         2020.0               [1365-2168]
#
#       Linking ISSN split_PORTICO
# 30                     0002-9106
# 31                     1554-527X
# 32                     0739-4462
# 33                     1097-0029
# 34                     0021-9541
# ...                          ...
# 30870                  1087-2914
# 30871                  2151-1136
# 30872                  1937-3384
# 30873                  1937-3368
# 30874                  1365-2168
#
# [26563 rows x 10 columns]

# %%
df_pcad_btaa_portico = pd.merge(df_pcad_btaa,portico_gran,how='left',left_on='ISSN_to_match',right_on='ISSN_PORTICO')
df_pcad_btaa_portico
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 4            112352  9967759560001701
# ...             ...               ...
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
# 16161        114862  9977101571201701
# 16162         14688  9933514930001701
#
#                                              Title_bib       ISSN_bib  \
# 0                   The Wilson journal of ornithology.  ['1559-4491']
# 1                    The Wilson journal of ornithology  ['1938-5447']
# 2         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 4           Journal of the University Film Association  ['2328-1944']
# ...                                                ...            ...
# 16158                                Americas (Online)           ['']
# 16159  International journal of adhesion and adhesives  ['0143-7496']
# 16160  International journal of adhesion and adhesives  ['1879-0127']
# 16161                                 Oriental insects  ['2157-8745']
# 16162                                 Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                           ...    ...               ...           ...
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 16161  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 16162               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
# 16161  [['61808506700001701', 'Taylor & Francis Biolo...
# 16162                                                NaN
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 0                                                    NaN  ...          NaN
# 1      [['53588425000001701', 'The Wilson journal of ...  ...          NaN
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 4      [['53538633520001701', 'Journal of the Univers...  ...          NaN
# ...                                                  ...  ...          ...
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
# 16161  [['53815442430001701', 'Oriental insects'], ['...  ...          NaN
# 16162                                                NaN  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
# 16161                      NaN                   NaN                   NaN
# 16162                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0             NaN            NaN                             NaN
# 1             NaN            NaN                             NaN
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 4             NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
# 16161         NaN            NaN                             NaN
# 16162         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ...                             ...                       ...
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
# 16161                           NaN                       NaN
# 16162                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
# 16161                        NaN
# 16162                        NaN
#
# [16163 rows x 34 columns]

# %%
df_pcad_btaa_portico.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib', 'ISSN_cluster',
#        'p_or_e', 'matches_group_id', 'ISSN_to_match', 'e_coll_info',
#        'portfolio_info', 'Coverage Information Combined', 'PCAD?',
#        'Vendor_key', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
#        'Publisher (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Publisher (Print).1_BTAA-SPR', 'Title 3 (Print)_BTAA-SPR',
#        'Publisher (Print).2_BTAA-SPR', '(more bib records?)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'SPR Missing_BTAA-SPR',
#        'ISSN_PORTICO', 'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'Linking ISSN list_PORTICO', 'Linking ISSN split_PORTICO'],
#       dtype='object')

# %%
df_pcad_btaa_portico.drop_duplicates(subset=['record_index', 'MMS_ID', 'Title_bib', 
       'p_or_e', 'matches_group_id', 'ISSN_to_match', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
                                             'Title 2 (Print)_BTAA-SPR','Title 3 (Print)_BTAA-SPR',
       'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
       'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
       'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
       'Linking ISSN split_PORTICO'], inplace=True)
df_pcad_btaa_portico
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 4            112352  9967759560001701
# ...             ...               ...
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
# 16161        114862  9977101571201701
# 16162         14688  9933514930001701
#
#                                              Title_bib       ISSN_bib  \
# 0                   The Wilson journal of ornithology.  ['1559-4491']
# 1                    The Wilson journal of ornithology  ['1938-5447']
# 2         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 4           Journal of the University Film Association  ['2328-1944']
# ...                                                ...            ...
# 16158                                Americas (Online)           ['']
# 16159  International journal of adhesion and adhesives  ['0143-7496']
# 16160  International journal of adhesion and adhesives  ['1879-0127']
# 16161                                 Oriental insects  ['2157-8745']
# 16162                                 Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                           ...    ...               ...           ...
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 16161  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 16162               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
# 16161  [['61808506700001701', 'Taylor & Francis Biolo...
# 16162                                                NaN
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 0                                                    NaN  ...          NaN
# 1      [['53588425000001701', 'The Wilson journal of ...  ...          NaN
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 4      [['53538633520001701', 'Journal of the Univers...  ...          NaN
# ...                                                  ...  ...          ...
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
# 16161  [['53815442430001701', 'Oriental insects'], ['...  ...          NaN
# 16162                                                NaN  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
# 16161                      NaN                   NaN                   NaN
# 16162                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0             NaN            NaN                             NaN
# 1             NaN            NaN                             NaN
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 4             NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
# 16161         NaN            NaN                             NaN
# 16162         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ...                             ...                       ...
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
# 16161                           NaN                       NaN
# 16162                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
# 16161                        NaN
# 16162                        NaN
#
# [15900 rows x 34 columns]

# %%
df_pcad_btaa_portico[df_pcad_btaa_portico.duplicated(['MMS_ID'], keep=False) == True].sort_values(['MMS_ID'])
df_pcad_btaa_portico
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 4            112352  9967759560001701
# ...             ...               ...
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
# 16161        114862  9977101571201701
# 16162         14688  9933514930001701
#
#                                              Title_bib       ISSN_bib  \
# 0                   The Wilson journal of ornithology.  ['1559-4491']
# 1                    The Wilson journal of ornithology  ['1938-5447']
# 2         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 4           Journal of the University Film Association  ['2328-1944']
# ...                                                ...            ...
# 16158                                Americas (Online)           ['']
# 16159  International journal of adhesion and adhesives  ['0143-7496']
# 16160  International journal of adhesion and adhesives  ['1879-0127']
# 16161                                 Oriental insects  ['2157-8745']
# 16162                                 Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                           ...    ...               ...           ...
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 16161  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 16162               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
# 16161  [['61808506700001701', 'Taylor & Francis Biolo...
# 16162                                                NaN
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 0                                                    NaN  ...          NaN
# 1      [['53588425000001701', 'The Wilson journal of ...  ...          NaN
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 4      [['53538633520001701', 'Journal of the Univers...  ...          NaN
# ...                                                  ...  ...          ...
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
# 16161  [['53815442430001701', 'Oriental insects'], ['...  ...          NaN
# 16162                                                NaN  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
# 16161                      NaN                   NaN                   NaN
# 16162                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0             NaN            NaN                             NaN
# 1             NaN            NaN                             NaN
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 4             NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
# 16161         NaN            NaN                             NaN
# 16162         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ...                             ...                       ...
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
# 16161                           NaN                       NaN
# 16162                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
# 16161                        NaN
# 16162                        NaN
#
# [15900 rows x 34 columns]

# %%
df_pcad_btaa_portico.to_pickle(f'df_pcad_repos_{today}.pkl')

# %%
df_pcad_btaa_portico.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib', 'ISSN_cluster',
#        'p_or_e', 'matches_group_id', 'ISSN_to_match', 'e_coll_info',
#        'portfolio_info', 'Coverage Information Combined', 'PCAD?',
#        'Vendor_key', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
#        'Publisher (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Publisher (Print).1_BTAA-SPR', 'Title 3 (Print)_BTAA-SPR',
#        'Publisher (Print).2_BTAA-SPR', '(more bib records?)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'SPR Missing_BTAA-SPR',
#        'ISSN_PORTICO', 'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'Linking ISSN list_PORTICO', 'Linking ISSN split_PORTICO'],
#       dtype='object')

# %%
df_pcad_btaa_portico[['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib', 'ISSN_cluster',
       'p_or_e', 'matches_group_id', 'ISSN_to_match', 'e_coll_info',
       'portfolio_info', 'Coverage Information Combined', 'PCAD?',
       'Vendor_key', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
       'Title 2 (Print)_BTAA-SPR','Title 3 (Print)_BTAA-SPR',
       'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR',
       'ISSN_PORTICO', 'Title (Complete)_PORTICO',
       'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
       'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
       'Latest Year Preserved_PORTICO']]
df_pcad_btaa_portico
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 4            112352  9967759560001701
# ...             ...               ...
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
# 16161        114862  9977101571201701
# 16162         14688  9933514930001701
#
#                                              Title_bib       ISSN_bib  \
# 0                   The Wilson journal of ornithology.  ['1559-4491']
# 1                    The Wilson journal of ornithology  ['1938-5447']
# 2         IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3         IEEE transactions on ultrasonics engineering  ['2162-1373']
# 4           Journal of the University Film Association  ['2328-1944']
# ...                                                ...            ...
# 16158                                Americas (Online)           ['']
# 16159  International journal of adhesion and adhesives  ['0143-7496']
# 16160  International journal of adhesion and adhesives  ['1879-0127']
# 16161                                 Oriental insects  ['2157-8745']
# 16162                                 Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# ...                           ...    ...               ...           ...
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
# 16161  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 16162               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
# 16161  [['61808506700001701', 'Taylor & Francis Biolo...
# 16162                                                NaN
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 0                                                    NaN  ...          NaN
# 1      [['53588425000001701', 'The Wilson journal of ...  ...          NaN
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 4      [['53538633520001701', 'Journal of the Univers...  ...          NaN
# ...                                                  ...  ...          ...
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
# 16161  [['53815442430001701', 'Oriental insects'], ['...  ...          NaN
# 16162                                                NaN  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
# 16161                      NaN                   NaN                   NaN
# 16162                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0             NaN            NaN                             NaN
# 1             NaN            NaN                             NaN
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 4             NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
# 16161         NaN            NaN                             NaN
# 16162         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ...                             ...                       ...
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
# 16161                           NaN                       NaN
# 16162                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
# 16161                        NaN
# 16162                        NaN
#
# [15900 rows x 34 columns]

# %% [markdown]
# #### Determine PCAD groups with repository coverage

# %%
df = df_pcad_btaa_portico

# %%
df.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib', 'ISSN_cluster',
#        'p_or_e', 'matches_group_id', 'ISSN_to_match', 'e_coll_info',
#        'portfolio_info', 'Coverage Information Combined', 'PCAD?',
#        'Vendor_key', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
#        'Publisher (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Publisher (Print).1_BTAA-SPR', 'Title 3 (Print)_BTAA-SPR',
#        'Publisher (Print).2_BTAA-SPR', '(more bib records?)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'SPR Missing_BTAA-SPR',
#        'ISSN_PORTICO', 'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'Linking ISSN list_PORTICO', 'Linking ISSN split_PORTICO'],
#       dtype='object')

# %%
has_preservation = df[(df['Earliest Year Preserved_PORTICO'].notnull()) | df['SPR Holdings_BTAA-SPR'].notnull()]
has_preservation
# Out:
#        record_index            MMS_ID  \
# 2             57684  9963550760001701
# 7             88618  9939481760001701
# 16            25439  9963082590001701
# 29            78022  9964617400001701
# 32            62770  9942472340001701
# ...             ...               ...
# 16146         91677  9953205880001701
# 16149         18706  9950698160001701
# 16150         26122  9914298940001701
# 16156         17960  9946768760001701
# 16159         31683  9957960200001701
#
#                                                Title_bib       ISSN_bib  \
# 2           IEEE transactions on ultrasonics engineering  ['0893-6706']
# 7                  Journal of the Institute of Actuaries  ['0020-2681']
# 16        Giornale degli economisti e annali di economia  ['0017-0097']
# 29                    Mathematics of the USSR. Izvestija  ['0025-5726']
# 32     Laboratory techniques in biochemistry and mole...  ['0075-7535']
# ...                                                  ...            ...
# 16146                         Physics letters. Section B  ['0370-2693']
# 16149  Proceedings and addresses of the American Phil...  ['0065-972X']
# 16150  Proceedings of the American Philosophical Society  ['0003-049X']
# 16156                                       The Americas  ['0003-1615']
# 16159    International journal of adhesion and adhesives  ['0143-7496']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 2                   ['0893-6706']      p                 5     0893-6706
# 7                   ['0020-2681']      p                12     0020-2681
# 16                  ['0017-0097']      p                92     0017-0097
# 29                  ['0025-5726']      p               267     0025-5726
# 32                  ['0075-7535']      p               277     0075-7535
# ...                           ...    ...               ...           ...
# 16146  ['0031-9163', '0370-2693']      p            101461     0370-2693
# 16149  ['0065-972X', '0003-049X']      p            101522     0065-972X
# 16150               ['0003-049X']      p            101522     0003-049X
# 16156  ['1533-6247', '0003-1615']      p            101581     0003-1615
# 16159               ['0143-7496']      p            101582     0143-7496
#
#       e_coll_info portfolio_info  ... ISSN_PORTICO  \
# 2             NaN            NaN  ...          NaN
# 7             NaN            NaN  ...          NaN
# 16            NaN            NaN  ...          NaN
# 29            NaN            NaN  ...          NaN
# 32            NaN            NaN  ...    0075-7535
# ...           ...            ...  ...          ...
# 16146         NaN            NaN  ...          NaN
# 16149         NaN            NaN  ...          NaN
# 16150         NaN            NaN  ...          NaN
# 16156         NaN            NaN  ...          NaN
# 16159         NaN            NaN  ...          NaN
#
#                                 Title (Complete)_PORTICO  \
# 2                                                    NaN
# 7                                                    NaN
# 16                                                   NaN
# 29                                                   NaN
# 32     Laboratory techniques in biochemistry and mole...
# ...                                                  ...
# 16146                                                NaN
# 16149                                                NaN
# 16150                                                NaN
# 16156                                                NaN
# 16159                                                NaN
#
#       Portico Match_PORTICO  \
# 2                       NaN
# 7                       NaN
# 16                      NaN
# 29                      NaN
# 32                      Yes
# ...                     ...
# 16146                   NaN
# 16149                   NaN
# 16150                   NaN
# 16156                   NaN
# 16159                   NaN
#
#                                    Portico Title_PORTICO PCA_PORTICO  \
# 2                                                    NaN         NaN
# 7                                                    NaN         NaN
# 16                                                   NaN         NaN
# 29                                                   NaN         NaN
# 32     Laboratory Techniques in Biochemistry and Mole...         Yes
# ...                                                  ...         ...
# 16146                                                NaN         NaN
# 16149                                                NaN         NaN
# 16150                                                NaN         NaN
# 16156                                                NaN         NaN
# 16159                                                NaN         NaN
#
#       Status_PORTICO Earliest Year Preserved_PORTICO  \
# 2                NaN                             NaN
# 7                NaN                             NaN
# 16               NaN                             NaN
# 29               NaN                             NaN
# 32         Preserved                             NaN
# ...              ...                             ...
# 16146            NaN                             NaN
# 16149            NaN                             NaN
# 16150            NaN                             NaN
# 16156            NaN                             NaN
# 16159            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 2                               NaN                       NaN
# 7                               NaN                       NaN
# 16                              NaN                       NaN
# 29                              NaN                       NaN
# 32                              NaN               [2589-2789]
# ...                             ...                       ...
# 16146                           NaN                       NaN
# 16149                           NaN                       NaN
# 16150                           NaN                       NaN
# 16156                           NaN                       NaN
# 16159                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 2                            NaN
# 7                            NaN
# 16                           NaN
# 29                           NaN
# 32                     2589-2789
# ...                          ...
# 16146                        NaN
# 16149                        NaN
# 16150                        NaN
# 16156                        NaN
# 16159                        NaN
#
# [4481 rows x 34 columns]

# %%
p_pres_groups = has_preservation['matches_group_id'].unique().tolist()
p_pres_groups
# Out:
# [5,
#  12,
#  92,
#  267,
#  277,
#  513,
#  537,
#  686,
#  707,
#  739,
#  744,
#  895,
#  914,
#  1001,
#  1066,
#  1087,
#  1208,
#  1345,
#  1527,
#  1606,
#  1725,
#  1745,
#  1809,
#  1857,
#  2059,
#  2065,
#  2067,
#  2078,
#  2364,
#  2435,
#  2492,
#  2529,
#  2537,
#  2557,
#  2571,
#  2592,
#  2603,
#  2604,
#  2725,
#  2734,
#  2961,
#  2993,
#  3023,
#  3399,
#  3434,
#  3475,
#  3489,
#  3544,
#  3573,
#  3682,
#  3702,
#  3724,
#  3740,
#  3794,
#  3861,
#  3960,
#  4013,
#  4058,
#  4105,
#  4188,
#  4237,
#  4258,
#  4265,
#  4273,
#  4300,
#  4321,
#  4338,
#  4344,
#  4361,
#  4368,
#  4376,
#  4380,
#  4381,
#  4393,
#  4401,
#  4422,
#  4508,
#  4511,
#  4542,
#  4588,
#  4618,
#  4690,
#  4851,
#  4904,
#  4909,
#  4954,
#  4961,
#  5058,
#  5087,
#  5088,
#  5093,
#  5110,
#  5186,
#  5225,
#  5371,
#  5420,
#  5433,
#  5600,
#  5660,
#  5665,
#  5700,
#  5712,
#  5714,
#  5857,
#  6100,
#  6126,
#  6195,
#  6213,
#  6294,
#  6311,
#  6326,
#  6346,
#  6352,
#  6367,
#  6419,
#  6426,
#  6429,
#  6433,
#  6434,
#  6475,
#  6476,
#  6596,
#  6619,
#  6637,
#  6687,
#  6728,
#  6797,
#  6825,
#  6841,
#  6851,
#  6894,
#  6935,
#  6959,
#  7012,
#  7120,
#  7141,
#  7152,
#  7242,
#  7254,
#  7257,
#  7339,
#  7340,
#  7341,
#  7356,
#  7520,
#  7618,
#  7636,
#  7687,
#  7701,
#  7721,
#  7768,
#  7786,
#  7808,
#  7869,
#  7907,
#  7962,
#  8061,
#  8085,
#  8090,
#  8109,
#  8110,
#  8255,
#  8263,
#  8361,
#  8371,
#  8409,
#  8412,
#  8445,
#  8492,
#  8551,
#  8577,
#  8600,
#  8614,
#  8677,
#  8693,
#  8712,
#  8773,
#  8786,
#  8797,
#  8800,
#  8812,
#  8874,
#  9074,
#  9075,
#  9167,
#  9171,
#  9175,
#  9192,
#  9193,
#  9194,
#  9237,
#  9255,
#  9291,
#  9310,
#  9314,
#  9393,
#  9402,
#  9405,
#  9411,
#  9423,
#  9446,
#  9447,
#  9488,
#  9581,
#  9603,
#  9614,
#  9642,
#  9651,
#  9698,
#  9726,
#  9782,
#  9910,
#  9930,
#  9933,
#  9956,
#  9964,
#  10106,
#  10124,
#  10155,
#  10174,
#  10201,
#  10203,
#  10204,
#  10207,
#  10214,
#  10263,
#  10272,
#  10281,
#  10313,
#  10328,
#  10384,
#  10431,
#  10445,
#  10488,
#  10491,
#  10495,
#  10590,
#  10595,
#  10596,
#  10610,
#  10630,
#  10638,
#  10654,
#  10662,
#  10667,
#  10681,
#  10693,
#  10727,
#  10731,
#  10751,
#  10880,
#  10889,
#  10892,
#  10906,
#  10966,
#  10981,
#  11002,
#  11093,
#  11102,
#  11125,
#  11164,
#  11185,
#  11222,
#  11225,
#  11252,
#  11264,
#  11267,
#  11282,
#  11287,
#  11289,
#  11347,
#  11362,
#  11367,
#  11369,
#  11371,
#  11373,
#  11376,
#  11384,
#  11394,
#  11395,
#  11420,
#  11421,
#  11429,
#  11468,
#  11475,
#  11480,
#  11497,
#  11510,
#  11550,
#  11566,
#  11575,
#  11592,
#  11593,
#  11612,
#  11643,
#  11653,
#  11655,
#  11689,
#  11731,
#  11753,
#  11778,
#  11817,
#  11827,
#  11872,
#  11978,
#  12007,
#  12024,
#  12029,
#  12086,
#  12091,
#  12098,
#  12114,
#  12123,
#  12129,
#  12158,
#  12206,
#  12227,
#  12256,
#  12258,
#  12279,
#  12285,
#  12362,
#  12375,
#  12450,
#  12484,
#  12512,
#  12578,
#  12593,
#  12673,
#  12747,
#  12759,
#  12781,
#  12822,
#  12828,
#  12832,
#  12836,
#  12841,
#  12847,
#  12860,
#  12866,
#  12871,
#  12878,
#  12909,
#  12930,
#  12951,
#  12953,
#  12970,
#  12972,
#  13001,
#  13035,
#  13078,
#  13083,
#  13104,
#  13151,
#  13177,
#  13204,
#  13221,
#  13243,
#  13256,
#  13277,
#  13327,
#  13353,
#  13382,
#  13384,
#  13424,
#  13425,
#  13439,
#  13470,
#  13490,
#  13502,
#  13555,
#  13570,
#  13596,
#  13612,
#  13641,
#  13648,
#  13654,
#  13677,
#  13718,
#  13737,
#  13744,
#  13746,
#  13795,
#  13803,
#  13819,
#  13864,
#  13878,
#  13881,
#  13885,
#  13919,
#  13920,
#  13935,
#  13939,
#  14016,
#  14023,
#  14028,
#  14035,
#  14053,
#  14055,
#  14060,
#  14079,
#  14097,
#  14106,
#  14126,
#  14166,
#  14175,
#  14200,
#  14269,
#  14316,
#  14337,
#  14374,
#  14378,
#  14403,
#  14433,
#  14436,
#  14437,
#  14441,
#  14471,
#  14475,
#  14483,
#  14485,
#  14503,
#  14513,
#  14531,
#  14537,
#  14538,
#  14540,
#  14545,
#  14551,
#  14556,
#  14558,
#  14566,
#  14569,
#  14575,
#  14578,
#  14580,
#  14581,
#  14583,
#  14598,
#  14602,
#  14620,
#  14629,
#  14631,
#  14632,
#  14636,
#  14660,
#  14662,
#  14666,
#  14713,
#  14756,
#  14781,
#  14796,
#  14801,
#  14803,
#  14829,
#  14851,
#  14858,
#  14871,
#  14901,
#  14955,
#  14966,
#  15004,
#  15022,
#  15039,
#  15041,
#  15145,
#  15244,
#  15246,
#  15248,
#  15283,
#  15303,
#  15306,
#  15335,
#  15342,
#  15395,
#  15411,
#  15419,
#  15466,
#  15479,
#  15575,
#  15591,
#  15596,
#  15641,
#  15643,
#  15646,
#  15659,
#  15787,
#  15790,
#  15805,
#  15817,
#  15820,
#  15821,
#  15848,
#  15867,
#  15882,
#  15910,
#  15912,
#  15921,
#  15922,
#  15966,
#  15986,
#  16032,
#  16061,
#  16071,
#  16100,
#  16165,
#  16186,
#  16350,
#  16352,
#  16360,
#  16393,
#  16431,
#  16501,
#  16515,
#  16540,
#  16681,
#  16682,
#  16742,
#  16751,
#  16801,
#  16838,
#  16915,
#  16938,
#  16947,
#  16958,
#  16969,
#  16972,
#  16978,
#  16987,
#  17003,
#  17033,
#  17036,
#  17043,
#  17053,
#  17072,
#  17083,
#  17088,
#  17103,
#  17120,
#  17169,
#  17170,
#  17178,
#  17183,
#  17210,
#  17213,
#  17224,
#  17229,
#  17232,
#  17234,
#  17237,
#  17250,
#  17269,
#  17275,
#  17300,
#  17305,
#  17309,
#  17376,
#  17377,
#  17395,
#  17407,
#  17433,
#  17438,
#  17445,
#  17547,
#  17598,
#  17610,
#  17621,
#  17637,
#  17641,
#  17643,
#  17721,
#  17723,
#  17730,
#  17747,
#  17772,
#  17812,
#  17831,
#  17896,
#  17927,
#  17951,
#  18121,
#  18125,
#  18139,
#  18140,
#  18150,
#  18159,
#  18171,
#  18186,
#  18224,
#  18240,
#  18262,
#  18394,
#  18454,
#  18469,
#  18470,
#  18522,
#  18579,
#  18592,
#  18621,
#  18625,
#  18630,
#  18657,
#  18705,
#  18712,
#  18718,
#  18719,
#  18737,
#  18743,
#  18762,
#  18809,
#  18896,
#  18907,
#  18980,
#  18987,
#  18994,
#  19014,
#  19042,
#  19056,
#  19079,
#  19085,
#  19088,
#  19097,
#  19105,
#  19112,
#  19119,
#  19138,
#  19228,
#  19233,
#  19242,
#  19253,
#  19262,
#  19263,
#  19278,
#  19297,
#  19310,
#  19312,
#  19385,
#  19571,
#  19619,
#  19706,
#  19709,
#  19739,
#  19747,
#  19789,
#  19803,
#  19840,
#  19885,
#  19936,
#  19964,
#  19992,
#  19993,
#  20015,
#  20036,
#  20040,
#  20200,
#  20232,
#  20295,
#  20365,
#  20375,
#  20404,
#  20477,
#  20530,
#  20532,
#  20548,
#  20617,
#  20623,
#  20631,
#  20641,
#  20700,
#  20713,
#  20757,
#  20818,
#  20839,
#  20907,
#  21003,
#  21015,
#  21038,
#  21056,
#  21072,
#  21082,
#  21119,
#  21141,
#  21164,
#  21171,
#  21235,
#  21246,
#  21279,
#  21289,
#  21302,
#  21325,
#  21358,
#  21378,
#  21476,
#  21497,
#  21512,
#  21545,
#  21561,
#  21640,
#  21641,
#  21646,
#  21660,
#  21692,
#  21814,
#  21946,
#  21983,
#  21993,
#  22059,
#  22060,
#  22133,
#  22191,
#  22202,
#  22234,
#  22256,
#  22262,
#  22264,
#  22276,
#  22282,
#  22284,
#  22338,
#  22385,
#  22393,
#  22518,
#  22534,
#  22554,
#  22594,
#  22635,
#  22639,
#  22668,
#  22729,
#  22765,
#  22788,
#  22817,
#  22844,
#  22855,
#  22869,
#  22870,
#  22906,
#  22980,
#  22982,
#  23085,
#  23100,
#  23143,
#  23307,
#  23358,
#  23450,
#  23596,
#  23598,
#  23603,
#  23604,
#  23672,
#  23720,
#  23732,
#  23758,
#  23778,
#  23816,
#  24120,
#  24217,
#  24219,
#  24240,
#  24250,
#  24429,
#  24435,
#  24440,
#  24441,
#  24452,
#  24488,
#  24500,
#  24506,
#  24513,
#  24611,
#  24645,
#  24739,
#  24780,
#  24823,
#  24959,
#  24971,
#  25028,
#  25039,
#  25040,
#  25041,
#  25042,
#  25044,
#  25088,
#  25238,
#  25243,
#  25291,
#  25304,
#  25366,
#  25394,
#  25442,
#  25544,
#  25569,
#  25605,
#  25630,
#  25633,
#  25637,
#  25673,
#  25783,
#  25803,
#  25822,
#  25854,
#  25858,
#  25969,
#  26055,
#  26066,
#  26086,
#  26088,
#  26181,
#  26212,
#  26242,
#  26282,
#  26306,
#  26310,
#  26337,
#  26385,
#  26403,
#  26428,
#  26471,
#  26513,
#  26535,
#  26540,
#  26554,
#  26586,
#  26603,
#  26614,
#  26706,
#  26739,
#  26760,
#  26910,
#  26919,
#  26939,
#  26948,
#  26972,
#  27054,
#  27058,
#  27069,
#  27107,
#  27110,
#  27125,
#  27255,
#  27379,
#  27383,
#  27395,
#  27397,
#  27519,
#  27546,
#  27560,
#  27606,
#  27644,
#  27657,
#  27679,
#  27738,
#  27750,
#  27778,
#  27780,
#  27796,
#  27882,
#  27888,
#  27898,
#  28003,
#  28004,
#  28024,
#  28038,
#  28101,
#  28119,
#  28147,
#  28150,
#  28194,
#  28204,
#  28241,
#  28257,
#  28269,
#  28300,
#  28302,
#  28317,
#  28372,
#  28387,
#  28431,
#  28451,
#  28464,
#  28469,
#  28557,
#  28559,
#  28561,
#  28620,
#  28630,
#  28656,
#  28665,
#  28676,
#  28701,
#  28717,
#  28769,
#  28783,
#  28842,
#  28865,
#  29022,
#  29065,
#  29096,
#  29098,
#  29099,
#  29115,
#  29263,
#  29267,
#  29307,
#  29330,
#  29342,
#  29365,
#  29372,
#  29376,
#  29469,
#  29563,
#  29570,
#  29572,
#  29603,
#  29612,
#  29616,
#  29628,
#  29649,
#  29659,
#  29687,
#  29699,
#  29720,
#  29745,
#  29756,
#  29762,
#  29791,
#  29800,
#  29815,
#  29828,
#  29867,
#  29874,
#  29902,
#  29972,
#  30056,
#  30151,
#  30191,
#  30207,
#  30219,
#  30229,
#  30255,
#  30285,
#  30290,
#  30314,
#  30361,
#  30367,
#  30377,
#  30383,
#  30386,
#  30463,
#  30488,
#  30508,
#  30576,
#  30592,
#  30602,
#  30618,
#  30635,
#  30658,
#  30659,
#  30661,
#  30662,
#  30665,
#  30687,
#  30731,
#  30735,
#  30770,
#  30803,
#  30811,
#  30827,
#  30853,
#  30862,
#  30871,
#  30893,
#  30967,
#  30968,
#  31007,
#  31009,
#  31027,
#  31040,
#  31061,
#  31117,
#  31122,
#  31123,
#  31186,
#  31335,
#  31338,
#  31450,
#  31575,
#  31583,
#  31657,
#  31698,
#  31745,
#  31784,
#  31809,
#  31843,
#  31861,
#  31870,
#  31931,
#  31951,
#  31978,
#  31998,
#  ...]

# %%
len(p_pres_groups)
# Out:
# 3543

# %%
p_pres_groups_df = df[df['matches_group_id'].isin(p_pres_groups)]
p_pres_groups_df
# Out:
#        record_index            MMS_ID  \
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 7             88618  9939481760001701
# 8            111951  9968429800001701
# 15           123907  9967115530001701
# ...             ...               ...
# 16156         17960  9946768760001701
# 16157        117510  9967987860001701
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
#
#                                                Title_bib       ISSN_bib  \
# 2           IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3           IEEE transactions on ultrasonics engineering  ['2162-1373']
# 7                  Journal of the Institute of Actuaries  ['0020-2681']
# 8                  Journal of the Institute of Actuaries  ['2058-1009']
# 15        Giornale degli economisti e annali di economia           ['']
# ...                                                  ...            ...
# 16156                                       The Americas  ['0003-1615']
# 16157  The Americas - Academy of American Franciscan ...  ['1533-6247']
# 16158                                  Americas (Online)           ['']
# 16159    International journal of adhesion and adhesives  ['0143-7496']
# 16160    International journal of adhesion and adhesives  ['1879-0127']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 7                   ['0020-2681']      p                12     0020-2681
# 8      ['0020-2681', '2058-1009']      e                12     2058-1009
# 15                  ['0017-0097']      e                92
# ...                           ...    ...               ...           ...
# 16156  ['1533-6247', '0003-1615']      p            101581     0003-1615
# 16157  ['1533-6247', '0003-1615']      e            101581     1533-6247
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
#
#                                              e_coll_info  \
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 7                                                    NaN
# 8      [['61535216140001701', 'JSTOR Business III Col...
# 15     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16156                                                NaN
# 16157  [['61535211010001701', 'JSTOR Arts and Science...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 7                                                    NaN  ...          NaN
# 8      [['53540140170001701', 'Journal of the Institu...  ...          NaN
# 15     [['53537228640001701', 'Giornale degli economi...  ...          NaN
# ...                                                  ...  ...          ...
# 16156                                                NaN  ...          NaN
# 16157           [['53539160390001701', 'The Americas.']]  ...          NaN
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 7                          NaN                   NaN                   NaN
# 8                          NaN                   NaN                   NaN
# 15                         NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16156                      NaN                   NaN                   NaN
# 16157                      NaN                   NaN                   NaN
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 7             NaN            NaN                             NaN
# 8             NaN            NaN                             NaN
# 15            NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16156         NaN            NaN                             NaN
# 16157         NaN            NaN                             NaN
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 15                              NaN                       NaN
# ...                             ...                       ...
# 16156                           NaN                       NaN
# 16157                           NaN                       NaN
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 2                            NaN
# 3                            NaN
# 7                            NaN
# 8                            NaN
# 15                           NaN
# ...                          ...
# 16156                        NaN
# 16157                        NaN
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
#
# [8872 rows x 34 columns]

# %%
no_repo_p_pres_groups_df = df[~df['matches_group_id'].isin(p_pres_groups)]
no_repo_p_pres_groups_df
# Out:
#        record_index            MMS_ID  \
# 0             69875  9939153590001701
# 1            113344  9968879310001701
# 4            112352  9967759560001701
# 5            107439  9967145520001701
# 6             78492  9933370000001701
# ...             ...               ...
# 16140         36337  9957951680001701
# 16147        113874  9974799725001701
# 16148          3295  9953296770001701
# 16161        114862  9977101571201701
# 16162         14688  9933514930001701
#
#                                                Title_bib       ISSN_bib  \
# 0                     The Wilson journal of ornithology.  ['1559-4491']
# 1                      The Wilson journal of ornithology  ['1938-5447']
# 4             Journal of the University Film Association  ['2328-1944']
# 5      Journal of the University Film and Video Assoc...  ['2328-1936']
# 6      Journal of the University Film and Video Assoc...  ['0734-919X']
# ...                                                  ...            ...
# 16140                                       Bird-banding  ['0006-3630']
# 16147                                              Nomos           ['']
# 16148                                              Nomos  ['0078-0979']
# 16161                                   Oriental insects  ['2157-8745']
# 16162                                   Oriental insects  ['0030-5316']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                   ['1559-4491']      p                 2     1559-4491
# 1      ['1559-4491', '1938-5447']      e                 2     1938-5447
# 4      ['0041-9311', '2328-1944']      e                 7     2328-1944
# 5      ['2328-1936', '0734-919X']      e                 7     2328-1936
# 6      ['0041-9311', '0734-919X']      p                 7     0734-919X
# ...                           ...    ...               ...           ...
# 16140               ['0006-3630']      p            101457     0006-3630
# 16147               ['0078-0979']      e            101504
# 16148               ['0078-0979']      p            101504     0078-0979
# 16161  ['0030-5316', '2157-8745']      e            101697     2157-8745
# 16162               ['0030-5316']      p            101697     0030-5316
#
#                                              e_coll_info  \
# 0                                                    NaN
# 1      [['61588428410001701', 'JSTOR Life Sciences Co...
# 4      [['61535210810001701', 'JSTOR Arts and Science...
# 5      [['61535210810001701', 'JSTOR Arts and Science...
# 6                                                    NaN
# ...                                                  ...
# 16140                                                NaN
# 16147  [['61789519150001701', 'JSTOR Arts & Sciences ...
# 16148                                                NaN
# 16161  [['61808506700001701', 'Taylor & Francis Biolo...
# 16162                                                NaN
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 0                                                    NaN  ...          NaN
# 1      [['53588425000001701', 'The Wilson journal of ...  ...          NaN
# 4      [['53538633520001701', 'Journal of the Univers...  ...          NaN
# 5      [['53537295580001701', 'Journal of the Univers...  ...          NaN
# 6                                                    NaN  ...          NaN
# ...                                                  ...  ...          ...
# 16140                                                NaN  ...          NaN
# 16147                  [['53789566180001701', 'Nomos.']]  ...          NaN
# 16148                                                NaN  ...          NaN
# 16161  [['53815442430001701', 'Oriental insects'], ['...  ...          NaN
# 16162                                                NaN  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
# 5                          NaN                   NaN                   NaN
# 6                          NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16140                      NaN                   NaN                   NaN
# 16147                      NaN                   NaN                   NaN
# 16148                      NaN                   NaN                   NaN
# 16161                      NaN                   NaN                   NaN
# 16162                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0             NaN            NaN                             NaN
# 1             NaN            NaN                             NaN
# 4             NaN            NaN                             NaN
# 5             NaN            NaN                             NaN
# 6             NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16140         NaN            NaN                             NaN
# 16147         NaN            NaN                             NaN
# 16148         NaN            NaN                             NaN
# 16161         NaN            NaN                             NaN
# 16162         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 4                               NaN                       NaN
# 5                               NaN                       NaN
# 6                               NaN                       NaN
# ...                             ...                       ...
# 16140                           NaN                       NaN
# 16147                           NaN                       NaN
# 16148                           NaN                       NaN
# 16161                           NaN                       NaN
# 16162                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 0                            NaN
# 1                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# ...                          ...
# 16140                        NaN
# 16147                        NaN
# 16148                        NaN
# 16161                        NaN
# 16162                        NaN
#
# [7028 rows x 34 columns]

# %%
p_pres_groups_df.to_pickle('all_groups_' + today + '.pkl')
no_repo_p_pres_groups_df.to_pickle('no_repo_groups_' + today + '.pkl')

# %%
df = p_pres_groups_df
df
# Out:
#        record_index            MMS_ID  \
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 7             88618  9939481760001701
# 8            111951  9968429800001701
# 15           123907  9967115530001701
# ...             ...               ...
# 16156         17960  9946768760001701
# 16157        117510  9967987860001701
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
#
#                                                Title_bib       ISSN_bib  \
# 2           IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3           IEEE transactions on ultrasonics engineering  ['2162-1373']
# 7                  Journal of the Institute of Actuaries  ['0020-2681']
# 8                  Journal of the Institute of Actuaries  ['2058-1009']
# 15        Giornale degli economisti e annali di economia           ['']
# ...                                                  ...            ...
# 16156                                       The Americas  ['0003-1615']
# 16157  The Americas - Academy of American Franciscan ...  ['1533-6247']
# 16158                                  Americas (Online)           ['']
# 16159    International journal of adhesion and adhesives  ['0143-7496']
# 16160    International journal of adhesion and adhesives  ['1879-0127']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 7                   ['0020-2681']      p                12     0020-2681
# 8      ['0020-2681', '2058-1009']      e                12     2058-1009
# 15                  ['0017-0097']      e                92
# ...                           ...    ...               ...           ...
# 16156  ['1533-6247', '0003-1615']      p            101581     0003-1615
# 16157  ['1533-6247', '0003-1615']      e            101581     1533-6247
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
#
#                                              e_coll_info  \
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 7                                                    NaN
# 8      [['61535216140001701', 'JSTOR Business III Col...
# 15     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16156                                                NaN
# 16157  [['61535211010001701', 'JSTOR Arts and Science...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 7                                                    NaN  ...          NaN
# 8      [['53540140170001701', 'Journal of the Institu...  ...          NaN
# 15     [['53537228640001701', 'Giornale degli economi...  ...          NaN
# ...                                                  ...  ...          ...
# 16156                                                NaN  ...          NaN
# 16157           [['53539160390001701', 'The Americas.']]  ...          NaN
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 7                          NaN                   NaN                   NaN
# 8                          NaN                   NaN                   NaN
# 15                         NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16156                      NaN                   NaN                   NaN
# 16157                      NaN                   NaN                   NaN
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 7             NaN            NaN                             NaN
# 8             NaN            NaN                             NaN
# 15            NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16156         NaN            NaN                             NaN
# 16157         NaN            NaN                             NaN
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 15                              NaN                       NaN
# ...                             ...                       ...
# 16156                           NaN                       NaN
# 16157                           NaN                       NaN
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 2                            NaN
# 3                            NaN
# 7                            NaN
# 8                            NaN
# 15                           NaN
# ...                          ...
# 16156                        NaN
# 16157                        NaN
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
#
# [8872 rows x 34 columns]

# %%
df['MMS_ID'].nunique()
# Out:
# 8628

# %% [markdown]
# #### Get list of Physical MMS IDs where group has p2e, pcad, and repo coverage
# You will need this file to populate a set in Alma of print records that are candidates for withdrawal.

# %%
p_mms_ids = df[df['p_or_e'] == 'p']['MMS_ID'].unique().tolist()
len(p_mms_ids)
# Out:
# 4454

# %%
pmms = pd.DataFrame(p_mms_ids, columns=['MMS ID'])
pmms.to_csv(f'all_p_mms_ids-pcad-preserved_{today}.txt', sep='\t', index=False)
