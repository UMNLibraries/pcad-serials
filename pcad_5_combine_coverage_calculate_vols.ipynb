# %% [markdown]
# # PCAD notebook 5
#
# This notebook completes the analysis, resulting in dataframes that are close to the final output.
# - Counts items per title and merges that data with the main dataframe
# - Processes chronology data for print holdings, trusted repositories, and electronic coverage so that overlap can be calculated
# - Calculates the number of volumes per title that are candidates for withdrawal based on PCA and repository holdings
# - Parses the main dataframe into separate dataframes by number of vendors, number of locations, and vendor groups.
#
# This is the trickiest section of the entire process; the last big drop duplicates operation requires recasting list-type columns to strings, and then recasting the resulting dataframe's columns to their original types. There may be some trial and error involved there; please improve the code if you can.
#
# Required files/inputs:
# - `.pkl` file of location-filtered item-level enumeration and chronology data produced by PCAD notebook 4
# - "All groups" pickle file produced by PCAD notebook 3 (`all_groups_{date}.pkl`)
#
# Ouputs:
# - `multi_loc_100*.pkl` files (8 files)
# - `single_loc_100*.pkl` files (8 files)
#
# Because this notebook is lengthy, and there are several complex operations, several other `.pkl` files are saved before critical or dangerous operations; these can be discarded if they are not needed.

# %%
import ast
import math
import re
import pandas as pd
import numpy as np
from os.path import splitext
from datetime import date
today = str(date.today()).replace('-','')

# %%
#change filename
chron = pd.read_pickle('items-enumchron-20201011.pkl')
chron
# Out:
#                    001              954$a            954$b    954$c    954$d  \
# 0     9936524420001701  23409495250001701  31951000208506R        8     1978
# 0     9954539020001701  23484960990001701  31951P002253064      350     1994
# 0     9954539020001701  23484960900001701  31951P00454482T      354     1996
# 0     9954539020001701  23484960670001701  31951000265036H  278-279     1973
# 0     9954539020001701  23484960620001701  31951000265039B  284-285     1974
# ..                 ...                ...              ...      ...      ...
# 0     9961581080001701  23516118280001701  31951P00204631A       39     1993
# 0     9954865450001701  23486326540001701  31951P01062120F       88     2009
# 0     9961654610001701  23516343280001701  31951P005115126       12     1996
# 0     9946991890001701  23453395340001701  319510026777515  117-118  1922-23
# 0     9956479890001701  23492880700001701  31951000293726K    13-14  1942-43
#
#                          954$e  954$f 954$g  954$h 954$i
# 0                   v.8 (1978)  TBIOM  PERS  TBIOM  PERS
# 0          v.350:no.1-3 (1994)  TBIOM  PERS  TBIOM  PERS
# 0   v.354:no.4-6+suppl. (1996)  TBIOM  PERS  TBIOM  PERS
# 0      v.278-279+suppl. (1973)  TBIOM  PERS  TBIOM  PERS
# 0             v.284-285 (1974)  TBIOM  PERS  TBIOM  PERS
# ..                         ...    ...   ...    ...   ...
# 0          v.39:no.7-12 (1993)  TBIOM  PERS  TBIOM  PERS
# 0           v.88A:no.3-4(2009)  TBIOM  PERS  TBIOM  PERS
# 0                  v.12 (1996)  TBIOM  PERS  TBIOM  PERS
# 0         bd.117-118 (1922-23)  TBIOM  PERS  TBIOM  PERS
# 0            v.13-14 (1942-43)  TBIOM  PERS  TBIOM  PERS
#
# [254258 rows x 10 columns]

# %%
chron.columns
# Out:
# Index(['001', '954$a', '954$b', '954$c', '954$d', '954$e', '954$f', '954$g',
#        '954$h', '954$i'],
#       dtype='object')

# %%
chron.rename(columns={'001':'001-MMS_ID', '954$a':'954$a-Holdings', '954$b':'954$b-barcode', 
                      '954$c':'954$c-enum', '954$d':'954$d-chron', '954$e':'954$e-descr', 
                      '954$f':'954$f-perm-lib', '954$g':'954$g-perm-loc','954$h':'954$h-curr-lib', 
                      '954$i':'954$i-curr-loc'},inplace=True)
chron
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc
# 0               TBIOM           PERS
# 1               TBIOM           PERS
# 2               TBIOM           PERS
# 3               TBIOM           PERS
# 4               TBIOM           PERS
# ...               ...            ...
# 254171          TBIOM           PERS
# 254172          TBIOM           PERS
# 254173          TBIOM           PERS
# 254174          TBIOM           PERS
# 254175          TBIOM           PERS
#
# [254176 rows x 10 columns]

# %%
chron = chron[chron['954$h-curr-lib'].notnull()]
chron
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc
# 0               TBIOM           PERS
# 1               TBIOM           PERS
# 2               TBIOM           PERS
# 3               TBIOM           PERS
# 4               TBIOM           PERS
# ...               ...            ...
# 254171          TBIOM           PERS
# 254172          TBIOM           PERS
# 254173          TBIOM           PERS
# 254174          TBIOM           PERS
# 254175          TBIOM           PERS
#
# [254176 rows x 10 columns]

# %%
chron['curr-lib-loc'] = chron.apply(lambda row: row['954$h-curr-lib'] + ' ' + row['954$i-curr-loc'], axis=1)
chron
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc curr-lib-loc
# 0               TBIOM           PERS   TBIOM PERS
# 1               TBIOM           PERS   TBIOM PERS
# 2               TBIOM           PERS   TBIOM PERS
# 3               TBIOM           PERS   TBIOM PERS
# 4               TBIOM           PERS   TBIOM PERS
# ...               ...            ...          ...
# 254171          TBIOM           PERS   TBIOM PERS
# 254172          TBIOM           PERS   TBIOM PERS
# 254173          TBIOM           PERS   TBIOM PERS
# 254174          TBIOM           PERS   TBIOM PERS
# 254175          TBIOM           PERS   TBIOM PERS
#
# [254176 rows x 11 columns]

# %%
cgs = chron.groupby('001-MMS_ID').agg(lambda x: list(set(x))).reset_index()
cgs
# Out:
#             001-MMS_ID                                     954$a-Holdings  \
# 0     9912002260001701  [23305012440001701, 23305012240001701, 2330501...
# 1     9912023030001701  [23305079150001701, 23305079170001701, 2330507...
# 2     9912037080001701                                [23305080030001701]
# 3     9912038890001701  [23305086820001701, 23305086840001701, 2330508...
# 4     9912065260001701  [23305229070001701, 23305229110001701, 2330522...
# ...                ...                                                ...
# 4448  9975901508601701  [23485188320001701, 23485188170001701, 2348518...
# 4449  9975989409901701  [23361481890001701, 23361483880001701, 2336148...
# 4450  9976125196401701  [23454315640001701, 23454315530001701, 2345431...
# 4451  9976125496801701  [23454315800001701, 23454315810001701, 2345431...
# 4452  9976424005001701             [23765223960001701, 23765225470001701]
#
#                                           954$b-barcode  \
# 0     [31951P00378985E, 31951P00654897M, 31951P00992...
# 1     [31951P00548994H, 31951P00403583M, 31951D01258...
# 2                                     [31951P00784468K]
# 3     [31951P00686774A, 31951P003775736, 31951P00607...
# 4     [31951000608115E, 31951000608122H, 31951000608...
# ...                                                 ...
# 4448  [31951D02173957I, 31951D02173954O, 31951D02173...
# 4449  [31951000597515S, 31951D002011808, 31951D00201...
# 4450  [31951D00263557D, 31951D00263542Q, 31951D00263...
# 4451  [31951D00263534P, 31951D00263528K, 31951D00263...
# 4452                        [X1333049, 31951P012479931]
#
#                                              954$c-enum  \
# 0     [22, 23, 26, 7, 12, 6, 33, 16, 31, 21, 30, 20,...
# 1     [22, 7, 26, 23, 12, 6, 21, 16, 20, 1, 25, 14, ...
# 2                                                  [60]
# 3                        [325, 320, 319, 318, 324, 321]
# 4     [3-4, 20, 22, 19, 23, 5-7, 15-16, 13-14, 11-12...
# ...                                                 ...
# 4448                       [10-14, 19-22, 15-18, 23-26]
# 4449  [46, 7, 44-45, 1-2, 6, 45, 43, 37, 34-35, 46-4...
# 4450  [26-27, 24-25, 19, 17, 34-35, 32-33, 36-37, 40...
# 4451  [16, 3-4, 15, 7, 8, 14, 12, 10, 5, 13, 11, 9, ...
# 4452                                     [136, 133-135]
#
#                                             954$d-chron  \
# 0     [nan, 2004, 2010, 1978, 1984, 1995, 1971, 1977...
# 1     [nan, 1978, 1995, 1987, 1977, 2001, 1980, 1985...
# 2                                                [2004]
# 3                                    [1994, 1995, 1997]
# 4     [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# ...                                                 ...
# 4448       [1934-1937, 1942-1945, 1938-1941, 1929-1933]
# 4449  [1905, 1906, 1890, 1904, 1888/89, 1885-1885/18...
# 4450  [1933-1934, 1934-1935, 1930-1931, 1932, 1938, ...
# 4451          [1926, 1924-1925, 1925, 1928, 1927, 1929]
# 4452                                  [2015-2017, 2018]
#
#                                             954$e-descr  954$f-perm-lib  \
# 0     [v.3:no.1 (1973:winter), v.30:no.3-4 (2000), v...         [TBIOM]
# 1     [v.13:no.2 (1986:Summer), v.6 (1977), v.22 (19...         [TBIOM]
# 2                                    [v.60:no.1-2 2004]          [TSCI]
# 3     [t.324:no.1-6 (1997), t.319:no.7-12 (1994), v....   [TCOS, ZMLAC]
# 4     [v.22 (1966), v.15-16 (1965), v.8-10 (1964), v...         [ZMLAC]
# ...                                                 ...             ...
# 4448  [v.10-14 (1929-1933), v.15-18 (1934-1937), v.2...         [TMAGR]
# 4449  [v.44-45 (1907), v.43 (1906), v.10 (1889/90), ...  [TWILS, TMAGR]
# 4450  [Bd.18 (1930), Bd.26-27 (1932-33), Bd.28-29 (1...         [TMAGR]
# 4451  [Bd.13 (1929), Bd.11 (1928), Bd.7 (1926), Bd.1...         [TMAGR]
# 4452                [v.136 (2018), v.133-135 (2015-17)]         [TWILS]
#
#      954$g-perm-loc  954$h-curr-lib 954$i-curr-loc             curr-lib-loc
# 0            [PERS]         [TBIOM]         [PERS]             [TBIOM PERS]
# 1            [PERS]         [TBIOM]         [PERS]             [TBIOM PERS]
# 2             [PER]          [TSCI]          [PER]               [TSCI PER]
# 3        [SN1, OWL]   [TCOS, ZMLAC]     [SN1, OWL]    [TCOS SN1, ZMLAC OWL]
# 4             [OWL]         [ZMLAC]          [OWL]              [ZMLAC OWL]
# ...             ...             ...            ...                      ...
# 4448          [PER]         [TMAGR]          [PER]              [TMAGR PER]
# 4449    [PERC, PER]  [TWILS, TMAGR]    [PERC, PER]  [TWILS PERC, TMAGR PER]
# 4450          [PER]         [TMAGR]          [PER]              [TMAGR PER]
# 4451          [PER]         [TMAGR]          [PER]              [TMAGR PER]
# 4452          [PER]         [TWILS]          [PER]              [TWILS PER]
#
# [4453 rows x 11 columns]

# %%
chron0 = pd.merge(chron, cgs[['001-MMS_ID','curr-lib-loc']],how='left',on='001-MMS_ID')
chron0
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc curr-lib-loc_x  \
# 0               TBIOM           PERS     TBIOM PERS
# 1               TBIOM           PERS     TBIOM PERS
# 2               TBIOM           PERS     TBIOM PERS
# 3               TBIOM           PERS     TBIOM PERS
# 4               TBIOM           PERS     TBIOM PERS
# ...               ...            ...            ...
# 254171          TBIOM           PERS     TBIOM PERS
# 254172          TBIOM           PERS     TBIOM PERS
# 254173          TBIOM           PERS     TBIOM PERS
# 254174          TBIOM           PERS     TBIOM PERS
# 254175          TBIOM           PERS     TBIOM PERS
#
#                             curr-lib-loc_y
# 0                             [TBIOM PERS]
# 1                   [TVET PER, TBIOM PERS]
# 2                   [TVET PER, TBIOM PERS]
# 3                   [TVET PER, TBIOM PERS]
# 4                   [TVET PER, TBIOM PERS]
# ...                                    ...
# 254171            [ZMLAC UMDN, TBIOM PERS]
# 254172                        [TBIOM PERS]
# 254173                        [TBIOM PERS]
# 254174                        [TBIOM PERS]
# 254175  [TBIOM PERS, ZMLAC OWL, TWILS PER]
#
# [254176 rows x 12 columns]

# %%
item_ct = chron0.groupby('001-MMS_ID').agg(lambda x: len(x))
item_ct
# Out:
#                   954$a-Holdings  954$b-barcode  954$c-enum  954$d-chron  \
# 001-MMS_ID
# 9912002260001701              74             74          74           74
# 9912023030001701              35             35          35           35
# 9912037080001701               1              1           1            1
# 9912038890001701              13             13          13           13
# 9912065260001701              14             14          14           14
# ...                          ...            ...         ...          ...
# 9975901508601701               4              4           4            4
# 9975989409901701              34             34          34           34
# 9976125196401701              14             14          14           14
# 9976125496801701              14             14          14           14
# 9976424005001701               2              2           2            2
#
#                   954$e-descr  954$f-perm-lib  954$g-perm-loc  954$h-curr-lib  \
# 001-MMS_ID
# 9912002260001701           74              74              74              74
# 9912023030001701           35              35              35              35
# 9912037080001701            1               1               1               1
# 9912038890001701           13              13              13              13
# 9912065260001701           14              14              14              14
# ...                       ...             ...             ...             ...
# 9975901508601701            4               4               4               4
# 9975989409901701           34              34              34              34
# 9976125196401701           14              14              14              14
# 9976125496801701           14              14              14              14
# 9976424005001701            2               2               2               2
#
#                   954$i-curr-loc  curr-lib-loc_x  curr-lib-loc_y
# 001-MMS_ID
# 9912002260001701              74              74              74
# 9912023030001701              35              35              35
# 9912037080001701               1               1               1
# 9912038890001701              13              13              13
# 9912065260001701              14              14              14
# ...                          ...             ...             ...
# 9975901508601701               4               4               4
# 9975989409901701              34              34              34
# 9976125196401701              14              14              14
# 9976125496801701              14              14              14
# 9976424005001701               2               2               2
#
# [4453 rows x 11 columns]

# %%
item_ct.reset_index(inplace=True)
item_ct
# Out:
#             001-MMS_ID  954$a-Holdings  954$b-barcode  954$c-enum  \
# 0     9912002260001701              74             74          74
# 1     9912023030001701              35             35          35
# 2     9912037080001701               1              1           1
# 3     9912038890001701              13             13          13
# 4     9912065260001701              14             14          14
# ...                ...             ...            ...         ...
# 4448  9975901508601701               4              4           4
# 4449  9975989409901701              34             34          34
# 4450  9976125196401701              14             14          14
# 4451  9976125496801701              14             14          14
# 4452  9976424005001701               2              2           2
#
#       954$d-chron  954$e-descr  954$f-perm-lib  954$g-perm-loc  \
# 0              74           74              74              74
# 1              35           35              35              35
# 2               1            1               1               1
# 3              13           13              13              13
# 4              14           14              14              14
# ...           ...          ...             ...             ...
# 4448            4            4               4               4
# 4449           34           34              34              34
# 4450           14           14              14              14
# 4451           14           14              14              14
# 4452            2            2               2               2
#
#       954$h-curr-lib  954$i-curr-loc  curr-lib-loc_x  curr-lib-loc_y
# 0                 74              74              74              74
# 1                 35              35              35              35
# 2                  1               1               1               1
# 3                 13              13              13              13
# 4                 14              14              14              14
# ...              ...             ...             ...             ...
# 4448               4               4               4               4
# 4449              34              34              34              34
# 4450              14              14              14              14
# 4451              14              14              14              14
# 4452               2               2               2               2
#
# [4453 rows x 12 columns]

# %%
item_ct = item_ct[['001-MMS_ID','954$b-barcode']].rename(columns={'954$b-barcode':'all_item_count'})
item_ct
# Out:
#             001-MMS_ID  all_item_count
# 0     9912002260001701              74
# 1     9912023030001701              35
# 2     9912037080001701               1
# 3     9912038890001701              13
# 4     9912065260001701              14
# ...                ...             ...
# 4448  9975901508601701               4
# 4449  9975989409901701              34
# 4450  9976125196401701              14
# 4451  9976125496801701              14
# 4452  9976424005001701               2
#
# [4453 rows x 2 columns]

# %%
#optional check of a specific MMS ID
item_ct[item_ct['001-MMS_ID'] == '9956479890001701']
# Out:
#             001-MMS_ID  all_item_count
# 3628  9956479890001701             181

# %%
chron2 = pd.merge(chron0,item_ct,how='left',on='001-MMS_ID')
chron2
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc curr-lib-loc_x  \
# 0               TBIOM           PERS     TBIOM PERS
# 1               TBIOM           PERS     TBIOM PERS
# 2               TBIOM           PERS     TBIOM PERS
# 3               TBIOM           PERS     TBIOM PERS
# 4               TBIOM           PERS     TBIOM PERS
# ...               ...            ...            ...
# 254171          TBIOM           PERS     TBIOM PERS
# 254172          TBIOM           PERS     TBIOM PERS
# 254173          TBIOM           PERS     TBIOM PERS
# 254174          TBIOM           PERS     TBIOM PERS
# 254175          TBIOM           PERS     TBIOM PERS
#
#                             curr-lib-loc_y  all_item_count
# 0                             [TBIOM PERS]             123
# 1                   [TVET PER, TBIOM PERS]             146
# 2                   [TVET PER, TBIOM PERS]             146
# 3                   [TVET PER, TBIOM PERS]             146
# 4                   [TVET PER, TBIOM PERS]             146
# ...                                    ...             ...
# 254171            [ZMLAC UMDN, TBIOM PERS]              64
# 254172                        [TBIOM PERS]              48
# 254173                        [TBIOM PERS]              13
# 254174                        [TBIOM PERS]             216
# 254175  [TBIOM PERS, ZMLAC OWL, TWILS PER]             181
#
# [254176 rows x 13 columns]

# %%
chron2.fillna('',inplace=True)
chron2
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc curr-lib-loc_x  \
# 0               TBIOM           PERS     TBIOM PERS
# 1               TBIOM           PERS     TBIOM PERS
# 2               TBIOM           PERS     TBIOM PERS
# 3               TBIOM           PERS     TBIOM PERS
# 4               TBIOM           PERS     TBIOM PERS
# ...               ...            ...            ...
# 254171          TBIOM           PERS     TBIOM PERS
# 254172          TBIOM           PERS     TBIOM PERS
# 254173          TBIOM           PERS     TBIOM PERS
# 254174          TBIOM           PERS     TBIOM PERS
# 254175          TBIOM           PERS     TBIOM PERS
#
#                             curr-lib-loc_y  all_item_count
# 0                             [TBIOM PERS]             123
# 1                   [TVET PER, TBIOM PERS]             146
# 2                   [TVET PER, TBIOM PERS]             146
# 3                   [TVET PER, TBIOM PERS]             146
# 4                   [TVET PER, TBIOM PERS]             146
# ...                                    ...             ...
# 254171            [ZMLAC UMDN, TBIOM PERS]              64
# 254172                        [TBIOM PERS]              48
# 254173                        [TBIOM PERS]              13
# 254174                        [TBIOM PERS]             216
# 254175  [TBIOM PERS, ZMLAC OWL, TWILS PER]             181
#
# [254176 rows x 13 columns]

# %%
def year_search(x):
    if re.search('[1-2][0-9]{3}[-/][1-2][0-9]{3}', x):
        return re.search('[1-2][0-9]{3}[-/][1-2][0-9]{3}', x).group(0)
    elif re.search('[1-2][0-9]{3}[-/][0-9]{2}', x):
        return re.search('[1-2][0-9]{3}[-/][0-9]{2}', x).group(0)
    elif re.search('[1-2][0-9]{3}', x):
        return re.search('[1-2][0-9]{3}', x).group(0)
    else:
        return ""

# %%
chron2['descr-year'] = chron2['954$e-descr'].apply(lambda x: year_search(x))
chron2
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc curr-lib-loc_x  \
# 0               TBIOM           PERS     TBIOM PERS
# 1               TBIOM           PERS     TBIOM PERS
# 2               TBIOM           PERS     TBIOM PERS
# 3               TBIOM           PERS     TBIOM PERS
# 4               TBIOM           PERS     TBIOM PERS
# ...               ...            ...            ...
# 254171          TBIOM           PERS     TBIOM PERS
# 254172          TBIOM           PERS     TBIOM PERS
# 254173          TBIOM           PERS     TBIOM PERS
# 254174          TBIOM           PERS     TBIOM PERS
# 254175          TBIOM           PERS     TBIOM PERS
#
#                             curr-lib-loc_y  all_item_count descr-year
# 0                             [TBIOM PERS]             123       1978
# 1                   [TVET PER, TBIOM PERS]             146       1994
# 2                   [TVET PER, TBIOM PERS]             146       1996
# 3                   [TVET PER, TBIOM PERS]             146       1973
# 4                   [TVET PER, TBIOM PERS]             146       1974
# ...                                    ...             ...        ...
# 254171            [ZMLAC UMDN, TBIOM PERS]              64       1993
# 254172                        [TBIOM PERS]              48       2009
# 254173                        [TBIOM PERS]              13       1996
# 254174                        [TBIOM PERS]             216    1922-23
# 254175  [TBIOM PERS, ZMLAC OWL, TWILS PER]             181    1942-43
#
# [254176 rows x 14 columns]

# %%
chron2['chron'] = chron2.apply(lambda row: row['954$d-chron'] if (row['954$d-chron'] != '') else row['descr-year'], axis=1)
chron2
# Out:
#               001-MMS_ID     954$a-Holdings    954$b-barcode 954$c-enum  \
# 0       9936524420001701  23409495250001701  31951000208506R          8
# 1       9954539020001701  23484960990001701  31951P002253064        350
# 2       9954539020001701  23484960900001701  31951P00454482T        354
# 3       9954539020001701  23484960670001701  31951000265036H    278-279
# 4       9954539020001701  23484960620001701  31951000265039B    284-285
# ...                  ...                ...              ...        ...
# 254171  9961581080001701  23516118280001701  31951P00204631A         39
# 254172  9954865450001701  23486326540001701  31951P01062120F         88
# 254173  9961654610001701  23516343280001701  31951P005115126         12
# 254174  9946991890001701  23453395340001701  319510026777515    117-118
# 254175  9956479890001701  23492880700001701  31951000293726K      13-14
#
#        954$d-chron                 954$e-descr 954$f-perm-lib 954$g-perm-loc  \
# 0             1978                  v.8 (1978)          TBIOM           PERS
# 1             1994         v.350:no.1-3 (1994)          TBIOM           PERS
# 2             1996  v.354:no.4-6+suppl. (1996)          TBIOM           PERS
# 3             1973     v.278-279+suppl. (1973)          TBIOM           PERS
# 4             1974            v.284-285 (1974)          TBIOM           PERS
# ...            ...                         ...            ...            ...
# 254171        1993         v.39:no.7-12 (1993)          TBIOM           PERS
# 254172        2009          v.88A:no.3-4(2009)          TBIOM           PERS
# 254173        1996                 v.12 (1996)          TBIOM           PERS
# 254174     1922-23        bd.117-118 (1922-23)          TBIOM           PERS
# 254175     1942-43           v.13-14 (1942-43)          TBIOM           PERS
#
#        954$h-curr-lib 954$i-curr-loc curr-lib-loc_x  \
# 0               TBIOM           PERS     TBIOM PERS
# 1               TBIOM           PERS     TBIOM PERS
# 2               TBIOM           PERS     TBIOM PERS
# 3               TBIOM           PERS     TBIOM PERS
# 4               TBIOM           PERS     TBIOM PERS
# ...               ...            ...            ...
# 254171          TBIOM           PERS     TBIOM PERS
# 254172          TBIOM           PERS     TBIOM PERS
# 254173          TBIOM           PERS     TBIOM PERS
# 254174          TBIOM           PERS     TBIOM PERS
# 254175          TBIOM           PERS     TBIOM PERS
#
#                             curr-lib-loc_y  all_item_count descr-year    chron
# 0                             [TBIOM PERS]             123       1978     1978
# 1                   [TVET PER, TBIOM PERS]             146       1994     1994
# 2                   [TVET PER, TBIOM PERS]             146       1996     1996
# 3                   [TVET PER, TBIOM PERS]             146       1973     1973
# 4                   [TVET PER, TBIOM PERS]             146       1974     1974
# ...                                    ...             ...        ...      ...
# 254171            [ZMLAC UMDN, TBIOM PERS]              64       1993     1993
# 254172                        [TBIOM PERS]              48       2009     2009
# 254173                        [TBIOM PERS]              13       1996     1996
# 254174                        [TBIOM PERS]             216    1922-23  1922-23
# 254175  [TBIOM PERS, ZMLAC OWL, TWILS PER]             181    1942-43  1942-43
#
# [254176 rows x 15 columns]

# %%
chron3 = chron2.groupby(['001-MMS_ID']).agg(lambda x: list(set(x))).reset_index()
chron3
# Out:
#             001-MMS_ID                                     954$a-Holdings  \
# 0     9912002260001701  [23305012440001701, 23305012240001701, 2330501...
# 1     9912023030001701  [23305079150001701, 23305079170001701, 2330507...
# 2     9912037080001701                                [23305080030001701]
# 3     9912038890001701  [23305086820001701, 23305086840001701, 2330508...
# 4     9912065260001701  [23305229070001701, 23305229110001701, 2330522...
# ...                ...                                                ...
# 4448  9975901508601701  [23485188320001701, 23485188170001701, 2348518...
# 4449  9975989409901701  [23361481890001701, 23361483880001701, 2336148...
# 4450  9976125196401701  [23454315640001701, 23454315530001701, 2345431...
# 4451  9976125496801701  [23454315800001701, 23454315810001701, 2345431...
# 4452  9976424005001701             [23765223960001701, 23765225470001701]
#
#                                           954$b-barcode  \
# 0     [31951P00378985E, 31951P00654897M, 31951P00992...
# 1     [31951P00548994H, 31951P00403583M, 31951D01258...
# 2                                     [31951P00784468K]
# 3     [31951P00686774A, 31951P003775736, 31951P00607...
# 4     [31951000608115E, 31951000608122H, 31951000608...
# ...                                                 ...
# 4448  [31951D02173957I, 31951D02173954O, 31951D02173...
# 4449  [31951000597515S, 31951D002011808, 31951D00201...
# 4450  [31951D00263557D, 31951D00263542Q, 31951D00263...
# 4451  [31951D00263534P, 31951D00263528K, 31951D00263...
# 4452                        [X1333049, 31951P012479931]
#
#                                              954$c-enum  \
# 0     [22, 23, 26, 7, 12, 6, 33, 16, 31, 21, 30, 20,...
# 1     [22, 7, 26, 23, 12, 6, 21, 16, 20, 1, 25, 14, ...
# 2                                                  [60]
# 3                        [325, 320, 319, 318, 324, 321]
# 4     [3-4, 20, 22, 19, 23, 5-7, 15-16, 13-14, 11-12...
# ...                                                 ...
# 4448                       [10-14, 19-22, 15-18, 23-26]
# 4449  [46, 7, 44-45, 1-2, 6, 45, 43, 37, 34-35, 46-4...
# 4450  [26-27, 24-25, 19, 17, 34-35, 32-33, 36-37, 40...
# 4451  [16, 3-4, 15, 7, 8, 14, 12, 10, 5, 13, 11, 9, ...
# 4452                                     [136, 133-135]
#
#                                             954$d-chron  \
# 0     [, 2004, 2010, 1978, 1984, 1995, 1971, 1977, 1...
# 1     [, 1978, 1995, 1987, 1977, 2001, 1980, 1985, 1...
# 2                                                [2004]
# 3                                    [1994, 1995, 1997]
# 4     [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# ...                                                 ...
# 4448       [1934-1937, 1942-1945, 1938-1941, 1929-1933]
# 4449  [1905, 1906, 1890, 1904, 1888/89, 1885-1885/18...
# 4450  [1933-1934, 1934-1935, 1930-1931, 1932, 1938, ...
# 4451          [1926, 1924-1925, 1925, 1928, 1927, 1929]
# 4452                                  [2015-2017, 2018]
#
#                                             954$e-descr  954$f-perm-lib  \
# 0     [v.3:no.1 (1973:winter), v.30:no.3-4 (2000), v...         [TBIOM]
# 1     [v.13:no.2 (1986:Summer), v.6 (1977), v.22 (19...         [TBIOM]
# 2                                    [v.60:no.1-2 2004]          [TSCI]
# 3     [t.324:no.1-6 (1997), t.319:no.7-12 (1994), v....   [TCOS, ZMLAC]
# 4     [v.22 (1966), v.15-16 (1965), v.8-10 (1964), v...         [ZMLAC]
# ...                                                 ...             ...
# 4448  [v.10-14 (1929-1933), v.15-18 (1934-1937), v.2...         [TMAGR]
# 4449  [v.44-45 (1907), v.43 (1906), v.10 (1889/90), ...  [TWILS, TMAGR]
# 4450  [Bd.18 (1930), Bd.26-27 (1932-33), Bd.28-29 (1...         [TMAGR]
# 4451  [Bd.13 (1929), Bd.11 (1928), Bd.7 (1926), Bd.1...         [TMAGR]
# 4452                [v.136 (2018), v.133-135 (2015-17)]         [TWILS]
#
#      954$g-perm-loc  954$h-curr-lib 954$i-curr-loc           curr-lib-loc_x  \
# 0            [PERS]         [TBIOM]         [PERS]             [TBIOM PERS]
# 1            [PERS]         [TBIOM]         [PERS]             [TBIOM PERS]
# 2             [PER]          [TSCI]          [PER]               [TSCI PER]
# 3        [SN1, OWL]   [TCOS, ZMLAC]     [SN1, OWL]    [TCOS SN1, ZMLAC OWL]
# 4             [OWL]         [ZMLAC]          [OWL]              [ZMLAC OWL]
# ...             ...             ...            ...                      ...
# 4448          [PER]         [TMAGR]          [PER]              [TMAGR PER]
# 4449    [PERC, PER]  [TWILS, TMAGR]    [PERC, PER]  [TWILS PERC, TMAGR PER]
# 4450          [PER]         [TMAGR]          [PER]              [TMAGR PER]
# 4451          [PER]         [TMAGR]          [PER]              [TMAGR PER]
# 4452          [PER]         [TWILS]          [PER]              [TWILS PER]
#
#      all_item_count                                         descr-year  \
# 0              [74]  [2004, 2010, 1978, 1984, 1995, 1971, 1977, 198...
# 1              [35]  [1978, 1995, 1987, 1977, 2001, 1980, 1985, 199...
# 2               [1]                                             [2004]
# 3              [13]                                 [1994, 1995, 1997]
# 4              [14]  [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# ...             ...                                                ...
# 4448            [4]       [1934-1937, 1942-1945, 1938-1941, 1929-1933]
# 4449           [34]  [1905, 1906, 1890, 1904, 1888/89, 1885-1885, 1...
# 4450           [14]  [1932-33, 1936-37, 1930-31, 1932, 1938, 1935, ...
# 4451           [14]            [1926, 1924-25, 1925, 1928, 1927, 1929]
# 4452            [2]                                    [2015-17, 2018]
#
#                                                   chron
# 0     [2004, 2010, 1978, 1984, 1995, 1971, 1977, 198...
# 1     [1978, 1995, 1987, 1977, 2001, 1980, 1985, 199...
# 2                                                [2004]
# 3                                    [1994, 1995, 1997]
# 4     [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# ...                                                 ...
# 4448       [1934-1937, 1942-1945, 1938-1941, 1929-1933]
# 4449  [1905, 1906, 1890, 1904, 1888/89, 1885-1885/18...
# 4450  [1933-1934, 1934-1935, 1930-1931, 1932, 1938, ...
# 4451          [1926, 1924-1925, 1925, 1928, 1927, 1929]
# 4452                                  [2015-2017, 2018]
#
# [4453 rows x 14 columns]

# %%
chron4 = chron2[['001-MMS_ID','curr-lib-loc_y']]
chron4.rename(columns={'curr-lib-loc_y':'curr-lib-loc_ALL'}, inplace=True)
chron4
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#               001-MMS_ID                    curr-lib-loc_ALL
# 0       9936524420001701                        [TBIOM PERS]
# 1       9954539020001701              [TVET PER, TBIOM PERS]
# 2       9954539020001701              [TVET PER, TBIOM PERS]
# 3       9954539020001701              [TVET PER, TBIOM PERS]
# 4       9954539020001701              [TVET PER, TBIOM PERS]
# ...                  ...                                 ...
# 254171  9961581080001701            [ZMLAC UMDN, TBIOM PERS]
# 254172  9954865450001701                        [TBIOM PERS]
# 254173  9961654610001701                        [TBIOM PERS]
# 254174  9946991890001701                        [TBIOM PERS]
# 254175  9956479890001701  [TBIOM PERS, ZMLAC OWL, TWILS PER]
#
# [254176 rows x 2 columns]

# %%
chron4['curr-lib-loc_ALL'] = chron4['curr-lib-loc_ALL'].apply(lambda x: str(x))
chron4
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#               001-MMS_ID                          curr-lib-loc_ALL
# 0       9936524420001701                            ['TBIOM PERS']
# 1       9954539020001701                ['TVET PER', 'TBIOM PERS']
# 2       9954539020001701                ['TVET PER', 'TBIOM PERS']
# 3       9954539020001701                ['TVET PER', 'TBIOM PERS']
# 4       9954539020001701                ['TVET PER', 'TBIOM PERS']
# ...                  ...                                       ...
# 254171  9961581080001701              ['ZMLAC UMDN', 'TBIOM PERS']
# 254172  9954865450001701                            ['TBIOM PERS']
# 254173  9961654610001701                            ['TBIOM PERS']
# 254174  9946991890001701                            ['TBIOM PERS']
# 254175  9956479890001701  ['TBIOM PERS', 'ZMLAC OWL', 'TWILS PER']
#
# [254176 rows x 2 columns]

# %%
chron4.drop_duplicates(inplace=True)
chron4
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#               001-MMS_ID            curr-lib-loc_ALL
# 0       9936524420001701              ['TBIOM PERS']
# 1       9954539020001701  ['TVET PER', 'TBIOM PERS']
# 5       9957961320001701              ['TBIOM PERS']
# 7       9956272140001701  ['TBIOM PERS', 'TZDS GEN']
# 8       9915259360001701              ['TBIOM PERS']
# ...                  ...                         ...
# 241614  9931402570001701               ['TWILS GEN']
# 243145  9949826010001701               ['TWILS PER']
# 246532  9963550760001701                ['TZDS GEN']
# 252477  9942510430001701               ['ZMLAC OWL']
# 253349  9937800230001701                ['TZDS GEN']
#
# [4453 rows x 2 columns]

# %%
chron3.columns
# Out:
# Index(['001-MMS_ID', '954$a-Holdings', '954$b-barcode', '954$c-enum',
#        '954$d-chron', '954$e-descr', '954$f-perm-lib', '954$g-perm-loc',
#        '954$h-curr-lib', '954$i-curr-loc', 'curr-lib-loc_x', 'all_item_count',
#        'descr-year', 'chron'],
#       dtype='object')

# %%
chron3 = chron3[['001-MMS_ID','curr-lib-loc_x','all_item_count', 'chron']]
chron3
# Out:
#             001-MMS_ID           curr-lib-loc_x all_item_count  \
# 0     9912002260001701             [TBIOM PERS]           [74]
# 1     9912023030001701             [TBIOM PERS]           [35]
# 2     9912037080001701               [TSCI PER]            [1]
# 3     9912038890001701    [TCOS SN1, ZMLAC OWL]           [13]
# 4     9912065260001701              [ZMLAC OWL]           [14]
# ...                ...                      ...            ...
# 4448  9975901508601701              [TMAGR PER]            [4]
# 4449  9975989409901701  [TWILS PERC, TMAGR PER]           [34]
# 4450  9976125196401701              [TMAGR PER]           [14]
# 4451  9976125496801701              [TMAGR PER]           [14]
# 4452  9976424005001701              [TWILS PER]            [2]
#
#                                                   chron
# 0     [2004, 2010, 1978, 1984, 1995, 1971, 1977, 198...
# 1     [1978, 1995, 1987, 1977, 2001, 1980, 1985, 199...
# 2                                                [2004]
# 3                                    [1994, 1995, 1997]
# 4     [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# ...                                                 ...
# 4448       [1934-1937, 1942-1945, 1938-1941, 1929-1933]
# 4449  [1905, 1906, 1890, 1904, 1888/89, 1885-1885/18...
# 4450  [1933-1934, 1934-1935, 1930-1931, 1932, 1938, ...
# 4451          [1926, 1924-1925, 1925, 1928, 1927, 1929]
# 4452                                  [2015-2017, 2018]
#
# [4453 rows x 4 columns]

# %%
chron_combo = pd.merge(chron3, chron4, how='left',on='001-MMS_ID')
chron_combo
# Out:
#             001-MMS_ID           curr-lib-loc_x all_item_count  \
# 0     9912002260001701             [TBIOM PERS]           [74]
# 1     9912023030001701             [TBIOM PERS]           [35]
# 2     9912037080001701               [TSCI PER]            [1]
# 3     9912038890001701    [TCOS SN1, ZMLAC OWL]           [13]
# 4     9912065260001701              [ZMLAC OWL]           [14]
# ...                ...                      ...            ...
# 4448  9975901508601701              [TMAGR PER]            [4]
# 4449  9975989409901701  [TWILS PERC, TMAGR PER]           [34]
# 4450  9976125196401701              [TMAGR PER]           [14]
# 4451  9976125496801701              [TMAGR PER]           [14]
# 4452  9976424005001701              [TWILS PER]            [2]
#
#                                                   chron  \
# 0     [2004, 2010, 1978, 1984, 1995, 1971, 1977, 198...
# 1     [1978, 1995, 1987, 1977, 2001, 1980, 1985, 199...
# 2                                                [2004]
# 3                                    [1994, 1995, 1997]
# 4     [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# ...                                                 ...
# 4448       [1934-1937, 1942-1945, 1938-1941, 1929-1933]
# 4449  [1905, 1906, 1890, 1904, 1888/89, 1885-1885/18...
# 4450  [1933-1934, 1934-1935, 1930-1931, 1932, 1938, ...
# 4451          [1926, 1924-1925, 1925, 1928, 1927, 1929]
# 4452                                  [2015-2017, 2018]
#
#                  curr-lib-loc_ALL
# 0                  ['TBIOM PERS']
# 1                  ['TBIOM PERS']
# 2                    ['TSCI PER']
# 3       ['TCOS SN1', 'ZMLAC OWL']
# 4                   ['ZMLAC OWL']
# ...                           ...
# 4448                ['TMAGR PER']
# 4449  ['TWILS PERC', 'TMAGR PER']
# 4450                ['TMAGR PER']
# 4451                ['TMAGR PER']
# 4452                ['TWILS PER']
#
# [4453 rows x 5 columns]

# %%
#change filename
groups_df = pd.read_pickle('all_groups_20201110.pkl')
groups_df
# Out:
#        record_index            MMS_ID  \
# 2             57684  9963550760001701
# 3            128733  9968441380001701
# 7             88618  9939481760001701
# 8            111951  9968429800001701
# 15           123907  9967115530001701
# ...             ...               ...
# 16156         17960  9946768760001701
# 16157        117510  9967987860001701
# 16158        124654  9924328340001701
# 16159         31683  9957960200001701
# 16160        125537  9968947900001701
#
#                                                Title_bib       ISSN_bib  \
# 2           IEEE transactions on ultrasonics engineering  ['0893-6706']
# 3           IEEE transactions on ultrasonics engineering  ['2162-1373']
# 7                  Journal of the Institute of Actuaries  ['0020-2681']
# 8                  Journal of the Institute of Actuaries  ['2058-1009']
# 15        Giornale degli economisti e annali di economia           ['']
# ...                                                  ...            ...
# 16156                                       The Americas  ['0003-1615']
# 16157  The Americas - Academy of American Franciscan ...  ['1533-6247']
# 16158                                  Americas (Online)           ['']
# 16159    International journal of adhesion and adhesives  ['0143-7496']
# 16160    International journal of adhesion and adhesives  ['1879-0127']
#
#                      ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 2                   ['0893-6706']      p                 5     0893-6706
# 3      ['0893-6706', '2162-1373']      e                 5     2162-1373
# 7                   ['0020-2681']      p                12     0020-2681
# 8      ['0020-2681', '2058-1009']      e                12     2058-1009
# 15                  ['0017-0097']      e                92
# ...                           ...    ...               ...           ...
# 16156  ['1533-6247', '0003-1615']      p            101581     0003-1615
# 16157  ['1533-6247', '0003-1615']      e            101581     1533-6247
# 16158               ['0003-1615']      e            101581
# 16159               ['0143-7496']      p            101582     0143-7496
# 16160  ['0143-7496', '1879-0127']      e            101582     1879-0127
#
#                                              e_coll_info  \
# 2                                                    NaN
# 3      [['61619505660001701', 'IEEE/IET Electronic Li...
# 7                                                    NaN
# 8      [['61535216140001701', 'JSTOR Business III Col...
# 15     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                  ...
# 16156                                                NaN
# 16157  [['61535211010001701', 'JSTOR Arts and Science...
# 16158                                                NaN
# 16159                                                NaN
# 16160  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                           portfolio_info  ... ISSN_PORTICO  \
# 2                                                    NaN  ...          NaN
# 3      [['53620359120001701', 'IEEE transactions on u...  ...          NaN
# 7                                                    NaN  ...          NaN
# 8      [['53540140170001701', 'Journal of the Institu...  ...          NaN
# 15     [['53537228640001701', 'Giornale degli economi...  ...          NaN
# ...                                                  ...  ...          ...
# 16156                                                NaN  ...          NaN
# 16157           [['53539160390001701', 'The Americas.']]  ...          NaN
# 16158                                                NaN  ...          NaN
# 16159                                                NaN  ...          NaN
# 16160  [['53624617390001701', 'International journal ...  ...          NaN
#
#       Title (Complete)_PORTICO Portico Match_PORTICO Portico Title_PORTICO  \
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 7                          NaN                   NaN                   NaN
# 8                          NaN                   NaN                   NaN
# 15                         NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 16156                      NaN                   NaN                   NaN
# 16157                      NaN                   NaN                   NaN
# 16158                      NaN                   NaN                   NaN
# 16159                      NaN                   NaN                   NaN
# 16160                      NaN                   NaN                   NaN
#
#       PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 2             NaN            NaN                             NaN
# 3             NaN            NaN                             NaN
# 7             NaN            NaN                             NaN
# 8             NaN            NaN                             NaN
# 15            NaN            NaN                             NaN
# ...           ...            ...                             ...
# 16156         NaN            NaN                             NaN
# 16157         NaN            NaN                             NaN
# 16158         NaN            NaN                             NaN
# 16159         NaN            NaN                             NaN
# 16160         NaN            NaN                             NaN
#
#       Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 7                               NaN                       NaN
# 8                               NaN                       NaN
# 15                              NaN                       NaN
# ...                             ...                       ...
# 16156                           NaN                       NaN
# 16157                           NaN                       NaN
# 16158                           NaN                       NaN
# 16159                           NaN                       NaN
# 16160                           NaN                       NaN
#
#       Linking ISSN split_PORTICO
# 2                            NaN
# 3                            NaN
# 7                            NaN
# 8                            NaN
# 15                           NaN
# ...                          ...
# 16156                        NaN
# 16157                        NaN
# 16158                        NaN
# 16159                        NaN
# 16160                        NaN
#
# [8872 rows x 34 columns]

# %%
df2 = pd.merge(groups_df,chron_combo,how='left',left_on='MMS_ID',right_on='001-MMS_ID')
df2
# Out:
#       record_index            MMS_ID  \
# 0            57684  9963550760001701
# 1           128733  9968441380001701
# 2            88618  9939481760001701
# 3           111951  9968429800001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8867         17960  9946768760001701
# 8868        117510  9967987860001701
# 8869        124654  9924328340001701
# 8870         31683  9957960200001701
# 8871        125537  9968947900001701
#
#                                               Title_bib       ISSN_bib  \
# 0          IEEE transactions on ultrasonics engineering  ['0893-6706']
# 1          IEEE transactions on ultrasonics engineering  ['2162-1373']
# 2                 Journal of the Institute of Actuaries  ['0020-2681']
# 3                 Journal of the Institute of Actuaries  ['2058-1009']
# 4        Giornale degli economisti e annali di economia           ['']
# ...                                                 ...            ...
# 8867                                       The Americas  ['0003-1615']
# 8868  The Americas - Academy of American Franciscan ...  ['1533-6247']
# 8869                                  Americas (Online)           ['']
# 8870    International journal of adhesion and adhesives  ['0143-7496']
# 8871    International journal of adhesion and adhesives  ['1879-0127']
#
#                     ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                  ['0893-6706']      p                 5     0893-6706
# 1     ['0893-6706', '2162-1373']      e                 5     2162-1373
# 2                  ['0020-2681']      p                12     0020-2681
# 3     ['0020-2681', '2058-1009']      e                12     2058-1009
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...           ...
# 8867  ['1533-6247', '0003-1615']      p            101581     0003-1615
# 8868  ['1533-6247', '0003-1615']      e            101581     1533-6247
# 8869               ['0003-1615']      e            101581
# 8870               ['0143-7496']      p            101582     0143-7496
# 8871  ['0143-7496', '1879-0127']      e            101582     1879-0127
#
#                                             e_coll_info  \
# 0                                                   NaN
# 1     [['61619505660001701', 'IEEE/IET Electronic Li...
# 2                                                   NaN
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8867                                                NaN
# 8868  [['61535211010001701', 'JSTOR Arts and Science...
# 8869                                                NaN
# 8870                                                NaN
# 8871  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                          portfolio_info  ... Status_PORTICO  \
# 0                                                   NaN  ...            NaN
# 1     [['53620359120001701', 'IEEE transactions on u...  ...            NaN
# 2                                                   NaN  ...            NaN
# 3     [['53540140170001701', 'Journal of the Institu...  ...            NaN
# 4     [['53537228640001701', 'Giornale degli economi...  ...            NaN
# ...                                                 ...  ...            ...
# 8867                                                NaN  ...            NaN
# 8868           [['53539160390001701', 'The Americas.']]  ...            NaN
# 8869                                                NaN  ...            NaN
# 8870                                                NaN  ...            NaN
# 8871  [['53624617390001701', 'International journal ...  ...            NaN
#
#      Earliest Year Preserved_PORTICO Latest Year Preserved_PORTICO  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 8867                             NaN                           NaN
# 8868                             NaN                           NaN
# 8869                             NaN                           NaN
# 8870                             NaN                           NaN
# 8871                             NaN                           NaN
#
#      Linking ISSN list_PORTICO Linking ISSN split_PORTICO        001-MMS_ID  \
# 0                          NaN                        NaN  9963550760001701
# 1                          NaN                        NaN               NaN
# 2                          NaN                        NaN  9939481760001701
# 3                          NaN                        NaN               NaN
# 4                          NaN                        NaN               NaN
# ...                        ...                        ...               ...
# 8867                       NaN                        NaN  9946768760001701
# 8868                       NaN                        NaN               NaN
# 8869                       NaN                        NaN               NaN
# 8870                       NaN                        NaN  9957960200001701
# 8871                       NaN                        NaN               NaN
#
#               curr-lib-loc_x all_item_count  \
# 0                 [TZDS GEN]            [1]
# 1                        NaN            NaN
# 2                [TWILS CLS]           [46]
# 3                        NaN            NaN
# 4                        NaN            NaN
# ...                      ...            ...
# 8867  [ZMLAC OWL, TWILS PER]           [74]
# 8868                     NaN            NaN
# 8869                     NaN            NaN
# 8870              [TSCI PER]            [6]
# 8871                     NaN            NaN
#
#                                                   chron  \
# 0                                           [1963-1966]
# 1                                                   NaN
# 2     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8867  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8868                                                NaN
# 8869                                                NaN
# 8870  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
# 8871                                                NaN
#
#                 curr-lib-loc_ALL
# 0                   ['TZDS GEN']
# 1                            NaN
# 2                  ['TWILS CLS']
# 3                            NaN
# 4                            NaN
# ...                          ...
# 8867  ['ZMLAC OWL', 'TWILS PER']
# 8868                         NaN
# 8869                         NaN
# 8870                ['TSCI PER']
# 8871                         NaN
#
# [8872 rows x 39 columns]

# %%
df2.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib', 'ISSN_cluster',
#        'p_or_e', 'matches_group_id', 'ISSN_to_match', 'e_coll_info',
#        'portfolio_info', 'Coverage Information Combined', 'PCAD?',
#        'Vendor_key', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
#        'Publisher (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Publisher (Print).1_BTAA-SPR', 'Title 3 (Print)_BTAA-SPR',
#        'Publisher (Print).2_BTAA-SPR', '(more bib records?)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'SPR Missing_BTAA-SPR',
#        'ISSN_PORTICO', 'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'Linking ISSN list_PORTICO', 'Linking ISSN split_PORTICO', '001-MMS_ID',
#        'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL'],
#       dtype='object')

# %% [markdown]
# #### Process chron data to get semi-sensical dates

# %%
dates = df2['chron']
dates.dropna(inplace=True)
dates
# Out:
# 0                                             [1963-1966]
# 2       [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 5       [1970, 1939, 1969, 1950, 1960, 1978, 1940, 199...
# 7       [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...
# 8       [1970, 1978, 1984, 1995, 1987, 1983, 2009, 197...
#                               ...
# 8862                                         [1984, 1985]
# 8863    [2004, 2012, 1940, 1975-76, 1964, 1987, 1981-8...
# 8866    [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8867    [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8870    [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
# Name: chron, Length: 4628, dtype: object

# %%
dates = dates[dates.apply(len) > 0]
dates
# Out:
# 0                                             [1963-1966]
# 2       [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 5       [1970, 1939, 1969, 1950, 1960, 1978, 1940, 199...
# 7       [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...
# 8       [1970, 1978, 1984, 1995, 1987, 1983, 2009, 197...
#                               ...
# 8862                                         [1984, 1985]
# 8863    [2004, 2012, 1940, 1975-76, 1964, 1987, 1981-8...
# 8866    [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8867    [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8870    [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
# Name: chron, Length: 4628, dtype: object

# %%
def date_fix (dlist):
    fixed_dates = []
    for date in dlist:
        #date = date.replace(' ','')
            
        date = str(date).strip()
        if date == '':
            print(date)
            print('Nothin?')
        #1973-89

        elif re.findall("^\d{4}-\d{2}$", date):
            #print(date + " range")
            year, partyear = re.split('-',date)
            century = year[:2]
            newyear = century + partyear
            rangeYear = int(newyear) + 1
            year_range = list(range(int(year), rangeYear))
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        elif re.findall("^\d{4}$", date):
            ##print(date + " four digits")
            fixed_dates.append(int(date))
            ##print(fixed_dates)

        elif re.findall("^\d{4}-\d{4}$",date):
            #print(date + " year-year")
            year1, year2 = re.split(r'[-]',date)
            #print(year1)
            #print(year2)
            year_range = list(range(int(year1),int(year2)+1))
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        elif re.findall("^\d{4}\/\d{4}$",date):
            #print(date + " year/year")
            year1, year2 = re.split(r'[/]',date)
            #print(year1)
            #print(year2)
            year_range = list(range(int(year1),int(year2)+1))
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        elif re.findall("^\d{4}\/\d{2}$",date):
            #print(date + " year/year")
            year, partyear = re.split(r'[/]',date)
            century = year[:2]
            newyear = century + partyear
            rangeYear = int(newyear) + 1
            year_range = list(range(int(year), rangeYear))
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        #1990/91-1991/92
        elif re.findall("^\d{4}\/\d{2}-\d{4}\/\d{2}$",date):
            #print(date)
            p = re.search("(?P<year1>^\d{4})(\/)(?P<yrpt2>\d{2})(-)(?P<year3>\d{4})(\/)(?P<yrpt4>\d{2}$)",date)
            #print(p)
            y1 = p.group('year1')
            c1 = y1[:2]
            y2 = c1 + p.group('yrpt2')
            range1 = list(range(int(y1),int(y2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            y3 = p.group('year3')
            c2 = y3[:2]

            range3 = list(range(int(y2),int(y3)+1))
            #print(range3)
            fixed_dates.extend(range3)

            y4 = c2 + p.group('yrpt4')
            range2 = list(range(int(y3),int(y4)+1))
            #print(range2)
            fixed_dates.extend(range2)

            #print(fixed_dates)

        #2003/2004-2004/2005
        elif re.findall("^\d{4}\/\d{4}-\d{4}\/\d{4}$",date):
            #print(date + " year/year-year/year")
            date1, date2 = re.split('-',date)

            year1, year2 = re.split(r'[/]',date1)
            year_range1 = list(range(int(year1), int(year2)+1))
            #print(year_range1)
            fixed_dates.extend(year_range1)

            year3, year4 = re.split(r'[/]',date2)
            year_range2 = list(range(int(year2), int(year3)+1))
            #print(year_range2)
            fixed_dates.extend(year_range2)

            year_range3 = list(range(int(year3),int(year4)+1))
            #print(year_range3)
            fixed_dates.extend(year_range3)

            #print(fixed_dates)

        #2001-2001/2002
        elif re.findall("^\d{4}-\d{4}\/\d{4}$",date):
            #print(date + " year-year/year")
            date1, date2 = re.split('-',date)

            fixed_dates.append(int(date1))

            year1, year2 = re.split(r'[/]',date2)
            year_range = list(range(int(year1), int(year2)+1))
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        #1999/2000-2000
        elif re.findall("^\d{4}\/\d{4}-\d{4}$",date):
            #print(date + " year/year-year")
            date1, date2 = re.split('-',date)

            fixed_dates.append(int(date2))

            year1, year2 = re.split(r'[/]',date1)
            year_range = list(range(int(year1), int(year2)+1))
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        #1985-89/90
        elif re.findall("^\d{4}-\d{2}\/\d{2}$",date):
            #print(date + " year-yr/yr")
            y1,y2,y3 = re.split(r'[/-]',date)
            century = y1[:2]
            ny2 = century + y2
            ny3 = century + y3

            year_range1 = list(range(int(y1), int(ny2)+1))
            #print(year_range1)
            fixed_dates.extend(year_range1)

            year_range2 = list(range(int(ny2), int(ny3)+1))
            #print(year_range2)
            fixed_dates.extend(year_range2)

            #print(fixed_dates)        

        #1988/89-90
        elif re.findall("^\d{4}\/\d{2}-\d{2}$",date):
            #print(date + " year/yr-yr")
            year1, years = re.split(r'[/]',date)
            partyear1, partyear2 = re.split('-',years)
            century = year1[:2]
            newyear1 = century + partyear1
            newyear2 = century + partyear2

            rangeYear1 = int(newyear1) + 1
            year_range1 = list(range(int(year1), rangeYear1))
            #print(year_range1)
            fixed_dates.extend(year_range1)

            rangeYear2 = int(newyear2) + 1
            year_range2 = list(range(int(newyear1), rangeYear2))
            #print(year_range2)
            fixed_dates.extend(year_range2)

            #print(fixed_dates)    

        #2001/02-2004
        elif re.findall("^\d{4}\/\d{2}-\d{4}$",date):
            #print(date + " year/yr-year")
            years, year2 = re.split(r'[-]',date)
            year1, partyear =  re.split(r'[/]',years)
            century = year1[:2]
            newyear = century + partyear

            rangeYear1 = int(newyear) + 1
            year_range1 = list(range(int(year1), rangeYear1))
            #print(year_range1)
            fixed_dates.extend(year_range1)

            rangeYear2 = int(year2) + 1
            year_range2 = list(range(rangeYear1, rangeYear2))
            #print(year_range2)
            fixed_dates.extend(year_range2)
            #print(fixed_dates)            

        #1999/2000-2000/01
        elif re.findall("^\d{4}\/\d{4}-\d{4}\/\d{2}$",date):
            #print(date + " year/year-year/yr")
            ys1, ys2 = re.split(r'[-]',date)
            y1a, y1b  =  re.split(r'[/]',ys1)

            year_range1 = list(range(int(y1a), int(y1b)+1))
            #print(year_range1)
            fixed_dates.extend(year_range1)

            y2,py2 = re.split(r'[/]',ys2)
            ce2 = y2[:2]
            ny2 = ce2 + py2
            year_range2 = list(range(int(y2),int(ny2)+1))
            #print(year_range2)
            fixed_dates.extend(year_range2)
            #print(fixed_dates)  

        #1989-1990/91
        elif re.findall("^\d{4}-\d{4}\/\d{2}$",date):
            #print(date + " year-year/yr")
            y1, ys2 = re.split(r'[-]',date)
            y2a, y2b  =  re.split(r'[/]',ys2)

            year_range1 = list(range(int(y1), int(y2a)+1))
            #print(year_range1)
            fixed_dates.extend(year_range1)

            ce2 = y2a[:2]
            ny2 = ce2 + y2b
            year_range2 = list(range(int(y2a),int(ny2)+1))
            #print(year_range2)
            fixed_dates.extend(year_range2)
            #print(fixed_dates)  

        #1999,2001
        elif re.findall("^\d{4}\,\d{4}$",date):
            #print(date + " year,year")
            year1, year2 = re.split(r'[,]',date)
            year_range = [int(year1),int(year2)]
            #print(year_range)
            fixed_dates.extend(year_range)
            #print(fixed_dates)

        #200602006/2007
        elif re.findall("^\d{4}0\d{4}\/\d{4}$",date):
            p = re.search("(?P<year1>^\d{4})(?P<zero>0)(?P<range>\d{4}\/\d{4}$)",date)
            #print(p)
            y1 = p.group('year1')
            yset = p.group('range')
            year1,year2 = re.split(r'[/]',yset)
            yrange = list(range(int(y1),int(year1)+1))
            #print(yrange)
            fixed_dates.extend(yrange)
            yrange2 = list(range(int(year1),int(year2)+1))
            #print(yrange2)
            fixed_dates.extend(yrange2)

        #1960-68, 1978-2005
        elif re.findall("^\d{4}-\d{2},\s\d{4}-\d{4}$",date):
            #print(date)
            p = re.search("(?P<year1>^\d{4})(-)(?P<yrpt1>\d{2})(,\s)(?P<year3>\d{4})(-)(?P<year4>\d{4}$)",date)
            #p = re.search("(?P<year1>\d{4})(-)(?P<yrpt1>\d{2})(,\s)(?P<year3>\d{4})(-)",date)
            #print(p)
            y1 = p.group('year1')
            c1 = y1[:2]
            y2 = c1 + p.group('yrpt1')
            range1 = list(range(int(y1),int(y2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            range2 = list(range(int(p.group('year3')),int(p.group('year4'))+1))
            #print(range2)
            fixed_dates.extend(range2)
            #print(fixed_dates)

        #1948-66,1970
        elif re.findall("^\d{4}-\d{2},\d{4}$",date):
            #print(date)
            p = re.search("(?P<year1>^\d{4})(-)(?P<yrpt1>\d{2})(,)(?P<year3>\d{4}$)",date)
            #print(p)
            y1 = p.group('year1')
            c1 = y1[:2]
            y2 = c1 + p.group('yrpt1')
            range1 = list(range(int(y1),int(y2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            fixed_dates.append(int(p.group('year3')))
            #print(fixed_dates)

        #1988/89-89/90
        elif re.findall("^\d{4}\/\d{2}-\d{2}\/\d{2}$",date):
            #print(date)
            p = re.search("(?P<year1>^\d{4})(\/)(?P<yrpt2>\d{2})(-)(?P<yrpt3>\d{2})(\/)(?P<yrpt4>\d{2}$)",date)
            #print(p)
            y1 = p.group('year1')
            c1 = y1[:2]
            y2 = c1 + p.group('yrpt2')
            range1 = list(range(int(y1),int(y2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            y3 = c1 + p.group('yrpt3')
            range2 = list(range(int(y2),int(y3)+1))
            #print(range2)
            fixed_dates.extend(range2)

            range3 = list(range(int(y3),int(c1 + p.group('yrpt4'))+1))
            #print(range3)
            fixed_dates.extend(range3)
            #print(fixed_dates)

        #1998/99-1999/2000
        elif re.findall("^\d{4}\/\d{2}-\d{4}\/\d{4}$",date):
            #print(date)
            p = re.search("(?P<year1>^\d{4})(\/)(?P<yrpt2>\d{2})(-)(?P<y3>\d{4})(\/)(?P<y4>\d{4}$)",date)
            #print(p)
            y1 = p.group('year1')
            c1 = y1[:2]
            y2 = c1 + p.group('yrpt2')
            range1 = list(range(int(y1),int(y2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            y3 = p.group('y3')
            range2 = list(range(int(y2),int(y3)+1))
            #print(range2)
            fixed_dates.extend(range2)

            range3 = list(range(int(y3),int(p.group('y4'))+1))
            #print(range3)
            fixed_dates.extend(range3)
            #print(fixed_dates)

        #2015=2016
        elif re.findall("^\d{4}=\d{4}$",date):
            #print(date)
            p = re.search("(?P<year1>^\d{4})(\=)(?P<year2>\d{4}$)",date)
            #print(p)
            #print(type(p.group('year1')))
            #print(type(p.group('year2')))
            range1 = list(range(int(p.group('year1')),int(p.group('year2'))+1))
            #print(range1)
            fixed_dates.extend(range1)
            #print(fixed_dates)

        #200120/02-2003/2004
        elif re.findall("^\d{6}\/\d{2}-\d{4}\/\d{4}$",date):
            #print(date)
            yrs1,yrs2 = re.split(r'[-]',date)
            yrs1 = yrs1.replace("/","")
            year1 = yrs1[:4]
            year2 = yrs1[4:]
            #print(year1)
            #print(year2)

            year3,year4 = yrs2.split('/')
            #print(year3)
            #print(year4)

            range1 = list(range(int(year1),int(year2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            range2 = list(range(int(year2),int(year3)+1))
            #print(range2)
            fixed_dates.extend(range2)

            range3 = list(range(int(year3),int(year4)+1))
            #print(range3)
            fixed_dates.extend(range3)

            #print(fixed_dates)

        #1-1
        elif re.findall("^\d{1}-\d{1}$",date):
            print(date)
            print(" probably not a date?")

        #1997/98- 1998
        elif re.findall("^\d{4}\/\d{2}-\s\d{4}$",date):
            #print(date)
            yrs,year3 = re.split(r'[-]',date)
            year3 = year3.strip()
            year1,year2 = re.split(r'[/]',yrs)
            c1 = year1[:2]
            year2 = c1 + year2

            #print(year1)
            #print(year2)
            #print(year3)

            range1 = list(range(int(year1),int(year2)+1))
            #print(range1)
            fixed_dates.extend(range1)

            range2 = list(range(int(year2),int(year3)+1))
            #print(range2)
            fixed_dates.extend(range2)

            #print(fixed_dates)

        #2001-10-12
        elif re.findall("^\d{4}-\d{2}-\d{2}$",date):
            #print(date + " year-mm-dd")
            year, mo, day = re.split('-',date)
            fixed_dates.append(int(year))

            #print(fixed_dates)

        #1976-19.78
        elif re.findall("^\d{4}-\d{2}\.\d{2}$",date):
            #print(date + " year-yy.yy")
            year1, year2 = re.split('-',date)
            #print(year1)
            year2 = year2.replace(".","")
            #print(year2)
            rangeyear = list(range(int(year1),int(year2)+1))
            fixed_dates.extend(rangeyear)

            #print(fixed_dates)

        else:
            print(date)
            print("UNKNOWN FORMAT")
            #fixed_dates.append(int(date))
            #print(fixed_dates)

    return list(sorted(set(fixed_dates)))

# %%
fixed_dates = dates.apply(date_fix)
fixed_dates
# Out:
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 1984198
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 195-
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 1961-
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 195/1966
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 2011, 2013-2014
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 2005/062007
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
#
# Nothin?
# 1992.93
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
# 1975-19+76
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
# 19931994
# UNKNOWN FORMAT
#
# Nothin?
#
# Nothin?
# 0                                [1963, 1964, 1965, 1966]
# 2       [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 5       [1939, 1940, 1941, 1942, 1946, 1947, 1949, 195...
# 7       [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8       [1969, 1970, 1972, 1975, 1976, 1978, 1980, 198...
#                               ...
# 8862                                         [1984, 1985]
# 8863    [1935, 1936, 1937, 1938, 1939, 1940, 1943, 194...
# 8866    [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8867    [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8870    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# Name: chron, Length: 4628, dtype: object

# %%
def ranges(ints):
    #print(ints)
    ints = sorted(set(ints))
    if ints == []:
        print('empty list')
        yield ''
    else:
        range_start = previous_number = ints[0]
        for number in ints[1:]:
            #print(number)
            #print(type(number))
            #print(previous_number)
            #print(type(previous_number))
            if number == (previous_number + 1):
                previous_number = number
            else:
                yield range_start, previous_number
                range_start = previous_number = number
        yield range_start, previous_number

# %%
date_ranges = fixed_dates.apply(ranges).apply(list)
date_ranges
# Out:
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# empty list
# 0                                          [(1963, 1966)]
# 2       [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 5       [(1939, 1942), (1946, 1947), (1949, 1951), (19...
# 7                                          [(1967, 1992)]
# 8       [(1969, 1970), (1972, 1972), (1975, 1976), (19...
#                               ...
# 8862                                       [(1984, 1985)]
# 8863    [(1935, 1940), (1943, 1944), (1947, 1951), (19...
# 8866           [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8867                                       [(1944, 2014)]
# 8870                                       [(1980, 1990)]
# Name: chron, Length: 4628, dtype: object

# %%
dates_df = pd.DataFrame(fixed_dates)
dates_df
# Out:
#                                                   chron
# 0                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 5     [1939, 1940, 1941, 1942, 1946, 1947, 1949, 195...
# 7     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8     [1969, 1970, 1972, 1975, 1976, 1978, 1980, 198...
# ...                                                 ...
# 8862                                       [1984, 1985]
# 8863  [1935, 1936, 1937, 1938, 1939, 1940, 1943, 194...
# 8866  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8867  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8870  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [4628 rows x 1 columns]

# %%
ranges_df = pd.DataFrame(date_ranges)
ranges_df
# Out:
#                                                   chron
# 0                                        [(1963, 1966)]
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 5     [(1939, 1942), (1946, 1947), (1949, 1951), (19...
# 7                                        [(1967, 1992)]
# 8     [(1969, 1970), (1972, 1972), (1975, 1976), (19...
# ...                                                 ...
# 8862                                     [(1984, 1985)]
# 8863  [(1935, 1940), (1943, 1944), (1947, 1951), (19...
# 8866         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8867                                     [(1944, 2014)]
# 8870                                     [(1980, 1990)]
#
# [4628 rows x 1 columns]

# %%
combo_ranges = pd.merge(dates_df,ranges_df,how='outer',right_index=True,left_index=True,suffixes=['_as_list','_ranges_calc'])
combo_ranges
# Out:
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 5     [1939, 1940, 1941, 1942, 1946, 1947, 1949, 195...
# 7     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8     [1969, 1970, 1972, 1975, 1976, 1978, 1980, 198...
# ...                                                 ...
# 8862                                       [1984, 1985]
# 8863  [1935, 1936, 1937, 1938, 1939, 1940, 1943, 194...
# 8866  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8867  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8870  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc
# 0                                        [(1963, 1966)]
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 5     [(1939, 1942), (1946, 1947), (1949, 1951), (19...
# 7                                        [(1967, 1992)]
# 8     [(1969, 1970), (1972, 1972), (1975, 1976), (19...
# ...                                                 ...
# 8862                                     [(1984, 1985)]
# 8863  [(1935, 1940), (1943, 1944), (1947, 1951), (19...
# 8866         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8867                                     [(1944, 2014)]
# 8870                                     [(1980, 1990)]
#
# [4628 rows x 2 columns]

# %%
df_with_ranges = pd.merge(df2,combo_ranges,how='left',right_index=True,left_index=True)
df_with_ranges
# Out:
#       record_index            MMS_ID  \
# 0            57684  9963550760001701
# 1           128733  9968441380001701
# 2            88618  9939481760001701
# 3           111951  9968429800001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8867         17960  9946768760001701
# 8868        117510  9967987860001701
# 8869        124654  9924328340001701
# 8870         31683  9957960200001701
# 8871        125537  9968947900001701
#
#                                               Title_bib       ISSN_bib  \
# 0          IEEE transactions on ultrasonics engineering  ['0893-6706']
# 1          IEEE transactions on ultrasonics engineering  ['2162-1373']
# 2                 Journal of the Institute of Actuaries  ['0020-2681']
# 3                 Journal of the Institute of Actuaries  ['2058-1009']
# 4        Giornale degli economisti e annali di economia           ['']
# ...                                                 ...            ...
# 8867                                       The Americas  ['0003-1615']
# 8868  The Americas - Academy of American Franciscan ...  ['1533-6247']
# 8869                                  Americas (Online)           ['']
# 8870    International journal of adhesion and adhesives  ['0143-7496']
# 8871    International journal of adhesion and adhesives  ['1879-0127']
#
#                     ISSN_cluster p_or_e  matches_group_id ISSN_to_match  \
# 0                  ['0893-6706']      p                 5     0893-6706
# 1     ['0893-6706', '2162-1373']      e                 5     2162-1373
# 2                  ['0020-2681']      p                12     0020-2681
# 3     ['0020-2681', '2058-1009']      e                12     2058-1009
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...           ...
# 8867  ['1533-6247', '0003-1615']      p            101581     0003-1615
# 8868  ['1533-6247', '0003-1615']      e            101581     1533-6247
# 8869               ['0003-1615']      e            101581
# 8870               ['0143-7496']      p            101582     0143-7496
# 8871  ['0143-7496', '1879-0127']      e            101582     1879-0127
#
#                                             e_coll_info  \
# 0                                                   NaN
# 1     [['61619505660001701', 'IEEE/IET Electronic Li...
# 2                                                   NaN
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8867                                                NaN
# 8868  [['61535211010001701', 'JSTOR Arts and Science...
# 8869                                                NaN
# 8870                                                NaN
# 8871  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                          portfolio_info  ...  \
# 0                                                   NaN  ...
# 1     [['53620359120001701', 'IEEE transactions on u...  ...
# 2                                                   NaN  ...
# 3     [['53540140170001701', 'Journal of the Institu...  ...
# 4     [['53537228640001701', 'Giornale degli economi...  ...
# ...                                                 ...  ...
# 8867                                                NaN  ...
# 8868           [['53539160390001701', 'The Americas.']]  ...
# 8869                                                NaN  ...
# 8870                                                NaN  ...
# 8871  [['53624617390001701', 'International journal ...  ...
#
#      Latest Year Preserved_PORTICO Linking ISSN list_PORTICO  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 8867                           NaN                       NaN
# 8868                           NaN                       NaN
# 8869                           NaN                       NaN
# 8870                           NaN                       NaN
# 8871                           NaN                       NaN
#
#      Linking ISSN split_PORTICO        001-MMS_ID          curr-lib-loc_x  \
# 0                           NaN  9963550760001701              [TZDS GEN]
# 1                           NaN               NaN                     NaN
# 2                           NaN  9939481760001701             [TWILS CLS]
# 3                           NaN               NaN                     NaN
# 4                           NaN               NaN                     NaN
# ...                         ...               ...                     ...
# 8867                        NaN  9946768760001701  [ZMLAC OWL, TWILS PER]
# 8868                        NaN               NaN                     NaN
# 8869                        NaN               NaN                     NaN
# 8870                        NaN  9957960200001701              [TSCI PER]
# 8871                        NaN               NaN                     NaN
#
#      all_item_count                                              chron  \
# 0               [1]                                        [1963-1966]
# 1               NaN                                                NaN
# 2              [46]  [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 8867           [74]  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8868            NaN                                                NaN
# 8869            NaN                                                NaN
# 8870            [6]  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
# 8871            NaN                                                NaN
#
#                 curr-lib-loc_ALL  \
# 0                   ['TZDS GEN']
# 1                            NaN
# 2                  ['TWILS CLS']
# 3                            NaN
# 4                            NaN
# ...                          ...
# 8867  ['ZMLAC OWL', 'TWILS PER']
# 8868                         NaN
# 8869                         NaN
# 8870                ['TSCI PER']
# 8871                         NaN
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                                                   NaN
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8867  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8868                                                NaN
# 8869                                                NaN
# 8870  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8871                                                NaN
#
#                                       chron_ranges_calc
# 0                                        [(1963, 1966)]
# 1                                                   NaN
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8867                                     [(1944, 2014)]
# 8868                                                NaN
# 8869                                                NaN
# 8870                                     [(1980, 1990)]
# 8871                                                NaN
#
# [8872 rows x 41 columns]

# %%
#check to make sure every row with data had a range calculated
df_with_ranges[df_with_ranges['chron_as_list'].notnull() & df_with_ranges['chron_ranges_calc'].isna()]
# Out:
# Empty DataFrame
# Columns: [record_index, MMS_ID, Title_bib, ISSN_bib, ISSN_cluster, p_or_e, matches_group_id, ISSN_to_match, e_coll_info, portfolio_info, Coverage Information Combined, PCAD?, Vendor_key, ISSN Number_BTAA-SPR, Title 1 (Print)_BTAA-SPR, Publisher (Print)_BTAA-SPR, Title 2 (Print)_BTAA-SPR, Publisher (Print).1_BTAA-SPR, Title 3 (Print)_BTAA-SPR, Publisher (Print).2_BTAA-SPR, (more bib records?)_BTAA-SPR, Match?_BTAA-SPR, SPR Holdings_BTAA-SPR, SPR Missing_BTAA-SPR, ISSN_PORTICO, Title (Complete)_PORTICO, Portico Match_PORTICO, Portico Title_PORTICO, PCA_PORTICO, Status_PORTICO, Earliest Year Preserved_PORTICO, Latest Year Preserved_PORTICO, Linking ISSN list_PORTICO, Linking ISSN split_PORTICO, 001-MMS_ID, curr-lib-loc_x, all_item_count, chron, curr-lib-loc_ALL, chron_as_list, chron_ranges_calc]
# Index: []
#
# [0 rows x 41 columns]

# %%
df_with_ranges.to_pickle(f'df_with_date_ranges_{today}.pkl')

# %% [markdown]
# #### Extract only the columns useful for coverage comparison

# %%
df = df_with_ranges
df.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_bib', 'ISSN_cluster',
#        'p_or_e', 'matches_group_id', 'ISSN_to_match', 'e_coll_info',
#        'portfolio_info', 'Coverage Information Combined', 'PCAD?',
#        'Vendor_key', 'ISSN Number_BTAA-SPR', 'Title 1 (Print)_BTAA-SPR',
#        'Publisher (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Publisher (Print).1_BTAA-SPR', 'Title 3 (Print)_BTAA-SPR',
#        'Publisher (Print).2_BTAA-SPR', '(more bib records?)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'SPR Missing_BTAA-SPR',
#        'ISSN_PORTICO', 'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'Linking ISSN list_PORTICO', 'Linking ISSN split_PORTICO', '001-MMS_ID',
#        'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL',
#        'chron_as_list', 'chron_ranges_calc'],
#       dtype='object')

# %%
df = df[['record_index', 'MMS_ID', 'Title_bib','ISSN_cluster',
         'p_or_e', 'matches_group_id','e_coll_info','portfolio_info',
         'Coverage Information Combined', 'PCAD?', 'Vendor_key',
         'Title 1 (Print)_BTAA-SPR','Title 2 (Print)_BTAA-SPR', 'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 
         'Title (Complete)_PORTICO','Portico Match_PORTICO', 'Portico Title_PORTICO', 
         'PCA_PORTICO','Status_PORTICO', 'Earliest Year Preserved_PORTICO',
         'Latest Year Preserved_PORTICO', 'curr-lib-loc_x','all_item_count', 
         'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc']]
df
# Out:
#       record_index            MMS_ID  \
# 0            57684  9963550760001701
# 1           128733  9968441380001701
# 2            88618  9939481760001701
# 3           111951  9968429800001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8867         17960  9946768760001701
# 8868        117510  9967987860001701
# 8869        124654  9924328340001701
# 8870         31683  9957960200001701
# 8871        125537  9968947900001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8867                                       The Americas
# 8868  The Americas - Academy of American Franciscan ...
# 8869                                  Americas (Online)
# 8870    International journal of adhesion and adhesives
# 8871    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0                  ['0893-6706']      p                 5
# 1     ['0893-6706', '2162-1373']      e                 5
# 2                  ['0020-2681']      p                12
# 3     ['0020-2681', '2058-1009']      e                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8867  ['1533-6247', '0003-1615']      p            101581
# 8868  ['1533-6247', '0003-1615']      e            101581
# 8869               ['0003-1615']      e            101581
# 8870               ['0143-7496']      p            101582
# 8871  ['0143-7496', '1879-0127']      e            101582
#
#                                             e_coll_info  \
# 0                                                   NaN
# 1     [['61619505660001701', 'IEEE/IET Electronic Li...
# 2                                                   NaN
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8867                                                NaN
# 8868  [['61535211010001701', 'JSTOR Arts and Science...
# 8869                                                NaN
# 8870                                                NaN
# 8871  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                          portfolio_info  \
# 0                                                   NaN
# 1     [['53620359120001701', 'IEEE transactions on u...
# 2                                                   NaN
# 3     [['53540140170001701', 'Journal of the Institu...
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8867                                                NaN
# 8868           [['53539160390001701', 'The Americas.']]
# 8869                                                NaN
# 8870                                                NaN
# 8871  [['53624617390001701', 'International journal ...
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0                                                   NaN    NaN  ...
# 1     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 2                                                   NaN    NaN  ...
# 3     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8867                                                NaN    NaN  ...
# 8868         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8869                                                NaN    NaN  ...
# 8870                                                NaN    NaN  ...
# 8871     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
#
#      PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0            NaN            NaN                             NaN
# 1            NaN            NaN                             NaN
# 2            NaN            NaN                             NaN
# 3            NaN            NaN                             NaN
# 4            NaN            NaN                             NaN
# ...          ...            ...                             ...
# 8867         NaN            NaN                             NaN
# 8868         NaN            NaN                             NaN
# 8869         NaN            NaN                             NaN
# 8870         NaN            NaN                             NaN
# 8871         NaN            NaN                             NaN
#
#      Latest Year Preserved_PORTICO          curr-lib-loc_x all_item_count  \
# 0                              NaN              [TZDS GEN]            [1]
# 1                              NaN                     NaN            NaN
# 2                              NaN             [TWILS CLS]           [46]
# 3                              NaN                     NaN            NaN
# 4                              NaN                     NaN            NaN
# ...                            ...                     ...            ...
# 8867                           NaN  [ZMLAC OWL, TWILS PER]           [74]
# 8868                           NaN                     NaN            NaN
# 8869                           NaN                     NaN            NaN
# 8870                           NaN              [TSCI PER]            [6]
# 8871                           NaN                     NaN            NaN
#
#                                                   chron  \
# 0                                           [1963-1966]
# 1                                                   NaN
# 2     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8867  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8868                                                NaN
# 8869                                                NaN
# 8870  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
# 8871                                                NaN
#
#                 curr-lib-loc_ALL  \
# 0                   ['TZDS GEN']
# 1                            NaN
# 2                  ['TWILS CLS']
# 3                            NaN
# 4                            NaN
# ...                          ...
# 8867  ['ZMLAC OWL', 'TWILS PER']
# 8868                         NaN
# 8869                         NaN
# 8870                ['TSCI PER']
# 8871                         NaN
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                                                   NaN
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8867  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8868                                                NaN
# 8869                                                NaN
# 8870  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8871                                                NaN
#
#                                       chron_ranges_calc
# 0                                        [(1963, 1966)]
# 1                                                   NaN
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8867                                     [(1944, 2014)]
# 8868                                                NaN
# 8869                                                NaN
# 8870                                     [(1980, 1990)]
# 8871                                                NaN
#
# [8872 rows x 28 columns]

# %%
df.sort_values(by=['matches_group_id','Title_bib','p_or_e'], inplace=True)
df
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       record_index            MMS_ID  \
# 1           128733  9968441380001701
# 0            57684  9963550760001701
# 3           111951  9968429800001701
# 2            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8869        124654  9924328340001701
# 8867         17960  9946768760001701
# 8868        117510  9967987860001701
# 8871        125537  9968947900001701
# 8870         31683  9957960200001701
#
#                                               Title_bib  \
# 1          IEEE transactions on ultrasonics engineering
# 0          IEEE transactions on ultrasonics engineering
# 3                 Journal of the Institute of Actuaries
# 2                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8869                                  Americas (Online)
# 8867                                       The Americas
# 8868  The Americas - Academy of American Franciscan ...
# 8871    International journal of adhesion and adhesives
# 8870    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 1     ['0893-6706', '2162-1373']      e                 5
# 0                  ['0893-6706']      p                 5
# 3     ['0020-2681', '2058-1009']      e                12
# 2                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8869               ['0003-1615']      e            101581
# 8867  ['1533-6247', '0003-1615']      p            101581
# 8868  ['1533-6247', '0003-1615']      e            101581
# 8871  ['0143-7496', '1879-0127']      e            101582
# 8870               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 1     [['61619505660001701', 'IEEE/IET Electronic Li...
# 0                                                   NaN
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 2                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8869                                                NaN
# 8867                                                NaN
# 8868  [['61535211010001701', 'JSTOR Arts and Science...
# 8871  [['61624504590001701', 'Elsevier ScienceDirect...
# 8870                                                NaN
#
#                                          portfolio_info  \
# 1     [['53620359120001701', 'IEEE transactions on u...
# 0                                                   NaN
# 3     [['53540140170001701', 'Journal of the Institu...
# 2                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8869                                                NaN
# 8867                                                NaN
# 8868           [['53539160390001701', 'The Americas.']]
# 8871  [['53624617390001701', 'International journal ...
# 8870                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 1     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 0                                                   NaN    NaN  ...
# 3     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 2                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8869                                                NaN    NaN  ...
# 8867                                                NaN    NaN  ...
# 8868         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8871     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8870                                                NaN    NaN  ...
#
#      PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 1            NaN            NaN                             NaN
# 0            NaN            NaN                             NaN
# 3            NaN            NaN                             NaN
# 2            NaN            NaN                             NaN
# 4            NaN            NaN                             NaN
# ...          ...            ...                             ...
# 8869         NaN            NaN                             NaN
# 8867         NaN            NaN                             NaN
# 8868         NaN            NaN                             NaN
# 8871         NaN            NaN                             NaN
# 8870         NaN            NaN                             NaN
#
#      Latest Year Preserved_PORTICO          curr-lib-loc_x all_item_count  \
# 1                              NaN                     NaN            NaN
# 0                              NaN              [TZDS GEN]            [1]
# 3                              NaN                     NaN            NaN
# 2                              NaN             [TWILS CLS]           [46]
# 4                              NaN                     NaN            NaN
# ...                            ...                     ...            ...
# 8869                           NaN                     NaN            NaN
# 8867                           NaN  [ZMLAC OWL, TWILS PER]           [74]
# 8868                           NaN                     NaN            NaN
# 8871                           NaN                     NaN            NaN
# 8870                           NaN              [TSCI PER]            [6]
#
#                                                   chron  \
# 1                                                   NaN
# 0                                           [1963-1966]
# 3                                                   NaN
# 2     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8869                                                NaN
# 8867  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8868                                                NaN
# 8871                                                NaN
# 8870  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 1                            NaN
# 0                   ['TZDS GEN']
# 3                            NaN
# 2                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8869                         NaN
# 8867  ['ZMLAC OWL', 'TWILS PER']
# 8868                         NaN
# 8871                         NaN
# 8870                ['TSCI PER']
#
#                                           chron_as_list  \
# 1                                                   NaN
# 0                              [1963, 1964, 1965, 1966]
# 3                                                   NaN
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8869                                                NaN
# 8867  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8868                                                NaN
# 8871                                                NaN
# 8870  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc
# 1                                                   NaN
# 0                                        [(1963, 1966)]
# 3                                                   NaN
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8869                                                NaN
# 8867                                     [(1944, 2014)]
# 8868                                                NaN
# 8871                                                NaN
# 8870                                     [(1980, 1990)]
#
# [8872 rows x 28 columns]

# %%
df = df[((df['p_or_e'] == 'e') & (df['PCAD?'].notnull())) | (df['p_or_e'] == 'p')]
df
# Out:
#       record_index            MMS_ID  \
# 1           128733  9968441380001701
# 0            57684  9963550760001701
# 3           111951  9968429800001701
# 2            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8866         61904  9959156260001701
# 8867         17960  9946768760001701
# 8868        117510  9967987860001701
# 8871        125537  9968947900001701
# 8870         31683  9957960200001701
#
#                                               Title_bib  \
# 1          IEEE transactions on ultrasonics engineering
# 0          IEEE transactions on ultrasonics engineering
# 3                 Journal of the Institute of Actuaries
# 2                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8866         Year book - American Philosophical Society
# 8867                                       The Americas
# 8868  The Americas - Academy of American Franciscan ...
# 8871    International journal of adhesion and adhesives
# 8870    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 1     ['0893-6706', '2162-1373']      e                 5
# 0                  ['0893-6706']      p                 5
# 3     ['0020-2681', '2058-1009']      e                12
# 2                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8866  ['0065-9762', '0003-049X']      p            101522
# 8867  ['1533-6247', '0003-1615']      p            101581
# 8868  ['1533-6247', '0003-1615']      e            101581
# 8871  ['0143-7496', '1879-0127']      e            101582
# 8870               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 1     [['61619505660001701', 'IEEE/IET Electronic Li...
# 0                                                   NaN
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 2                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8866                                                NaN
# 8867                                                NaN
# 8868  [['61535211010001701', 'JSTOR Arts and Science...
# 8871  [['61624504590001701', 'Elsevier ScienceDirect...
# 8870                                                NaN
#
#                                          portfolio_info  \
# 1     [['53620359120001701', 'IEEE transactions on u...
# 0                                                   NaN
# 3     [['53540140170001701', 'Journal of the Institu...
# 2                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8866                                                NaN
# 8867                                                NaN
# 8868           [['53539160390001701', 'The Americas.']]
# 8871  [['53624617390001701', 'International journal ...
# 8870                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 1     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 0                                                   NaN    NaN  ...
# 3     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 2                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8866                                                NaN    NaN  ...
# 8867                                                NaN    NaN  ...
# 8868         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8871     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8870                                                NaN    NaN  ...
#
#      PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 1            NaN            NaN                             NaN
# 0            NaN            NaN                             NaN
# 3            NaN            NaN                             NaN
# 2            NaN            NaN                             NaN
# 4            NaN            NaN                             NaN
# ...          ...            ...                             ...
# 8866         NaN            NaN                             NaN
# 8867         NaN            NaN                             NaN
# 8868         NaN            NaN                             NaN
# 8871         NaN            NaN                             NaN
# 8870         NaN            NaN                             NaN
#
#      Latest Year Preserved_PORTICO          curr-lib-loc_x all_item_count  \
# 1                              NaN                     NaN            NaN
# 0                              NaN              [TZDS GEN]            [1]
# 3                              NaN                     NaN            NaN
# 2                              NaN             [TWILS CLS]           [46]
# 4                              NaN                     NaN            NaN
# ...                            ...                     ...            ...
# 8866                           NaN   [TSCI PER, ZMLAC OWL]           [53]
# 8867                           NaN  [ZMLAC OWL, TWILS PER]           [74]
# 8868                           NaN                     NaN            NaN
# 8871                           NaN                     NaN            NaN
# 8870                           NaN              [TSCI PER]            [6]
#
#                                                   chron  \
# 1                                                   NaN
# 0                                           [1963-1966]
# 3                                                   NaN
# 2     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8866  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8867  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8868                                                NaN
# 8871                                                NaN
# 8870  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 1                            NaN
# 0                   ['TZDS GEN']
# 3                            NaN
# 2                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8866   ['TSCI PER', 'ZMLAC OWL']
# 8867  ['ZMLAC OWL', 'TWILS PER']
# 8868                         NaN
# 8871                         NaN
# 8870                ['TSCI PER']
#
#                                           chron_as_list  \
# 1                                                   NaN
# 0                              [1963, 1964, 1965, 1966]
# 3                                                   NaN
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8866  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8867  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8868                                                NaN
# 8871                                                NaN
# 8870  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc
# 1                                                   NaN
# 0                                        [(1963, 1966)]
# 3                                                   NaN
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8866         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8867                                     [(1944, 2014)]
# 8868                                                NaN
# 8871                                                NaN
# 8870                                     [(1980, 1990)]
#
# [8595 rows x 28 columns]

# %%
df['matches_group_id'].nunique()
# Out:
# 3543

# %%
dfe = df[df['p_or_e'] == 'e']
dfe
# Out:
#       record_index            MMS_ID  \
# 1           128733  9968441380001701
# 3           111951  9968429800001701
# 4           123907  9967115530001701
# 6           104047  9968936470001701
# 10          115295  9968336850001701
# ...            ...               ...
# 8856        118480  9968239890001701
# 8857        118481  9968240180001701
# 8864        123828  9968665290001701
# 8868        117510  9967987860001701
# 8871        125537  9968947900001701
#
#                                               Title_bib  \
# 1          IEEE transactions on ultrasonics engineering
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# 6           Mathematics of the USSR. Izvestija (Online)
# 10    Laboratory techniques in biochemistry and mole...
# ...                                                 ...
# 8856                                   Physics letters.
# 8857                                   Physics letters.
# 8864  Proceedings and addresses of the American Phil...
# 8868  The Americas - Academy of American Franciscan ...
# 8871    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 1     ['0893-6706', '2162-1373']      e                 5
# 3     ['0020-2681', '2058-1009']      e                12
# 4                  ['0017-0097']      e                92
# 6     ['0025-5726', '2169-5075']      e               267
# 10                 ['0075-7535']      e               277
# ...                          ...    ...               ...
# 8856  ['0375-9601', '1873-2429']      e            101461
# 8857  ['1873-2445', '0370-2693']      e            101461
# 8864  ['2325-9248', '0065-972X']      e            101522
# 8868  ['1533-6247', '0003-1615']      e            101581
# 8871  ['0143-7496', '1879-0127']      e            101582
#
#                                             e_coll_info  \
# 1     [['61619505660001701', 'IEEE/IET Electronic Li...
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# 6     [['61695747580001701', 'Institute of Physics T...
# 10    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8856  [['61624504590001701', 'Elsevier ScienceDirect...
# 8857  [['61624504590001701', 'Elsevier ScienceDirect...
# 8864  [['61535211010001701', 'JSTOR Arts and Science...
# 8868  [['61535211010001701', 'JSTOR Arts and Science...
# 8871  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                          portfolio_info  \
# 1     [['53620359120001701', 'IEEE transactions on u...
# 3     [['53540140170001701', 'Journal of the Institu...
# 4     [['53537228640001701', 'Giornale degli economi...
# 6     [['53695747410001701', 'Mathematics of the USS...
# 10    [['53624652880001701', 'Laboratory techniques ...
# ...                                                 ...
# 8856        [['53624670170001701', 'Physics letters.']]
# 8857        [['53624670190001701', 'Physics letters.']]
# 8864  [['53540700110001701', 'Proceedings and addres...
# 8868           [['53539160390001701', 'The Americas.']]
# 8871  [['53624617390001701', 'International journal ...
#
#                           Coverage Information Combined  PCAD?  ...  \
# 1     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 3     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# 6                                             [Unknown]  [Yes]  ...
# 10    [ Available from 2007 volume: 32 until 2009 vo...  [Yes]  ...
# ...                                                 ...    ...  ...
# 8856  [ Available from 1967-01-02 volume: 24 issue: 1;]  [Yes]  ...
# 8857  [ Available from 1967-01-09 volume: 24 issue: 1;]  [Yes]  ...
# 8864                  [ Available from 1927 volume: 1;]  [Yes]  ...
# 8868         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8871     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
#
#      PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 1            NaN            NaN                             NaN
# 3            NaN            NaN                             NaN
# 4            NaN            NaN                             NaN
# 6            NaN            NaN                             NaN
# 10           NaN            NaN                             NaN
# ...          ...            ...                             ...
# 8856         NaN            NaN                             NaN
# 8857         NaN            NaN                             NaN
# 8864         NaN            NaN                             NaN
# 8868         NaN            NaN                             NaN
# 8871         NaN            NaN                             NaN
#
#      Latest Year Preserved_PORTICO curr-lib-loc_x all_item_count chron  \
# 1                              NaN            NaN            NaN   NaN
# 3                              NaN            NaN            NaN   NaN
# 4                              NaN            NaN            NaN   NaN
# 6                              NaN            NaN            NaN   NaN
# 10                             NaN            NaN            NaN   NaN
# ...                            ...            ...            ...   ...
# 8856                           NaN            NaN            NaN   NaN
# 8857                           NaN            NaN            NaN   NaN
# 8864                           NaN            NaN            NaN   NaN
# 8868                           NaN            NaN            NaN   NaN
# 8871                           NaN            NaN            NaN   NaN
#
#      curr-lib-loc_ALL chron_as_list chron_ranges_calc
# 1                 NaN           NaN               NaN
# 3                 NaN           NaN               NaN
# 4                 NaN           NaN               NaN
# 6                 NaN           NaN               NaN
# 10                NaN           NaN               NaN
# ...               ...           ...               ...
# 8856              NaN           NaN               NaN
# 8857              NaN           NaN               NaN
# 8864              NaN           NaN               NaN
# 8868              NaN           NaN               NaN
# 8871              NaN           NaN               NaN
#
# [3969 rows x 28 columns]

# %%
dfe.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc'],
#       dtype='object')

# %%
dfe['PCAD?'] = dfe['PCAD?'].apply(lambda x: str(x))
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfe = dfe[['MMS_ID','Title_bib','p_or_e','PCAD?','Coverage Information Combined']]
dfe
# Out:
#                 MMS_ID                                          Title_bib  \
# 1     9968441380001701       IEEE transactions on ultrasonics engineering
# 3     9968429800001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# 6     9968936470001701        Mathematics of the USSR. Izvestija (Online)
# 10    9968336850001701  Laboratory techniques in biochemistry and mole...
# ...                ...                                                ...
# 8856  9968239890001701                                   Physics letters.
# 8857  9968240180001701                                   Physics letters.
# 8864  9968665290001701  Proceedings and addresses of the American Phil...
# 8868  9967987860001701  The Americas - Academy of American Franciscan ...
# 8871  9968947900001701    International journal of adhesion and adhesives
#
#      p_or_e    PCAD?                      Coverage Information Combined
# 1         e  ['Yes']  [ Available from 1963 volume: 10 issue: 1 unti...
# 3         e  ['Yes']  [ Available from 1886 volume: 25 issue: 5 unti...
# 4         e  ['Yes']       [ Available from 1939 volume: 1 until 2012;]
# 6         e  ['Yes']                                          [Unknown]
# 10        e  ['Yes']  [ Available from 2007 volume: 32 until 2009 vo...
# ...     ...      ...                                                ...
# 8856      e  ['Yes']  [ Available from 1967-01-02 volume: 24 issue: 1;]
# 8857      e  ['Yes']  [ Available from 1967-01-09 volume: 24 issue: 1;]
# 8864      e  ['Yes']                  [ Available from 1927 volume: 1;]
# 8868      e  ['Yes']         [ Available from 1944 volume: 1 issue: 1;]
# 8871      e  ['Yes']     [ Available from 1980-07- volume: 1 issue: 1;]
#
# [3969 rows x 5 columns]

# %%
dfe.reset_index(inplace=True)
dfe.rename(columns={'index':'record_index'}, inplace=True)
dfe
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#       record_index            MMS_ID  \
# 0                1  9968441380001701
# 1                3  9968429800001701
# 2                4  9967115530001701
# 3                6  9968936470001701
# 4               10  9968336850001701
# ...            ...               ...
# 3964          8856  9968239890001701
# 3965          8857  9968240180001701
# 3966          8864  9968665290001701
# 3967          8868  9967987860001701
# 3968          8871  9968947900001701
#
#                                               Title_bib p_or_e    PCAD?  \
# 0          IEEE transactions on ultrasonics engineering      e  ['Yes']
# 1                 Journal of the Institute of Actuaries      e  ['Yes']
# 2        Giornale degli economisti e annali di economia      e  ['Yes']
# 3           Mathematics of the USSR. Izvestija (Online)      e  ['Yes']
# 4     Laboratory techniques in biochemistry and mole...      e  ['Yes']
# ...                                                 ...    ...      ...
# 3964                                   Physics letters.      e  ['Yes']
# 3965                                   Physics letters.      e  ['Yes']
# 3966  Proceedings and addresses of the American Phil...      e  ['Yes']
# 3967  The Americas - Academy of American Franciscan ...      e  ['Yes']
# 3968    International journal of adhesion and adhesives      e  ['Yes']
#
#                           Coverage Information Combined
# 0     [ Available from 1963 volume: 10 issue: 1 unti...
# 1     [ Available from 1886 volume: 25 issue: 5 unti...
# 2          [ Available from 1939 volume: 1 until 2012;]
# 3                                             [Unknown]
# 4     [ Available from 2007 volume: 32 until 2009 vo...
# ...                                                 ...
# 3964  [ Available from 1967-01-02 volume: 24 issue: 1;]
# 3965  [ Available from 1967-01-09 volume: 24 issue: 1;]
# 3966                  [ Available from 1927 volume: 1;]
# 3967         [ Available from 1944 volume: 1 issue: 1;]
# 3968     [ Available from 1980-07- volume: 1 issue: 1;]
#
# [3969 rows x 6 columns]

# %%
def avail_from(x):
    if re.search('Available\sfrom\s[1-2][0-9]{3}', x):
        return re.search('[1-2][0-9]{3}', x).group(0)
    else:
        return np.nan

# %%
melted_cov = pd.concat([pd.DataFrame(v, index=np.repeat(k,len(v))) for k,v in dfe['Coverage Information Combined'].to_dict().items()])
melted_cov = melted_cov.rename(columns={0:'Coverage_atomic'})
melted_cov = melted_cov[melted_cov['Coverage_atomic'] != '']
melted_cov
# Out:
#                                         Coverage_atomic
# 0      Available from 1963 volume: 10 issue: 1 until...
# 1      Available from 1886 volume: 25 issue: 5 until...
# 2             Available from 1939 volume: 1 until 2012;
# 3                                               Unknown
# 4      Available from 2007 volume: 32 until 2009 vol...
# ...                                                 ...
# 3964     Available from 1967-01-02 volume: 24 issue: 1;
# 3965     Available from 1967-01-09 volume: 24 issue: 1;
# 3966                     Available from 1927 volume: 1;
# 3967            Available from 1944 volume: 1 issue: 1;
# 3968        Available from 1980-07- volume: 1 issue: 1;
#
# [5243 rows x 1 columns]

# %%
melted_cov['avail-start'] = melted_cov['Coverage_atomic'].apply(lambda x: avail_from(x))
melted_cov
# Out:
#                                         Coverage_atomic avail-start
# 0      Available from 1963 volume: 10 issue: 1 until...        1963
# 1      Available from 1886 volume: 25 issue: 5 until...        1886
# 2             Available from 1939 volume: 1 until 2012;        1939
# 3                                               Unknown         NaN
# 4      Available from 2007 volume: 32 until 2009 vol...        2007
# ...                                                 ...         ...
# 3964     Available from 1967-01-02 volume: 24 issue: 1;        1967
# 3965     Available from 1967-01-09 volume: 24 issue: 1;        1967
# 3966                     Available from 1927 volume: 1;        1927
# 3967            Available from 1944 volume: 1 issue: 1;        1944
# 3968        Available from 1980-07- volume: 1 issue: 1;        1980
#
# [5243 rows x 2 columns]

# %%
def avail_until(x):
    if re.search('until\s[1-2][0-9]{3}', x):
        return re.search('until\s[1-2][0-9]{3}', x).group(0).strip('until ')
    else:
        return np.nan

# %%
melted_cov['avail-end'] = melted_cov['Coverage_atomic'].apply(lambda x: avail_until(x))
melted_cov
# Out:
#                                         Coverage_atomic avail-start avail-end
# 0      Available from 1963 volume: 10 issue: 1 until...        1963      1963
# 1      Available from 1886 volume: 25 issue: 5 until...        1886      1995
# 2             Available from 1939 volume: 1 until 2012;        1939      2012
# 3                                               Unknown         NaN       NaN
# 4      Available from 2007 volume: 32 until 2009 vol...        2007      2009
# ...                                                 ...         ...       ...
# 3964     Available from 1967-01-02 volume: 24 issue: 1;        1967       NaN
# 3965     Available from 1967-01-09 volume: 24 issue: 1;        1967       NaN
# 3966                     Available from 1927 volume: 1;        1927       NaN
# 3967            Available from 1944 volume: 1 issue: 1;        1944       NaN
# 3968        Available from 1980-07- volume: 1 issue: 1;        1980       NaN
#
# [5243 rows x 3 columns]

# %%
mc_curr = melted_cov[(melted_cov['avail-start'].notnull()) & (melted_cov['avail-end'].isna())]
mc_curr
# Out:
#                                       Coverage_atomic avail-start avail-end
# 5             Available from 1893 volume: 1 issue: 1;        1893       NaN
# 7                      Available from 1922 volume: 4;        1922       NaN
# 12           Available from 1996 volume: 43 issue: 1;        1996       NaN
# 13            Available from 1890 volume: 1 issue: 1;        1890       NaN
# 15       Available from 2011-06- volume: 56 issue: 1;        2011       NaN
# ...                                               ...         ...       ...
# 3964   Available from 1967-01-02 volume: 24 issue: 1;        1967       NaN
# 3965   Available from 1967-01-09 volume: 24 issue: 1;        1967       NaN
# 3966                   Available from 1927 volume: 1;        1927       NaN
# 3967          Available from 1944 volume: 1 issue: 1;        1944       NaN
# 3968      Available from 1980-07- volume: 1 issue: 1;        1980       NaN
#
# [1942 rows x 3 columns]

# %%
mc_curr['avail-end'] = '2019'
mc_curr
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                       Coverage_atomic avail-start avail-end
# 5             Available from 1893 volume: 1 issue: 1;        1893      2019
# 7                      Available from 1922 volume: 4;        1922      2019
# 12           Available from 1996 volume: 43 issue: 1;        1996      2019
# 13            Available from 1890 volume: 1 issue: 1;        1890      2019
# 15       Available from 2011-06- volume: 56 issue: 1;        2011      2019
# ...                                               ...         ...       ...
# 3964   Available from 1967-01-02 volume: 24 issue: 1;        1967      2019
# 3965   Available from 1967-01-09 volume: 24 issue: 1;        1967      2019
# 3966                   Available from 1927 volume: 1;        1927      2019
# 3967          Available from 1944 volume: 1 issue: 1;        1944      2019
# 3968      Available from 1980-07- volume: 1 issue: 1;        1980      2019
#
# [1942 rows x 3 columns]

# %%
mc_com = melted_cov.combine_first(mc_curr)
mc_com
# Out:
#                                         Coverage_atomic avail-start avail-end
# 0      Available from 1963 volume: 10 issue: 1 until...        1963      1963
# 1      Available from 1886 volume: 25 issue: 5 until...        1886      1995
# 2             Available from 1939 volume: 1 until 2012;        1939      2012
# 3                                               Unknown         NaN       NaN
# 4      Available from 2007 volume: 32 until 2009 vol...        2007      2009
# ...                                                 ...         ...       ...
# 3964     Available from 1967-01-02 volume: 24 issue: 1;        1967      2019
# 3965     Available from 1967-01-09 volume: 24 issue: 1;        1967      2019
# 3966                     Available from 1927 volume: 1;        1927      2019
# 3967            Available from 1944 volume: 1 issue: 1;        1944      2019
# 3968        Available from 1980-07- volume: 1 issue: 1;        1980      2019
#
# [5680 rows x 3 columns]

# %%
dfe2 = mc_com[mc_com['avail-start'].notnull() & mc_com['avail-end'].notnull()]
dfe2
# Out:
#                                         Coverage_atomic avail-start avail-end
# 0      Available from 1963 volume: 10 issue: 1 until...        1963      1963
# 1      Available from 1886 volume: 25 issue: 5 until...        1886      1995
# 2             Available from 1939 volume: 1 until 2012;        1939      2012
# 4      Available from 2007 volume: 32 until 2009 vol...        2007      2009
# 5      Available from 1944-1-1 until 2000-10-31;  Av...        1944      2000
# ...                                                 ...         ...       ...
# 3964     Available from 1967-01-02 volume: 24 issue: 1;        1967      2019
# 3965     Available from 1967-01-09 volume: 24 issue: 1;        1967      2019
# 3966                     Available from 1927 volume: 1;        1927      2019
# 3967            Available from 1944 volume: 1 issue: 1;        1944      2019
# 3968        Available from 1980-07- volume: 1 issue: 1;        1980      2019
#
# [5581 rows x 3 columns]

# %%
dfe2_no_date_calc = mc_com[mc_com['avail-start'].isna() | mc_com['avail-end'].isna()]
dfe2_no_date_calc
# Out:
#      Coverage_atomic avail-start avail-end
# 3            Unknown         NaN       NaN
# 39           Unknown         NaN       NaN
# 60           Unknown         NaN       NaN
# 126          Unknown         NaN       NaN
# 127          Unknown         NaN       NaN
# ...              ...         ...       ...
# 3556         Unknown         NaN       NaN
# 3655         Unknown         NaN       NaN
# 3656         Unknown         NaN       NaN
# 3740         Unknown         NaN       NaN
# 3948         Unknown         NaN       NaN
#
# [99 rows x 3 columns]

# %%
dfe2_no_date_calc.shape
# Out:
# (99, 3)

# %%
dfe2_no_date_calc.reset_index(inplace=True)
dfe2_no_date_calc.rename(columns={'index':'record_index'},inplace=True)
dfe2_no_date_calc
# Out:
#     record_index Coverage_atomic avail-start avail-end
# 0              3         Unknown         NaN       NaN
# 1             39         Unknown         NaN       NaN
# 2             60         Unknown         NaN       NaN
# 3            126         Unknown         NaN       NaN
# 4            127         Unknown         NaN       NaN
# ..           ...             ...         ...       ...
# 94          3556         Unknown         NaN       NaN
# 95          3655         Unknown         NaN       NaN
# 96          3656         Unknown         NaN       NaN
# 97          3740         Unknown         NaN       NaN
# 98          3948         Unknown         NaN       NaN
#
# [99 rows x 4 columns]

# %%
dfe2_no_date_calc = pd.merge(dfe, dfe2_no_date_calc, how='right', on= 'record_index')
dfe2_no_date_calc
# Out:
#     record_index            MMS_ID  \
# 0              3  9968429800001701
# 1            209  9967220140001701
# 2            246  9968504000001701
# 3            345  9966479180001701
# 4            397  9975630388601701
# ..           ...               ...
# 94          3253               NaN
# 95          3291               NaN
# 96          3556               NaN
# 97          3656               NaN
# 98          3948               NaN
#
#                                             Title_bib p_or_e    PCAD?  \
# 0               Journal of the Institute of Actuaries      e  ['Yes']
# 1                                Seminars in oncology      e  ['Yes']
# 2                         Tennyson research bulletin.      e  ['Yes']
# 3        Mathematical methods in the applied sciences      e  ['Yes']
# 4   Clinical research practices and drug regulator...      e  ['Yes']
# ..                                                ...    ...      ...
# 94                                                NaN    NaN      NaN
# 95                                                NaN    NaN      NaN
# 96                                                NaN    NaN      NaN
# 97                                                NaN    NaN      NaN
# 98                                                NaN    NaN      NaN
#
#                         Coverage Information Combined Coverage_atomic  \
# 0   [ Available from 1886 volume: 25 issue: 5 unti...         Unknown
# 1              [ Available from 2001-02- volume: 28;]         Unknown
# 2   [ Available from 1985-1-1 until 1986-12-31;  A...         Unknown
# 3         [ Available from 1996 volume: 19 issue: 1;]         Unknown
# 4   [ Available from 1983 volume: 1 issue: 1 until...         Unknown
# ..                                                ...             ...
# 94                                                NaN         Unknown
# 95                                                NaN         Unknown
# 96                                                NaN         Unknown
# 97                                                NaN         Unknown
# 98                                                NaN         Unknown
#
#    avail-start avail-end
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ..         ...       ...
# 94         NaN       NaN
# 95         NaN       NaN
# 96         NaN       NaN
# 97         NaN       NaN
# 98         NaN       NaN
#
# [99 rows x 9 columns]

# %%
dfe2_no_date_calc_df = pd.merge(df, dfe2_no_date_calc, how='right', on= 'MMS_ID')
dfe2_no_date_calc_df
# Out:
#      record_index_x            MMS_ID  \
# 0          111951.0  9968429800001701
# 1          121955.0  9967220140001701
# 2          115366.0  9968504000001701
# 3          121390.0  9966479180001701
# 4          125290.0  9975630388601701
# ..              ...               ...
# 102             NaN               NaN
# 103             NaN               NaN
# 104             NaN               NaN
# 105             NaN               NaN
# 106             NaN               NaN
#
#                                            Title_bib_x  \
# 0                Journal of the Institute of Actuaries
# 1                                 Seminars in oncology
# 2                          Tennyson research bulletin.
# 3         Mathematical methods in the applied sciences
# 4    Clinical research practices and drug regulator...
# ..                                                 ...
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
#
#                    ISSN_cluster p_or_e_x  matches_group_id  \
# 0    ['0020-2681', '2058-1009']        e              12.0
# 1    ['0093-7754', '1532-8708']        e            4588.0
# 2                 ['0082-2841']        e            5186.0
# 3    ['0170-4214', '1099-1476']        e            6841.0
# 4                 ['0735-7915']        e            7786.0
# ..                          ...      ...               ...
# 102                         NaN      NaN               NaN
# 103                         NaN      NaN               NaN
# 104                         NaN      NaN               NaN
# 105                         NaN      NaN               NaN
# 106                         NaN      NaN               NaN
#
#                                            e_coll_info  \
# 0    [['61535216140001701', 'JSTOR Business III Col...
# 1    [['61624504590001701', 'Elsevier ScienceDirect...
# 2    [['61686647970001701', 'Periodicals Archive On...
# 3    [['61765175560001701', 'Wiley Online Library D...
# 4    [['61697871840001701', 'Taylor & Francis Medic...
# ..                                                 ...
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
#
#                                         portfolio_info  \
# 0    [['53540140170001701', 'Journal of the Institu...
# 1     [['53624692560001701', 'Seminars in oncology.']]
# 2    [['53686647540001701', 'Tennyson research bull...
# 3    [['53743071260001701', 'Mathematical methods i...
# 4    [['53697870630001701', 'Clinical research prac...
# ..                                                 ...
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
#
#                        Coverage Information Combined_x PCAD?_x  ...  \
# 0    [ Available from 1886 volume: 25 issue: 5 unti...   [Yes]  ...
# 1               [ Available from 2001-02- volume: 28;]   [Yes]  ...
# 2    [ Available from 1985-1-1 until 1986-12-31;  A...   [Yes]  ...
# 3          [ Available from 1996 volume: 19 issue: 1;]   [Yes]  ...
# 4    [ Available from 1983 volume: 1 issue: 1 until...   [Yes]  ...
# ..                                                 ...     ...  ...
# 102                                                NaN     NaN  ...
# 103                                                NaN     NaN  ...
# 104                                                NaN     NaN  ...
# 105                                                NaN     NaN  ...
# 106                                                NaN     NaN  ...
#
#     chron_as_list chron_ranges_calc record_index_y  \
# 0             NaN               NaN              3
# 1             NaN               NaN            209
# 2             NaN               NaN            246
# 3             NaN               NaN            345
# 4             NaN               NaN            397
# ..            ...               ...            ...
# 102           NaN               NaN           3253
# 103           NaN               NaN           3291
# 104           NaN               NaN           3556
# 105           NaN               NaN           3656
# 106           NaN               NaN           3948
#
#                                            Title_bib_y p_or_e_y  PCAD?_y  \
# 0                Journal of the Institute of Actuaries        e  ['Yes']
# 1                                 Seminars in oncology        e  ['Yes']
# 2                          Tennyson research bulletin.        e  ['Yes']
# 3         Mathematical methods in the applied sciences        e  ['Yes']
# 4    Clinical research practices and drug regulator...        e  ['Yes']
# ..                                                 ...      ...      ...
# 102                                                NaN      NaN      NaN
# 103                                                NaN      NaN      NaN
# 104                                                NaN      NaN      NaN
# 105                                                NaN      NaN      NaN
# 106                                                NaN      NaN      NaN
#
#                        Coverage Information Combined_y Coverage_atomic  \
# 0    [ Available from 1886 volume: 25 issue: 5 unti...         Unknown
# 1               [ Available from 2001-02- volume: 28;]         Unknown
# 2    [ Available from 1985-1-1 until 1986-12-31;  A...         Unknown
# 3          [ Available from 1996 volume: 19 issue: 1;]         Unknown
# 4    [ Available from 1983 volume: 1 issue: 1 until...         Unknown
# ..                                                 ...             ...
# 102                                                NaN         Unknown
# 103                                                NaN         Unknown
# 104                                                NaN         Unknown
# 105                                                NaN         Unknown
# 106                                                NaN         Unknown
#
#     avail-start avail-end
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ..          ...       ...
# 102         NaN       NaN
# 103         NaN       NaN
# 104         NaN       NaN
# 105         NaN       NaN
# 106         NaN       NaN
#
# [107 rows x 36 columns]

# %%
no_date_groups = list(dfe2_no_date_calc_df['matches_group_id'])
len(no_date_groups)
# Out:
# 107

# %%
dfe2_no_date_calc = df[df['matches_group_id'].isin(no_date_groups)]
dfe2_no_date_calc
# Out:
#       record_index            MMS_ID                              Title_bib  \
# 3           111951  9968429800001701  Journal of the Institute of Actuaries
# 2            88618  9939481760001701  Journal of the Institute of Actuaries
# 209         121955  9967220140001701                   Seminars in oncology
# 210          65075  9949345650001701                   Seminars in oncology
# 245          12584  9922468710001701             Tennyson research bulletin
# ...            ...               ...                                    ...
# 3740        104355  9966748550001701                           Biochemistry
# 3739         62835  9942519690001701                           Biochemistry
# 3741         77056  9956319410001701                           Biochemistry
# 3742        115410  9968561600001701                         Macromolecules
# 3743         33853  9953791480001701                         Macromolecules
#
#                                  ISSN_cluster p_or_e  matches_group_id  \
# 3                  ['0020-2681', '2058-1009']      e                12
# 2                               ['0020-2681']      p                12
# 209                ['0093-7754', '1532-8708']      e              4588
# 210                             ['0093-7754']      p              4588
# 245                             ['0082-2841']      p              5186
# ...                                       ...    ...               ...
# 3740               ['0006-2960', '1520-4995']      e             39912
# 3739                            ['0006-2960']      p             39912
# 3741                            ['0006-2960']      p             39912
# 3742               ['0024-9297', '1520-5835']      e             39912
# 3743  ['1520-5835', '0006-2960', '0024-9297']      p             39912
#
#                                             e_coll_info  \
# 3     [['61535216140001701', 'JSTOR Business III Col...
# 2                                                   NaN
# 209   [['61624504590001701', 'Elsevier ScienceDirect...
# 210                                                 NaN
# 245                                                 NaN
# ...                                                 ...
# 3740  [['61535215970001701', 'American Chemical Soci...
# 3739                                                NaN
# 3741                                                NaN
# 3742  [['61535215970001701', 'American Chemical Soci...
# 3743                                                NaN
#
#                                          portfolio_info  \
# 3     [['53540140170001701', 'Journal of the Institu...
# 2                                                   NaN
# 209    [['53624692560001701', 'Seminars in oncology.']]
# 210                                                 NaN
# 245                                                 NaN
# ...                                                 ...
# 3740           [['53536372850001701', 'Biochemistry.']]
# 3739                                                NaN
# 3741                                                NaN
# 3742         [['53540476540001701', 'Macromolecules.']]
# 3743                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 3     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 2                                                   NaN    NaN  ...
# 209              [ Available from 2001-02- volume: 28;]  [Yes]  ...
# 210                                                 NaN    NaN  ...
# 245                                                 NaN    NaN  ...
# ...                                                 ...    ...  ...
# 3740  [ Available from 1962 volume: 1 issue: 1 until...  [Yes]  ...
# 3739                                                NaN    NaN  ...
# 3741                                                NaN    NaN  ...
# 3742  [ Available from 1968 volume: 1 issue: 1 until...  [Yes]  ...
# 3743                                                NaN    NaN  ...
#
#      PCA_PORTICO Status_PORTICO Earliest Year Preserved_PORTICO  \
# 3            NaN            NaN                             NaN
# 2            NaN            NaN                             NaN
# 209          NaN            NaN                             NaN
# 210          NaN            NaN                             NaN
# 245          NaN            NaN                             NaN
# ...          ...            ...                             ...
# 3740         NaN            NaN                             NaN
# 3739         NaN            NaN                             NaN
# 3741         NaN            NaN                             NaN
# 3742         NaN            NaN                             NaN
# 3743         NaN            NaN                             NaN
#
#      Latest Year Preserved_PORTICO                     curr-lib-loc_x  \
# 3                              NaN                                NaN
# 2                              NaN                        [TWILS CLS]
# 209                            NaN                                NaN
# 210                            NaN                       [TBIOM PERS]
# 245                            NaN                        [TWILS PER]
# ...                            ...                                ...
# 3740                           NaN                                NaN
# 3739                           NaN                       [ZMLAC UMDN]
# 3741                           NaN  [TBIOM PERS, TZDS GEN, ZMLAC OWL]
# 3742                           NaN                                NaN
# 3743                           NaN    [ZMLAC GEN, TSCI PER, TZDS GEN]
#
#      all_item_count                                              chron  \
# 3               NaN                                                NaN
# 2              [46]  [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 209             NaN                                                NaN
# 210            [87]  [2004, 2010, 1984, 1995, 1987, 2001, 2009, 198...
# 245             [9]  [1982/91, 2012/2016, 2018, 1997/2001, 2017, 20...
# ...             ...                                                ...
# 3740            NaN                                                NaN
# 3739          [158]  [1970, 1978, 1984, 1964, 1963, 1977, 1971, 198...
# 3741          [865]  [2004, 1970, 1978, 1995, 1984, 1964, 1971, 197...
# 3742            NaN                                                NaN
# 3743          [319]  [, 2004, 1970, 1978, 1995, 1984, 1971, 1987, 1...
#
#                              curr-lib-loc_ALL  \
# 3                                         NaN
# 2                               ['TWILS CLS']
# 209                                       NaN
# 210                            ['TBIOM PERS']
# 245                             ['TWILS PER']
# ...                                       ...
# 3740                                      NaN
# 3739                           ['ZMLAC UMDN']
# 3741  ['TBIOM PERS', 'TZDS GEN', 'ZMLAC OWL']
# 3742                                      NaN
# 3743    ['ZMLAC GEN', 'TSCI PER', 'TZDS GEN']
#
#                                           chron_as_list  \
# 3                                                   NaN
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 209                                                 NaN
# 210   [1974, 1975, 1976, 1977, 1978, 1979, 1980, 198...
# 245   [1982, 1983, 1984, 1985, 1986, 1987, 1988, 198...
# ...                                                 ...
# 3740                                                NaN
# 3739  [1962, 1963, 1964, 1965, 1966, 1967, 1968, 196...
# 3741  [1962, 1963, 1964, 1965, 1966, 1967, 1968, 196...
# 3742                                                NaN
# 3743  [1968, 1969, 1970, 1971, 1972, 1973, 1974, 197...
#
#                                       chron_ranges_calc
# 3                                                   NaN
# 2     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 209                                                 NaN
# 210                        [(1974, 1982), (1984, 2011)]
# 245                                      [(1982, 2019)]
# ...                                                 ...
# 3740                                                NaN
# 3739                                     [(1962, 1993)]
# 3741                                     [(1962, 2009)]
# 3742                                                NaN
# 3743                                     [(1968, 2009)]
#
# [123 rows x 28 columns]

# %%
dfe2_no_date_calc.to_pickle(f'dfe2_no_date_calc_{today}.pkl')

# %%
dfe2['pcad-range'] = dfe2.apply(lambda row: list(range(int(row['avail-start']),int(row['avail-end'])+1)), axis=1)
dfe2
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                         Coverage_atomic avail-start avail-end  \
# 0      Available from 1963 volume: 10 issue: 1 until...        1963      1963
# 1      Available from 1886 volume: 25 issue: 5 until...        1886      1995
# 2             Available from 1939 volume: 1 until 2012;        1939      2012
# 4      Available from 2007 volume: 32 until 2009 vol...        2007      2009
# 5      Available from 1944-1-1 until 2000-10-31;  Av...        1944      2000
# ...                                                 ...         ...       ...
# 3964     Available from 1967-01-02 volume: 24 issue: 1;        1967      2019
# 3965     Available from 1967-01-09 volume: 24 issue: 1;        1967      2019
# 3966                     Available from 1927 volume: 1;        1927      2019
# 3967            Available from 1944 volume: 1 issue: 1;        1944      2019
# 3968        Available from 1980-07- volume: 1 issue: 1;        1980      2019
#
#                                              pcad-range
# 0                                                [1963]
# 1     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 2     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 4                                    [2007, 2008, 2009]
# 5     [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# ...                                                 ...
# 3964  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3965  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3966  [1927, 1928, 1929, 1930, 1931, 1932, 1933, 193...
# 3967  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 3968  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [5581 rows x 4 columns]

# %%
dfe2.reset_index(inplace=True)
dfe2.rename(columns={'index':'record_index'},inplace=True)
dfe2
# Out:
#       record_index                                    Coverage_atomic  \
# 0                0   Available from 1963 volume: 10 issue: 1 until...
# 1                1   Available from 1886 volume: 25 issue: 5 until...
# 2                2          Available from 1939 volume: 1 until 2012;
# 3                4   Available from 2007 volume: 32 until 2009 vol...
# 4                5   Available from 1944-1-1 until 2000-10-31;  Av...
# ...            ...                                                ...
# 5576          3964     Available from 1967-01-02 volume: 24 issue: 1;
# 5577          3965     Available from 1967-01-09 volume: 24 issue: 1;
# 5578          3966                     Available from 1927 volume: 1;
# 5579          3967            Available from 1944 volume: 1 issue: 1;
# 5580          3968        Available from 1980-07- volume: 1 issue: 1;
#
#      avail-start avail-end                                         pcad-range
# 0           1963      1963                                             [1963]
# 1           1886      1995  [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 2           1939      2012  [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 3           2007      2009                                 [2007, 2008, 2009]
# 4           1944      2000  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# ...          ...       ...                                                ...
# 5576        1967      2019  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 5577        1967      2019  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 5578        1927      2019  [1927, 1928, 1929, 1930, 1931, 1932, 1933, 193...
# 5579        1944      2019  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 5580        1980      2019  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [5581 rows x 5 columns]

# %%
dfeg = dfe2[['record_index','pcad-range']].groupby(['record_index']).agg(lambda x: list(set([item for sublist in x for item in sublist]))).reset_index()
dfeg
# Out:
#       record_index                                         pcad-range
# 0                0                                             [1963]
# 1                1  [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 2                2  [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 3                4                                 [2008, 2009, 2007]
# 4                5  [1893, 1894, 1895, 1896, 1897, 1898, 1899, 190...
# ...            ...                                                ...
# 3908          3964  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3909          3965  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3910          3966  [1927, 1928, 1929, 1930, 1931, 1932, 1933, 193...
# 3911          3967  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 3912          3968  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [3913 rows x 2 columns]

# %%
dfeg['pcad-range'] = dfeg['pcad-range'].apply(lambda x: sorted(x))
dfeg
# Out:
#       record_index                                         pcad-range
# 0                0                                             [1963]
# 1                1  [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 2                2  [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 3                4                                 [2007, 2008, 2009]
# 4                5  [1893, 1894, 1895, 1896, 1897, 1898, 1899, 190...
# ...            ...                                                ...
# 3908          3964  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3909          3965  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3910          3966  [1927, 1928, 1929, 1930, 1931, 1932, 1933, 193...
# 3911          3967  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 3912          3968  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [3913 rows x 2 columns]

# %%
dfe_pcad = pd.merge(dfe, dfeg, left_index=True, how='left', right_on= 'record_index')
dfe_pcad
# Out:
#         record_index  record_index_x            MMS_ID  \
# 0.0                0               1  9968441380001701
# 1.0                1               3  9968429800001701
# 2.0                2               4  9967115530001701
# NaN                3               6  9968936470001701
# 3.0                4              10  9968336850001701
# ...              ...             ...               ...
# 3908.0          3964            8856  9968239890001701
# 3909.0          3965            8857  9968240180001701
# 3910.0          3966            8864  9968665290001701
# 3911.0          3967            8868  9967987860001701
# 3912.0          3968            8871  9968947900001701
#
#                                                 Title_bib p_or_e    PCAD?  \
# 0.0          IEEE transactions on ultrasonics engineering      e  ['Yes']
# 1.0                 Journal of the Institute of Actuaries      e  ['Yes']
# 2.0        Giornale degli economisti e annali di economia      e  ['Yes']
# NaN           Mathematics of the USSR. Izvestija (Online)      e  ['Yes']
# 3.0     Laboratory techniques in biochemistry and mole...      e  ['Yes']
# ...                                                   ...    ...      ...
# 3908.0                                   Physics letters.      e  ['Yes']
# 3909.0                                   Physics letters.      e  ['Yes']
# 3910.0  Proceedings and addresses of the American Phil...      e  ['Yes']
# 3911.0  The Americas - Academy of American Franciscan ...      e  ['Yes']
# 3912.0    International journal of adhesion and adhesives      e  ['Yes']
#
#                             Coverage Information Combined  record_index_y  \
# 0.0     [ Available from 1963 volume: 10 issue: 1 unti...             0.0
# 1.0     [ Available from 1886 volume: 25 issue: 5 unti...             1.0
# 2.0          [ Available from 1939 volume: 1 until 2012;]             2.0
# NaN                                             [Unknown]             NaN
# 3.0     [ Available from 2007 volume: 32 until 2009 vo...             4.0
# ...                                                   ...             ...
# 3908.0  [ Available from 1967-01-02 volume: 24 issue: 1;]          3964.0
# 3909.0  [ Available from 1967-01-09 volume: 24 issue: 1;]          3965.0
# 3910.0                  [ Available from 1927 volume: 1;]          3966.0
# 3911.0         [ Available from 1944 volume: 1 issue: 1;]          3967.0
# 3912.0     [ Available from 1980-07- volume: 1 issue: 1;]          3968.0
#
#                                                pcad-range
# 0.0                                                [1963]
# 1.0     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 2.0     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# NaN                                                   NaN
# 3.0                                    [2007, 2008, 2009]
# ...                                                   ...
# 3908.0  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3909.0  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 3910.0  [1927, 1928, 1929, 1930, 1931, 1932, 1933, 193...
# 3911.0  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 3912.0  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [3969 rows x 9 columns]

# %%
dfe_pcad.columns
# Out:
# Index(['record_index', 'record_index_x', 'MMS_ID', 'Title_bib', 'p_or_e',
#        'PCAD?', 'Coverage Information Combined', 'record_index_y',
#        'pcad-range'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc'],
#       dtype='object')

# %%
df_e_range = pd.merge(df, dfe_pcad[['MMS_ID','pcad-range']], how='left', on='MMS_ID')
df_e_range
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#      Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0               NaN                             NaN
# 1               NaN                             NaN
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4               NaN                             NaN
# ...             ...                             ...
# 8818            NaN                             NaN
# 8819            NaN                             NaN
# 8820            NaN                             NaN
# 8821            NaN                             NaN
# 8822            NaN                             NaN
#
#      Latest Year Preserved_PORTICO          curr-lib-loc_x all_item_count  \
# 0                              NaN                     NaN            NaN
# 1                              NaN              [TZDS GEN]            [1]
# 2                              NaN                     NaN            NaN
# 3                              NaN             [TWILS CLS]           [46]
# 4                              NaN                     NaN            NaN
# ...                            ...                     ...            ...
# 8818                           NaN   [TSCI PER, ZMLAC OWL]           [53]
# 8819                           NaN  [ZMLAC OWL, TWILS PER]           [74]
# 8820                           NaN                     NaN            NaN
# 8821                           NaN                     NaN            NaN
# 8822                           NaN              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
# [8823 rows x 29 columns]

# %%
df_e_range.sort_values(['matches_group_id','Title_bib','p_or_e'], inplace=True)
df_e_range
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#      Status_PORTICO Earliest Year Preserved_PORTICO  \
# 0               NaN                             NaN
# 1               NaN                             NaN
# 2               NaN                             NaN
# 3               NaN                             NaN
# 4               NaN                             NaN
# ...             ...                             ...
# 8818            NaN                             NaN
# 8819            NaN                             NaN
# 8820            NaN                             NaN
# 8821            NaN                             NaN
# 8822            NaN                             NaN
#
#      Latest Year Preserved_PORTICO          curr-lib-loc_x all_item_count  \
# 0                              NaN                     NaN            NaN
# 1                              NaN              [TZDS GEN]            [1]
# 2                              NaN                     NaN            NaN
# 3                              NaN             [TWILS CLS]           [46]
# 4                              NaN                     NaN            NaN
# ...                            ...                     ...            ...
# 8818                           NaN   [TSCI PER, ZMLAC OWL]           [53]
# 8819                           NaN  [ZMLAC OWL, TWILS PER]           [74]
# 8820                           NaN                     NaN            NaN
# 8821                           NaN                     NaN            NaN
# 8822                           NaN              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
# [8823 rows x 29 columns]

# %% [markdown]
# #### Process date ranges for SPR data

# %%
df_e_range.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc',
#        'pcad-range'],
#       dtype='object')

# %%
df_spr = df_e_range[['MMS_ID', 'Title_bib', 'p_or_e', 'matches_group_id',
       'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR', 'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR']]
df_spr
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8818  9959156260001701         Year book - American Philosophical Society
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#      p_or_e  matches_group_id  \
# 0         e                 5
# 1         p                 5
# 2         e                12
# 3         p                12
# 4         e                92
# ...     ...               ...
# 8818      p            101522
# 8819      p            101581
# 8820      e            101581
# 8821      e            101582
# 8822      p            101582
#
#                               Title 1 (Print)_BTAA-SPR  \
# 0                                                  NaN
# 1        IEEE transactions on ultrasonics engineering.
# 2                                                  NaN
# 3               Journal of the Institute of Actuaries.
# 4                                                  NaN
# ...                                                ...
# 8818                                               NaN
# 8819                                     The Americas.
# 8820                                               NaN
# 8821                                               NaN
# 8822  International journal of adhesion and adhesives.
#
#      Title 2 (Print)_BTAA-SPR Match?_BTAA-SPR    SPR Holdings_BTAA-SPR
# 0                         NaN             NaN                      NaN
# 1                         NaN             YES                10 (1963)
# 2                         NaN             NaN                      NaN
# 3                         NaN             YES     66 (1935)-110 (1983)
# 4                         NaN             NaN                      NaN
# ...                       ...             ...                      ...
# 8818                      NaN             NaN                      NaN
# 8819                      NaN             NaN  1 (1969-1970)-45 (1989)
# 8820                      NaN             NaN                      NaN
# 8821                      NaN             NaN                      NaN
# 8822                      NaN             YES      10 (1990)-26 (2006)
#
# [8823 rows x 8 columns]

# %%
df_spr = df_spr[df_spr['Match?_BTAA-SPR'].notnull()]
df_spr
# Out:
#                 MMS_ID                                        Title_bib  \
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 3     9939481760001701            Journal of the Institute of Actuaries
# 6     9964617400001701               Mathematics of the USSR. Izvestija
# 18    9929554030001701              Veterinary research communications.
# 25    9931084310001701                                    Neuropeptides
# ...                ...                                              ...
# 8793  9939180800001701       Annals of the New York Academy of Sciences
# 8808  9912065260001701                                  Physics letters
# 8811  9953202980001701                       Physics letters. Section A
# 8812  9953205880001701                       Physics letters. Section B
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#      p_or_e  matches_group_id  \
# 1         p                 5
# 3         p                12
# 6         p               267
# 18        p               707
# 25        p               744
# ...     ...               ...
# 8793      p            101219
# 8808      p            101461
# 8811      p            101461
# 8812      p            101461
# 8822      p            101582
#
#                               Title 1 (Print)_BTAA-SPR  \
# 1        IEEE transactions on ultrasonics engineering.
# 3               Journal of the Institute of Actuaries.
# 6                  Mathematics of the USSR: Izvestija.
# 18                 Veterinary research communications.
# 25                                      Neuropeptides.
# ...                                                ...
# 8793       Annals of the New York Academy of Sciences.
# 8808                                  Physics letters.
# 8811                                  Physics letters.
# 8812                                  Physics letters.
# 8822  International journal of adhesion and adhesives.
#
#                            Title 2 (Print)_BTAA-SPR Match?_BTAA-SPR  \
# 1                                               NaN             YES
# 3                                               NaN             YES
# 6                                               NaN             YES
# 18                                              NaN             YES
# 25                                              NaN             YES
# ...                                             ...             ...
# 8793  The year in ecology and conservation biology.             YES
# 8808                               Physics letters.             YES
# 8811                                            NaN             YES
# 8812                                            NaN             YES
# 8822                                            NaN             YES
#
#                                   SPR Holdings_BTAA-SPR
# 1                                             10 (1963)
# 3                                  66 (1935)-110 (1983)
# 6                                    1 (1967)-39 (1992)
# 18                                   4 (1980)-33 (2009)
# 25                              1 (1980/1981)-40 (2006)
# ...                                                 ...
# 8793  1-8, 10-83, 85-104, 106-126, 128, 130-146, 148...
# 8808                                 1 (1962)-23 (1966)
# 8811                               24 (1967)-347 (2005)
# 8812  24 (1967)-269 (1991), 271 (1991)-566 (2009), 5...
# 8822                                10 (1990)-26 (2006)
#
# [2179 rows x 8 columns]

# %%
df_spr['SPR Holdings_BTAA-SPR'] = df_spr['SPR Holdings_BTAA-SPR'].apply(lambda x: x.strip().replace(';',',').replace(' ',''))
df_spr
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 3     9939481760001701            Journal of the Institute of Actuaries
# 6     9964617400001701               Mathematics of the USSR. Izvestija
# 18    9929554030001701              Veterinary research communications.
# 25    9931084310001701                                    Neuropeptides
# ...                ...                                              ...
# 8793  9939180800001701       Annals of the New York Academy of Sciences
# 8808  9912065260001701                                  Physics letters
# 8811  9953202980001701                       Physics letters. Section A
# 8812  9953205880001701                       Physics letters. Section B
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#      p_or_e  matches_group_id  \
# 1         p                 5
# 3         p                12
# 6         p               267
# 18        p               707
# 25        p               744
# ...     ...               ...
# 8793      p            101219
# 8808      p            101461
# 8811      p            101461
# 8812      p            101461
# 8822      p            101582
#
#                               Title 1 (Print)_BTAA-SPR  \
# 1        IEEE transactions on ultrasonics engineering.
# 3               Journal of the Institute of Actuaries.
# 6                  Mathematics of the USSR: Izvestija.
# 18                 Veterinary research communications.
# 25                                      Neuropeptides.
# ...                                                ...
# 8793       Annals of the New York Academy of Sciences.
# 8808                                  Physics letters.
# 8811                                  Physics letters.
# 8812                                  Physics letters.
# 8822  International journal of adhesion and adhesives.
#
#                            Title 2 (Print)_BTAA-SPR Match?_BTAA-SPR  \
# 1                                               NaN             YES
# 3                                               NaN             YES
# 6                                               NaN             YES
# 18                                              NaN             YES
# 25                                              NaN             YES
# ...                                             ...             ...
# 8793  The year in ecology and conservation biology.             YES
# 8808                               Physics letters.             YES
# 8811                                            NaN             YES
# 8812                                            NaN             YES
# 8822                                            NaN             YES
#
#                                   SPR Holdings_BTAA-SPR
# 1                                              10(1963)
# 3                                    66(1935)-110(1983)
# 6                                      1(1967)-39(1992)
# 18                                     4(1980)-33(2009)
# 25                                1(1980/1981)-40(2006)
# ...                                                 ...
# 8793  1-8,10-83,85-104,106-126,128,130-146,148-149,1...
# 8808                                   1(1962)-23(1966)
# 8811                                 24(1967)-347(2005)
# 8812  24(1967)-269(1991),271(1991)-566(2009),571(200...
# 8822                                  10(1990)-26(2006)
#
# [2179 rows x 8 columns]

# %%
df_spr['SPR-holdings'] = df_spr['SPR Holdings_BTAA-SPR'].apply(lambda x: x.split(','))
df_spr
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 3     9939481760001701            Journal of the Institute of Actuaries
# 6     9964617400001701               Mathematics of the USSR. Izvestija
# 18    9929554030001701              Veterinary research communications.
# 25    9931084310001701                                    Neuropeptides
# ...                ...                                              ...
# 8793  9939180800001701       Annals of the New York Academy of Sciences
# 8808  9912065260001701                                  Physics letters
# 8811  9953202980001701                       Physics letters. Section A
# 8812  9953205880001701                       Physics letters. Section B
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#      p_or_e  matches_group_id  \
# 1         p                 5
# 3         p                12
# 6         p               267
# 18        p               707
# 25        p               744
# ...     ...               ...
# 8793      p            101219
# 8808      p            101461
# 8811      p            101461
# 8812      p            101461
# 8822      p            101582
#
#                               Title 1 (Print)_BTAA-SPR  \
# 1        IEEE transactions on ultrasonics engineering.
# 3               Journal of the Institute of Actuaries.
# 6                  Mathematics of the USSR: Izvestija.
# 18                 Veterinary research communications.
# 25                                      Neuropeptides.
# ...                                                ...
# 8793       Annals of the New York Academy of Sciences.
# 8808                                  Physics letters.
# 8811                                  Physics letters.
# 8812                                  Physics letters.
# 8822  International journal of adhesion and adhesives.
#
#                            Title 2 (Print)_BTAA-SPR Match?_BTAA-SPR  \
# 1                                               NaN             YES
# 3                                               NaN             YES
# 6                                               NaN             YES
# 18                                              NaN             YES
# 25                                              NaN             YES
# ...                                             ...             ...
# 8793  The year in ecology and conservation biology.             YES
# 8808                               Physics letters.             YES
# 8811                                            NaN             YES
# 8812                                            NaN             YES
# 8822                                            NaN             YES
#
#                                   SPR Holdings_BTAA-SPR  \
# 1                                              10(1963)
# 3                                    66(1935)-110(1983)
# 6                                      1(1967)-39(1992)
# 18                                     4(1980)-33(2009)
# 25                                1(1980/1981)-40(2006)
# ...                                                 ...
# 8793  1-8,10-83,85-104,106-126,128,130-146,148-149,1...
# 8808                                   1(1962)-23(1966)
# 8811                                 24(1967)-347(2005)
# 8812  24(1967)-269(1991),271(1991)-566(2009),571(200...
# 8822                                  10(1990)-26(2006)
#
#                                            SPR-holdings
# 1                                            [10(1963)]
# 3                                  [66(1935)-110(1983)]
# 6                                    [1(1967)-39(1992)]
# 18                                   [4(1980)-33(2009)]
# 25                              [1(1980/1981)-40(2006)]
# ...                                                 ...
# 8793  [1-8, 10-83, 85-104, 106-126, 128, 130-146, 14...
# 8808                                 [1(1962)-23(1966)]
# 8811                               [24(1967)-347(2005)]
# 8812  [24(1967)-269(1991), 271(1991)-566(2009), 571(...
# 8822                                [10(1990)-26(2006)]
#
# [2179 rows x 9 columns]

# %%
def spr_years(holdings):
    years = []
    for x in holdings :
        yr = re.findall(r'[1-2][0-9]{3}',x)
        if len(yr) > 1:
            years.extend(list(range(int(yr[0]),int(yr[1])+1)))
        elif len(yr) == 1:
            y = yr[0]
            years.append(int(y))
        else:
            print(yr)
            print(holdings)
    return years

# %%
df_spr['SPR-yrs'] = df_spr['SPR-holdings'].apply(lambda x: sorted(spr_years(x)))
df_spr
# Out:
# []
# ['ser.1', '1(1969)-2(1970)', 'ser.2', '1(1971)-7(1977)', 'ser.3', '1(1978)-ser.3', '19(1996)']
# []
# ['ser.1', '1(1969)-2(1970)', 'ser.2', '1(1971)-7(1977)', 'ser.3', '1(1978)-ser.3', '19(1996)']
# []
# ['ser.1', '1(1969)-2(1970)', 'ser.2', '1(1971)-7(1977)', 'ser.3', '1(1978)-ser.3', '19(1996)']
# []
# ['ser.1', 'v.1(1859)-ser.8', 'v.6(1906)', 'ser.9', 'v.1(1907)-ser.14', 'v.6(1942)', 'ser.14', 'v.1(1937)-ser.14', 'v.3(1939)', '85(1943)-146(2004)']
# []
# ['ser.1', 'v.1(1859)-ser.8', 'v.6(1906)', 'ser.9', 'v.1(1907)-ser.14', 'v.6(1942)', 'ser.14', 'v.1(1937)-ser.14', 'v.3(1939)', '85(1943)-146(2004)']
# []
# ['ser.1', 'v.1(1859)-ser.8', 'v.6(1906)', 'ser.9', 'v.1(1907)-ser.14', 'v.6(1942)', 'ser.14', 'v.1(1937)-ser.14', 'v.3(1939)', '85(1943)-146(2004)']
# []
# ['1(1969)-89(2006)', 'Index20-22', '28-36', '38-40']
# []
# ['1(1969)-89(2006)', 'Index20-22', '28-36', '38-40']
# []
# ['1(1969)-89(2006)', 'Index20-22', '28-36', '38-40']
# []
# ['35(1973)-70(2008)', 'Suppl.63', '65-67']
# []
# ['35(1973)-70(2008)', 'Suppl.63', '65-67']
# []
# ['62(1970)-152(2006)', 'Indexes']
# []
# ['1(1836)-20(1855)', 'ser.2:v.1(1856)-v.19(1874)', 'ser.3:v.1(1875)-v.10(1884)', 'ser.4:v.1(1885)-v.10(1894)', 'ser.5:v.1(1895)-v.10(1904)', 'ser.6:v.1(1905)-v.10(1914)', 'ser.7:v.1(1915)-v.4(1918)', 'ser.8:v.2(1919)-v.4(1921)', 'ser.9', 'v.1(1922)-ser.9', 'v.84(2005)']
# []
# ['1(1836)-20(1855)', 'ser.2:v.1(1856)-v.19(1874)', 'ser.3:v.1(1875)-v.10(1884)', 'ser.4:v.1(1885)-v.10(1894)', 'ser.5:v.1(1895)-v.10(1904)', 'ser.6:v.1(1905)-v.10(1914)', 'ser.7:v.1(1915)-v.4(1918)', 'ser.8:v.2(1919)-v.4(1921)', 'ser.9', 'v.1(1922)-ser.9', 'v.84(2005)']
# []
# ['1(1916)-93(2008)', 'Indexv.1-50']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# []
# ['1-8', '10-83', '85-104', '106-126', '128', '130-146', '148-149', '151-155', '157-299', '301', '303-349', '357', '365', '371', '373', '375', '395', '404', '410', '422', '452', '461', '470', '480', '571', '581', '596', '608', '631', '688', '894', '898', '925', '931']
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 3     9939481760001701            Journal of the Institute of Actuaries
# 6     9964617400001701               Mathematics of the USSR. Izvestija
# 18    9929554030001701              Veterinary research communications.
# 25    9931084310001701                                    Neuropeptides
# ...                ...                                              ...
# 8793  9939180800001701       Annals of the New York Academy of Sciences
# 8808  9912065260001701                                  Physics letters
# 8811  9953202980001701                       Physics letters. Section A
# 8812  9953205880001701                       Physics letters. Section B
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#      p_or_e  matches_group_id  \
# 1         p                 5
# 3         p                12
# 6         p               267
# 18        p               707
# 25        p               744
# ...     ...               ...
# 8793      p            101219
# 8808      p            101461
# 8811      p            101461
# 8812      p            101461
# 8822      p            101582
#
#                               Title 1 (Print)_BTAA-SPR  \
# 1        IEEE transactions on ultrasonics engineering.
# 3               Journal of the Institute of Actuaries.
# 6                  Mathematics of the USSR: Izvestija.
# 18                 Veterinary research communications.
# 25                                      Neuropeptides.
# ...                                                ...
# 8793       Annals of the New York Academy of Sciences.
# 8808                                  Physics letters.
# 8811                                  Physics letters.
# 8812                                  Physics letters.
# 8822  International journal of adhesion and adhesives.
#
#                            Title 2 (Print)_BTAA-SPR Match?_BTAA-SPR  \
# 1                                               NaN             YES
# 3                                               NaN             YES
# 6                                               NaN             YES
# 18                                              NaN             YES
# 25                                              NaN             YES
# ...                                             ...             ...
# 8793  The year in ecology and conservation biology.             YES
# 8808                               Physics letters.             YES
# 8811                                            NaN             YES
# 8812                                            NaN             YES
# 8822                                            NaN             YES
#
#                                   SPR Holdings_BTAA-SPR  \
# 1                                              10(1963)
# 3                                    66(1935)-110(1983)
# 6                                      1(1967)-39(1992)
# 18                                     4(1980)-33(2009)
# 25                                1(1980/1981)-40(2006)
# ...                                                 ...
# 8793  1-8,10-83,85-104,106-126,128,130-146,148-149,1...
# 8808                                   1(1962)-23(1966)
# 8811                                 24(1967)-347(2005)
# 8812  24(1967)-269(1991),271(1991)-566(2009),571(200...
# 8822                                  10(1990)-26(2006)
#
#                                            SPR-holdings  \
# 1                                            [10(1963)]
# 3                                  [66(1935)-110(1983)]
# 6                                    [1(1967)-39(1992)]
# 18                                   [4(1980)-33(2009)]
# 25                              [1(1980/1981)-40(2006)]
# ...                                                 ...
# 8793  [1-8, 10-83, 85-104, 106-126, 128, 130-146, 14...
# 8808                                 [1(1962)-23(1966)]
# 8811                               [24(1967)-347(2005)]
# 8812  [24(1967)-269(1991), 271(1991)-566(2009), 571(...
# 8822                                [10(1990)-26(2006)]
#
#                                                 SPR-yrs
# 1                                                [1963]
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 25                                         [1980, 1981]
# ...                                                 ...
# 8793                                                 []
# 8808                     [1962, 1963, 1964, 1965, 1966]
# 8811  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8812  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [2179 rows x 10 columns]

# %%
dfs = pd.merge(df_e_range,df_spr[['SPR-yrs']],how='left',left_index=True,right_index=True)
dfs
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#      Earliest Year Preserved_PORTICO Latest Year Preserved_PORTICO  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 8818                             NaN                           NaN
# 8819                             NaN                           NaN
# 8820                             NaN                           NaN
# 8821                             NaN                           NaN
# 8822                             NaN                           NaN
#
#               curr-lib-loc_x all_item_count  \
# 0                        NaN            NaN
# 1                 [TZDS GEN]            [1]
# 2                        NaN            NaN
# 3                [TWILS CLS]           [46]
# 4                        NaN            NaN
# ...                      ...            ...
# 8818   [TSCI PER, ZMLAC OWL]           [53]
# 8819  [ZMLAC OWL, TWILS PER]           [74]
# 8820                     NaN            NaN
# 8821                     NaN            NaN
# 8822              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 30 columns]

# %% [markdown]
# #### Process Portico coverage

# %%
dfs.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc',
#        'pcad-range', 'SPR-yrs'],
#       dtype='object')

# %%
dfp = dfs[['record_index', 'MMS_ID', 'Title_bib', 'p_or_e', 'matches_group_id',
       'Title (Complete)_PORTICO','Portico Match_PORTICO', 
       'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
       'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO']]
dfp
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib p_or_e  \
# 0          IEEE transactions on ultrasonics engineering      e
# 1          IEEE transactions on ultrasonics engineering      p
# 2                 Journal of the Institute of Actuaries      e
# 3                 Journal of the Institute of Actuaries      p
# 4        Giornale degli economisti e annali di economia      e
# ...                                                 ...    ...
# 8818         Year book - American Philosophical Society      p
# 8819                                       The Americas      p
# 8820  The Americas - Academy of American Franciscan ...      e
# 8821    International journal of adhesion and adhesives      e
# 8822    International journal of adhesion and adhesives      p
#
#       matches_group_id Title (Complete)_PORTICO Portico Match_PORTICO  \
# 0                    5                      NaN                   NaN
# 1                    5                      NaN                   NaN
# 2                   12                      NaN                   NaN
# 3                   12                      NaN                   NaN
# 4                   92                      NaN                   NaN
# ...                ...                      ...                   ...
# 8818            101522                      NaN                   NaN
# 8819            101581                      NaN                   NaN
# 8820            101581                      NaN                   NaN
# 8821            101582                      NaN                   NaN
# 8822            101582                      NaN                   NaN
#
#      Portico Title_PORTICO PCA_PORTICO Status_PORTICO  \
# 0                      NaN         NaN            NaN
# 1                      NaN         NaN            NaN
# 2                      NaN         NaN            NaN
# 3                      NaN         NaN            NaN
# 4                      NaN         NaN            NaN
# ...                    ...         ...            ...
# 8818                   NaN         NaN            NaN
# 8819                   NaN         NaN            NaN
# 8820                   NaN         NaN            NaN
# 8821                   NaN         NaN            NaN
# 8822                   NaN         NaN            NaN
#
#       Earliest Year Preserved_PORTICO  Latest Year Preserved_PORTICO
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 8818                              NaN                            NaN
# 8819                              NaN                            NaN
# 8820                              NaN                            NaN
# 8821                              NaN                            NaN
# 8822                              NaN                            NaN
#
# [8823 rows x 12 columns]

# %%
dfp = dfp[(dfp['Portico Match_PORTICO'] == 'Yes') & (dfp['PCA_PORTICO'] == 'Yes') & (dfp['Status_PORTICO'] == 'Preserved')]
dfp
# Out:
#       record_index            MMS_ID  \
# 8            62770  9942472340001701
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                               Title_bib p_or_e  \
# 8     Laboratory techniques in biochemistry and mole...      p
# 33                      Annals of agricultural science.      p
# 36     Journal für praktische Chemie, Chemiker-Zeitung      p
# 37     Journal für praktische Chemie, Chemiker-Zeitung      p
# 38     Journal für praktische Chemie, Chemiker-Zeitung      p
# ...                                                 ...    ...
# 8704                Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8705                Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8706                Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8787                                            Ophelia      p
# 8789                   South African journal of zoology      p
#
#       matches_group_id                           Title (Complete)_PORTICO  \
# 8                  277  Laboratory techniques in biochemistry and mole...
# 33                1066                    Annals of agricultural science.
# 36                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 37                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 38                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# ...                ...                                                ...
# 8704             93064                 Zentralblatt für Veterinärmedizin.
# 8705             93064                 Zentralblatt für Veterinärmedizin.
# 8706             93064                 Zentralblatt für Veterinärmedizin.
# 8787            101035                                           Ophelia.
# 8789            101036  South African journal of zoology. Suid-Afrikaa...
#
#      Portico Match_PORTICO                              Portico Title_PORTICO  \
# 8                      Yes  Laboratory Techniques in Biochemistry and Mole...
# 33                     Yes                    Annals of Agricultural Sciences
# 36                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 37                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 38                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# ...                    ...                                                ...
# 8704                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8705                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8706                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8787                   Yes                                            Ophelia
# 8789                   Yes                   South African Journal of Zoology
#
#      PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 8            Yes      Preserved                              NaN
# 33           Yes      Preserved                           2011.0
# 36           Yes      Preserved                           2001.0
# 37           Yes      Preserved                           2001.0
# 38           Yes      Preserved                           2001.0
# ...          ...            ...                              ...
# 8704         Yes      Preserved                           1954.0
# 8705         Yes      Preserved                           1954.0
# 8706         Yes      Preserved                           1954.0
# 8787         Yes      Preserved                           1986.0
# 8789         Yes      Preserved                           1989.0
#
#       Latest Year Preserved_PORTICO
# 8                               NaN
# 33                           2019.0
# 36                           2020.0
# 37                           2020.0
# 38                           2020.0
# ...                             ...
# 8704                         1997.0
# 8705                         1997.0
# 8706                         1997.0
# 8787                         2001.0
# 8789                         1992.0
#
# [855 rows x 12 columns]

# %%
dfp['Earliest Year Preserved_PORTICO'].isna().value_counts()
# Out:
# False    831
# True      24
# Name: Earliest Year Preserved_PORTICO, dtype: int64

# %%
dfp[(dfp['Earliest Year Preserved_PORTICO'].isna())]
# Out:
#       record_index            MMS_ID  \
# 8            62770  9942472340001701
# 143          52765  9916006040001701
# 145          97135  9934198220001701
# 865          33250  9915103410001701
# 867         123843  9967042010001701
# 981          83005  9954507840001701
# 1382        124764  9975238308201701
# 1383         17569  9942533970001701
# 1458         49759  9953227240001701
# 1594         38529  9930589110001701
# 1919         17823  9942712620001701
# 2354         72590  9952386460001701
# 2703         41816  9927973550001701
# 4419        107714  9975214791201701
# 4420         68272  9933253580001701
# 5411          2801  9917463220001701
# 6022           409  9927166050001701
# 6106         19384  9924981970001701
# 6176         95639  9960671760001701
# 6930         32978  9933068010001701
# 7755         31043  9956364580001701
# 7756        114986  9967833700001701
# 7768         51350  9934201800001701
# 8638         85289  9913195390001701
#
#                                               Title_bib p_or_e  \
# 8     Laboratory techniques in biochemistry and mole...      p
# 143                       Semiconductors and semimetals      p
# 145                       Advances in applied mechanics      p
# 865                                          PN review.      p
# 867                                      Poetry nation.      e
# 981                      Reviews of infectious diseases      p
# 1382  Journal of the American Pharmaceutical Associa...      e
# 1383  Journal of the American Pharmaceutical Associa...      p
# 1458                                 Progress in optics      p
# 1594                              Advances in catalysis      p
# 1919                               Advances in genetics      p
# 2354  International review of research in mental ret...      p
# 2703                                Solid state physics      p
# 4419                Veterinary clinics of North America      e
# 4420                Veterinary clinics of North America      p
# 5411                            Methods in cell biology      p
# 6022                         Advances in heat transfer.      p
# 6106  Progress in nucleic acid research and molecula...      p
# 6176            Transactions of the Society of Rheology      p
# 6930              Australian journal of Chinese affairs      p
# 7755         Advances in child development and behavior      p
# 7756        Advances in child development and behavior.      e
# 7768                              Advances in computers      p
# 8638                   Advances in applied microbiology      p
#
#       matches_group_id                           Title (Complete)_PORTICO  \
# 8                  277  Laboratory techniques in biochemistry and mole...
# 143               4013  Semiconductors and semimetals [electronic reso...
# 145               4058  Advances in Applied Mechanics [electronic reso...
# 865              13001                                     Poetry nation.
# 867              13001                                     Poetry nation.
# 981              14097                    Reviews of infectious diseases.
# 1382             17896  Journal of the American Pharmaceutical Associa...
# 1383             17896  Journal of the American Pharmaceutical Associa...
# 1458             18743          Progress in optics [electronic resource].
# 1594             20477       Advances in catalysis [electronic resource].
# 1919             24611                              Advances in genetics.
# 2354             30377  International review of research in mental ret...
# 2703             33479         Solid state physics [electronic resource].
# 4419             42406           The Veterinary clinics of North America.
# 4420             42406           The Veterinary clinics of North America.
# 5411             45982                           Methods in cell biology.
# 6022             59387   Advances in heat transfer [electronic resource].
# 6106             61137  Progress in nucleic acid research and molecula...
# 6176             62820           Transactions of the Society of Rheology.
# 6930             71060  The Australian journal of Chinese affairs = Ao...
# 7755             78636        Advances in child development and behavior.
# 7756             78636        Advances in child development and behavior.
# 7768             78687                             Advances in computers.
# 8638             91688                  Advances in applied microbiology.
#
#      Portico Match_PORTICO                              Portico Title_PORTICO  \
# 8                      Yes  Laboratory Techniques in Biochemistry and Mole...
# 143                    Yes                      Semiconductors and Semimetals
# 145                    Yes                      Advances in Applied Mechanics
# 865                    Yes                                          PN Review
# 867                    Yes                                          PN Review
# 981                    Yes                     Reviews of Infectious Diseases
# 1382                   Yes  Journal of the American Pharmaceutical Associa...
# 1383                   Yes  Journal of the American Pharmaceutical Associa...
# 1458                   Yes                                 Progress in Optics
# 1594                   Yes                              Advances in Catalysis
# 1919                   Yes                               Advances in Genetics
# 2354                   Yes  International Review of Research in Mental Ret...
# 2703                   Yes                                Solid State Physics
# 4419                   Yes                Veterinary Clinics of North America
# 4420                   Yes                Veterinary Clinics of North America
# 5411                   Yes                            Methods in Cell Biology
# 6022                   Yes                          Advances in Heat Transfer
# 6106                   Yes  Progress in Nucleic Acid Research and Molecula...
# 6176                   Yes            Transactions of the Society of Rheology
# 6930                   Yes          The Australian Journal of Chinese Affairs
# 7755                   Yes         Advances in Child Development and Behavior
# 7756                   Yes         Advances in Child Development and Behavior
# 7768                   Yes                              Advances in Computers
# 8638                   Yes                   Advances in Applied Microbiology
#
#      PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 8            Yes      Preserved                              NaN
# 143          Yes      Preserved                              NaN
# 145          Yes      Preserved                              NaN
# 865          Yes      Preserved                              NaN
# 867          Yes      Preserved                              NaN
# 981          Yes      Preserved                              NaN
# 1382         Yes      Preserved                              NaN
# 1383         Yes      Preserved                              NaN
# 1458         Yes      Preserved                              NaN
# 1594         Yes      Preserved                              NaN
# 1919         Yes      Preserved                              NaN
# 2354         Yes      Preserved                              NaN
# 2703         Yes      Preserved                              NaN
# 4419         Yes      Preserved                              NaN
# 4420         Yes      Preserved                              NaN
# 5411         Yes      Preserved                              NaN
# 6022         Yes      Preserved                              NaN
# 6106         Yes      Preserved                              NaN
# 6176         Yes      Preserved                              NaN
# 6930         Yes      Preserved                              NaN
# 7755         Yes      Preserved                              NaN
# 7756         Yes      Preserved                              NaN
# 7768         Yes      Preserved                              NaN
# 8638         Yes      Preserved                              NaN
#
#       Latest Year Preserved_PORTICO
# 8                               NaN
# 143                             NaN
# 145                             NaN
# 865                             NaN
# 867                             NaN
# 981                             NaN
# 1382                            NaN
# 1383                            NaN
# 1458                            NaN
# 1594                            NaN
# 1919                            NaN
# 2354                            NaN
# 2703                            NaN
# 4419                            NaN
# 4420                            NaN
# 5411                            NaN
# 6022                            NaN
# 6106                            NaN
# 6176                            NaN
# 6930                            NaN
# 7755                            NaN
# 7756                            NaN
# 7768                            NaN
# 8638                            NaN

# %%
dfp = dfp[(dfp['Earliest Year Preserved_PORTICO'].notnull())]
dfp
# Out:
#       record_index            MMS_ID  \
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# 39           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                              Title_bib p_or_e  \
# 33                     Annals of agricultural science.      p
# 36    Journal für praktische Chemie, Chemiker-Zeitung      p
# 37    Journal für praktische Chemie, Chemiker-Zeitung      p
# 38    Journal für praktische Chemie, Chemiker-Zeitung      p
# 39    Journal für praktische Chemie, Chemiker-Zeitung      p
# ...                                                ...    ...
# 8704               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8705               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8706               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8787                                           Ophelia      p
# 8789                  South African journal of zoology      p
#
#       matches_group_id                           Title (Complete)_PORTICO  \
# 33                1066                    Annals of agricultural science.
# 36                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 37                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 38                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 39                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# ...                ...                                                ...
# 8704             93064                 Zentralblatt für Veterinärmedizin.
# 8705             93064                 Zentralblatt für Veterinärmedizin.
# 8706             93064                 Zentralblatt für Veterinärmedizin.
# 8787            101035                                           Ophelia.
# 8789            101036  South African journal of zoology. Suid-Afrikaa...
#
#      Portico Match_PORTICO                              Portico Title_PORTICO  \
# 33                     Yes                    Annals of Agricultural Sciences
# 36                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 37                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 38                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 39                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# ...                    ...                                                ...
# 8704                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8705                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8706                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8787                   Yes                                            Ophelia
# 8789                   Yes                   South African Journal of Zoology
#
#      PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 33           Yes      Preserved                           2011.0
# 36           Yes      Preserved                           2001.0
# 37           Yes      Preserved                           2001.0
# 38           Yes      Preserved                           2001.0
# 39           Yes      Preserved                           2001.0
# ...          ...            ...                              ...
# 8704         Yes      Preserved                           1954.0
# 8705         Yes      Preserved                           1954.0
# 8706         Yes      Preserved                           1954.0
# 8787         Yes      Preserved                           1986.0
# 8789         Yes      Preserved                           1989.0
#
#       Latest Year Preserved_PORTICO
# 33                           2019.0
# 36                           2020.0
# 37                           2020.0
# 38                           2020.0
# 39                           2020.0
# ...                             ...
# 8704                         1997.0
# 8705                         1997.0
# 8706                         1997.0
# 8787                         2001.0
# 8789                         1992.0
#
# [831 rows x 12 columns]

# %%
dfp['Earliest Year Preserved_PORTICO'] = dfp['Earliest Year Preserved_PORTICO'].apply(lambda x: int(x))
dfp
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       record_index            MMS_ID  \
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# 39           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                              Title_bib p_or_e  \
# 33                     Annals of agricultural science.      p
# 36    Journal für praktische Chemie, Chemiker-Zeitung      p
# 37    Journal für praktische Chemie, Chemiker-Zeitung      p
# 38    Journal für praktische Chemie, Chemiker-Zeitung      p
# 39    Journal für praktische Chemie, Chemiker-Zeitung      p
# ...                                                ...    ...
# 8704               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8705               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8706               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8787                                           Ophelia      p
# 8789                  South African journal of zoology      p
#
#       matches_group_id                           Title (Complete)_PORTICO  \
# 33                1066                    Annals of agricultural science.
# 36                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 37                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 38                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 39                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# ...                ...                                                ...
# 8704             93064                 Zentralblatt für Veterinärmedizin.
# 8705             93064                 Zentralblatt für Veterinärmedizin.
# 8706             93064                 Zentralblatt für Veterinärmedizin.
# 8787            101035                                           Ophelia.
# 8789            101036  South African journal of zoology. Suid-Afrikaa...
#
#      Portico Match_PORTICO                              Portico Title_PORTICO  \
# 33                     Yes                    Annals of Agricultural Sciences
# 36                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 37                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 38                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 39                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# ...                    ...                                                ...
# 8704                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8705                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8706                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8787                   Yes                                            Ophelia
# 8789                   Yes                   South African Journal of Zoology
#
#      PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 33           Yes      Preserved                             2011
# 36           Yes      Preserved                             2001
# 37           Yes      Preserved                             2001
# 38           Yes      Preserved                             2001
# 39           Yes      Preserved                             2001
# ...          ...            ...                              ...
# 8704         Yes      Preserved                             1954
# 8705         Yes      Preserved                             1954
# 8706         Yes      Preserved                             1954
# 8787         Yes      Preserved                             1986
# 8789         Yes      Preserved                             1989
#
#       Latest Year Preserved_PORTICO
# 33                           2019.0
# 36                           2020.0
# 37                           2020.0
# 38                           2020.0
# 39                           2020.0
# ...                             ...
# 8704                         1997.0
# 8705                         1997.0
# 8706                         1997.0
# 8787                         2001.0
# 8789                         1992.0
#
# [831 rows x 12 columns]

# %%
dfp['Latest Year Preserved_PORTICO'] = dfp['Latest Year Preserved_PORTICO'].apply(lambda x: int(x))
dfp
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       record_index            MMS_ID  \
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# 39           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                              Title_bib p_or_e  \
# 33                     Annals of agricultural science.      p
# 36    Journal für praktische Chemie, Chemiker-Zeitung      p
# 37    Journal für praktische Chemie, Chemiker-Zeitung      p
# 38    Journal für praktische Chemie, Chemiker-Zeitung      p
# 39    Journal für praktische Chemie, Chemiker-Zeitung      p
# ...                                                ...    ...
# 8704               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8705               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8706               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8787                                           Ophelia      p
# 8789                  South African journal of zoology      p
#
#       matches_group_id                           Title (Complete)_PORTICO  \
# 33                1066                    Annals of agricultural science.
# 36                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 37                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 38                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 39                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# ...                ...                                                ...
# 8704             93064                 Zentralblatt für Veterinärmedizin.
# 8705             93064                 Zentralblatt für Veterinärmedizin.
# 8706             93064                 Zentralblatt für Veterinärmedizin.
# 8787            101035                                           Ophelia.
# 8789            101036  South African journal of zoology. Suid-Afrikaa...
#
#      Portico Match_PORTICO                              Portico Title_PORTICO  \
# 33                     Yes                    Annals of Agricultural Sciences
# 36                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 37                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 38                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 39                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# ...                    ...                                                ...
# 8704                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8705                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8706                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8787                   Yes                                            Ophelia
# 8789                   Yes                   South African Journal of Zoology
#
#      PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 33           Yes      Preserved                             2011
# 36           Yes      Preserved                             2001
# 37           Yes      Preserved                             2001
# 38           Yes      Preserved                             2001
# 39           Yes      Preserved                             2001
# ...          ...            ...                              ...
# 8704         Yes      Preserved                             1954
# 8705         Yes      Preserved                             1954
# 8706         Yes      Preserved                             1954
# 8787         Yes      Preserved                             1986
# 8789         Yes      Preserved                             1989
#
#       Latest Year Preserved_PORTICO
# 33                             2019
# 36                             2020
# 37                             2020
# 38                             2020
# 39                             2020
# ...                             ...
# 8704                           1997
# 8705                           1997
# 8706                           1997
# 8787                           2001
# 8789                           1992
#
# [831 rows x 12 columns]

# %%
dfp['Earliest Year Preserved_PORTICO'].isna().value_counts()
# Out:
# False    831
# Name: Earliest Year Preserved_PORTICO, dtype: int64

# %%
dfp.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'p_or_e', 'matches_group_id',
#        'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO'],
#       dtype='object')

# %%
dfp['Portico-years'] = dfp.apply(lambda row: list(range(row['Earliest Year Preserved_PORTICO'],
                                                        row['Latest Year Preserved_PORTICO']+1)), axis=1)
dfp
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       record_index            MMS_ID  \
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# 39           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                              Title_bib p_or_e  \
# 33                     Annals of agricultural science.      p
# 36    Journal für praktische Chemie, Chemiker-Zeitung      p
# 37    Journal für praktische Chemie, Chemiker-Zeitung      p
# 38    Journal für praktische Chemie, Chemiker-Zeitung      p
# 39    Journal für praktische Chemie, Chemiker-Zeitung      p
# ...                                                ...    ...
# 8704               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8705               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8706               Zentralblatt f©ơr Veterin©Þrmedizin      e
# 8787                                           Ophelia      p
# 8789                  South African journal of zoology      p
#
#       matches_group_id                           Title (Complete)_PORTICO  \
# 33                1066                    Annals of agricultural science.
# 36                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 37                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 38                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# 39                1087  Journal für praktische Chemie, Chemiker-Zeitu...
# ...                ...                                                ...
# 8704             93064                 Zentralblatt für Veterinärmedizin.
# 8705             93064                 Zentralblatt für Veterinärmedizin.
# 8706             93064                 Zentralblatt für Veterinärmedizin.
# 8787            101035                                           Ophelia.
# 8789            101036  South African journal of zoology. Suid-Afrikaa...
#
#      Portico Match_PORTICO                              Portico Title_PORTICO  \
# 33                     Yes                    Annals of Agricultural Sciences
# 36                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 37                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 38                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# 39                     Yes  Journal für Praktische Chemie (1834-1991) | Jo...
# ...                    ...                                                ...
# 8704                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8705                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8706                   Yes  Zentralblatt für Veterinärmedizin | Journal of...
# 8787                   Yes                                            Ophelia
# 8789                   Yes                   South African Journal of Zoology
#
#      PCA_PORTICO Status_PORTICO  Earliest Year Preserved_PORTICO  \
# 33           Yes      Preserved                             2011
# 36           Yes      Preserved                             2001
# 37           Yes      Preserved                             2001
# 38           Yes      Preserved                             2001
# 39           Yes      Preserved                             2001
# ...          ...            ...                              ...
# 8704         Yes      Preserved                             1954
# 8705         Yes      Preserved                             1954
# 8706         Yes      Preserved                             1954
# 8787         Yes      Preserved                             1986
# 8789         Yes      Preserved                             1989
#
#       Latest Year Preserved_PORTICO  \
# 33                             2019
# 36                             2020
# 37                             2020
# 38                             2020
# 39                             2020
# ...                             ...
# 8704                           1997
# 8705                           1997
# 8706                           1997
# 8787                           2001
# 8789                           1992
#
#                                           Portico-years
# 33    [2011, 2012, 2013, 2014, 2015, 2016, 2017, 201...
# 36    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 37    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 38    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 39    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# ...                                                 ...
# 8704  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8705  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8706  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8789                           [1989, 1990, 1991, 1992]
#
# [831 rows x 13 columns]

# %%
df = pd.merge(dfs,dfp[['Portico-years']],how='left',left_index=True,right_index=True)
df
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#      Latest Year Preserved_PORTICO          curr-lib-loc_x all_item_count  \
# 0                              NaN                     NaN            NaN
# 1                              NaN              [TZDS GEN]            [1]
# 2                              NaN                     NaN            NaN
# 3                              NaN             [TWILS CLS]           [46]
# 4                              NaN                     NaN            NaN
# ...                            ...                     ...            ...
# 8818                           NaN   [TSCI PER, ZMLAC OWL]           [53]
# 8819                           NaN  [ZMLAC OWL, TWILS PER]           [74]
# 8820                           NaN                     NaN            NaN
# 8821                           NaN                     NaN            NaN
# 8822                           NaN              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8818                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
# [8823 rows x 31 columns]

# %% [markdown]
# #### Combine repository coverage

# %%
df_s_p = df[df['SPR-yrs'].notnull() & df['Portico-years'].notnull()]
df_s_p
# Out:
#       record_index            MMS_ID  \
# 422         121903  9967349630001701
# 423          20683  9956330160001701
# 462          89929  9941324470001701
# 463          89929  9941324470001701
# 586         112463  9968110510001701
# 587          39855  9965015360001701
# 1438        121712  9969448190001701
# 1439         64008  9947190700001701
# 1441         46587  9956317740001701
# 1509         96778  9921748030001701
# 1585         83267  9937379680001701
# 1586         83267  9937379680001701
# 1716         59191  9931107390001701
# 1894         77858  9966174660001701
# 1895         77858  9966174660001701
# 1896         77858  9966174660001701
# 1914         89168  9919990170001701
# 2069         76972  9959129210001701
# 2070        114305  9967154110001701
# 3006         55755  9946061610001701
# 3007         55755  9946061610001701
# 5576         26891  9921500400001701
# 5577         26891  9921500400001701
# 5643          7401  9932304400001701
# 5644          7401  9932304400001701
# 5645          7401  9932304400001701
# 5778        112340  9967712950001701
# 5780          1607  9937246550001701
# 5781         46048  9962695870001701
# 5782         94707  9927089100001701
# 5799        104383  9966783990001701
# 5800          1629  9937256840001701
# 6166         43413  9942534960001701
# 8133        128359  9968936570001701
# 8134        128359  9968936570001701
# 8135        128359  9968936570001701
# 8136        128359  9968936570001701
# 8137         12988  9944403410001701
# 8138         12988  9944403410001701
# 8627        111759  9966705960001701
# 8628         45405  9963079910001701
# 8674         99829  9932638730001701
# 8675         99829  9932638730001701
# 8676         99829  9932638730001701
# 8677         39691  9952644280001701
# 8678         39691  9952644280001701
# 8679         39691  9952644280001701
#
#                                               Title_bib  \
# 422   Canadian journal of biochemistry and cell biology
# 423   Canadian journal of biochemistry and cell biology
# 462                    Australian journal of statistics
# 463                    Australian journal of statistics
# 586   Journal of Comparative Pathology and Therapeutics
# 587   Journal of Comparative Pathology and Therapeutics
# 1438           Comparative biochemistry and physiology.
# 1439           Comparative biochemistry and physiology.
# 1441  Comparative biochemistry and physiology. A. Co...
# 1509  Pharmacology and therapeutics. Part C. Clinica...
# 1585                Acta pharmacologica et toxicologica
# 1586                Acta pharmacologica et toxicologica
# 1716            Journal of electroanalytical chemistry.
# 1894                      Fette, Seifen, Anstrichmittel
# 1895                      Fette, Seifen, Anstrichmittel
# 1896                      Fette, Seifen, Anstrichmittel
# 1914                            Filtration & separation
# 2069         Proceedings of the Geologists' Association
# 2070  Proceedings of the Geologists' Association (On...
# 3006  The BankAmerica journal of applied corporate f...
# 3007  The BankAmerica journal of applied corporate f...
# 5576                   New Zealand journal of geography
# 5577                   New Zealand journal of geography
# 5643                    Academic review (Boston, Mass.)
# 5644                    Academic review (Boston, Mass.)
# 5645                    Academic review (Boston, Mass.)
# 5778                  Journal of African earth sciences
# 5780                  Journal of African earth sciences
# 5781  Journal of African earth sciences (Oxford, Eng...
# 5782  Journal of African earth sciences, and the Mid...
# 5799                   Canadian journal of biochemistry
# 5800                   Canadian journal of biochemistry
# 6166                    Journal of Great Lakes research
# 8133                               Kristall und Technik
# 8134                               Kristall und Technik
# 8135                               Kristall und Technik
# 8136                               Kristall und Technik
# 8137                               Kristall und Technik
# 8138                               Kristall und Technik
# 8627  Journal of electroanalytical chemistry and int...
# 8628  Journal of electroanalytical chemistry and int...
# 8674     Australian and New Zealand journal of medicine
# 8675     Australian and New Zealand journal of medicine
# 8676     Australian and New Zealand journal of medicine
# 8677     Australian and New Zealand journal of medicine
# 8678     Australian and New Zealand journal of medicine
# 8679     Australian and New Zealand journal of medicine
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 422                ['0714-7511']      e              8412
# 423                ['0714-7511']      p              8412
# 462                ['0004-9581']      p              8786
# 463                ['0004-9581']      p              8786
# 586                ['0368-1742']      e             10384
# 587                ['0368-1742']      p             10384
# 1438               ['0300-9629']      e             18625
# 1439               ['0300-9629']      p             18625
# 1441               ['0300-9629']      p             18625
# 1509               ['0362-5486']      p             19112
# 1585               ['0001-6683']      p             20365
# 1586               ['0001-6683']      p             20365
# 1716               ['0368-1874']      p             21561
# 1894               ['0015-038X']      p             24250
# 1895               ['0015-038X']      p             24250
# 1896               ['0015-038X']      p             24250
# 1914               ['0015-1882']      p             24506
# 2069               ['0016-7878']      p             26706
# 2070               ['0016-7878']      e             26706
# 3006               ['1078-1196']      p             36691
# 3007               ['1078-1196']      p             36691
# 5576  ['0028-8292', '0228-8144']      p             48208
# 5577  ['0028-8292', '0228-8144']      p             48208
# 5643  ['1045-7194', '1554-1142']      p             49563
# 5644  ['1045-7194', '1554-1142']      p             49563
# 5645  ['1045-7194', '1554-1142']      p             49563
# 5778               ['0899-5362']      e             52713
# 5780               ['0731-7247']      p             52713
# 5781               ['0899-5362']      p             52713
# 5782  ['0731-7247', '0899-5362']      p             52713
# 5799               ['0008-4018']      e             53241
# 5800               ['0008-4018']      p             53241
# 6166               ['0380-1330']      p             62541
# 8133               ['0023-4753']      e             83713
# 8134               ['0023-4753']      e             83713
# 8135               ['0023-4753']      e             83713
# 8136               ['0023-4753']      e             83713
# 8137               ['0023-4753']      p             83713
# 8138               ['0023-4753']      p             83713
# 8627               ['0022-0728']      e             91565
# 8628  ['0449-2455', '0022-0728']      p             91565
# 8674               ['0004-8291']      p             92798
# 8675               ['0004-8291']      p             92798
# 8676               ['0004-8291']      p             92798
# 8677               ['0004-8291']      p             92798
# 8678               ['0004-8291']      p             92798
# 8679               ['0004-8291']      p             92798
#
#                                             e_coll_info  \
# 422   [['61535212690001701', 'Canadian Science Publi...
# 423                                                 NaN
# 462                                                 NaN
# 463                                                 NaN
# 586   [['61624504590001701', 'Elsevier ScienceDirect...
# 587                                                 NaN
# 1438  [['61535212360001701', 'Elsevier SD Backfile B...
# 1439                                                NaN
# 1441                                                NaN
# 1509                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1716                                                NaN
# 1894                                                NaN
# 1895                                                NaN
# 1896                                                NaN
# 1914                                                NaN
# 2069                                                NaN
# 2070  [['61624504590001701', 'Elsevier ScienceDirect...
# 3006                                                NaN
# 3007                                                NaN
# 5576                                                NaN
# 5577                                                NaN
# 5643                                                NaN
# 5644                                                NaN
# 5645                                                NaN
# 5778  [['61624504590001701', 'Elsevier ScienceDirect...
# 5780                                                NaN
# 5781                                                NaN
# 5782                                                NaN
# 5799  [['61535212690001701', 'Canadian Science Publi...
# 5800                                                NaN
# 6166                                                NaN
# 8133  [['61535212600001701', 'Wiley Online Library P...
# 8134  [['61535212600001701', 'Wiley Online Library P...
# 8135  [['61535212600001701', 'Wiley Online Library P...
# 8136  [['61535212600001701', 'Wiley Online Library P...
# 8137                                                NaN
# 8138                                                NaN
# 8627  [['61624504590001701', 'Elsevier ScienceDirect...
# 8628                                                NaN
# 8674                                                NaN
# 8675                                                NaN
# 8676                                                NaN
# 8677                                                NaN
# 8678                                                NaN
# 8679                                                NaN
#
#                                          portfolio_info  \
# 422   [['53537719460001701', 'Canadian journal of bi...
# 423                                                 NaN
# 462                                                 NaN
# 463                                                 NaN
# 586   [['53624638360001701', 'Journal of Comparative...
# 587                                                 NaN
# 1438  [['53624576870001701', 'Comparative biochemist...
# 1439                                                NaN
# 1441                                                NaN
# 1509                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1716                                                NaN
# 1894                                                NaN
# 1895                                                NaN
# 1896                                                NaN
# 1914                                                NaN
# 2069                                                NaN
# 2070  [['53624688260001701', "Proceedings of the Geo...
# 3006                                                NaN
# 3007                                                NaN
# 5576                                                NaN
# 5577                                                NaN
# 5643                                                NaN
# 5644                                                NaN
# 5645                                                NaN
# 5778  [['53624623280001701', 'Journal of African ear...
# 5780                                                NaN
# 5781                                                NaN
# 5782                                                NaN
# 5799  [['53536465350001701', 'Canadian journal of bi...
# 5800                                                NaN
# 6166                                                NaN
# 8133    [['53541283490001701', 'Kristall und Technik']]
# 8134    [['53541283490001701', 'Kristall und Technik']]
# 8135    [['53541283490001701', 'Kristall und Technik']]
# 8136    [['53541283490001701', 'Kristall und Technik']]
# 8137                                                NaN
# 8138                                                NaN
# 8627  [['53624635200001701', 'Journal of electroanal...
# 8628                                                NaN
# 8674                                                NaN
# 8675                                                NaN
# 8676                                                NaN
# 8677                                                NaN
# 8678                                                NaN
# 8679                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 422   [ Available from 1983 volume: 61 issue: 1 unti...  [Yes]  ...
# 423                                                 NaN    NaN  ...
# 462                                                 NaN    NaN  ...
# 463                                                 NaN    NaN  ...
# 586   [ Available from 1888 volume: 1 until 1964 vol...  [Yes]  ...
# 587                                                 NaN    NaN  ...
# 1438  [ Available from 1971 volume: 38 until 1994 vo...  [Yes]  ...
# 1439                                                NaN    NaN  ...
# 1441                                                NaN    NaN  ...
# 1509                                                NaN    NaN  ...
# 1585                                                NaN    NaN  ...
# 1586                                                NaN    NaN  ...
# 1716                                                NaN    NaN  ...
# 1894                                                NaN    NaN  ...
# 1895                                                NaN    NaN  ...
# 1896                                                NaN    NaN  ...
# 1914                                                NaN    NaN  ...
# 2069                                                NaN    NaN  ...
# 2070  [ Available from 1859 volume: 1 until 2012-09-...  [Yes]  ...
# 3006                                                NaN    NaN  ...
# 3007                                                NaN    NaN  ...
# 5576                                                NaN    NaN  ...
# 5577                                                NaN    NaN  ...
# 5643                                                NaN    NaN  ...
# 5644                                                NaN    NaN  ...
# 5645                                                NaN    NaN  ...
# 5778  [ Available from 1988 volume: 7 until 1993-11-...  [Yes]  ...
# 5780                                                NaN    NaN  ...
# 5781                                                NaN    NaN  ...
# 5782                                                NaN    NaN  ...
# 5799  [ Available from 1964 volume: 42 issue: 1 unti...  [Yes]  ...
# 5800                                                NaN    NaN  ...
# 6166                                                NaN    NaN  ...
# 8133  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8134  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8135  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8136  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8137                                                NaN    NaN  ...
# 8138                                                NaN    NaN  ...
# 8627  [ Available from 1967-01- volume: 13 issue: 1 ...  [Yes]  ...
# 8628                                                NaN    NaN  ...
# 8674                                                NaN    NaN  ...
# 8675                                                NaN    NaN  ...
# 8676                                                NaN    NaN  ...
# 8677                                                NaN    NaN  ...
# 8678                                                NaN    NaN  ...
# 8679                                                NaN    NaN  ...
#
#      Latest Year Preserved_PORTICO           curr-lib-loc_x all_item_count  \
# 422                         1985.0                      NaN            NaN
# 423                         1985.0             [TBIOM PERS]            [6]
# 462                         2019.0             [TWILS PERC]           [18]
# 463                         2019.0             [TWILS PERC]           [18]
# 586                         1964.0                      NaN            NaN
# 587                         1964.0    [ZMLAC NON, TVET PER]           [43]
# 1438                        1997.0                      NaN            NaN
# 1439                        1997.0             [TBIOM PERS]           [12]
# 1441                        1997.0  [TBIOM PERS, ZMLAC OWL]           [90]
# 1509                        1978.0               [TCOS SN1]            [2]
# 1585                        2001.0  [TBIOM PERS, ZMLAC OWL]           [97]
# 1586                        2001.0  [TBIOM PERS, ZMLAC OWL]           [97]
# 1716                        1989.0               [TZDS GEN]           [12]
# 1894                        1999.0              [ZMLAC GEN]           [35]
# 1895                        1999.0              [ZMLAC GEN]           [35]
# 1896                        1999.0              [ZMLAC GEN]           [35]
# 1914                        2019.0               [TSCI PER]           [49]
# 2069                        2020.0    [TSCI PER, ZMLAC OWL]           [17]
# 2070                        2020.0                      NaN            NaN
# 3006                        2020.0              [ZMLAC OWL]            [1]
# 3007                        2020.0              [ZMLAC OWL]            [1]
# 5576                        2019.0              [TWILS PER]            [7]
# 5577                        2019.0              [TWILS PER]            [7]
# 5643                        2020.0              [TMAGR PER]            [1]
# 5644                        2020.0              [TMAGR PER]            [1]
# 5645                        2020.0              [TMAGR PER]            [1]
# 5778                        2004.0                      NaN            NaN
# 5780                        1987.0              [ZMLAC OWL]            [7]
# 5781                        2004.0               [TSCI PER]           [20]
# 5782                        2004.0              [ZMLAC OWL]           [12]
# 5799                        1982.0                      NaN            NaN
# 5800                        1982.0             [TBIOM PERS]           [35]
# 6166                        2020.0     [TSCI PER, TZDS GEN]           [76]
# 8133                        2020.0                      NaN            NaN
# 8134                        2020.0                      NaN            NaN
# 8135                        2020.0                      NaN            NaN
# 8136                        2020.0                      NaN            NaN
# 8137                        2020.0              [ZMLAC OWL]           [24]
# 8138                        2020.0              [ZMLAC OWL]           [24]
# 8627                        2009.0                      NaN            NaN
# 8628                        2009.0               [TZDS GEN]          [137]
# 8674                        2020.0             [ZMLAC UMDN]            [7]
# 8675                        2020.0             [ZMLAC UMDN]            [7]
# 8676                        2020.0             [ZMLAC UMDN]            [7]
# 8677                        2020.0             [TBIOM PERS]           [34]
# 8678                        2020.0             [TBIOM PERS]           [34]
# 8679                        2020.0             [TBIOM PERS]           [34]
#
#                                                   chron  \
# 422                                                 NaN
# 423                                  [1983, 1984, 1985]
# 462   [1984-85, 1967-70, 1963-66, 1959/1983, 1991, 1...
# 463   [1984-85, 1967-70, 1963-66, 1959/1983, 1991, 1...
# 586                                                 NaN
# 587   [1949-50, 1936-37, 1899-1900, 1914, 1964, 1903...
# 1438                                                NaN
# 1439                           [1995, 1997, 1994, 1996]
# 1441  [1978, 1984, 1987, 1971, 1977, 1983, 1972, 198...
# 1509                                       [1976, 1977]
# 1585  [1970, 1948, 1950, 1960, 1978, 1984, 1965-66, ...
# 1586  [1970, 1948, 1950, 1960, 1978, 1984, 1965-66, ...
# 1716      [1959/60, 1962, 1964, 1963, 1961, 1965, 1966]
# 1894  [1970, 1960, 1978, 1964, 1963, 1961, 1977, 197...
# 1895  [1970, 1960, 1978, 1964, 1963, 1961, 1977, 197...
# 1896  [1970, 1960, 1978, 1964, 1963, 1961, 1977, 197...
# 1914  [2004, 1970, 1978, 1995, 1984, 1987, 1971, 197...
# 2069  [1872/73, 1881/82, 1859/65, 1889/90, 1879/80, ...
# 2070                                                NaN
# 3006                                             [1994]
# 3007                                             [1994]
# 5576  [1995-99, 1990-94, 1986-89, 1974-78, 1969-73, ...
# 5577  [1995-99, 1990-94, 1986-89, 1974-78, 1969-73, ...
# 5643                                             [2002]
# 5644                                             [2002]
# 5645                                             [2002]
# 5778                                                NaN
# 5780                     [1985, 1984, 1986, 1987, 1983]
# 5781  [1997, 2000, 1999, 1995, 1998, 1994, 2002, 200...
# 5782               [1991, 1988, 1993, 1989, 1990, 1992]
# 5799                                                NaN
# 5800  [1970, 1978, 1964, 1971, 1977, 1972, 1980, 197...
# 6166  [2004, 1978, 1995, 1984, 1975-76, 1987, 1977, ...
# 8133                                                NaN
# 8134                                                NaN
# 8135                                                NaN
# 8136                                                NaN
# 8137  [1974, 1970, 1973, 1976, 1975, 1978, 1979, 196...
# 8138  [1974, 1970, 1973, 1976, 1975, 1978, 1979, 196...
# 8627                                                NaN
# 8628  [1970, 1991-92, 1978, 1984, 1975-76, 1987, 197...
# 8674                                                 []
# 8675                                                 []
# 8676                                                 []
# 8677  [1978, 1984, 1995, 1987, 1977, 1971, 1983, 197...
# 8678  [1978, 1984, 1995, 1987, 1977, 1971, 1983, 197...
# 8679  [1978, 1984, 1995, 1987, 1977, 1971, 1983, 197...
#
#                  curr-lib-loc_ALL  \
# 422                           NaN
# 423                ['TBIOM PERS']
# 462                ['TWILS PERC']
# 463                ['TWILS PERC']
# 586                           NaN
# 587     ['ZMLAC NON', 'TVET PER']
# 1438                          NaN
# 1439               ['TBIOM PERS']
# 1441  ['TBIOM PERS', 'ZMLAC OWL']
# 1509                 ['TCOS SN1']
# 1585  ['TBIOM PERS', 'ZMLAC OWL']
# 1586  ['TBIOM PERS', 'ZMLAC OWL']
# 1716                 ['TZDS GEN']
# 1894                ['ZMLAC GEN']
# 1895                ['ZMLAC GEN']
# 1896                ['ZMLAC GEN']
# 1914                 ['TSCI PER']
# 2069    ['TSCI PER', 'ZMLAC OWL']
# 2070                          NaN
# 3006                ['ZMLAC OWL']
# 3007                ['ZMLAC OWL']
# 5576                ['TWILS PER']
# 5577                ['TWILS PER']
# 5643                ['TMAGR PER']
# 5644                ['TMAGR PER']
# 5645                ['TMAGR PER']
# 5778                          NaN
# 5780                ['ZMLAC OWL']
# 5781                 ['TSCI PER']
# 5782                ['ZMLAC OWL']
# 5799                          NaN
# 5800               ['TBIOM PERS']
# 6166     ['TSCI PER', 'TZDS GEN']
# 8133                          NaN
# 8134                          NaN
# 8135                          NaN
# 8136                          NaN
# 8137                ['ZMLAC OWL']
# 8138                ['ZMLAC OWL']
# 8627                          NaN
# 8628                 ['TZDS GEN']
# 8674               ['ZMLAC UMDN']
# 8675               ['ZMLAC UMDN']
# 8676               ['ZMLAC UMDN']
# 8677               ['TBIOM PERS']
# 8678               ['TBIOM PERS']
# 8679               ['TBIOM PERS']
#
#                                           chron_as_list  \
# 422                                                 NaN
# 423                                  [1983, 1984, 1985]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586                                                 NaN
# 587   [1894, 1895, 1896, 1899, 1900, 1901, 1902, 190...
# 1438                                                NaN
# 1439                           [1994, 1995, 1996, 1997]
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                       [1976, 1977]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966]
# 1894  [1956, 1957, 1958, 1959, 1960, 1961, 1962, 196...
# 1895  [1956, 1957, 1958, 1959, 1960, 1961, 1962, 196...
# 1896  [1956, 1957, 1958, 1959, 1960, 1961, 1962, 196...
# 1914  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 187...
# 2070                                                NaN
# 3006                                             [1994]
# 3007                                             [1994]
# 5576  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5577  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5643                                             [2002]
# 5644                                             [2002]
# 5645                                             [2002]
# 5778                                                NaN
# 5780                     [1983, 1984, 1985, 1986, 1987]
# 5781  [1994, 1995, 1996, 1997, 1998, 1999, 2000, 200...
# 5782               [1988, 1989, 1990, 1991, 1992, 1993]
# 5799                                                NaN
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133                                                NaN
# 8134                                                NaN
# 8135                                                NaN
# 8136                                                NaN
# 8137  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8138  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8627                                                NaN
# 8628  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8674                                                 []
# 8675                                                 []
# 8676                                                 []
# 8677  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 8678  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 8679  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
#
#                                chron_ranges_calc  \
# 422                                          NaN
# 423                               [(1983, 1985)]
# 462                               [(1959, 1993)]
# 463                               [(1959, 1993)]
# 586                                          NaN
# 587   [(1894, 1896), (1899, 1939), (1943, 1964)]
# 1438                                         NaN
# 1439                              [(1994, 1997)]
# 1441                              [(1971, 1991)]
# 1509                              [(1976, 1977)]
# 1585                              [(1945, 1986)]
# 1586                              [(1945, 1986)]
# 1716                              [(1959, 1966)]
# 1894                              [(1956, 1979)]
# 1895                              [(1956, 1979)]
# 1896                              [(1956, 1979)]
# 1914                              [(1964, 2004)]
# 2069  [(1859, 1865), (1870, 1900), (2002, 2002)]
# 2070                                         NaN
# 3006                              [(1994, 1994)]
# 3007                              [(1994, 1994)]
# 5576                              [(1969, 2004)]
# 5577                              [(1969, 2004)]
# 5643                              [(2002, 2002)]
# 5644                              [(2002, 2002)]
# 5645                              [(2002, 2002)]
# 5778                                         NaN
# 5780                              [(1983, 1987)]
# 5781                              [(1994, 2002)]
# 5782                              [(1988, 1993)]
# 5799                                         NaN
# 5800                              [(1964, 1982)]
# 6166                              [(1975, 2008)]
# 8133                                         NaN
# 8134                                         NaN
# 8135                                         NaN
# 8136                                         NaN
# 8137                              [(1966, 1980)]
# 8138                              [(1966, 1980)]
# 8627                                         NaN
# 8628                              [(1967, 1992)]
# 8674                                          []
# 8675                                          []
# 8676                                          []
# 8677                              [(1971, 2000)]
# 8678                              [(1971, 2000)]
# 8679                              [(1971, 2000)]
#
#                                              pcad-range  \
# 422                                  [1983, 1984, 1985]
# 423                                                 NaN
# 462                                                 NaN
# 463                                                 NaN
# 586   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 587                                                 NaN
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439                                                NaN
# 1441                                                NaN
# 1509                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1716                                                NaN
# 1894                                                NaN
# 1895                                                NaN
# 1896                                                NaN
# 1914                                                NaN
# 2069                                                NaN
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 3006                                                NaN
# 3007                                                NaN
# 5576                                                NaN
# 5577                                                NaN
# 5643                                                NaN
# 5644                                                NaN
# 5645                                                NaN
# 5778               [1988, 1989, 1990, 1991, 1992, 1993]
# 5780                                                NaN
# 5781                                                NaN
# 5782                                                NaN
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800                                                NaN
# 6166                                                NaN
# 8133  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8134  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8135  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8136  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8137                                                NaN
# 8138                                                NaN
# 8627  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8628                                                NaN
# 8674                                                NaN
# 8675                                                NaN
# 8676                                                NaN
# 8677                                                NaN
# 8678                                                NaN
# 8679                                                NaN
#
#                                                 SPR-yrs  \
# 422                                  [1983, 1984, 1985]
# 423                                  [1983, 1984, 1985]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586   [1891, 1896, 1897, 1898, 1899, 1900, 1901, 190...
# 587   [1891, 1896, 1897, 1898, 1899, 1900, 1901, 190...
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                 [1976, 1977, 1978]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966]
# 1894  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 1895  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 1896  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 1914  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 188...
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 188...
# 3006  [1994, 1995, 1996, 1997, 1998, 1999, 2000, 200...
# 3007  [1994, 1995, 1996, 1997, 1998, 1999, 2000, 200...
# 5576  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5577  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5643                                 [2000, 2001, 2002]
# 5644                                 [2000, 2001, 2002]
# 5645                                 [2000, 2001, 2002]
# 5778                     [1989, 1990, 1991, 1992, 1993]
# 5780                     [1983, 1984, 1985, 1986, 1987]
# 5781                     [1989, 1990, 1991, 1992, 1993]
# 5782                     [1989, 1990, 1991, 1992, 1993]
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8134  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8135  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8136  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8137  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8138  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8627  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8628  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8674  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8675  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8676  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8677  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8678  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8679  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
#
#                                           Portico-years
# 422                                  [1983, 1984, 1985]
# 423                                  [1983, 1984, 1985]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 587   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                 [1976, 1977, 1978]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 1894  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1895  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1896  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1914  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 3006  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 3007  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 5576  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 5577  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 5643  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5644  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5645  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5778  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5780                     [1983, 1984, 1985, 1986, 1987]
# 5781  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5782  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8134  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8135  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8136  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8137  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8138  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8627  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 8628  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 8674  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8675  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8676  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8677  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8678  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8679  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
#
# [47 rows x 31 columns]

# %%
#both should be lists; change index as needed
print(type(df_s_p['SPR-yrs'][1914]))
print(type(df_s_p['Portico-years'][1914]))
# Out:
# <class 'list'>
# <class 'list'>

# %%
df_s_p['repo-coverage'] = df_s_p.apply(lambda row: list(set(row['SPR-yrs'] + row['Portico-years'])), axis=1)
df_s_p
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       record_index            MMS_ID  \
# 422         121903  9967349630001701
# 423          20683  9956330160001701
# 462          89929  9941324470001701
# 463          89929  9941324470001701
# 586         112463  9968110510001701
# 587          39855  9965015360001701
# 1438        121712  9969448190001701
# 1439         64008  9947190700001701
# 1441         46587  9956317740001701
# 1509         96778  9921748030001701
# 1585         83267  9937379680001701
# 1586         83267  9937379680001701
# 1716         59191  9931107390001701
# 1894         77858  9966174660001701
# 1895         77858  9966174660001701
# 1896         77858  9966174660001701
# 1914         89168  9919990170001701
# 2069         76972  9959129210001701
# 2070        114305  9967154110001701
# 3006         55755  9946061610001701
# 3007         55755  9946061610001701
# 5576         26891  9921500400001701
# 5577         26891  9921500400001701
# 5643          7401  9932304400001701
# 5644          7401  9932304400001701
# 5645          7401  9932304400001701
# 5778        112340  9967712950001701
# 5780          1607  9937246550001701
# 5781         46048  9962695870001701
# 5782         94707  9927089100001701
# 5799        104383  9966783990001701
# 5800          1629  9937256840001701
# 6166         43413  9942534960001701
# 8133        128359  9968936570001701
# 8134        128359  9968936570001701
# 8135        128359  9968936570001701
# 8136        128359  9968936570001701
# 8137         12988  9944403410001701
# 8138         12988  9944403410001701
# 8627        111759  9966705960001701
# 8628         45405  9963079910001701
# 8674         99829  9932638730001701
# 8675         99829  9932638730001701
# 8676         99829  9932638730001701
# 8677         39691  9952644280001701
# 8678         39691  9952644280001701
# 8679         39691  9952644280001701
#
#                                               Title_bib  \
# 422   Canadian journal of biochemistry and cell biology
# 423   Canadian journal of biochemistry and cell biology
# 462                    Australian journal of statistics
# 463                    Australian journal of statistics
# 586   Journal of Comparative Pathology and Therapeutics
# 587   Journal of Comparative Pathology and Therapeutics
# 1438           Comparative biochemistry and physiology.
# 1439           Comparative biochemistry and physiology.
# 1441  Comparative biochemistry and physiology. A. Co...
# 1509  Pharmacology and therapeutics. Part C. Clinica...
# 1585                Acta pharmacologica et toxicologica
# 1586                Acta pharmacologica et toxicologica
# 1716            Journal of electroanalytical chemistry.
# 1894                      Fette, Seifen, Anstrichmittel
# 1895                      Fette, Seifen, Anstrichmittel
# 1896                      Fette, Seifen, Anstrichmittel
# 1914                            Filtration & separation
# 2069         Proceedings of the Geologists' Association
# 2070  Proceedings of the Geologists' Association (On...
# 3006  The BankAmerica journal of applied corporate f...
# 3007  The BankAmerica journal of applied corporate f...
# 5576                   New Zealand journal of geography
# 5577                   New Zealand journal of geography
# 5643                    Academic review (Boston, Mass.)
# 5644                    Academic review (Boston, Mass.)
# 5645                    Academic review (Boston, Mass.)
# 5778                  Journal of African earth sciences
# 5780                  Journal of African earth sciences
# 5781  Journal of African earth sciences (Oxford, Eng...
# 5782  Journal of African earth sciences, and the Mid...
# 5799                   Canadian journal of biochemistry
# 5800                   Canadian journal of biochemistry
# 6166                    Journal of Great Lakes research
# 8133                               Kristall und Technik
# 8134                               Kristall und Technik
# 8135                               Kristall und Technik
# 8136                               Kristall und Technik
# 8137                               Kristall und Technik
# 8138                               Kristall und Technik
# 8627  Journal of electroanalytical chemistry and int...
# 8628  Journal of electroanalytical chemistry and int...
# 8674     Australian and New Zealand journal of medicine
# 8675     Australian and New Zealand journal of medicine
# 8676     Australian and New Zealand journal of medicine
# 8677     Australian and New Zealand journal of medicine
# 8678     Australian and New Zealand journal of medicine
# 8679     Australian and New Zealand journal of medicine
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 422                ['0714-7511']      e              8412
# 423                ['0714-7511']      p              8412
# 462                ['0004-9581']      p              8786
# 463                ['0004-9581']      p              8786
# 586                ['0368-1742']      e             10384
# 587                ['0368-1742']      p             10384
# 1438               ['0300-9629']      e             18625
# 1439               ['0300-9629']      p             18625
# 1441               ['0300-9629']      p             18625
# 1509               ['0362-5486']      p             19112
# 1585               ['0001-6683']      p             20365
# 1586               ['0001-6683']      p             20365
# 1716               ['0368-1874']      p             21561
# 1894               ['0015-038X']      p             24250
# 1895               ['0015-038X']      p             24250
# 1896               ['0015-038X']      p             24250
# 1914               ['0015-1882']      p             24506
# 2069               ['0016-7878']      p             26706
# 2070               ['0016-7878']      e             26706
# 3006               ['1078-1196']      p             36691
# 3007               ['1078-1196']      p             36691
# 5576  ['0028-8292', '0228-8144']      p             48208
# 5577  ['0028-8292', '0228-8144']      p             48208
# 5643  ['1045-7194', '1554-1142']      p             49563
# 5644  ['1045-7194', '1554-1142']      p             49563
# 5645  ['1045-7194', '1554-1142']      p             49563
# 5778               ['0899-5362']      e             52713
# 5780               ['0731-7247']      p             52713
# 5781               ['0899-5362']      p             52713
# 5782  ['0731-7247', '0899-5362']      p             52713
# 5799               ['0008-4018']      e             53241
# 5800               ['0008-4018']      p             53241
# 6166               ['0380-1330']      p             62541
# 8133               ['0023-4753']      e             83713
# 8134               ['0023-4753']      e             83713
# 8135               ['0023-4753']      e             83713
# 8136               ['0023-4753']      e             83713
# 8137               ['0023-4753']      p             83713
# 8138               ['0023-4753']      p             83713
# 8627               ['0022-0728']      e             91565
# 8628  ['0449-2455', '0022-0728']      p             91565
# 8674               ['0004-8291']      p             92798
# 8675               ['0004-8291']      p             92798
# 8676               ['0004-8291']      p             92798
# 8677               ['0004-8291']      p             92798
# 8678               ['0004-8291']      p             92798
# 8679               ['0004-8291']      p             92798
#
#                                             e_coll_info  \
# 422   [['61535212690001701', 'Canadian Science Publi...
# 423                                                 NaN
# 462                                                 NaN
# 463                                                 NaN
# 586   [['61624504590001701', 'Elsevier ScienceDirect...
# 587                                                 NaN
# 1438  [['61535212360001701', 'Elsevier SD Backfile B...
# 1439                                                NaN
# 1441                                                NaN
# 1509                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1716                                                NaN
# 1894                                                NaN
# 1895                                                NaN
# 1896                                                NaN
# 1914                                                NaN
# 2069                                                NaN
# 2070  [['61624504590001701', 'Elsevier ScienceDirect...
# 3006                                                NaN
# 3007                                                NaN
# 5576                                                NaN
# 5577                                                NaN
# 5643                                                NaN
# 5644                                                NaN
# 5645                                                NaN
# 5778  [['61624504590001701', 'Elsevier ScienceDirect...
# 5780                                                NaN
# 5781                                                NaN
# 5782                                                NaN
# 5799  [['61535212690001701', 'Canadian Science Publi...
# 5800                                                NaN
# 6166                                                NaN
# 8133  [['61535212600001701', 'Wiley Online Library P...
# 8134  [['61535212600001701', 'Wiley Online Library P...
# 8135  [['61535212600001701', 'Wiley Online Library P...
# 8136  [['61535212600001701', 'Wiley Online Library P...
# 8137                                                NaN
# 8138                                                NaN
# 8627  [['61624504590001701', 'Elsevier ScienceDirect...
# 8628                                                NaN
# 8674                                                NaN
# 8675                                                NaN
# 8676                                                NaN
# 8677                                                NaN
# 8678                                                NaN
# 8679                                                NaN
#
#                                          portfolio_info  \
# 422   [['53537719460001701', 'Canadian journal of bi...
# 423                                                 NaN
# 462                                                 NaN
# 463                                                 NaN
# 586   [['53624638360001701', 'Journal of Comparative...
# 587                                                 NaN
# 1438  [['53624576870001701', 'Comparative biochemist...
# 1439                                                NaN
# 1441                                                NaN
# 1509                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1716                                                NaN
# 1894                                                NaN
# 1895                                                NaN
# 1896                                                NaN
# 1914                                                NaN
# 2069                                                NaN
# 2070  [['53624688260001701', "Proceedings of the Geo...
# 3006                                                NaN
# 3007                                                NaN
# 5576                                                NaN
# 5577                                                NaN
# 5643                                                NaN
# 5644                                                NaN
# 5645                                                NaN
# 5778  [['53624623280001701', 'Journal of African ear...
# 5780                                                NaN
# 5781                                                NaN
# 5782                                                NaN
# 5799  [['53536465350001701', 'Canadian journal of bi...
# 5800                                                NaN
# 6166                                                NaN
# 8133    [['53541283490001701', 'Kristall und Technik']]
# 8134    [['53541283490001701', 'Kristall und Technik']]
# 8135    [['53541283490001701', 'Kristall und Technik']]
# 8136    [['53541283490001701', 'Kristall und Technik']]
# 8137                                                NaN
# 8138                                                NaN
# 8627  [['53624635200001701', 'Journal of electroanal...
# 8628                                                NaN
# 8674                                                NaN
# 8675                                                NaN
# 8676                                                NaN
# 8677                                                NaN
# 8678                                                NaN
# 8679                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 422   [ Available from 1983 volume: 61 issue: 1 unti...  [Yes]  ...
# 423                                                 NaN    NaN  ...
# 462                                                 NaN    NaN  ...
# 463                                                 NaN    NaN  ...
# 586   [ Available from 1888 volume: 1 until 1964 vol...  [Yes]  ...
# 587                                                 NaN    NaN  ...
# 1438  [ Available from 1971 volume: 38 until 1994 vo...  [Yes]  ...
# 1439                                                NaN    NaN  ...
# 1441                                                NaN    NaN  ...
# 1509                                                NaN    NaN  ...
# 1585                                                NaN    NaN  ...
# 1586                                                NaN    NaN  ...
# 1716                                                NaN    NaN  ...
# 1894                                                NaN    NaN  ...
# 1895                                                NaN    NaN  ...
# 1896                                                NaN    NaN  ...
# 1914                                                NaN    NaN  ...
# 2069                                                NaN    NaN  ...
# 2070  [ Available from 1859 volume: 1 until 2012-09-...  [Yes]  ...
# 3006                                                NaN    NaN  ...
# 3007                                                NaN    NaN  ...
# 5576                                                NaN    NaN  ...
# 5577                                                NaN    NaN  ...
# 5643                                                NaN    NaN  ...
# 5644                                                NaN    NaN  ...
# 5645                                                NaN    NaN  ...
# 5778  [ Available from 1988 volume: 7 until 1993-11-...  [Yes]  ...
# 5780                                                NaN    NaN  ...
# 5781                                                NaN    NaN  ...
# 5782                                                NaN    NaN  ...
# 5799  [ Available from 1964 volume: 42 issue: 1 unti...  [Yes]  ...
# 5800                                                NaN    NaN  ...
# 6166                                                NaN    NaN  ...
# 8133  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8134  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8135  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8136  [ Available from 1966 volume: 1 issue: 1 until...  [Yes]  ...
# 8137                                                NaN    NaN  ...
# 8138                                                NaN    NaN  ...
# 8627  [ Available from 1967-01- volume: 13 issue: 1 ...  [Yes]  ...
# 8628                                                NaN    NaN  ...
# 8674                                                NaN    NaN  ...
# 8675                                                NaN    NaN  ...
# 8676                                                NaN    NaN  ...
# 8677                                                NaN    NaN  ...
# 8678                                                NaN    NaN  ...
# 8679                                                NaN    NaN  ...
#
#                curr-lib-loc_x all_item_count  \
# 422                       NaN            NaN
# 423              [TBIOM PERS]            [6]
# 462              [TWILS PERC]           [18]
# 463              [TWILS PERC]           [18]
# 586                       NaN            NaN
# 587     [ZMLAC NON, TVET PER]           [43]
# 1438                      NaN            NaN
# 1439             [TBIOM PERS]           [12]
# 1441  [TBIOM PERS, ZMLAC OWL]           [90]
# 1509               [TCOS SN1]            [2]
# 1585  [TBIOM PERS, ZMLAC OWL]           [97]
# 1586  [TBIOM PERS, ZMLAC OWL]           [97]
# 1716               [TZDS GEN]           [12]
# 1894              [ZMLAC GEN]           [35]
# 1895              [ZMLAC GEN]           [35]
# 1896              [ZMLAC GEN]           [35]
# 1914               [TSCI PER]           [49]
# 2069    [TSCI PER, ZMLAC OWL]           [17]
# 2070                      NaN            NaN
# 3006              [ZMLAC OWL]            [1]
# 3007              [ZMLAC OWL]            [1]
# 5576              [TWILS PER]            [7]
# 5577              [TWILS PER]            [7]
# 5643              [TMAGR PER]            [1]
# 5644              [TMAGR PER]            [1]
# 5645              [TMAGR PER]            [1]
# 5778                      NaN            NaN
# 5780              [ZMLAC OWL]            [7]
# 5781               [TSCI PER]           [20]
# 5782              [ZMLAC OWL]           [12]
# 5799                      NaN            NaN
# 5800             [TBIOM PERS]           [35]
# 6166     [TSCI PER, TZDS GEN]           [76]
# 8133                      NaN            NaN
# 8134                      NaN            NaN
# 8135                      NaN            NaN
# 8136                      NaN            NaN
# 8137              [ZMLAC OWL]           [24]
# 8138              [ZMLAC OWL]           [24]
# 8627                      NaN            NaN
# 8628               [TZDS GEN]          [137]
# 8674             [ZMLAC UMDN]            [7]
# 8675             [ZMLAC UMDN]            [7]
# 8676             [ZMLAC UMDN]            [7]
# 8677             [TBIOM PERS]           [34]
# 8678             [TBIOM PERS]           [34]
# 8679             [TBIOM PERS]           [34]
#
#                                                   chron  \
# 422                                                 NaN
# 423                                  [1983, 1984, 1985]
# 462   [1984-85, 1967-70, 1963-66, 1959/1983, 1991, 1...
# 463   [1984-85, 1967-70, 1963-66, 1959/1983, 1991, 1...
# 586                                                 NaN
# 587   [1949-50, 1936-37, 1899-1900, 1914, 1964, 1903...
# 1438                                                NaN
# 1439                           [1995, 1997, 1994, 1996]
# 1441  [1978, 1984, 1987, 1971, 1977, 1983, 1972, 198...
# 1509                                       [1976, 1977]
# 1585  [1970, 1948, 1950, 1960, 1978, 1984, 1965-66, ...
# 1586  [1970, 1948, 1950, 1960, 1978, 1984, 1965-66, ...
# 1716      [1959/60, 1962, 1964, 1963, 1961, 1965, 1966]
# 1894  [1970, 1960, 1978, 1964, 1963, 1961, 1977, 197...
# 1895  [1970, 1960, 1978, 1964, 1963, 1961, 1977, 197...
# 1896  [1970, 1960, 1978, 1964, 1963, 1961, 1977, 197...
# 1914  [2004, 1970, 1978, 1995, 1984, 1987, 1971, 197...
# 2069  [1872/73, 1881/82, 1859/65, 1889/90, 1879/80, ...
# 2070                                                NaN
# 3006                                             [1994]
# 3007                                             [1994]
# 5576  [1995-99, 1990-94, 1986-89, 1974-78, 1969-73, ...
# 5577  [1995-99, 1990-94, 1986-89, 1974-78, 1969-73, ...
# 5643                                             [2002]
# 5644                                             [2002]
# 5645                                             [2002]
# 5778                                                NaN
# 5780                     [1985, 1984, 1986, 1987, 1983]
# 5781  [1997, 2000, 1999, 1995, 1998, 1994, 2002, 200...
# 5782               [1991, 1988, 1993, 1989, 1990, 1992]
# 5799                                                NaN
# 5800  [1970, 1978, 1964, 1971, 1977, 1972, 1980, 197...
# 6166  [2004, 1978, 1995, 1984, 1975-76, 1987, 1977, ...
# 8133                                                NaN
# 8134                                                NaN
# 8135                                                NaN
# 8136                                                NaN
# 8137  [1974, 1970, 1973, 1976, 1975, 1978, 1979, 196...
# 8138  [1974, 1970, 1973, 1976, 1975, 1978, 1979, 196...
# 8627                                                NaN
# 8628  [1970, 1991-92, 1978, 1984, 1975-76, 1987, 197...
# 8674                                                 []
# 8675                                                 []
# 8676                                                 []
# 8677  [1978, 1984, 1995, 1987, 1977, 1971, 1983, 197...
# 8678  [1978, 1984, 1995, 1987, 1977, 1971, 1983, 197...
# 8679  [1978, 1984, 1995, 1987, 1977, 1971, 1983, 197...
#
#                  curr-lib-loc_ALL  \
# 422                           NaN
# 423                ['TBIOM PERS']
# 462                ['TWILS PERC']
# 463                ['TWILS PERC']
# 586                           NaN
# 587     ['ZMLAC NON', 'TVET PER']
# 1438                          NaN
# 1439               ['TBIOM PERS']
# 1441  ['TBIOM PERS', 'ZMLAC OWL']
# 1509                 ['TCOS SN1']
# 1585  ['TBIOM PERS', 'ZMLAC OWL']
# 1586  ['TBIOM PERS', 'ZMLAC OWL']
# 1716                 ['TZDS GEN']
# 1894                ['ZMLAC GEN']
# 1895                ['ZMLAC GEN']
# 1896                ['ZMLAC GEN']
# 1914                 ['TSCI PER']
# 2069    ['TSCI PER', 'ZMLAC OWL']
# 2070                          NaN
# 3006                ['ZMLAC OWL']
# 3007                ['ZMLAC OWL']
# 5576                ['TWILS PER']
# 5577                ['TWILS PER']
# 5643                ['TMAGR PER']
# 5644                ['TMAGR PER']
# 5645                ['TMAGR PER']
# 5778                          NaN
# 5780                ['ZMLAC OWL']
# 5781                 ['TSCI PER']
# 5782                ['ZMLAC OWL']
# 5799                          NaN
# 5800               ['TBIOM PERS']
# 6166     ['TSCI PER', 'TZDS GEN']
# 8133                          NaN
# 8134                          NaN
# 8135                          NaN
# 8136                          NaN
# 8137                ['ZMLAC OWL']
# 8138                ['ZMLAC OWL']
# 8627                          NaN
# 8628                 ['TZDS GEN']
# 8674               ['ZMLAC UMDN']
# 8675               ['ZMLAC UMDN']
# 8676               ['ZMLAC UMDN']
# 8677               ['TBIOM PERS']
# 8678               ['TBIOM PERS']
# 8679               ['TBIOM PERS']
#
#                                           chron_as_list  \
# 422                                                 NaN
# 423                                  [1983, 1984, 1985]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586                                                 NaN
# 587   [1894, 1895, 1896, 1899, 1900, 1901, 1902, 190...
# 1438                                                NaN
# 1439                           [1994, 1995, 1996, 1997]
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                       [1976, 1977]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966]
# 1894  [1956, 1957, 1958, 1959, 1960, 1961, 1962, 196...
# 1895  [1956, 1957, 1958, 1959, 1960, 1961, 1962, 196...
# 1896  [1956, 1957, 1958, 1959, 1960, 1961, 1962, 196...
# 1914  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 187...
# 2070                                                NaN
# 3006                                             [1994]
# 3007                                             [1994]
# 5576  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5577  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5643                                             [2002]
# 5644                                             [2002]
# 5645                                             [2002]
# 5778                                                NaN
# 5780                     [1983, 1984, 1985, 1986, 1987]
# 5781  [1994, 1995, 1996, 1997, 1998, 1999, 2000, 200...
# 5782               [1988, 1989, 1990, 1991, 1992, 1993]
# 5799                                                NaN
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133                                                NaN
# 8134                                                NaN
# 8135                                                NaN
# 8136                                                NaN
# 8137  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8138  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8627                                                NaN
# 8628  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8674                                                 []
# 8675                                                 []
# 8676                                                 []
# 8677  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 8678  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 8679  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
#
#                                chron_ranges_calc  \
# 422                                          NaN
# 423                               [(1983, 1985)]
# 462                               [(1959, 1993)]
# 463                               [(1959, 1993)]
# 586                                          NaN
# 587   [(1894, 1896), (1899, 1939), (1943, 1964)]
# 1438                                         NaN
# 1439                              [(1994, 1997)]
# 1441                              [(1971, 1991)]
# 1509                              [(1976, 1977)]
# 1585                              [(1945, 1986)]
# 1586                              [(1945, 1986)]
# 1716                              [(1959, 1966)]
# 1894                              [(1956, 1979)]
# 1895                              [(1956, 1979)]
# 1896                              [(1956, 1979)]
# 1914                              [(1964, 2004)]
# 2069  [(1859, 1865), (1870, 1900), (2002, 2002)]
# 2070                                         NaN
# 3006                              [(1994, 1994)]
# 3007                              [(1994, 1994)]
# 5576                              [(1969, 2004)]
# 5577                              [(1969, 2004)]
# 5643                              [(2002, 2002)]
# 5644                              [(2002, 2002)]
# 5645                              [(2002, 2002)]
# 5778                                         NaN
# 5780                              [(1983, 1987)]
# 5781                              [(1994, 2002)]
# 5782                              [(1988, 1993)]
# 5799                                         NaN
# 5800                              [(1964, 1982)]
# 6166                              [(1975, 2008)]
# 8133                                         NaN
# 8134                                         NaN
# 8135                                         NaN
# 8136                                         NaN
# 8137                              [(1966, 1980)]
# 8138                              [(1966, 1980)]
# 8627                                         NaN
# 8628                              [(1967, 1992)]
# 8674                                          []
# 8675                                          []
# 8676                                          []
# 8677                              [(1971, 2000)]
# 8678                              [(1971, 2000)]
# 8679                              [(1971, 2000)]
#
#                                              pcad-range  \
# 422                                  [1983, 1984, 1985]
# 423                                                 NaN
# 462                                                 NaN
# 463                                                 NaN
# 586   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 587                                                 NaN
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439                                                NaN
# 1441                                                NaN
# 1509                                                NaN
# 1585                                                NaN
# 1586                                                NaN
# 1716                                                NaN
# 1894                                                NaN
# 1895                                                NaN
# 1896                                                NaN
# 1914                                                NaN
# 2069                                                NaN
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 3006                                                NaN
# 3007                                                NaN
# 5576                                                NaN
# 5577                                                NaN
# 5643                                                NaN
# 5644                                                NaN
# 5645                                                NaN
# 5778               [1988, 1989, 1990, 1991, 1992, 1993]
# 5780                                                NaN
# 5781                                                NaN
# 5782                                                NaN
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800                                                NaN
# 6166                                                NaN
# 8133  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8134  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8135  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8136  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8137                                                NaN
# 8138                                                NaN
# 8627  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8628                                                NaN
# 8674                                                NaN
# 8675                                                NaN
# 8676                                                NaN
# 8677                                                NaN
# 8678                                                NaN
# 8679                                                NaN
#
#                                                 SPR-yrs  \
# 422                                  [1983, 1984, 1985]
# 423                                  [1983, 1984, 1985]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586   [1891, 1896, 1897, 1898, 1899, 1900, 1901, 190...
# 587   [1891, 1896, 1897, 1898, 1899, 1900, 1901, 190...
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                 [1976, 1977, 1978]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966]
# 1894  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 1895  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 1896  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 1914  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 188...
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 188...
# 3006  [1994, 1995, 1996, 1997, 1998, 1999, 2000, 200...
# 3007  [1994, 1995, 1996, 1997, 1998, 1999, 2000, 200...
# 5576  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5577  [1969, 1970, 1971, 1972, 1973, 1974, 1975, 197...
# 5643                                 [2000, 2001, 2002]
# 5644                                 [2000, 2001, 2002]
# 5645                                 [2000, 2001, 2002]
# 5778                     [1989, 1990, 1991, 1992, 1993]
# 5780                     [1983, 1984, 1985, 1986, 1987]
# 5781                     [1989, 1990, 1991, 1992, 1993]
# 5782                     [1989, 1990, 1991, 1992, 1993]
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8134  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8135  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8136  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8137  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8138  [1966, 1967, 1972, 1973, 1974, 1976, 1977, 197...
# 8627  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8628  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8674  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8675  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8676  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8677  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8678  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
# 8679  [1971, 1972, 1974, 1975, 1976, 1977, 1978, 197...
#
#                                           Portico-years  \
# 422                                  [1983, 1984, 1985]
# 423                                  [1983, 1984, 1985]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 587   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                 [1976, 1977, 1978]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 1894  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1895  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1896  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1914  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 3006  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 3007  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 5576  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 5577  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 5643  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5644  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5645  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5778  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5780                     [1983, 1984, 1985, 1986, 1987]
# 5781  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5782  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8134  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8135  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8136  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8137  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8138  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8627  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 8628  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 8674  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8675  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8676  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8677  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8678  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8679  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
#
#                                           repo-coverage
# 422                                  [1984, 1985, 1983]
# 423                                  [1984, 1985, 1983]
# 462   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 463   [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 586   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 587   [1888, 1889, 1890, 1891, 1892, 1893, 1894, 189...
# 1438  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1439  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1441  [1971, 1972, 1973, 1974, 1975, 1976, 1977, 197...
# 1509                                 [1976, 1977, 1978]
# 1585  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1586  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 1716  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 1894  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1895  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1896  [1894, 1895, 1896, 1897, 1898, 1899, 1900, 190...
# 1914  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 2069  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 2070  [1859, 1860, 1861, 1862, 1863, 1864, 1865, 186...
# 3006  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 3007  [1988, 1989, 1990, 1991, 1992, 1993, 1994, 199...
# 5576  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 5577  [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# 5643  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5644  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5645  [1989, 1990, 1991, 1992, 1993, 1994, 1995, 199...
# 5778  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5780                     [1984, 1985, 1986, 1987, 1983]
# 5781  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5782  [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# 5799  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 5800  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 6166  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 8133  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8134  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8135  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8136  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8137  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8138  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 8627  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 8628  [1959, 1960, 1961, 1962, 1963, 1964, 1965, 196...
# 8674  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8675  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8676  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8677  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8678  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
# 8679  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...
#
# [47 rows x 32 columns]

# %%
#next 3 cells to check results of last operation; use different index if needed
df_s_p['SPR-yrs'][587]
# Out:
# [1891,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964]

# %%
df_s_p['Portico-years'][587]
# Out:
# [1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964]

# %%
df_s_p['repo-coverage'][587]
# Out:
# [1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964]

# %%
df = pd.merge(df,df_s_p[['repo-coverage']],how='left',left_index=True,right_index=True)
df
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#               curr-lib-loc_x all_item_count  \
# 0                        NaN            NaN
# 1                 [TZDS GEN]            [1]
# 2                        NaN            NaN
# 3                [TWILS CLS]           [46]
# 4                        NaN            NaN
# ...                      ...            ...
# 8818   [TSCI PER, ZMLAC OWL]           [53]
# 8819  [ZMLAC OWL, TWILS PER]           [74]
# 8820                     NaN            NaN
# 8821                     NaN            NaN
# 8822              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8818                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#      repo-coverage
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 8818           NaN
# 8819           NaN
# 8820           NaN
# 8821           NaN
# 8822           NaN
#
# [8823 rows x 32 columns]

# %%
df_s = df[df['SPR-yrs'].notnull() & df['Portico-years'].isna()]
df_s
# Out:
#       record_index            MMS_ID  \
# 1            57684  9963550760001701
# 3            88618  9939481760001701
# 6            78022  9964617400001701
# 18           92015  9929554030001701
# 25           72522  9931084310001701
# ...            ...               ...
# 8793         43247  9939180800001701
# 8808         20011  9912065260001701
# 8811         49755  9953202980001701
# 8812         91677  9953205880001701
# 8822         31683  9957960200001701
#
#                                             Title_bib  \
# 1        IEEE transactions on ultrasonics engineering
# 3               Journal of the Institute of Actuaries
# 6                  Mathematics of the USSR. Izvestija
# 18                Veterinary research communications.
# 25                                      Neuropeptides
# ...                                               ...
# 8793       Annals of the New York Academy of Sciences
# 8808                                  Physics letters
# 8811                       Physics letters. Section A
# 8812                       Physics letters. Section B
# 8822  International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id e_coll_info  \
# 1                  ['0893-6706']      p                 5         NaN
# 3                  ['0020-2681']      p                12         NaN
# 6                  ['0025-5726']      p               267         NaN
# 18    ['0378-4312', '0165-7380']      p               707         NaN
# 25                 ['0143-4179']      p               744         NaN
# ...                          ...    ...               ...         ...
# 8793               ['0077-8923']      p            101219         NaN
# 8808  ['0031-9163', '1873-2410']      p            101461         NaN
# 8811  ['0375-9601', '0031-9163']      p            101461         NaN
# 8812  ['0031-9163', '0370-2693']      p            101461         NaN
# 8822               ['0143-7496']      p            101582         NaN
#
#      portfolio_info Coverage Information Combined PCAD?  ...  \
# 1               NaN                           NaN   NaN  ...
# 3               NaN                           NaN   NaN  ...
# 6               NaN                           NaN   NaN  ...
# 18              NaN                           NaN   NaN  ...
# 25              NaN                           NaN   NaN  ...
# ...             ...                           ...   ...  ...
# 8793            NaN                           NaN   NaN  ...
# 8808            NaN                           NaN   NaN  ...
# 8811            NaN                           NaN   NaN  ...
# 8812            NaN                           NaN   NaN  ...
# 8822            NaN                           NaN   NaN  ...
#
#                          curr-lib-loc_x all_item_count  \
# 1                            [TZDS GEN]            [1]
# 3                           [TWILS CLS]           [46]
# 6                           [TMATH PER]           [40]
# 18                           [TVET PER]           [31]
# 25                         [TBIOM PERS]           [35]
# ...                                 ...            ...
# 8793  [TBIOM PERS, ZMLAC OWL, TSCI GEN]         [1796]
# 8808                        [ZMLAC OWL]           [14]
# 8811                         [TZDS GEN]          [306]
# 8812                         [TZDS GEN]          [517]
# 8822                         [TSCI PER]            [6]
#
#                                                   chron  \
# 1                                           [1963-1966]
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 6     [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...
# 18    [1984-85, 2004, 1995, 1987, 1983, 2001, 1997, ...
# 25    [1984-85, 1995, 1987, 2001, 1985, 1997, 1991, ...
# ...                                                 ...
# 8793  [2004, 2012, 1940, 2015, 1964, 1987, 1968-1969...
# 8808  [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# 8811  [1974/75, 1970, 1978, 1984, 1995, 1982/84, 197...
# 8812  [1974/75, 2004, 1970, 1978, 1984, 1995, 1983/8...
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                              curr-lib-loc_ALL  \
# 1                                ['TZDS GEN']
# 3                               ['TWILS CLS']
# 6                               ['TMATH PER']
# 18                               ['TVET PER']
# 25                             ['TBIOM PERS']
# ...                                       ...
# 8793  ['TBIOM PERS', 'ZMLAC OWL', 'TSCI GEN']
# 8808                            ['ZMLAC OWL']
# 8811                             ['TZDS GEN']
# 8812                             ['TZDS GEN']
# 8822                             ['TSCI PER']
#
#                                           chron_as_list  \
# 1                              [1963, 1964, 1965, 1966]
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 25    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8793  [1877, 1878, 1879, 1880, 1881, 1882, 1883, 188...
# 8808                     [1962, 1963, 1964, 1965, 1966]
# 8811  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8812  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc pcad-range  \
# 1                                        [(1963, 1966)]        NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...        NaN
# 6                                        [(1967, 1992)]        NaN
# 18                                       [(1980, 2007)]        NaN
# 25                                       [(1980, 2003)]        NaN
# ...                                                 ...        ...
# 8793         [(1877, 1885), (1887, 1894), (1896, 2015)]        NaN
# 8808                                     [(1962, 1966)]        NaN
# 8811                                     [(1967, 2003)]        NaN
# 8812                                     [(1967, 2004)]        NaN
# 8822                                     [(1980, 1990)]        NaN
#
#                                                 SPR-yrs Portico-years  \
# 1                                                [1963]           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...           NaN
# 25                                         [1980, 1981]           NaN
# ...                                                 ...           ...
# 8793                                                 []           NaN
# 8808                     [1962, 1963, 1964, 1965, 1966]           NaN
# 8811  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 8812  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#      repo-coverage
# 1              NaN
# 3              NaN
# 6              NaN
# 18             NaN
# 25             NaN
# ...            ...
# 8793           NaN
# 8808           NaN
# 8811           NaN
# 8812           NaN
# 8822           NaN
#
# [2132 rows x 32 columns]

# %%
df_s['repo-coverage'] = df_s.apply(lambda row : row['SPR-yrs'], axis=1)
df_s
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       record_index            MMS_ID  \
# 1            57684  9963550760001701
# 3            88618  9939481760001701
# 6            78022  9964617400001701
# 18           92015  9929554030001701
# 25           72522  9931084310001701
# ...            ...               ...
# 8793         43247  9939180800001701
# 8808         20011  9912065260001701
# 8811         49755  9953202980001701
# 8812         91677  9953205880001701
# 8822         31683  9957960200001701
#
#                                             Title_bib  \
# 1        IEEE transactions on ultrasonics engineering
# 3               Journal of the Institute of Actuaries
# 6                  Mathematics of the USSR. Izvestija
# 18                Veterinary research communications.
# 25                                      Neuropeptides
# ...                                               ...
# 8793       Annals of the New York Academy of Sciences
# 8808                                  Physics letters
# 8811                       Physics letters. Section A
# 8812                       Physics letters. Section B
# 8822  International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id e_coll_info  \
# 1                  ['0893-6706']      p                 5         NaN
# 3                  ['0020-2681']      p                12         NaN
# 6                  ['0025-5726']      p               267         NaN
# 18    ['0378-4312', '0165-7380']      p               707         NaN
# 25                 ['0143-4179']      p               744         NaN
# ...                          ...    ...               ...         ...
# 8793               ['0077-8923']      p            101219         NaN
# 8808  ['0031-9163', '1873-2410']      p            101461         NaN
# 8811  ['0375-9601', '0031-9163']      p            101461         NaN
# 8812  ['0031-9163', '0370-2693']      p            101461         NaN
# 8822               ['0143-7496']      p            101582         NaN
#
#      portfolio_info Coverage Information Combined PCAD?  ...  \
# 1               NaN                           NaN   NaN  ...
# 3               NaN                           NaN   NaN  ...
# 6               NaN                           NaN   NaN  ...
# 18              NaN                           NaN   NaN  ...
# 25              NaN                           NaN   NaN  ...
# ...             ...                           ...   ...  ...
# 8793            NaN                           NaN   NaN  ...
# 8808            NaN                           NaN   NaN  ...
# 8811            NaN                           NaN   NaN  ...
# 8812            NaN                           NaN   NaN  ...
# 8822            NaN                           NaN   NaN  ...
#
#                          curr-lib-loc_x all_item_count  \
# 1                            [TZDS GEN]            [1]
# 3                           [TWILS CLS]           [46]
# 6                           [TMATH PER]           [40]
# 18                           [TVET PER]           [31]
# 25                         [TBIOM PERS]           [35]
# ...                                 ...            ...
# 8793  [TBIOM PERS, ZMLAC OWL, TSCI GEN]         [1796]
# 8808                        [ZMLAC OWL]           [14]
# 8811                         [TZDS GEN]          [306]
# 8812                         [TZDS GEN]          [517]
# 8822                         [TSCI PER]            [6]
#
#                                                   chron  \
# 1                                           [1963-1966]
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 6     [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...
# 18    [1984-85, 2004, 1995, 1987, 1983, 2001, 1997, ...
# 25    [1984-85, 1995, 1987, 2001, 1985, 1997, 1991, ...
# ...                                                 ...
# 8793  [2004, 2012, 1940, 2015, 1964, 1987, 1968-1969...
# 8808  [1962-63, 1962, 1964, 1963, 1962/66, 1965, 196...
# 8811  [1974/75, 1970, 1978, 1984, 1995, 1982/84, 197...
# 8812  [1974/75, 2004, 1970, 1978, 1984, 1995, 1983/8...
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                              curr-lib-loc_ALL  \
# 1                                ['TZDS GEN']
# 3                               ['TWILS CLS']
# 6                               ['TMATH PER']
# 18                               ['TVET PER']
# 25                             ['TBIOM PERS']
# ...                                       ...
# 8793  ['TBIOM PERS', 'ZMLAC OWL', 'TSCI GEN']
# 8808                            ['ZMLAC OWL']
# 8811                             ['TZDS GEN']
# 8812                             ['TZDS GEN']
# 8822                             ['TSCI PER']
#
#                                           chron_as_list  \
# 1                              [1963, 1964, 1965, 1966]
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 25    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8793  [1877, 1878, 1879, 1880, 1881, 1882, 1883, 188...
# 8808                     [1962, 1963, 1964, 1965, 1966]
# 8811  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8812  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc pcad-range  \
# 1                                        [(1963, 1966)]        NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...        NaN
# 6                                        [(1967, 1992)]        NaN
# 18                                       [(1980, 2007)]        NaN
# 25                                       [(1980, 2003)]        NaN
# ...                                                 ...        ...
# 8793         [(1877, 1885), (1887, 1894), (1896, 2015)]        NaN
# 8808                                     [(1962, 1966)]        NaN
# 8811                                     [(1967, 2003)]        NaN
# 8812                                     [(1967, 2004)]        NaN
# 8822                                     [(1980, 1990)]        NaN
#
#                                                 SPR-yrs Portico-years  \
# 1                                                [1963]           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...           NaN
# 25                                         [1980, 1981]           NaN
# ...                                                 ...           ...
# 8793                                                 []           NaN
# 8808                     [1962, 1963, 1964, 1965, 1966]           NaN
# 8811  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 8812  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 1                                                [1963]
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 25                                         [1980, 1981]
# ...                                                 ...
# 8793                                                 []
# 8808                     [1962, 1963, 1964, 1965, 1966]
# 8811  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8812  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [2132 rows x 32 columns]

# %%
df_s.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc',
#        'pcad-range', 'SPR-yrs', 'Portico-years', 'repo-coverage'],
#       dtype='object')

# %%
df0 = df.combine_first(df_s[['MMS_ID','repo-coverage']])
df0
# Out:
#                           Coverage Information Combined  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...
# 1                                                   NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...
# 3                                                   NaN
# 4          [ Available from 1939 volume: 1 until 2012;]
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]
# 8822                                                NaN
#
#       Earliest Year Preserved_PORTICO                ISSN_cluster  \
# 0                                 NaN  ['0893-6706', '2162-1373']
# 1                                 NaN               ['0893-6706']
# 2                                 NaN  ['0020-2681', '2058-1009']
# 3                                 NaN               ['0020-2681']
# 4                                 NaN               ['0017-0097']
# ...                               ...                         ...
# 8818                              NaN  ['0065-9762', '0003-049X']
# 8819                              NaN  ['1533-6247', '0003-1615']
# 8820                              NaN  ['1533-6247', '0003-1615']
# 8821                              NaN  ['0143-7496', '1879-0127']
# 8822                              NaN               ['0143-7496']
#
#       Latest Year Preserved_PORTICO            MMS_ID Match?_BTAA-SPR  PCAD?  \
# 0                               NaN  9968441380001701             NaN  [Yes]
# 1                               NaN  9963550760001701             YES    NaN
# 2                               NaN  9968429800001701             NaN  [Yes]
# 3                               NaN  9939481760001701             YES    NaN
# 4                               NaN  9967115530001701             NaN  [Yes]
# ...                             ...               ...             ...    ...
# 8818                            NaN  9959156260001701             NaN    NaN
# 8819                            NaN  9946768760001701             NaN    NaN
# 8820                            NaN  9967987860001701             NaN  [Yes]
# 8821                            NaN  9968947900001701             NaN  [Yes]
# 8822                            NaN  9957960200001701             YES    NaN
#
#      PCA_PORTICO Portico Match_PORTICO Portico Title_PORTICO  ...  \
# 0            NaN                   NaN                   NaN  ...
# 1            NaN                   NaN                   NaN  ...
# 2            NaN                   NaN                   NaN  ...
# 3            NaN                   NaN                   NaN  ...
# 4            NaN                   NaN                   NaN  ...
# ...          ...                   ...                   ...  ...
# 8818         NaN                   NaN                   NaN  ...
# 8819         NaN                   NaN                   NaN  ...
# 8820         NaN                   NaN                   NaN  ...
# 8821         NaN                   NaN                   NaN  ...
# 8822         NaN                   NaN                   NaN  ...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                 curr-lib-loc_ALL          curr-lib-loc_x  \
# 0                            NaN                     NaN
# 1                   ['TZDS GEN']              [TZDS GEN]
# 2                            NaN                     NaN
# 3                  ['TWILS CLS']             [TWILS CLS]
# 4                            NaN                     NaN
# ...                          ...                     ...
# 8818   ['TSCI PER', 'ZMLAC OWL']   [TSCI PER, ZMLAC OWL]
# 8819  ['ZMLAC OWL', 'TWILS PER']  [ZMLAC OWL, TWILS PER]
# 8820                         NaN                     NaN
# 8821                         NaN                     NaN
# 8822                ['TSCI PER']              [TSCI PER]
#
#                                             e_coll_info matches_group_id  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...                5
# 1                                                   NaN                5
# 2     [['61535216140001701', 'JSTOR Business III Col...               12
# 3                                                   NaN               12
# 4     [['61745117840001701', 'JSTOR Arts and Science...               92
# ...                                                 ...              ...
# 8818                                                NaN           101522
# 8819                                                NaN           101581
# 8820  [['61535211010001701', 'JSTOR Arts and Science...           101581
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...           101582
# 8822                                                NaN           101582
#
#      p_or_e                                         pcad-range  \
# 0         e                                             [1963]
# 1         p                                                NaN
# 2         e  [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3         p                                                NaN
# 4         e  [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...     ...                                                ...
# 8818      p                                                NaN
# 8819      p                                                NaN
# 8820      e  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821      e  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822      p                                                NaN
#
#                                          portfolio_info record_index  \
# 0     [['53620359120001701', 'IEEE transactions on u...       128733
# 1                                                   NaN        57684
# 2     [['53540140170001701', 'Journal of the Institu...       111951
# 3                                                   NaN        88618
# 4     [['53537228640001701', 'Giornale degli economi...       123907
# ...                                                 ...          ...
# 8818                                                NaN        61904
# 8819                                                NaN        17960
# 8820           [['53539160390001701', 'The Americas.']]       117510
# 8821  [['53624617390001701', 'International journal ...       125537
# 8822                                                NaN        31683
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 32 columns]

# %%
df0 = df0[['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
       'matches_group_id', 'e_coll_info', 'portfolio_info',
       'Coverage Information Combined', 'PCAD?', 'Vendor_key',
       'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
       'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR',
       'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
       'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
       'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
       'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL',
       'chron_as_list', 'chron_ranges_calc', 'pcad-range', 'SPR-yrs',
       'Portico-years', 'repo-coverage']]
df0
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#               curr-lib-loc_x all_item_count  \
# 0                        NaN            NaN
# 1                 [TZDS GEN]            [1]
# 2                        NaN            NaN
# 3                [TWILS CLS]           [46]
# 4                        NaN            NaN
# ...                      ...            ...
# 8818   [TSCI PER, ZMLAC OWL]           [53]
# 8819  [ZMLAC OWL, TWILS PER]           [74]
# 8820                     NaN            NaN
# 8821                     NaN            NaN
# 8822              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8818                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 32 columns]

# %%
df_p = df0[df0['SPR-yrs'].isna() & df['Portico-years'].notnull()]
df_p
# Out:
#       record_index            MMS_ID  \
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# 39           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                              Title_bib  \
# 33                     Annals of agricultural science.
# 36    Journal für praktische Chemie, Chemiker-Zeitung
# 37    Journal für praktische Chemie, Chemiker-Zeitung
# 38    Journal für praktische Chemie, Chemiker-Zeitung
# 39    Journal für praktische Chemie, Chemiker-Zeitung
# ...                                                ...
# 8704               Zentralblatt f©ơr Veterin©Þrmedizin
# 8705               Zentralblatt f©ơr Veterin©Þrmedizin
# 8706               Zentralblatt f©ơr Veterin©Þrmedizin
# 8787                                           Ophelia
# 8789                  South African journal of zoology
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 33    ['1110-0249', '0570-1783']      p              1066
# 36                 ['0941-1216']      p              1087
# 37                 ['0941-1216']      p              1087
# 38                 ['0941-1216']      p              1087
# 39                 ['0941-1216']      p              1087
# ...                          ...    ...               ...
# 8704               ['0044-4294']      e             93064
# 8705               ['0044-4294']      e             93064
# 8706               ['0044-4294']      e             93064
# 8787               ['0078-5326']      p            101035
# 8789               ['0254-1858']      p            101036
#
#                                             e_coll_info  \
# 33                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 8704  [['61535213310001701', 'Wiley Online Library V...
# 8705  [['61535213310001701', 'Wiley Online Library V...
# 8706  [['61535213310001701', 'Wiley Online Library V...
# 8787                                                NaN
# 8789                                                NaN
#
#                                          portfolio_info  \
# 33                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 8704  [['53742266770001701', 'Zentralblatt für Veter...
# 8705  [['53742266770001701', 'Zentralblatt für Veter...
# 8706  [['53742266770001701', 'Zentralblatt für Veter...
# 8787                                                NaN
# 8789                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 33                                                  NaN    NaN  ...
# 36                                                  NaN    NaN  ...
# 37                                                  NaN    NaN  ...
# 38                                                  NaN    NaN  ...
# 39                                                  NaN    NaN  ...
# ...                                                 ...    ...  ...
# 8704  [ Available from 1954 volume: 1 issue: 1 until...  [Yes]  ...
# 8705  [ Available from 1954 volume: 1 issue: 1 until...  [Yes]  ...
# 8706  [ Available from 1954 volume: 1 issue: 1 until...  [Yes]  ...
# 8787                                                NaN    NaN  ...
# 8789                                                NaN    NaN  ...
#
#      curr-lib-loc_x all_item_count  \
# 33      [ZMLAC OWL]            [7]
# 36      [ZMLAC OWL]           [10]
# 37      [ZMLAC OWL]           [10]
# 38      [ZMLAC OWL]           [10]
# 39      [ZMLAC OWL]           [10]
# ...             ...            ...
# 8704            NaN            NaN
# 8705            NaN            NaN
# 8706            NaN            NaN
# 8787    [TMAGR PER]           [20]
# 8789    [TMAGR PER]           [14]
#
#                                                   chron curr-lib-loc_ALL  \
# 33           [1960, 1956, 1959, 1964, 1961, 1965, 1957]    ['ZMLAC OWL']
# 36                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# 37                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# 38                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# 39                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# ...                                                 ...              ...
# 8704                                                NaN              NaN
# 8705                                                NaN              NaN
# 8706                                                NaN              NaN
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
#
#                                           chron_as_list  \
# 33           [1956, 1957, 1959, 1960, 1961, 1964, 1965]
# 36                       [1992, 1993, 1994, 1995, 1996]
# 37                       [1992, 1993, 1994, 1995, 1996]
# 38                       [1992, 1993, 1994, 1995, 1996]
# 39                       [1992, 1993, 1994, 1995, 1996]
# ...                                                 ...
# 8704                                                NaN
# 8705                                                NaN
# 8706                                                NaN
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
#
#                                chron_ranges_calc  \
# 33    [(1956, 1957), (1959, 1961), (1964, 1965)]
# 36                                [(1992, 1996)]
# 37                                [(1992, 1996)]
# 38                                [(1992, 1996)]
# 39                                [(1992, 1996)]
# ...                                          ...
# 8704                                         NaN
# 8705                                         NaN
# 8706                                         NaN
# 8787                              [(1964, 1994)]
# 8789                              [(1979, 1999)]
#
#                                              pcad-range SPR-yrs  \
# 33                                                  NaN     NaN
# 36                                                  NaN     NaN
# 37                                                  NaN     NaN
# 38                                                  NaN     NaN
# 39                                                  NaN     NaN
# ...                                                 ...     ...
# 8704  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...     NaN
# 8705  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...     NaN
# 8706  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...     NaN
# 8787                                                NaN     NaN
# 8789                                                NaN     NaN
#
#                                           Portico-years repo-coverage
# 33    [2011, 2012, 2013, 2014, 2015, 2016, 2017, 201...           NaN
# 36    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...           NaN
# 37    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...           NaN
# 38    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...           NaN
# 39    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...           NaN
# ...                                                 ...           ...
# 8704  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...           NaN
# 8705  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...           NaN
# 8706  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...           NaN
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...           NaN
# 8789                           [1989, 1990, 1991, 1992]           NaN
#
# [784 rows x 32 columns]

# %%
df_p['repo-coverage'] = df_p['Portico-years']
df_p
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       record_index            MMS_ID  \
# 33           74020  9918228280001701
# 36           43622  9975846880001701
# 37           43622  9975846880001701
# 38           43622  9975846880001701
# 39           43622  9975846880001701
# ...            ...               ...
# 8704        125990  9970295590001701
# 8705        125990  9970295590001701
# 8706        125990  9970295590001701
# 8787         37420  9931018220001701
# 8789         40052  9942687740001701
#
#                                              Title_bib  \
# 33                     Annals of agricultural science.
# 36    Journal für praktische Chemie, Chemiker-Zeitung
# 37    Journal für praktische Chemie, Chemiker-Zeitung
# 38    Journal für praktische Chemie, Chemiker-Zeitung
# 39    Journal für praktische Chemie, Chemiker-Zeitung
# ...                                                ...
# 8704               Zentralblatt f©ơr Veterin©Þrmedizin
# 8705               Zentralblatt f©ơr Veterin©Þrmedizin
# 8706               Zentralblatt f©ơr Veterin©Þrmedizin
# 8787                                           Ophelia
# 8789                  South African journal of zoology
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 33    ['1110-0249', '0570-1783']      p              1066
# 36                 ['0941-1216']      p              1087
# 37                 ['0941-1216']      p              1087
# 38                 ['0941-1216']      p              1087
# 39                 ['0941-1216']      p              1087
# ...                          ...    ...               ...
# 8704               ['0044-4294']      e             93064
# 8705               ['0044-4294']      e             93064
# 8706               ['0044-4294']      e             93064
# 8787               ['0078-5326']      p            101035
# 8789               ['0254-1858']      p            101036
#
#                                             e_coll_info  \
# 33                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 8704  [['61535213310001701', 'Wiley Online Library V...
# 8705  [['61535213310001701', 'Wiley Online Library V...
# 8706  [['61535213310001701', 'Wiley Online Library V...
# 8787                                                NaN
# 8789                                                NaN
#
#                                          portfolio_info  \
# 33                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# ...                                                 ...
# 8704  [['53742266770001701', 'Zentralblatt für Veter...
# 8705  [['53742266770001701', 'Zentralblatt für Veter...
# 8706  [['53742266770001701', 'Zentralblatt für Veter...
# 8787                                                NaN
# 8789                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 33                                                  NaN    NaN  ...
# 36                                                  NaN    NaN  ...
# 37                                                  NaN    NaN  ...
# 38                                                  NaN    NaN  ...
# 39                                                  NaN    NaN  ...
# ...                                                 ...    ...  ...
# 8704  [ Available from 1954 volume: 1 issue: 1 until...  [Yes]  ...
# 8705  [ Available from 1954 volume: 1 issue: 1 until...  [Yes]  ...
# 8706  [ Available from 1954 volume: 1 issue: 1 until...  [Yes]  ...
# 8787                                                NaN    NaN  ...
# 8789                                                NaN    NaN  ...
#
#      curr-lib-loc_x all_item_count  \
# 33      [ZMLAC OWL]            [7]
# 36      [ZMLAC OWL]           [10]
# 37      [ZMLAC OWL]           [10]
# 38      [ZMLAC OWL]           [10]
# 39      [ZMLAC OWL]           [10]
# ...             ...            ...
# 8704            NaN            NaN
# 8705            NaN            NaN
# 8706            NaN            NaN
# 8787    [TMAGR PER]           [20]
# 8789    [TMAGR PER]           [14]
#
#                                                   chron curr-lib-loc_ALL  \
# 33           [1960, 1956, 1959, 1964, 1961, 1965, 1957]    ['ZMLAC OWL']
# 36                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# 37                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# 38                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# 39                       [1995, 1993, 1992, 1994, 1996]    ['ZMLAC OWL']
# ...                                                 ...              ...
# 8704                                                NaN              NaN
# 8705                                                NaN              NaN
# 8706                                                NaN              NaN
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
#
#                                           chron_as_list  \
# 33           [1956, 1957, 1959, 1960, 1961, 1964, 1965]
# 36                       [1992, 1993, 1994, 1995, 1996]
# 37                       [1992, 1993, 1994, 1995, 1996]
# 38                       [1992, 1993, 1994, 1995, 1996]
# 39                       [1992, 1993, 1994, 1995, 1996]
# ...                                                 ...
# 8704                                                NaN
# 8705                                                NaN
# 8706                                                NaN
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
#
#                                chron_ranges_calc  \
# 33    [(1956, 1957), (1959, 1961), (1964, 1965)]
# 36                                [(1992, 1996)]
# 37                                [(1992, 1996)]
# 38                                [(1992, 1996)]
# 39                                [(1992, 1996)]
# ...                                          ...
# 8704                                         NaN
# 8705                                         NaN
# 8706                                         NaN
# 8787                              [(1964, 1994)]
# 8789                              [(1979, 1999)]
#
#                                              pcad-range SPR-yrs  \
# 33                                                  NaN     NaN
# 36                                                  NaN     NaN
# 37                                                  NaN     NaN
# 38                                                  NaN     NaN
# 39                                                  NaN     NaN
# ...                                                 ...     ...
# 8704  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...     NaN
# 8705  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...     NaN
# 8706  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...     NaN
# 8787                                                NaN     NaN
# 8789                                                NaN     NaN
#
#                                           Portico-years  \
# 33    [2011, 2012, 2013, 2014, 2015, 2016, 2017, 201...
# 36    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 37    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 38    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 39    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# ...                                                 ...
# 8704  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8705  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8706  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8789                           [1989, 1990, 1991, 1992]
#
#                                           repo-coverage
# 33    [2011, 2012, 2013, 2014, 2015, 2016, 2017, 201...
# 36    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 37    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 38    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# 39    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# ...                                                 ...
# 8704  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8705  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8706  [1954, 1955, 1956, 1957, 1958, 1959, 1960, 196...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8789                           [1989, 1990, 1991, 1992]
#
# [784 rows x 32 columns]

# %%
df_p.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc',
#        'pcad-range', 'SPR-yrs', 'Portico-years', 'repo-coverage'],
#       dtype='object')

# %%
df = df0.combine_first(df_p[['repo-coverage']])
df
# Out:
#                           Coverage Information Combined  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...
# 1                                                   NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...
# 3                                                   NaN
# 4          [ Available from 1939 volume: 1 until 2012;]
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]
# 8822                                                NaN
#
#       Earliest Year Preserved_PORTICO                ISSN_cluster  \
# 0                                 NaN  ['0893-6706', '2162-1373']
# 1                                 NaN               ['0893-6706']
# 2                                 NaN  ['0020-2681', '2058-1009']
# 3                                 NaN               ['0020-2681']
# 4                                 NaN               ['0017-0097']
# ...                               ...                         ...
# 8818                              NaN  ['0065-9762', '0003-049X']
# 8819                              NaN  ['1533-6247', '0003-1615']
# 8820                              NaN  ['1533-6247', '0003-1615']
# 8821                              NaN  ['0143-7496', '1879-0127']
# 8822                              NaN               ['0143-7496']
#
#       Latest Year Preserved_PORTICO            MMS_ID Match?_BTAA-SPR  PCAD?  \
# 0                               NaN  9968441380001701             NaN  [Yes]
# 1                               NaN  9963550760001701             YES    NaN
# 2                               NaN  9968429800001701             NaN  [Yes]
# 3                               NaN  9939481760001701             YES    NaN
# 4                               NaN  9967115530001701             NaN  [Yes]
# ...                             ...               ...             ...    ...
# 8818                            NaN  9959156260001701             NaN    NaN
# 8819                            NaN  9946768760001701             NaN    NaN
# 8820                            NaN  9967987860001701             NaN  [Yes]
# 8821                            NaN  9968947900001701             NaN  [Yes]
# 8822                            NaN  9957960200001701             YES    NaN
#
#      PCA_PORTICO Portico Match_PORTICO Portico Title_PORTICO  ...  \
# 0            NaN                   NaN                   NaN  ...
# 1            NaN                   NaN                   NaN  ...
# 2            NaN                   NaN                   NaN  ...
# 3            NaN                   NaN                   NaN  ...
# 4            NaN                   NaN                   NaN  ...
# ...          ...                   ...                   ...  ...
# 8818         NaN                   NaN                   NaN  ...
# 8819         NaN                   NaN                   NaN  ...
# 8820         NaN                   NaN                   NaN  ...
# 8821         NaN                   NaN                   NaN  ...
# 8822         NaN                   NaN                   NaN  ...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                 curr-lib-loc_ALL          curr-lib-loc_x  \
# 0                            NaN                     NaN
# 1                   ['TZDS GEN']              [TZDS GEN]
# 2                            NaN                     NaN
# 3                  ['TWILS CLS']             [TWILS CLS]
# 4                            NaN                     NaN
# ...                          ...                     ...
# 8818   ['TSCI PER', 'ZMLAC OWL']   [TSCI PER, ZMLAC OWL]
# 8819  ['ZMLAC OWL', 'TWILS PER']  [ZMLAC OWL, TWILS PER]
# 8820                         NaN                     NaN
# 8821                         NaN                     NaN
# 8822                ['TSCI PER']              [TSCI PER]
#
#                                             e_coll_info matches_group_id  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...                5
# 1                                                   NaN                5
# 2     [['61535216140001701', 'JSTOR Business III Col...               12
# 3                                                   NaN               12
# 4     [['61745117840001701', 'JSTOR Arts and Science...               92
# ...                                                 ...              ...
# 8818                                                NaN           101522
# 8819                                                NaN           101581
# 8820  [['61535211010001701', 'JSTOR Arts and Science...           101581
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...           101582
# 8822                                                NaN           101582
#
#      p_or_e                                         pcad-range  \
# 0         e                                             [1963]
# 1         p                                                NaN
# 2         e  [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3         p                                                NaN
# 4         e  [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...     ...                                                ...
# 8818      p                                                NaN
# 8819      p                                                NaN
# 8820      e  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821      e  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822      p                                                NaN
#
#                                          portfolio_info record_index  \
# 0     [['53620359120001701', 'IEEE transactions on u...       128733
# 1                                                   NaN        57684
# 2     [['53540140170001701', 'Journal of the Institu...       111951
# 3                                                   NaN        88618
# 4     [['53537228640001701', 'Giornale degli economi...       123907
# ...                                                 ...          ...
# 8818                                                NaN        61904
# 8819                                                NaN        17960
# 8820           [['53539160390001701', 'The Americas.']]       117510
# 8821  [['53624617390001701', 'International journal ...       125537
# 8822                                                NaN        31683
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['Coverage Information Combined', 'Earliest Year Preserved_PORTICO',
#        'ISSN_cluster', 'Latest Year Preserved_PORTICO', 'MMS_ID',
#        'Match?_BTAA-SPR', 'PCAD?', 'PCA_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'Portico-years', 'SPR Holdings_BTAA-SPR',
#        'SPR-yrs', 'Status_PORTICO', 'Title (Complete)_PORTICO',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR', 'Title_bib',
#        'Vendor_key', 'all_item_count', 'chron', 'chron_as_list',
#        'chron_ranges_calc', 'curr-lib-loc_ALL', 'curr-lib-loc_x',
#        'e_coll_info', 'matches_group_id', 'p_or_e', 'pcad-range',
#        'portfolio_info', 'record_index', 'repo-coverage'],
#       dtype='object')

# %%
df = df[['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
       'matches_group_id', 'e_coll_info', 'portfolio_info',
       'Coverage Information Combined', 'PCAD?', 'Vendor_key',
       'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
       'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR',
       'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
       'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
       'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
       'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL',
       'chron_as_list', 'chron_ranges_calc', 'pcad-range', 'SPR-yrs',
       'Portico-years', 'repo-coverage']]
df
# Out:
#       record_index            MMS_ID  \
# 0           128733  9968441380001701
# 1            57684  9963550760001701
# 2           111951  9968429800001701
# 3            88618  9939481760001701
# 4           123907  9967115530001701
# ...            ...               ...
# 8818         61904  9959156260001701
# 8819         17960  9946768760001701
# 8820        117510  9967987860001701
# 8821        125537  9968947900001701
# 8822         31683  9957960200001701
#
#                                               Title_bib  \
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  ...  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]  ...
# 1                                                   NaN    NaN  ...
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]  ...
# 3                                                   NaN    NaN  ...
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]  ...
# ...                                                 ...    ...  ...
# 8818                                                NaN    NaN  ...
# 8819                                                NaN    NaN  ...
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]  ...
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  ...
# 8822                                                NaN    NaN  ...
#
#               curr-lib-loc_x all_item_count  \
# 0                        NaN            NaN
# 1                 [TZDS GEN]            [1]
# 2                        NaN            NaN
# 3                [TWILS CLS]           [46]
# 4                        NaN            NaN
# ...                      ...            ...
# 8818   [TSCI PER, ZMLAC OWL]           [53]
# 8819  [ZMLAC OWL, TWILS PER]           [74]
# 8820                     NaN            NaN
# 8821                     NaN            NaN
# 8822              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8818                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 32 columns]

# %%
df.to_pickle(f'all_coverage_as_lists_{today}.pkl')

# %% [markdown]
# #### Drop duplicates
# In order to drop dups, we need to convert columns with list data types to strings, drop duplicates, then convert back by reading as string literal to data type.

# %%
df = pd.read_pickle('all_coverage_as_lists_20201112.pkl')
df.columns
# Out:
# Index(['record_index', 'MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
#        'matches_group_id', 'e_coll_info', 'portfolio_info',
#        'Coverage Information Combined', 'PCAD?', 'Vendor_key',
#        'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
#        'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR', 'Title (Complete)_PORTICO',
#        'Portico Match_PORTICO', 'Portico Title_PORTICO', 'PCA_PORTICO',
#        'Status_PORTICO', 'Earliest Year Preserved_PORTICO',
#        'Latest Year Preserved_PORTICO', 'curr-lib-loc_x', 'all_item_count',
#        'chron', 'curr-lib-loc_ALL', 'chron_as_list', 'chron_ranges_calc',
#        'pcad-range', 'SPR-yrs', 'Portico-years', 'repo-coverage'],
#       dtype='object')

# %%
df = df[['MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e',
       'matches_group_id', 'e_coll_info', 'portfolio_info',
       'Coverage Information Combined', 'PCAD?', 'Vendor_key',
       'Title 1 (Print)_BTAA-SPR', 'Title 2 (Print)_BTAA-SPR',
       'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR',
       'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
       'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
       'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
       'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL',
       'chron_as_list', 'chron_ranges_calc', 'pcad-range', 'SPR-yrs',
       'Portico-years', 'repo-coverage']]
df
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8818  9959156260001701         Year book - American Philosophical Society
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]     [other]
# 1                                                   NaN    NaN         NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]     [JSTOR]
# 3                                                   NaN    NaN         NaN
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]     [JSTOR]
# ...                                                 ...    ...         ...
# 8818                                                NaN    NaN         NaN
# 8819                                                NaN    NaN         NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]     [JSTOR]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# 8822                                                NaN    NaN         NaN
#
#       ...          curr-lib-loc_x all_item_count  \
# 0     ...                     NaN            NaN
# 1     ...              [TZDS GEN]            [1]
# 2     ...                     NaN            NaN
# 3     ...             [TWILS CLS]           [46]
# 4     ...                     NaN            NaN
# ...   ...                     ...            ...
# 8818  ...   [TSCI PER, ZMLAC OWL]           [53]
# 8819  ...  [ZMLAC OWL, TWILS PER]           [74]
# 8820  ...                     NaN            NaN
# 8821  ...                     NaN            NaN
# 8822  ...              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8818                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 31 columns]

# %%
cols = list(df.columns)
cols
# Out:
# ['MMS_ID',
#  'Title_bib',
#  'ISSN_cluster',
#  'p_or_e',
#  'matches_group_id',
#  'e_coll_info',
#  'portfolio_info',
#  'Coverage Information Combined',
#  'PCAD?',
#  'Vendor_key',
#  'Title 1 (Print)_BTAA-SPR',
#  'Title 2 (Print)_BTAA-SPR',
#  'Match?_BTAA-SPR',
#  'SPR Holdings_BTAA-SPR',
#  'Title (Complete)_PORTICO',
#  'Portico Match_PORTICO',
#  'Portico Title_PORTICO',
#  'PCA_PORTICO',
#  'Status_PORTICO',
#  'Earliest Year Preserved_PORTICO',
#  'Latest Year Preserved_PORTICO',
#  'curr-lib-loc_x',
#  'all_item_count',
#  'chron',
#  'curr-lib-loc_ALL',
#  'chron_as_list',
#  'chron_ranges_calc',
#  'pcad-range',
#  'SPR-yrs',
#  'Portico-years',
#  'repo-coverage']

# %%
len(cols)
# Out:
# 31

# %%
for x in df.loc[2564]:
    print(type(x))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'float'>
# <class 'list'>
# <class 'float'>
# <class 'list'>

# %%
list_cols = []
i = 0
for x in df.loc[0]:
    if type(x) == list:
        list_cols.append(cols[i])
    i += 1
list_cols
# Out:
# ['e_coll_info',
#  'portfolio_info',
#  'Coverage Information Combined',
#  'PCAD?',
#  'Vendor_key',
#  'pcad-range']

# %% [markdown]
# *There's probably a better way to do this, but until you figure it out: run the next cell several times with different indices in df.loc until list_cols stops changing.*

# %%
i = 0
for x in df.loc[987]:
    if type(x) == list:
        list_cols.append(cols[i])
    i += 1
list_cols = list(set(list_cols))
print(list_cols)
len(list_cols)
# Out:
# ['Coverage Information Combined', 'SPR-yrs', 'Portico-years', 'chron_ranges_calc', 'e_coll_info', 'chron', 'repo-coverage', 'PCAD?', 'all_item_count', 'pcad-range', 'Vendor_key', 'curr-lib-loc_x', 'portfolio_info', 'chron_as_list']
# 14

# %%
for x in list_cols:
    df[x] = df[x].apply(lambda x: str(x))
df
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8818  9959156260001701         Year book - American Philosophical Society
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     ["['61619505660001701', 'IEEE/IET Electronic L...
# 1                                                   nan
# 2     ["['61535216140001701', 'JSTOR Business III Co...
# 3                                                   nan
# 4     ["['61745117840001701', 'JSTOR Arts and Scienc...
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820  ["['61535211010001701', 'JSTOR Arts and Scienc...
# 8821  ["['61624504590001701', 'Elsevier ScienceDirec...
# 8822                                                nan
#
#                                          portfolio_info  \
# 0     ["['53620359120001701', 'IEEE transactions on ...
# 1                                                   nan
# 2     ["['53540140170001701', 'Journal of the Instit...
# 3                                                   nan
# 4     ["['53537228640001701', 'Giornale degli econom...
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820         ["['53539160390001701', 'The Americas.']"]
# 8821  ["['53624617390001701', 'International journal...
# 8822                                                nan
#
#                           Coverage Information Combined    PCAD?  \
# 0     [' Available from 1963 volume: 10 issue: 1 unt...  ['Yes']
# 1                                                   nan      nan
# 2     [' Available from 1886 volume: 25 issue: 5 unt...  ['Yes']
# 3                                                   nan      nan
# 4        [' Available from 1939 volume: 1 until 2012;']  ['Yes']
# ...                                                 ...      ...
# 8818                                                nan      nan
# 8819                                                nan      nan
# 8820       [' Available from 1944 volume: 1 issue: 1;']  ['Yes']
# 8821   [' Available from 1980-07- volume: 1 issue: 1;']  ['Yes']
# 8822                                                nan      nan
#
#         Vendor_key  ...              curr-lib-loc_x all_item_count  \
# 0        ['other']  ...                         nan            nan
# 1              nan  ...                ['TZDS GEN']            [1]
# 2        ['JSTOR']  ...                         nan            nan
# 3              nan  ...               ['TWILS CLS']           [46]
# 4        ['JSTOR']  ...                         nan            nan
# ...            ...  ...                         ...            ...
# 8818           nan  ...   ['TSCI PER', 'ZMLAC OWL']           [53]
# 8819           nan  ...  ['ZMLAC OWL', 'TWILS PER']           [74]
# 8820     ['JSTOR']  ...                         nan            nan
# 8821  ['Elsevier']  ...                         nan            nan
# 8822           nan  ...                ['TSCI PER']            [6]
#
#                                                   chron  \
# 0                                                   nan
# 1                                         ['1963-1966']
# 2                                                   nan
# 3     ['', '1890', '1939', '1948', '1915', '1943', '...
# 4                                                   nan
# ...                                                 ...
# 8818  ['1970', '1939', '1998/99', '1960', '1978', '1...
# 8819  ['', '1973/1974', '2004', '1958/1959', '1968/1...
# 8820                                                nan
# 8821                                                nan
# 8822  ['1989-90', '1985-86', '1982', '1980/81', '198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   nan
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   nan
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   nan
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                nan
# 8821                                                nan
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   nan
# 1                                        [(1963, 1966)]
# 2                                                   nan
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   nan
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                nan
# 8821                                                nan
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   nan
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   nan
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                nan
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   nan           nan
# 1                                                [1963]           nan
# 2                                                   nan           nan
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           nan
# 4                                                   nan           nan
# ...                                                 ...           ...
# 8818                                                nan           nan
# 8819                                                nan           nan
# 8820                                                nan           nan
# 8821                                                nan           nan
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           nan
#
#                                           repo-coverage
# 0                                                   nan
# 1                                                [1963]
# 2                                                   nan
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   nan
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820                                                nan
# 8821                                                nan
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8823 rows x 31 columns]

# %%
for x in df.loc[1776]:
    print(type(x))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8818  9959156260001701         Year book - American Philosophical Society
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#                     ISSN_cluster p_or_e  matches_group_id  \
# 0     ['0893-6706', '2162-1373']      e                 5
# 1                  ['0893-6706']      p                 5
# 2     ['0020-2681', '2058-1009']      e                12
# 3                  ['0020-2681']      p                12
# 4                  ['0017-0097']      e                92
# ...                          ...    ...               ...
# 8818  ['0065-9762', '0003-049X']      p            101522
# 8819  ['1533-6247', '0003-1615']      p            101581
# 8820  ['1533-6247', '0003-1615']      e            101581
# 8821  ['0143-7496', '1879-0127']      e            101582
# 8822               ['0143-7496']      p            101582
#
#                                             e_coll_info  \
# 0     ["['61619505660001701', 'IEEE/IET Electronic L...
# 1                                                   nan
# 2     ["['61535216140001701', 'JSTOR Business III Co...
# 3                                                   nan
# 4     ["['61745117840001701', 'JSTOR Arts and Scienc...
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820  ["['61535211010001701', 'JSTOR Arts and Scienc...
# 8821  ["['61624504590001701', 'Elsevier ScienceDirec...
# 8822                                                nan
#
#                                          portfolio_info  \
# 0     ["['53620359120001701', 'IEEE transactions on ...
# 1                                                   nan
# 2     ["['53540140170001701', 'Journal of the Instit...
# 3                                                   nan
# 4     ["['53537228640001701', 'Giornale degli econom...
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820         ["['53539160390001701', 'The Americas.']"]
# 8821  ["['53624617390001701', 'International journal...
# 8822                                                nan
#
#                           Coverage Information Combined    PCAD?  \
# 0     [' Available from 1963 volume: 10 issue: 1 unt...  ['Yes']
# 1                                                   nan      nan
# 2     [' Available from 1886 volume: 25 issue: 5 unt...  ['Yes']
# 3                                                   nan      nan
# 4        [' Available from 1939 volume: 1 until 2012;']  ['Yes']
# ...                                                 ...      ...
# 8818                                                nan      nan
# 8819                                                nan      nan
# 8820       [' Available from 1944 volume: 1 issue: 1;']  ['Yes']
# 8821   [' Available from 1980-07- volume: 1 issue: 1;']  ['Yes']
# 8822                                                nan      nan
#
#         Vendor_key  ...              curr-lib-loc_x all_item_count  \
# 0        ['other']  ...                         nan            nan
# 1              nan  ...                ['TZDS GEN']            [1]
# 2        ['JSTOR']  ...                         nan            nan
# 3              nan  ...               ['TWILS CLS']           [46]
# 4        ['JSTOR']  ...                         nan            nan
# ...            ...  ...                         ...            ...
# 8818           nan  ...   ['TSCI PER', 'ZMLAC OWL']           [53]
# 8819           nan  ...  ['ZMLAC OWL', 'TWILS PER']           [74]
# 8820     ['JSTOR']  ...                         nan            nan
# 8821  ['Elsevier']  ...                         nan            nan
# 8822           nan  ...                ['TSCI PER']            [6]
#
#                                                   chron  \
# 0                                                   nan
# 1                                         ['1963-1966']
# 2                                                   nan
# 3     ['', '1890', '1939', '1948', '1915', '1943', '...
# 4                                                   nan
# ...                                                 ...
# 8818  ['1970', '1939', '1998/99', '1960', '1978', '1...
# 8819  ['', '1973/1974', '2004', '1958/1959', '1968/1...
# 8820                                                nan
# 8821                                                nan
# 8822  ['1989-90', '1985-86', '1982', '1980/81', '198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   nan
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   nan
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   nan
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                nan
# 8821                                                nan
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   nan
# 1                                        [(1963, 1966)]
# 2                                                   nan
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   nan
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                nan
# 8821                                                nan
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   nan
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   nan
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                nan
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   nan           nan
# 1                                                [1963]           nan
# 2                                                   nan           nan
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           nan
# 4                                                   nan           nan
# ...                                                 ...           ...
# 8818                                                nan           nan
# 8819                                                nan           nan
# 8820                                                nan           nan
# 8821                                                nan           nan
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           nan
#
#                                           repo-coverage
# 0                                                   nan
# 1                                                [1963]
# 2                                                   nan
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   nan
# ...                                                 ...
# 8818                                                nan
# 8819                                                nan
# 8820                                                nan
# 8821                                                nan
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8354 rows x 31 columns]

# %%
cols
# Out:
# ['MMS_ID',
#  'Title_bib',
#  'ISSN_cluster',
#  'p_or_e',
#  'matches_group_id',
#  'e_coll_info',
#  'portfolio_info',
#  'Coverage Information Combined',
#  'PCAD?',
#  'Vendor_key',
#  'Title 1 (Print)_BTAA-SPR',
#  'Title 2 (Print)_BTAA-SPR',
#  'Match?_BTAA-SPR',
#  'SPR Holdings_BTAA-SPR',
#  'Title (Complete)_PORTICO',
#  'Portico Match_PORTICO',
#  'Portico Title_PORTICO',
#  'PCA_PORTICO',
#  'Status_PORTICO',
#  'Earliest Year Preserved_PORTICO',
#  'Latest Year Preserved_PORTICO',
#  'curr-lib-loc_x',
#  'all_item_count',
#  'chron',
#  'curr-lib-loc_ALL',
#  'chron_as_list',
#  'chron_ranges_calc',
#  'pcad-range',
#  'SPR-yrs',
#  'Portico-years',
#  'repo-coverage']

# %%
list_cols.append('ISSN_cluster')
for x in list_cols:
    df[x] = df[x].apply(lambda x: ast.literal_eval(x) if (x != 'nan') else np.nan)
df
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8818  9959156260001701         Year book - American Philosophical Society
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 4                [0017-0097]      e                92
# ...                      ...    ...               ...
# 8818  [0065-9762, 0003-049X]      p            101522
# 8819  [1533-6247, 0003-1615]      p            101581
# 8820  [1533-6247, 0003-1615]      e            101581
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]     [other]
# 1                                                   NaN    NaN         NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]     [JSTOR]
# 3                                                   NaN    NaN         NaN
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]     [JSTOR]
# ...                                                 ...    ...         ...
# 8818                                                NaN    NaN         NaN
# 8819                                                NaN    NaN         NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]     [JSTOR]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# 8822                                                NaN    NaN         NaN
#
#       ...          curr-lib-loc_x all_item_count  \
# 0     ...                     NaN            NaN
# 1     ...              [TZDS GEN]            [1]
# 2     ...                     NaN            NaN
# 3     ...             [TWILS CLS]           [46]
# 4     ...                     NaN            NaN
# ...   ...                     ...            ...
# 8818  ...   [TSCI PER, ZMLAC OWL]           [53]
# 8819  ...  [ZMLAC OWL, TWILS PER]           [74]
# 8820  ...                     NaN            NaN
# 8821  ...                     NaN            NaN
# 8822  ...              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8818   ['TSCI PER', 'ZMLAC OWL']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8818                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8818                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [8354 rows x 31 columns]

# %% [markdown]
# #### Make sure all groups still have p and e

# %%
find_only_p_or_e = df[['matches_group_id','p_or_e','MMS_ID','Title_bib']]
find_only_p_or_e
# Out:
#       matches_group_id p_or_e            MMS_ID  \
# 0                    5      e  9968441380001701
# 1                    5      p  9963550760001701
# 2                   12      e  9968429800001701
# 3                   12      p  9939481760001701
# 4                   92      e  9967115530001701
# ...                ...    ...               ...
# 8818            101522      p  9959156260001701
# 8819            101581      p  9946768760001701
# 8820            101581      e  9967987860001701
# 8821            101582      e  9968947900001701
# 8822            101582      p  9957960200001701
#
#                                               Title_bib
# 0          IEEE transactions on ultrasonics engineering
# 1          IEEE transactions on ultrasonics engineering
# 2                 Journal of the Institute of Actuaries
# 3                 Journal of the Institute of Actuaries
# 4        Giornale degli economisti e annali di economia
# ...                                                 ...
# 8818         Year book - American Philosophical Society
# 8819                                       The Americas
# 8820  The Americas - Academy of American Franciscan ...
# 8821    International journal of adhesion and adhesives
# 8822    International journal of adhesion and adhesives
#
# [8354 rows x 4 columns]

# %%
find_only_p_or_e = find_only_p_or_e.groupby(['matches_group_id']).agg(lambda x: sorted(list(set(x)))).reset_index()
find_only_p_or_e
# Out:
#       matches_group_id  p_or_e  \
# 0                    5  [e, p]
# 1                   12  [e, p]
# 2                   92  [e, p]
# 3                  267  [e, p]
# 4                  277  [e, p]
# ...                ...     ...
# 3538            101448  [e, p]
# 3539            101461  [e, p]
# 3540            101522  [e, p]
# 3541            101581  [e, p]
# 3542            101582  [e, p]
#
#                                                  MMS_ID  \
# 0                  [9963550760001701, 9968441380001701]
# 1                  [9939481760001701, 9968429800001701]
# 2                  [9963082590001701, 9967115530001701]
# 3                  [9964617400001701, 9968936470001701]
# 4                  [9942472340001701, 9968336850001701]
# ...                                                 ...
# 3538  [9931514970001701, 9936090000001701, 996927747...
# 3539  [9912065260001701, 9953202980001701, 995320588...
# 3540  [9914298940001701, 9918096880001701, 992826753...
# 3541               [9946768760001701, 9967987860001701]
# 3542               [9957960200001701, 9968947900001701]
#
#                                               Title_bib
# 0        [IEEE transactions on ultrasonics engineering]
# 1               [Journal of the Institute of Actuaries]
# 2      [Giornale degli economisti e annali di economia]
# 3     [Mathematics of the USSR. Izvestija, Mathemati...
# 4     [Laboratory techniques in biochemistry and mol...
# ...                                                 ...
# 3538  [Gazette, Gazette (Leiden, Netherlands : Onlin...
# 3539  [Physics letters, Physics letters., Physics le...
# 3540  [Grantees' reports /, Memoirs of the American ...
# 3541  [The Americas, The Americas - Academy of Ameri...
# 3542  [International journal of adhesion and adhesives]
#
# [3543 rows x 4 columns]

# %%
find_only_p_or_e['pore'] = find_only_p_or_e['p_or_e'].apply(lambda x: ' '.join(x))
find_only_p_or_e
# Out:
#       matches_group_id  p_or_e  \
# 0                    5  [e, p]
# 1                   12  [e, p]
# 2                   92  [e, p]
# 3                  267  [e, p]
# 4                  277  [e, p]
# ...                ...     ...
# 3538            101448  [e, p]
# 3539            101461  [e, p]
# 3540            101522  [e, p]
# 3541            101581  [e, p]
# 3542            101582  [e, p]
#
#                                                  MMS_ID  \
# 0                  [9963550760001701, 9968441380001701]
# 1                  [9939481760001701, 9968429800001701]
# 2                  [9963082590001701, 9967115530001701]
# 3                  [9964617400001701, 9968936470001701]
# 4                  [9942472340001701, 9968336850001701]
# ...                                                 ...
# 3538  [9931514970001701, 9936090000001701, 996927747...
# 3539  [9912065260001701, 9953202980001701, 995320588...
# 3540  [9914298940001701, 9918096880001701, 992826753...
# 3541               [9946768760001701, 9967987860001701]
# 3542               [9957960200001701, 9968947900001701]
#
#                                               Title_bib pore
# 0        [IEEE transactions on ultrasonics engineering]  e p
# 1               [Journal of the Institute of Actuaries]  e p
# 2      [Giornale degli economisti e annali di economia]  e p
# 3     [Mathematics of the USSR. Izvestija, Mathemati...  e p
# 4     [Laboratory techniques in biochemistry and mol...  e p
# ...                                                 ...  ...
# 3538  [Gazette, Gazette (Leiden, Netherlands : Onlin...  e p
# 3539  [Physics letters, Physics letters., Physics le...  e p
# 3540  [Grantees' reports /, Memoirs of the American ...  e p
# 3541  [The Americas, The Americas - Academy of Ameri...  e p
# 3542  [International journal of adhesion and adhesives]  e p
#
# [3543 rows x 5 columns]

# %%
#If all have p and e should only be one value here
find_only_p_or_e['pore'].value_counts()
# Out:
# e p    3543
# Name: pore, dtype: int64

# %% [markdown]
# #### Filter out groups with len > 2

# %%
grouped = df.groupby('matches_group_id')
print("Total count of groups")
print(len(grouped))
print("Shape of frame of groups bigger than 2")
print(grouped.filter(lambda x: len(x) > 2).shape)
print("Count of groups bigger than 2")
print(len(grouped.filter(lambda x: len(x) > 2).groupby('matches_group_id')))
print("Shape of frame of groups of length 2")
print(grouped.filter(lambda x: len(x) == 2).shape)
print("Count of groups of length 2")
print(len(grouped.filter(lambda x: len(x) == 2).groupby('matches_group_id')))
# Out:
# Total count of groups
# 3543
# Shape of frame of groups bigger than 2
# (2670, 31)
# Count of groups bigger than 2
# 701
# Shape of frame of groups of length 2
# (5684, 31)
# Count of groups of length 2
# 2842

# %%
df['matches_group_id'].max()
# Out:
# 101582

# %%
pe11 = grouped.filter(lambda x: len(x) == 2)
pe11
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8802  9946092870001701         Bibliothèque d'humanisme et renaissance ;
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 4                [0017-0097]      e                92
# ...                      ...    ...               ...
# 8802             [0006-1999]      p            101380
# 8819  [1533-6247, 0003-1615]      p            101581
# 8820  [1533-6247, 0003-1615]      e            101581
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]     [other]
# 1                                                   NaN    NaN         NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]     [JSTOR]
# 3                                                   NaN    NaN         NaN
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]     [JSTOR]
# ...                                                 ...    ...         ...
# 8802                                                NaN    NaN         NaN
# 8819                                                NaN    NaN         NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]     [JSTOR]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# 8822                                                NaN    NaN         NaN
#
#       ...          curr-lib-loc_x all_item_count  \
# 0     ...                     NaN            NaN
# 1     ...              [TZDS GEN]            [1]
# 2     ...                     NaN            NaN
# 3     ...             [TWILS CLS]           [46]
# 4     ...                     NaN            NaN
# ...   ...                     ...            ...
# 8802  ...             [TWILS PER]           [90]
# 8819  ...  [ZMLAC OWL, TWILS PER]           [74]
# 8820  ...                     NaN            NaN
# 8821  ...                     NaN            NaN
# 8822  ...              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8802  [2004, 2012, 2015, 1964, 1987, 2005, 1945, 196...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8802               ['TWILS PER']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                                                   NaN
# 1                              [1963, 1964, 1965, 1966]
# 2                                                   NaN
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4                                                   NaN
# ...                                                 ...
# 8802  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8802                       [(1941, 1948), (1950, 2020)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                   NaN
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3                                                   NaN
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 0                                                   NaN           NaN
# 1                                                [1963]           NaN
# 2                                                   NaN           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8802                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821                                                NaN           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 0                                                   NaN
# 1                                                [1963]
# 2                                                   NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [5684 rows x 31 columns]

# %% [markdown]
# ##### Note on next cell:
# In early PCAD runs, we reviewed the file of groups larger than 2 titles (rows), and added a new column for hand-coding new group ids based on actually looking at the records (for example: the script matched 4 rows under one group ID, but in looking at them they are two separate groups, so they get two different new group ids.) The purpose of this was that the script only handles calculating overlaps for groups of 2 rows, and to increase the number of groups that the script could analyze based on this constraint. We stopped doing this step because we had enough titles to work with without including them, but the list is something that a human should probably look at at some point. There are probably fewer titles on these lists since Sunshine and her team were doing some clean-up on e-resources with title changes, so there should be more records that match 1:1 now.
#
# So, to summarize, ignore these for now, knowing that someone needs to look at those big groups by hand at some point.

# %%
pe_big_groups = grouped.filter(lambda x: len(x) > 2)
pe_big_groups.to_csv('pe_big_groups_' + today + '.txt',sep='\t',index=False)
pe_big_groups
# Out:
#                 MMS_ID                                          Title_bib  \
# 12    9965662340001701                           Journal of endocrinology
# 13    9960319340001701                           Journal of endocrinology
# 14    9966705820001701                  Journal of endocrinology (Online)
# 17    9966212070001701                 Veterinary research communications
# 18    9929554030001701                Veterinary research communications.
# ...                ...                                                ...
# 8814  9918096880001701  Memoirs of the American Philosophical Society ...
# 8815  9968665290001701  Proceedings and addresses of the American Phil...
# 8816  9950698160001701  Proceedings and addresses of the American Phil...
# 8817  9914298940001701  Proceedings of the American Philosophical Society
# 8818  9959156260001701         Year book - American Philosophical Society
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 12               [0022-0795]      p               537
# 13               [0022-0795]      p               537
# 14    [0022-0795, 1479-6805]      e               537
# 17    [0165-7380, 1573-7446]      e               707
# 18    [0378-4312, 0165-7380]      p               707
# ...                      ...    ...               ...
# 8814  [0065-9738, 0065-9762]      p            101522
# 8815  [2325-9248, 0065-972X]      e            101522
# 8816  [0065-972X, 0003-049X]      p            101522
# 8817             [0003-049X]      p            101522
# 8818  [0065-9762, 0003-049X]      p            101522
#
#                                             e_coll_info  \
# 12                                                  NaN
# 13                                                  NaN
# 14    [['61808661620001701', 'Society for Endocrinol...
# 17    [['61535213730001701', 'SpringerLink Historica...
# 18                                                  NaN
# ...                                                 ...
# 8814                                                NaN
# 8815  [['61535211010001701', 'JSTOR Arts and Science...
# 8816                                                NaN
# 8817                                                NaN
# 8818                                                NaN
#
#                                          portfolio_info  \
# 12                                                  NaN
# 13                                                  NaN
# 14    [['53808661570001701', 'Journal of endocrinolo...
# 17    [['53535250180001701', 'Veterinary research co...
# 18                                                  NaN
# ...                                                 ...
# 8814                                                NaN
# 8815  [['53540700110001701', 'Proceedings and addres...
# 8816                                                NaN
# 8817                                                NaN
# 8818                                                NaN
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 12                                                  NaN    NaN         NaN
# 13                                                  NaN    NaN         NaN
# 14    [ Available from 1939 volume: 1 issue: 1 until...  [Yes]     [other]
# 17    [ Available from 1977 volume: 1 issue: 1 until...  [Yes]  [Springer]
# 18                                                  NaN    NaN         NaN
# ...                                                 ...    ...         ...
# 8814                                                NaN    NaN         NaN
# 8815                  [ Available from 1927 volume: 1;]  [Yes]     [JSTOR]
# 8816                                                NaN    NaN         NaN
# 8817                                                NaN    NaN         NaN
# 8818                                                NaN    NaN         NaN
#
#       ...          curr-lib-loc_x all_item_count  \
# 12    ...  [TVET PER, TBIOM PERS]          [432]
# 13    ...            [ZMLAC UMDN]          [154]
# 14    ...                     NaN            NaN
# 17    ...                     NaN            NaN
# 18    ...              [TVET PER]           [31]
# ...   ...                     ...            ...
# 8814  ...   [TSCI REFA, TSCI GEN]          [257]
# 8815  ...                     NaN            NaN
# 8816  ...  [TWILS CLS, TWILS PER]           [82]
# 8817  ...   [TSCI PER, ZMLAC OWL]          [151]
# 8818  ...   [TSCI PER, ZMLAC OWL]           [53]
#
#                                                   chron  \
# 12    [2004, 2012, 2015, 1964, 1987, 2005, 1956-57, ...
# 13    [1940/1941, 1970, 1939, 1978, 1960, 1995, 1984...
# 14                                                  NaN
# 17                                                  NaN
# 18    [1984-85, 2004, 1995, 1987, 1983, 2001, 1997, ...
# ...                                                 ...
# 8814  [2004, 2012, 1940, 1975-76, 1964, 1987, 1981-8...
# 8815                                                NaN
# 8816  [, 2004, 2010, 2012, 2018, 2001-2002, 2008-200...
# 8817  [2004, 2012, 1933, 1871/72, 1940, 2015, 1904-0...
# 8818  [1970, 1939, 1998/99, 1960, 1978, 1940, 1995, ...
#
#                 curr-lib-loc_ALL  \
# 12    ['TVET PER', 'TBIOM PERS']
# 13                ['ZMLAC UMDN']
# 14                           NaN
# 17                           NaN
# 18                  ['TVET PER']
# ...                          ...
# 8814   ['TSCI REFA', 'TSCI GEN']
# 8815                         NaN
# 8816  ['TWILS CLS', 'TWILS PER']
# 8817   ['TSCI PER', 'ZMLAC OWL']
# 8818   ['TSCI PER', 'ZMLAC OWL']
#
#                                           chron_as_list  \
# 12    [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 13    [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 14                                                  NaN
# 17                                                  NaN
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8814  [1935, 1936, 1937, 1938, 1939, 1940, 1943, 194...
# 8815                                                NaN
# 8816  [1985, 1986, 1987, 1988, 1989, 1990, 1991, 199...
# 8817  [1838, 1839, 1840, 1841, 1842, 1843, 1844, 184...
# 8818  [1937, 1938, 1939, 1940, 1941, 1942, 1943, 194...
#
#                                       chron_ranges_calc  \
# 12                                       [(1939, 2018)]
# 13           [(1939, 1947), (1949, 1955), (1957, 1999)]
# 14                                                  NaN
# 17                                                  NaN
# 18                                       [(1980, 2007)]
# ...                                                 ...
# 8814  [(1935, 1940), (1943, 1944), (1947, 1951), (19...
# 8815                                                NaN
# 8816                                     [(1985, 2019)]
# 8817                                     [(1838, 2019)]
# 8818         [(1937, 1947), (1952, 1952), (1960, 2003)]
#
#                                              pcad-range  \
# 12                                                  NaN
# 13                                                  NaN
# 14    [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# 17    [1977, 1978, 1979, 1980, 1981, 1982, 1983, 198...
# 18                                                  NaN
# ...                                                 ...
# 8814                                                NaN
# 8815  [1927, 1928, 1929, 1930, 1931, 1932, 1933, 193...
# 8816                                                NaN
# 8817                                                NaN
# 8818                                                NaN
#
#                                                 SPR-yrs Portico-years  \
# 12                                                  NaN           NaN
# 13                                                  NaN           NaN
# 14                                                  NaN           NaN
# 17                                                  NaN           NaN
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...           NaN
# ...                                                 ...           ...
# 8814                                                NaN           NaN
# 8815                                                NaN           NaN
# 8816                                                NaN           NaN
# 8817                                                NaN           NaN
# 8818                                                NaN           NaN
#
#                                           repo-coverage
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 17                                                  NaN
# 18    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8814                                                NaN
# 8815                                                NaN
# 8816                                                NaN
# 8817                                                NaN
# 8818                                                NaN
#
# [2670 rows x 31 columns]

# %% [markdown]
# #### Back and forward fill coverage ranges within groups

# %%
pegr = pe11.groupby('matches_group_id')
pegr

# %%
dates_lists = ['chron_as_list','pcad-range','SPR-yrs','Portico-years','repo-coverage']
for x in dates_lists:
    pe11[x] = pegr[x].bfill()
    pe11[x] = pegr[x].ffill()

pe11
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 1     9963550760001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 3     9939481760001701              Journal of the Institute of Actuaries
# 4     9967115530001701     Giornale degli economisti e annali di economia
# ...                ...                                                ...
# 8802  9946092870001701         Bibliothèque d'humanisme et renaissance ;
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
# 8821  9968947900001701    International journal of adhesion and adhesives
# 8822  9957960200001701    International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 4                [0017-0097]      e                92
# ...                      ...    ...               ...
# 8802             [0006-1999]      p            101380
# 8819  [1533-6247, 0003-1615]      p            101581
# 8820  [1533-6247, 0003-1615]      e            101581
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4     [['53537228640001701', 'Giornale degli economi...
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]     [other]
# 1                                                   NaN    NaN         NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]     [JSTOR]
# 3                                                   NaN    NaN         NaN
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]     [JSTOR]
# ...                                                 ...    ...         ...
# 8802                                                NaN    NaN         NaN
# 8819                                                NaN    NaN         NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]     [JSTOR]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# 8822                                                NaN    NaN         NaN
#
#       ...          curr-lib-loc_x all_item_count  \
# 0     ...                     NaN            NaN
# 1     ...              [TZDS GEN]            [1]
# 2     ...                     NaN            NaN
# 3     ...             [TWILS CLS]           [46]
# 4     ...                     NaN            NaN
# ...   ...                     ...            ...
# 8802  ...             [TWILS PER]           [90]
# 8819  ...  [ZMLAC OWL, TWILS PER]           [74]
# 8820  ...                     NaN            NaN
# 8821  ...                     NaN            NaN
# 8822  ...              [TSCI PER]            [6]
#
#                                                   chron  \
# 0                                                   NaN
# 1                                           [1963-1966]
# 2                                                   NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...
# 4                                                   NaN
# ...                                                 ...
# 8802  [2004, 2012, 2015, 1964, 1987, 2005, 1945, 196...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
# 8821                                                NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...
#
#                 curr-lib-loc_ALL  \
# 0                            NaN
# 1                   ['TZDS GEN']
# 2                            NaN
# 3                  ['TWILS CLS']
# 4                            NaN
# ...                          ...
# 8802               ['TWILS PER']
# 8819  ['ZMLAC OWL', 'TWILS PER']
# 8820                         NaN
# 8821                         NaN
# 8822                ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 4     [1939, 1940, 1941, 1942, 1946, 1947, 1949, 195...
# ...                                                 ...
# 8802  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 4                                                   NaN
# ...                                                 ...
# 8802                       [(1941, 1948), (1950, 2020)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...
# ...                                                 ...
# 8802  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs Portico-years  \
# 0                                                [1963]           NaN
# 1                                                [1963]           NaN
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 8802                                                NaN           NaN
# 8819                                                NaN           NaN
# 8820                                                NaN           NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...           NaN
#
#                                           repo-coverage
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 4                                                   NaN
# ...                                                 ...
# 8802                                                NaN
# 8819                                                NaN
# 8820                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [5684 rows x 31 columns]

# %% [markdown]
# #### Filter out no repo, no pcad, no chron

# %%
pe = pe11[pd.isnull(pe11['repo-coverage']) == False]
pe
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 6     9964617400001701               Mathematics of the USSR. Izvestija
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 6                [0025-5726]      p               267
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 6                                                   NaN    NaN
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... curr-lib-loc_x all_item_count  \
# 0                [other]  ...            NaN            NaN
# 1                    NaN  ...     [TZDS GEN]            [1]
# 2                [JSTOR]  ...            NaN            NaN
# 3                    NaN  ...    [TWILS CLS]           [46]
# 6                    NaN  ...    [TMATH PER]           [40]
# ...                  ...  ...            ...            ...
# 8787                 NaN  ...    [TMAGR PER]           [20]
# 8788  [Taylor & Francis]  ...            NaN            NaN
# 8789                 NaN  ...    [TMAGR PER]           [14]
# 8821          [Elsevier]  ...            NaN            NaN
# 8822                 NaN  ...     [TSCI PER]            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 6     [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...    ['TMATH PER']
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 6                                        [(1967, 1992)]
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 6                                                   NaN
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [3320 rows x 31 columns]

# %%
pe_no_repo = pe11[pd.isnull(pe11['repo-coverage']) == True]
pe_no_repo.sort_values(['matches_group_id'],inplace=True)
pe_no_repo
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 MMS_ID                                          Title_bib  \
# 4     9967115530001701     Giornale degli economisti e annali di economia
# 5     9963082590001701     Giornale degli economisti e annali di economia
# 8     9942472340001701  Laboratory techniques in biochemistry and mole...
# 9     9968336850001701  Laboratory techniques in biochemistry and mole...
# 10    9932958210001701                Revue de métaphysique et de morale
# ...                ...                                                ...
# 8800  9947993970001701                           New Zealand entomologist
# 8801  9966748600001701          Bibliothe  que d'humanisme et Renaissance
# 8802  9946092870001701         Bibliothèque d'humanisme et renaissance ;
# 8819  9946768760001701                                       The Americas
# 8820  9967987860001701  The Americas - Academy of American Franciscan ...
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 4                [0017-0097]      e                92
# 5                [0017-0097]      p                92
# 8                [0075-7535]      p               277
# 9                [0075-7535]      e               277
# 10               [0035-1571]      p               513
# ...                      ...    ...               ...
# 8800  [0077-9962, 1179-3430]      p            101345
# 8801  [0006-1999, 2418-7135]      e            101380
# 8802             [0006-1999]      p            101380
# 8819  [1533-6247, 0003-1615]      p            101581
# 8820  [1533-6247, 0003-1615]      e            101581
#
#                                             e_coll_info  \
# 4     [['61745117840001701', 'JSTOR Arts and Science...
# 5                                                   NaN
# 8                                                   NaN
# 9     [['61624504590001701', 'Elsevier ScienceDirect...
# 10                                                  NaN
# ...                                                 ...
# 8800                                                NaN
# 8801  [['61535214270001701', 'JSTOR Arts and Science...
# 8802                                                NaN
# 8819                                                NaN
# 8820  [['61535211010001701', 'JSTOR Arts and Science...
#
#                                          portfolio_info  \
# 4     [['53537228640001701', 'Giornale degli economi...
# 5                                                   NaN
# 8                                                   NaN
# 9     [['53624652880001701', 'Laboratory techniques ...
# 10                                                  NaN
# ...                                                 ...
# 8800                                                NaN
# 8801  [['53536372790001701', "Bibliothèque d'humani...
# 8802                                                NaN
# 8819                                                NaN
# 8820           [['53539160390001701', 'The Americas.']]
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 4          [ Available from 1939 volume: 1 until 2012;]  [Yes]     [JSTOR]
# 5                                                   NaN    NaN         NaN
# 8                                                   NaN    NaN         NaN
# 9     [ Available from 2007 volume: 32 until 2009 vo...  [Yes]  [Elsevier]
# 10                                                  NaN    NaN         NaN
# ...                                                 ...    ...         ...
# 8800                                                NaN    NaN         NaN
# 8801                  [ Available from 1941 volume: 1;]  [Yes]     [JSTOR]
# 8802                                                NaN    NaN         NaN
# 8819                                                NaN    NaN         NaN
# 8820         [ Available from 1944 volume: 1 issue: 1;]  [Yes]     [JSTOR]
#
#       ...           curr-lib-loc_x all_item_count  \
# 4     ...                      NaN            NaN
# 5     ...              [TWILS PER]           [58]
# 8     ...  [TBIOM GENS, TMAGR GEN]           [70]
# 9     ...                      NaN            NaN
# 10    ...              [TWILS PER]           [78]
# ...   ...                      ...            ...
# 8800  ...              [TMAGR PER]           [14]
# 8801  ...                      NaN            NaN
# 8802  ...              [TWILS PER]           [90]
# 8819  ...   [ZMLAC OWL, TWILS PER]           [74]
# 8820  ...                      NaN            NaN
#
#                                                   chron  \
# 4                                                   NaN
# 5     [1970, 1939, 1969, 1950, 1960, 1978, 1940, 199...
# 8     [1970, 1978, 1984, 1995, 1987, 1983, 2009, 197...
# 9                                                   NaN
# 10    [2004, 2010, 2012, 1948, 2018, 1960, 1978, 195...
# ...                                                 ...
# 8800  [1984-1987, 2000-2003, 2004-2007, 1975-1978, 2...
# 8801                                                NaN
# 8802  [2004, 2012, 2015, 1964, 1987, 2005, 1945, 196...
# 8819  [, 1973/1974, 2004, 1958/1959, 1968/1969, 1972...
# 8820                                                NaN
#
#                  curr-lib-loc_ALL  \
# 4                             NaN
# 5                   ['TWILS PER']
# 8     ['TBIOM GENS', 'TMAGR GEN']
# 9                             NaN
# 10                  ['TWILS PER']
# ...                           ...
# 8800                ['TMAGR PER']
# 8801                          NaN
# 8802                ['TWILS PER']
# 8819   ['ZMLAC OWL', 'TWILS PER']
# 8820                          NaN
#
#                                           chron_as_list  \
# 4     [1939, 1940, 1941, 1942, 1946, 1947, 1949, 195...
# 5     [1939, 1940, 1941, 1942, 1946, 1947, 1949, 195...
# 8     [1969, 1970, 1972, 1975, 1976, 1978, 1980, 198...
# 9     [1969, 1970, 1972, 1975, 1976, 1978, 1980, 198...
# 10    [1945, 1946, 1947, 1948, 1949, 1950, 1951, 195...
# ...                                                 ...
# 8800  [1962, 1963, 1964, 1965, 1966, 1967, 1968, 196...
# 8801  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...
# 8802  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...
#
#                                       chron_ranges_calc  \
# 4                                                   NaN
# 5     [(1939, 1942), (1946, 1947), (1949, 1951), (19...
# 8     [(1969, 1970), (1972, 1972), (1975, 1976), (19...
# 9                                                   NaN
# 10                                       [(1945, 2020)]
# ...                                                 ...
# 8800         [(1962, 1973), (1975, 1979), (1984, 2015)]
# 8801                                                NaN
# 8802                       [(1941, 1948), (1950, 2020)]
# 8819                                     [(1944, 2014)]
# 8820                                                NaN
#
#                                              pcad-range SPR-yrs Portico-years  \
# 4     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...     NaN           NaN
# 5     [1939, 1940, 1941, 1942, 1943, 1944, 1945, 194...     NaN           NaN
# 8                                    [2007, 2008, 2009]     NaN           NaN
# 9                                    [2007, 2008, 2009]     NaN           NaN
# 10    [1893, 1894, 1895, 1896, 1897, 1898, 1899, 190...     NaN           NaN
# ...                                                 ...     ...           ...
# 8800  [1952, 1953, 1954, 1955, 1956, 1957, 1958, 195...     NaN           NaN
# 8801  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...     NaN           NaN
# 8802  [1941, 1942, 1943, 1944, 1945, 1946, 1947, 194...     NaN           NaN
# 8819  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...     NaN           NaN
# 8820  [1944, 1945, 1946, 1947, 1948, 1949, 1950, 195...     NaN           NaN
#
#       repo-coverage
# 4               NaN
# 5               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# ...             ...
# 8800            NaN
# 8801            NaN
# 8802            NaN
# 8819            NaN
# 8820            NaN
#
# [2364 rows x 31 columns]

# %%
pe_no_repo.to_pickle('pe_no_repo_' + today + '.pkl')
pe_no_repo.to_csv('pe_no_repo_' + today + '.txt',sep='\t',index=False)

# %%
pe = pe.groupby('matches_group_id').filter(lambda x: len(x) == 2)
pe
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 6     9964617400001701               Mathematics of the USSR. Izvestija
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 6                [0025-5726]      p               267
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 6                                                   NaN    NaN
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... curr-lib-loc_x all_item_count  \
# 0                [other]  ...            NaN            NaN
# 1                    NaN  ...     [TZDS GEN]            [1]
# 2                [JSTOR]  ...            NaN            NaN
# 3                    NaN  ...    [TWILS CLS]           [46]
# 6                    NaN  ...    [TMATH PER]           [40]
# ...                  ...  ...            ...            ...
# 8787                 NaN  ...    [TMAGR PER]           [20]
# 8788  [Taylor & Francis]  ...            NaN            NaN
# 8789                 NaN  ...    [TMAGR PER]           [14]
# 8821          [Elsevier]  ...            NaN            NaN
# 8822                 NaN  ...     [TSCI PER]            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 6     [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...    ['TMATH PER']
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 6                                        [(1967, 1992)]
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 6                                                   NaN
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [3320 rows x 31 columns]

# %%
peno_no_PCAD = pe.groupby('matches_group_id').filter(lambda x: (x['pcad-range'].isnull().any()))
peno_no_PCAD
# Out:
#                 MMS_ID                                         Title_bib  \
# 6     9964617400001701                Mathematics of the USSR. Izvestija
# 7     9968936470001701       Mathematics of the USSR. Izvestija (Online)
# 87    9967380620001701  The Journal of the Acoustical Society of America
# 88    9963190950001701  The Journal of the Acoustical Society of America
# 503   9966238570001701                     Acta applicandae mathematicae
# ...                ...                                               ...
# 7208  9934784910001701                                        Meccanica.
# 7290  9949995780001701                     Annals of operations research
# 7291  9967674060001701            Annals of operations research (Online)
# 7442  9957936980001701                                      Inflammation
# 7443  9967845680001701                             Inflammation (Online)
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 6                [0025-5726]      p               267
# 7     [0025-5726, 2169-5075]      e               267
# 87    [0001-4966, 1520-8524]      e              2557
# 88               [0001-4966]      p              2557
# 503   [0167-8019, 1572-9036]      e              9314
# ...                      ...    ...               ...
# 7208             [0025-6455]      p             73451
# 7290             [0254-5330]      p             74717
# 7291  [1572-9338, 0254-5330]      e             74717
# 7442             [0360-3997]      p             75974
# 7443  [1573-2576, 0360-3997]      e             75974
#
#                                             e_coll_info  \
# 6                                                   NaN
# 7     [['61695747580001701', 'Institute of Physics T...
# 87    [['61549768600001701', 'AIP Digital Archive', ...
# 88                                                  NaN
# 503   [['61535213400001701', 'SpringerLink Historica...
# ...                                                 ...
# 7208                                                NaN
# 7290                                                NaN
# 7291  [['61535213690001701', 'SpringerLink Historica...
# 7442                                                NaN
# 7443  [['61535213730001701', 'SpringerLink Historica...
#
#                                          portfolio_info  \
# 6                                                   NaN
# 7     [['53695747410001701', 'Mathematics of the USS...
# 87    [['53804697800001701', 'The Journal of the Aco...
# 88                                                  NaN
# 503   [['53535251500001701', 'Acta applicandae mathe...
# ...                                                 ...
# 7208                                                NaN
# 7290                                                NaN
# 7291  [['53538467150001701', 'Annals of operations r...
# 7442                                                NaN
# 7443           [['53538819070001701', 'Inflammation.']]
#
#      Coverage Information Combined  PCAD?  Vendor_key  ...  \
# 6                              NaN    NaN         NaN  ...
# 7                        [Unknown]  [Yes]     [other]  ...
# 87                       [Unknown]  [Yes]     [other]  ...
# 88                             NaN    NaN         NaN  ...
# 503                      [Unknown]  [Yes]  [Springer]  ...
# ...                            ...    ...         ...  ...
# 7208                           NaN    NaN         NaN  ...
# 7290                           NaN    NaN         NaN  ...
# 7291                     [Unknown]  [Yes]  [Springer]  ...
# 7442                           NaN    NaN         NaN  ...
# 7443                     [Unknown]  [Yes]  [Springer]  ...
#
#               curr-lib-loc_x all_item_count  \
# 6                [TMATH PER]           [40]
# 7                        NaN            NaN
# 87                       NaN            NaN
# 88    [TSCI PER, TBIOM PERS]          [597]
# 503                      NaN            NaN
# ...                      ...            ...
# 7208              [TSCI PER]           [14]
# 7290             [TWILS GEN]            [6]
# 7291                     NaN            NaN
# 7442            [TBIOM PERS]           [31]
# 7443                     NaN            NaN
#
#                                                   chron  \
# 6     [1970, 1981-1982, 1980-1981, 1978, 1984, 1983-...
# 7                                                   NaN
# 87                                                  NaN
# 88    [, 2004, 2012, 2015, 1964, 1987, 1974/78, 1942...
# 503                                                 NaN
# ...                                                 ...
# 7208  [2004, 1999/2000, 1997, 2007, 2000, 2003, 1998...
# 7290                                             [2002]
# 7291                                                NaN
# 7442  [2004, 1984, 1995, 1987, 1983, 2001, 1980, 198...
# 7443                                                NaN
#
#                 curr-lib-loc_ALL  \
# 6                  ['TMATH PER']
# 7                            NaN
# 87                           NaN
# 88    ['TSCI PER', 'TBIOM PERS']
# 503                          NaN
# ...                          ...
# 7208                ['TSCI PER']
# 7290               ['TWILS GEN']
# 7291                         NaN
# 7442              ['TBIOM PERS']
# 7443                         NaN
#
#                                           chron_as_list  \
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 7     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 87    [1929, 1930, 1931, 1932, 1933, 1934, 1935, 193...
# 88    [1929, 1930, 1931, 1932, 1933, 1934, 1935, 193...
# 503   [1991, 1992, 1993, 1994, 1995, 1996, 1997, 199...
# ...                                                 ...
# 7208  [1996, 1997, 1998, 1999, 2000, 2001, 2002, 200...
# 7290                                             [2002]
# 7291                                             [2002]
# 7442  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 7443  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
#
#                  chron_ranges_calc pcad-range  \
# 6                   [(1967, 1992)]        NaN
# 7                              NaN        NaN
# 87                             NaN        NaN
# 88                  [(1929, 2017)]        NaN
# 503                            NaN        NaN
# ...                            ...        ...
# 7208  [(1996, 2005), (2007, 2007)]        NaN
# 7290                [(2002, 2002)]        NaN
# 7291                           NaN        NaN
# 7442                [(1975, 2004)]        NaN
# 7443                           NaN        NaN
#
#                                                 SPR-yrs Portico-years  \
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 7     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 87    [1929, 1930, 1931, 1932, 1933, 1934, 1935, 193...           NaN
# 88    [1929, 1930, 1931, 1932, 1933, 1934, 1935, 193...           NaN
# 503   [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...           NaN
# ...                                                 ...           ...
# 7208  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...           NaN
# 7290  [1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...           NaN
# 7291  [1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...           NaN
# 7442  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...           NaN
# 7443  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...           NaN
#
#                                           repo-coverage
# 6     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 7     [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 87    [1929, 1930, 1931, 1932, 1933, 1934, 1935, 193...
# 88    [1929, 1930, 1931, 1932, 1933, 1934, 1935, 193...
# 503   [1983, 1984, 1985, 1986, 1987, 1988, 1989, 199...
# ...                                                 ...
# 7208  [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# 7290  [1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 7291  [1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 7442  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
# 7443  [1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
#
# [74 rows x 31 columns]

# %%
peno_no_PCAD.to_pickle('peno_no_PCAD_' + today + '.pkl')
peno_no_PCAD.to_csv('peno_no_PCAD_' + today + '.txt',sep='\t',index=False)

# %%
peno = pe.groupby('matches_group_id').filter(lambda x: ~(x['pcad-range'].isnull().any()))
peno
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... curr-lib-loc_x all_item_count  \
# 0                [other]  ...            NaN            NaN
# 1                    NaN  ...     [TZDS GEN]            [1]
# 2                [JSTOR]  ...            NaN            NaN
# 3                    NaN  ...    [TWILS CLS]           [46]
# 24            [Elsevier]  ...            NaN            NaN
# ...                  ...  ...            ...            ...
# 8787                 NaN  ...    [TMAGR PER]           [20]
# 8788  [Taylor & Francis]  ...            NaN            NaN
# 8789                 NaN  ...    [TMAGR PER]           [14]
# 8821          [Elsevier]  ...            NaN            NaN
# 8822                 NaN  ...     [TSCI PER]            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 24                                                  NaN              NaN
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [3246 rows x 31 columns]

# %%
no_chron = pe.groupby('matches_group_id').filter(lambda x: (x['chron_as_list'].isnull().any()))
no_chron
# Out:
#                 MMS_ID                                      Title_bib  \
# 4544  9966792410001701   Physics of the earth and planetary interiors
# 4545  9950202520001701  Physics of the earth and planetary interiors.
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 4544  [1872-7395, 0031-9201]      e             43006
# 4545             [0031-9201]      p             43006
#
#                                             e_coll_info  \
# 4544  [['61624504590001701', 'Elsevier ScienceDirect...
# 4545                                                NaN
#
#                                          portfolio_info  \
# 4544  [['53624670100001701', 'Physics of the earth a...
# 4545                                                NaN
#
#                        Coverage Information Combined  PCAD?  Vendor_key  ...  \
# 4544  [ Available from 1967-10- volume: 1 issue: 1;]  [Yes]  [Elsevier]  ...
# 4545                                             NaN    NaN         NaN  ...
#
#      curr-lib-loc_x all_item_count chron curr-lib-loc_ALL chron_as_list  \
# 4544            NaN            NaN   NaN              NaN           NaN
# 4545            NaN            NaN   NaN              NaN           NaN
#
#      chron_ranges_calc                                         pcad-range  \
# 4544               NaN  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 4545               NaN  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
#
#                                                 SPR-yrs Portico-years  \
# 4544  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
# 4545  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...           NaN
#
#                                           repo-coverage
# 4544  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
# 4545  [1967, 1968, 1969, 1970, 1971, 1972, 1973, 197...
#
# [2 rows x 31 columns]

# %%
no_chron.to_pickle('no_chron_peok.pkl')
no_chron.to_csv('no_chron_peok.txt',sep='\t',index=False)

# %%
peok = peno.groupby('matches_group_id').filter(lambda x: ~(x['repo-coverage'].isnull().any()))
peok
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... curr-lib-loc_x all_item_count  \
# 0                [other]  ...            NaN            NaN
# 1                    NaN  ...     [TZDS GEN]            [1]
# 2                [JSTOR]  ...            NaN            NaN
# 3                    NaN  ...    [TWILS CLS]           [46]
# 24            [Elsevier]  ...            NaN            NaN
# ...                  ...  ...            ...            ...
# 8787                 NaN  ...    [TMAGR PER]           [20]
# 8788  [Taylor & Francis]  ...            NaN            NaN
# 8789                 NaN  ...    [TMAGR PER]           [14]
# 8821          [Elsevier]  ...            NaN            NaN
# 8822                 NaN  ...     [TSCI PER]            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 24                                                  NaN              NaN
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [3246 rows x 31 columns]

# %%
peok = peok.groupby('matches_group_id').filter(lambda x: ~(x['chron_as_list'].isnull().any()))
peok
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... curr-lib-loc_x all_item_count  \
# 0                [other]  ...            NaN            NaN
# 1                    NaN  ...     [TZDS GEN]            [1]
# 2                [JSTOR]  ...            NaN            NaN
# 3                    NaN  ...    [TWILS CLS]           [46]
# 24            [Elsevier]  ...            NaN            NaN
# ...                  ...  ...            ...            ...
# 8787                 NaN  ...    [TMAGR PER]           [20]
# 8788  [Taylor & Francis]  ...            NaN            NaN
# 8789                 NaN  ...    [TMAGR PER]           [14]
# 8821          [Elsevier]  ...            NaN            NaN
# 8822                 NaN  ...     [TSCI PER]            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 24                                                  NaN              NaN
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
# [3244 rows x 31 columns]

# %%
peok['matches_group_id'].nunique()
# Out:
# 1622

# %% [markdown]
# #### Calculate overlap

# %%
peok['p2e_no_pcad'] = peok.apply(lambda row: sorted(set(row['chron_as_list']) - set(row['pcad-range'])), axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... all_item_count  \
# 0                [other]  ...            NaN
# 1                    NaN  ...            [1]
# 2                [JSTOR]  ...            NaN
# 3                    NaN  ...           [46]
# 24            [Elsevier]  ...            NaN
# ...                  ...  ...            ...
# 8787                 NaN  ...           [20]
# 8788  [Taylor & Francis]  ...            NaN
# 8789                 NaN  ...           [14]
# 8821          [Elsevier]  ...            NaN
# 8822                 NaN  ...            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 24                                                  NaN              NaN
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad
# 0                                    [1964, 1965, 1966]
# 1                                    [1964, 1965, 1966]
# 2                                                    []
# 3                                                    []
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787                                                 []
# 8788                                                 []
# 8789                                                 []
# 8821                                                 []
# 8822                                                 []
#
# [3244 rows x 32 columns]

# %%
peok['chron_as_list'] = peok['chron_as_list'].apply(lambda x: sorted(x))
peok['pcad-range'] = peok['pcad-range'].apply(lambda x: sorted(x))
peok['repo-coverage'] = peok['repo-coverage'].apply(lambda x: sorted(x))
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... all_item_count  \
# 0                [other]  ...            NaN
# 1                    NaN  ...            [1]
# 2                [JSTOR]  ...            NaN
# 3                    NaN  ...           [46]
# 24            [Elsevier]  ...            NaN
# ...                  ...  ...            ...
# 8787                 NaN  ...           [20]
# 8788  [Taylor & Francis]  ...            NaN
# 8789                 NaN  ...           [14]
# 8821          [Elsevier]  ...            NaN
# 8822                 NaN  ...            [6]
#
#                                                   chron curr-lib-loc_ALL  \
# 0                                                   NaN              NaN
# 1                                           [1963-1966]     ['TZDS GEN']
# 2                                                   NaN              NaN
# 3     [, 1890, 1939, 1948, 1915, 1943, 1946, 1913, 1...    ['TWILS CLS']
# 24                                                  NaN              NaN
# ...                                                 ...              ...
# 8787  [1984-85, 1991-92, 1987-88, 1968-69, 1991, 198...    ['TMAGR PER']
# 8788                                                NaN              NaN
# 8789  [1985-86, 1996-97, 1979, 1984, 1988, 1994-95, ...    ['TMAGR PER']
# 8821                                                NaN              NaN
# 8822  [1989-90, 1985-86, 1982, 1980/81, 1983-84, 198...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad
# 0                                    [1964, 1965, 1966]
# 1                                    [1964, 1965, 1966]
# 2                                                    []
# 3                                                    []
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787                                                 []
# 8788                                                 []
# 8789                                                 []
# 8821                                                 []
# 8822                                                 []
#
# [3244 rows x 32 columns]

# %%
peok['ct_chron'] = peok.apply(lambda row: len(row['chron_as_list']), axis=1)
peok['ct_pcad'] = peok.apply(lambda row: len(row['pcad-range']),axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ... curr-lib-loc_ALL  \
# 0                [other]  ...              NaN
# 1                    NaN  ...     ['TZDS GEN']
# 2                [JSTOR]  ...              NaN
# 3                    NaN  ...    ['TWILS CLS']
# 24            [Elsevier]  ...              NaN
# ...                  ...  ...              ...
# 8787                 NaN  ...    ['TMAGR PER']
# 8788  [Taylor & Francis]  ...              NaN
# 8789                 NaN  ...    ['TMAGR PER']
# 8821          [Elsevier]  ...              NaN
# 8822                 NaN  ...     ['TSCI PER']
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron  ct_pcad
# 0                                    [1964, 1965, 1966]        4        1
# 1                                    [1964, 1965, 1966]        4        1
# 2                                                    []       13      110
# 3                                                    []       13      110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24       10
# ...                                                 ...      ...      ...
# 8787                                                 []       31       41
# 8788                                                 []       21       21
# 8789                                                 []       21       21
# 8821                                                 []       11       40
# 8822                                                 []       11       40
#
# [3244 rows x 34 columns]

# %%
peok['ct_p_no_match'] = peok.apply(lambda row: len(row['p2e_no_pcad']), axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                           chron_as_list  \
# 0                              [1963, 1964, 1965, 1966]
# 1                              [1963, 1964, 1965, 1966]
# 2     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 3     [1890, 1892, 1895, 1912, 1913, 1914, 1915, 193...
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#       ct_p_no_match
# 0                 3
# 1                 3
# 2                 0
# 3                 0
# 24               15
# ...             ...
# 8787              0
# 8788              0
# 8789              0
# 8821              0
# 8822              0
#
# [3244 rows x 35 columns]

# %%
peok.to_pickle('peok_before_calc.pkl')

# %%
peok['p2e-percent'] = peok.apply(lambda row: round((int(row['ct_chron'])-int(row['ct_p_no_match']))/(int(row['ct_chron'])),2) if int(row['ct_chron']) != 0 else 0,axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                       chron_ranges_calc  \
# 0                                                   NaN
# 1                                        [(1963, 1966)]
# 2                                                   NaN
# 3     [(1890, 1890), (1892, 1892), (1895, 1895), (19...
# 24                                                  NaN
# ...                                                 ...
# 8787                                     [(1964, 1994)]
# 8788                                                NaN
# 8789                                     [(1979, 1999)]
# 8821                                                NaN
# 8822                                     [(1980, 1990)]
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#      ct_p_no_match  p2e-percent
# 0                3         0.25
# 1                3         0.25
# 2                0         1.00
# 3                0         1.00
# 24              15         0.38
# ...            ...          ...
# 8787             0         1.00
# 8788             0         1.00
# 8789             0         1.00
# 8821             0         1.00
# 8822             0         1.00
#
# [3244 rows x 36 columns]

# %%
peok['p2e_has_pcad'] = peok.apply(lambda row: set(row['chron_as_list'])&set(row['pcad-range']),axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                              pcad-range  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 3     [1886, 1887, 1888, 1889, 1890, 1891, 1892, 189...
# 24    [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  [1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  [1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8822  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 1                3        0.25
# 2                0        1.00
# 3                0        1.00
# 24              15        0.38
# ...            ...         ...
# 8787             0        1.00
# 8788             0        1.00
# 8789             0        1.00
# 8821             0        1.00
# 8822             0        1.00
#
#                                            p2e_has_pcad
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 3     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 24    {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 8822  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
# [3244 rows x 37 columns]

# %%
peok['pcad-repo'] = peok.apply(lambda row: row['p2e_has_pcad'] & set(row['repo-coverage']), axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                                 SPR-yrs  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787                                                NaN
# 8788                                                NaN
# 8789                                                NaN
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 1                3        0.25
# 2                0        1.00
# 3                0        1.00
# 24              15        0.38
# ...            ...         ...
# 8787             0        1.00
# 8788             0        1.00
# 8789             0        1.00
# 8821             0        1.00
# 8822             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 3     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 24    {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 8822  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo
# 0                                                {1963}
# 1                                                {1963}
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}
# 24                                                   {}
# ...                                                 ...
# 8787  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           {1992, 1989, 1990, 1991}
# 8789                           {1992, 1989, 1990, 1991}
# 8821                                             {1990}
# 8822                                             {1990}
#
# [3244 rows x 38 columns]

# %%
peok['pcad-repo-percent'] = peok.apply(lambda row: round(len(row['pcad-repo'])/len(row['p2e_has_pcad']),2) if (len(row['p2e_has_pcad']) != 0) else 0,axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                           Portico-years  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 24                                                  NaN
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821                                                NaN
# 8822                                                NaN
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 1                3        0.25
# 2                0        1.00
# 3                0        1.00
# 24              15        0.38
# ...            ...         ...
# 8787             0        1.00
# 8788             0        1.00
# 8789             0        1.00
# 8821             0        1.00
# 8822             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 3     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 24    {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 8822  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo  pcad-repo-percent
# 0                                                {1963}               1.00
# 1                                                {1963}               1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}               0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}               0.46
# 24                                                   {}               0.00
# ...                                                 ...                ...
# 8787  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...               0.29
# 8788                           {1992, 1989, 1990, 1991}               0.19
# 8789                           {1992, 1989, 1990, 1991}               0.19
# 8821                                             {1990}               0.09
# 8822                                             {1990}               0.09
#
# [3244 rows x 39 columns]

# %%
peok['total-to-remove'] = peok.apply(lambda row: round(row['p2e-percent']*row['pcad-repo-percent'],2), axis=1)
peok
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 1                3        0.25
# 2                0        1.00
# 3                0        1.00
# 24              15        0.38
# ...            ...         ...
# 8787             0        1.00
# 8788             0        1.00
# 8789             0        1.00
# 8821             0        1.00
# 8822             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 3     {1890, 1915, 1892, 1895, 1939, 1943, 1912, 191...
# 24    {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 8822  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 24                                                   {}              0.00
# ...                                                 ...               ...
# 8787  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 8788                           {1992, 1989, 1990, 1991}              0.19
# 8789                           {1992, 1989, 1990, 1991}              0.19
# 8821                                             {1990}              0.09
# 8822                                             {1990}              0.09
#
#       total-to-remove
# 0                0.25
# 1                0.25
# 2                0.46
# 3                0.46
# 24               0.00
# ...               ...
# 8787             0.29
# 8788             0.19
# 8789             0.19
# 8821             0.09
# 8822             0.09
#
# [3244 rows x 40 columns]

# %%
peok.to_pickle(f'peok_{today}.pkl')

# %%
peok = pd.read_pickle('peok_20201112.pkl')
peok
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 24    9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 8787  9931018220001701                                          Ophelia
# 8788  9967674080001701                 South African journal of zoology
# 8789  9942687740001701                 South African journal of zoology
# 8821  9968947900001701  International journal of adhesion and adhesives
# 8822  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 24    [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 8787             [0078-5326]      p            101035
# 8788             [0254-1858]      e            101036
# 8789             [0254-1858]      p            101036
# 8821  [0143-7496, 1879-0127]      e            101582
# 8822             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 8787                                                NaN
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8789                                                NaN
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
# 8822                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 24            [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 8787                                                NaN
# 8788  [['53815442650001701', 'South African journal ...
# 8789                                                NaN
# 8821  [['53624617390001701', 'International journal ...
# 8822                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 8787                                                NaN    NaN
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8789                                                NaN    NaN
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 8822                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 24            [Elsevier]  ...
# ...                  ...  ...
# 8787                 NaN  ...
# 8788  [Taylor & Francis]  ...
# 8789                 NaN  ...
# 8821          [Elsevier]  ...
# 8822                 NaN  ...
#
#                                           repo-coverage  \
# 0                                                [1963]
# 1                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 3     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# ...                                                 ...
# 8787  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8789                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 8822  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 8787                                                 []       31      41
# 8788                                                 []       21      21
# 8789                                                 []       21      21
# 8821                                                 []       11      40
# 8822                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 1                3        0.25
# 2                0        1.00
# 3                0        1.00
# 24              15        0.38
# ...            ...         ...
# 8787             0        1.00
# 8788             0        1.00
# 8789             0        1.00
# 8821             0        1.00
# 8822             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 24    {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 8787  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8789  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 8822  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 24                                                   {}              0.00
# ...                                                 ...               ...
# 8787  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 8788                           {1992, 1989, 1990, 1991}              0.19
# 8789                           {1992, 1989, 1990, 1991}              0.19
# 8821                                             {1990}              0.09
# 8822                                             {1990}              0.09
#
#       total-to-remove
# 0                0.25
# 1                0.25
# 2                0.46
# 3                0.46
# 24               0.00
# ...               ...
# 8787             0.29
# 8788             0.19
# 8789             0.19
# 8821             0.09
# 8822             0.09
#
# [3244 rows x 40 columns]

# %%
peok[['MMS_ID','curr-lib-loc_ALL']]
# Out:
#                 MMS_ID curr-lib-loc_ALL
# 0     9968441380001701              NaN
# 1     9963550760001701     ['TZDS GEN']
# 2     9968429800001701              NaN
# 3     9939481760001701    ['TWILS CLS']
# 24    9966907990001701              NaN
# ...                ...              ...
# 8787  9931018220001701    ['TMAGR PER']
# 8788  9967674080001701              NaN
# 8789  9942687740001701    ['TMAGR PER']
# 8821  9968947900001701              NaN
# 8822  9957960200001701     ['TSCI PER']
#
# [3244 rows x 2 columns]

# %%
peok.columns
# Out:
# Index(['MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e', 'matches_group_id',
#        'e_coll_info', 'portfolio_info', 'Coverage Information Combined',
#        'PCAD?', 'Vendor_key', 'Title 1 (Print)_BTAA-SPR',
#        'Title 2 (Print)_BTAA-SPR', 'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR',
#        'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL',
#        'chron_as_list', 'chron_ranges_calc', 'pcad-range', 'SPR-yrs',
#        'Portico-years', 'repo-coverage', 'p2e_no_pcad', 'ct_chron', 'ct_pcad',
#        'ct_p_no_match', 'p2e-percent', 'p2e_has_pcad', 'pcad-repo',
#        'pcad-repo-percent', 'total-to-remove'],
#       dtype='object')

# %%
peok[peok['all_item_count'].isnull()]
# Out:
#                 MMS_ID                                          Title_bib  \
# 0     9968441380001701       IEEE transactions on ultrasonics engineering
# 2     9968429800001701              Journal of the Institute of Actuaries
# 24    9966907990001701                                      Neuropeptides
# 34    9967018760001701                   Annals of agricultural sciences.
# 35    9969535240001701  Journal fu r praktische Chemie, Chemiker-Zeitu...
# ...                ...                                                ...
# 8780  9968527570001701       Journal of muscle research and cell motility
# 8784  9967155120001701                  Journal of the Franklin Institute
# 8786  9977101567901701                                            Ophelia
# 8788  9967674080001701                   South African journal of zoology
# 8821  9968947900001701    International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 2     [0020-2681, 2058-1009]      e                12
# 24    [1532-2785, 0143-4179]      e               744
# 34               [0570-1783]      e              1066
# 35               [0941-1216]      e              1087
# ...                      ...    ...               ...
# 8780  [0142-4319, 1573-2657]      e            100867
# 8784  [1879-2693, 0016-0032]      e            101001
# 8786             [0078-5326]      e            101035
# 8788             [0254-1858]      e            101036
# 8821  [0143-7496, 1879-0127]      e            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 24    [['61624504590001701', 'Elsevier ScienceDirect...
# 34    [['61624504590001701', 'Elsevier ScienceDirect...
# 35    [['61535209520001701', 'Wiley Online Library C...
# ...                                                 ...
# 8780  [['61535213730001701', 'SpringerLink Historica...
# 8784  [['61624504590001701', 'Elsevier ScienceDirect...
# 8786  [['61808506700001701', 'Taylor & Francis Biolo...
# 8788  [['61808506700001701', 'Taylor & Francis Biolo...
# 8821  [['61624504590001701', 'Elsevier ScienceDirect...
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 2     [['53540140170001701', 'Journal of the Institu...
# 24            [['53624660480001701', 'Neuropeptides.']]
# 34    [['53624539550001701', 'Annals of agricultural...
# 35    [['53542636090001701', 'Journal für praktisch...
# ...                                                 ...
# 8780  [['53540364460001701', 'Journal of muscle rese...
# 8784  [['53624654960001701', 'Journal of the Frankli...
# 8786  [['53815441630001701', 'Ophelia.'], ['53815434...
# 8788  [['53815442650001701', 'South African journal ...
# 8821  [['53624617390001701', 'International journal ...
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 24    [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# 34      [ Available from 2011-06- volume: 56 issue: 1;]  [Yes]
# 35    [ Available from 1992 volume: 334 issue: 1 unt...  [Yes]
# ...                                                 ...    ...
# 8780  [ Available from 1980 volume: 1 issue: 1 until...  [Yes]
# 8784     [ Available from 1826-01- volume: 1 issue: 1;]  [Yes]
# 8786  [ Available from 1964 volume: 1 issue: 1 until...  [Yes]
# 8788  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 8821     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 2                [JSTOR]  ...
# 24            [Elsevier]  ...
# 34            [Elsevier]  ...
# 35               [Wiley]  ...
# ...                  ...  ...
# 8780          [Springer]  ...
# 8784          [Elsevier]  ...
# 8786  [Taylor & Francis]  ...
# 8788  [Taylor & Francis]  ...
# 8821          [Elsevier]  ...
#
#                                           repo-coverage  \
# 0                                                [1963]
# 2     [1935, 1936, 1937, 1938, 1939, 1940, 1941, 194...
# 24                                         [1980, 1981]
# 34    [2011, 2012, 2013, 2014, 2015, 2016, 2017, 201...
# 35    [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...
# ...                                                 ...
# 8780  [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
# 8784  [1829, 1830, 1831, 1832, 1833, 1834, 1835, 183...
# 8786  [1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...
# 8788                           [1989, 1990, 1991, 1992]
# 8821  [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 24    [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# 34           [1956, 1957, 1959, 1960, 1961, 1964, 1965]        7       9
# 35                                                   []        5       7
# ...                                                 ...      ...     ...
# 8780   [1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]       25      17
# 8784                                                 []      178     194
# 8786                                                 []       31      41
# 8788                                                 []       21      21
# 8821                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 2                0        1.00
# 24              15        0.38
# 34               7        0.00
# 35               0        1.00
# ...            ...         ...
# 8780             8        0.68
# 8784             0        1.00
# 8786             0        1.00
# 8788             0        1.00
# 8821             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 24    {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 34                                                   {}
# 35                       {1992, 1993, 1994, 1995, 1996}
# ...                                                 ...
# 8780  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 8784  {1826, 1827, 1828, 1829, 1830, 1831, 1832, 183...
# 8786  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 8788  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 8821  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 24                                                   {}              0.00
# 34                                                   {}              0.00
# 35                                                   {}              0.00
# ...                                                 ...               ...
# 8780  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...              1.00
# 8784  {1829, 1830, 1831, 1832, 1833, 1834, 1835, 183...              0.84
# 8786  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 8788                           {1992, 1989, 1990, 1991}              0.19
# 8821                                             {1990}              0.09
#
#       total-to-remove
# 0                0.25
# 2                0.46
# 24               0.00
# 34               0.00
# 35               0.00
# ...               ...
# 8780             0.68
# 8784             0.84
# 8786             0.29
# 8788             0.19
# 8821             0.09
#
# [1622 rows x 40 columns]

# %% [markdown]
# #### Add count of potential volumes to withdraw

# %%
pvols = peok[peok['all_item_count'].notnull() & peok['total-to-remove'].notnull()]
pvols = pvols[['MMS_ID','all_item_count','total-to-remove']]
pvols
# Out:
#                 MMS_ID all_item_count  total-to-remove
# 1     9963550760001701            [1]             0.25
# 3     9939481760001701           [46]             0.46
# 25    9931084310001701           [35]             0.00
# 33    9918228280001701            [7]             0.00
# 36    9975846880001701           [10]             0.00
# ...                ...            ...              ...
# 8781  9913415620001701           [38]             0.68
# 8785  9952125650001701          [312]             0.84
# 8787  9931018220001701           [20]             0.29
# 8789  9942687740001701           [14]             0.19
# 8822  9957960200001701            [6]             0.09
#
# [1622 rows x 3 columns]

# %%
pvols['all_item_count'] = pvols['all_item_count'].apply(lambda x: x[0])
pvols['potential volumes to withdraw'] = pvols.apply(lambda row: row['total-to-remove']*row['all_item_count'], axis=1)
pvols['potential volumes to withdraw'] = pvols['potential volumes to withdraw'].apply(lambda x: math.floor(x))
pvols
# Out:
#                 MMS_ID  all_item_count  total-to-remove  \
# 1     9963550760001701               1             0.25
# 3     9939481760001701              46             0.46
# 25    9931084310001701              35             0.00
# 33    9918228280001701               7             0.00
# 36    9975846880001701              10             0.00
# ...                ...             ...              ...
# 8781  9913415620001701              38             0.68
# 8785  9952125650001701             312             0.84
# 8787  9931018220001701              20             0.29
# 8789  9942687740001701              14             0.19
# 8822  9957960200001701               6             0.09
#
#       potential volumes to withdraw
# 1                                 0
# 3                                21
# 25                                0
# 33                                0
# 36                                0
# ...                             ...
# 8781                             25
# 8785                            262
# 8787                              5
# 8789                              2
# 8822                              0
#
# [1622 rows x 4 columns]

# %%
pvols = pvols.drop_duplicates()
pvols
# Out:
#                 MMS_ID  all_item_count  total-to-remove  \
# 1     9963550760001701               1             0.25
# 3     9939481760001701              46             0.46
# 25    9931084310001701              35             0.00
# 33    9918228280001701               7             0.00
# 36    9975846880001701              10             0.00
# ...                ...             ...              ...
# 8781  9913415620001701              38             0.68
# 8785  9952125650001701             312             0.84
# 8787  9931018220001701              20             0.29
# 8789  9942687740001701              14             0.19
# 8822  9957960200001701               6             0.09
#
#       potential volumes to withdraw
# 1                                 0
# 3                                21
# 25                                0
# 33                                0
# 36                                0
# ...                             ...
# 8781                             25
# 8785                            262
# 8787                              5
# 8789                              2
# 8822                              0
#
# [1622 rows x 4 columns]

# %%
df = pd.merge(peok, pvols[['MMS_ID','potential volumes to withdraw']], how='left', on='MMS_ID')
df
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 4     9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 3239  9931018220001701                                          Ophelia
# 3240  9967674080001701                 South African journal of zoology
# 3241  9942687740001701                 South African journal of zoology
# 3242  9968947900001701  International journal of adhesion and adhesives
# 3243  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 4     [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 3239             [0078-5326]      p            101035
# 3240             [0254-1858]      e            101036
# 3241             [0254-1858]      p            101036
# 3242  [0143-7496, 1879-0127]      e            101582
# 3243             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3239                                                NaN
# 3240  [['61808506700001701', 'Taylor & Francis Biolo...
# 3241                                                NaN
# 3242  [['61624504590001701', 'Elsevier ScienceDirect...
# 3243                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4             [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 3239                                                NaN
# 3240  [['53815442650001701', 'South African journal ...
# 3241                                                NaN
# 3242  [['53624617390001701', 'International journal ...
# 3243                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 4     [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 3239                                                NaN    NaN
# 3240  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 3241                                                NaN    NaN
# 3242     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 3243                                                NaN    NaN
#
#               Vendor_key  ...  \
# 0                [other]  ...
# 1                    NaN  ...
# 2                [JSTOR]  ...
# 3                    NaN  ...
# 4             [Elsevier]  ...
# ...                  ...  ...
# 3239                 NaN  ...
# 3240  [Taylor & Francis]  ...
# 3241                 NaN  ...
# 3242          [Elsevier]  ...
# 3243                 NaN  ...
#
#                                             p2e_no_pcad ct_chron ct_pcad  \
# 0                                    [1964, 1965, 1966]        4       1
# 1                                    [1964, 1965, 1966]        4       1
# 2                                                    []       13     110
# 3                                                    []       13     110
# 4     [1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...       24      10
# ...                                                 ...      ...     ...
# 3239                                                 []       31      41
# 3240                                                 []       21      21
# 3241                                                 []       21      21
# 3242                                                 []       11      40
# 3243                                                 []       11      40
#
#      ct_p_no_match p2e-percent  \
# 0                3        0.25
# 1                3        0.25
# 2                0        1.00
# 3                0        1.00
# 4               15        0.38
# ...            ...         ...
# 3239             0        1.00
# 3240             0        1.00
# 3241             0        1.00
# 3242             0        1.00
# 3243             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 4     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3240  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3242  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 4                                                    {}              0.00
# ...                                                 ...               ...
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3240                           {1992, 1989, 1990, 1991}              0.19
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3242                                             {1990}              0.09
# 3243                                             {1990}              0.09
#
#      total-to-remove  potential volumes to withdraw
# 0               0.25                            NaN
# 1               0.25                            0.0
# 2               0.46                            NaN
# 3               0.46                           21.0
# 4               0.00                            NaN
# ...              ...                            ...
# 3239            0.29                            5.0
# 3240            0.19                            NaN
# 3241            0.19                            2.0
# 3242            0.09                            NaN
# 3243            0.09                            0.0
#
# [3244 rows x 41 columns]

# %%
#check as many indices as desired
df.loc[12]
# Out:
# MMS_ID                                                              9969162730001701
# Title_bib                          Progress in nuclear magnetic resonance spectro...
# ISSN_cluster                                                  [0079-6565, 1873-3301]
# p_or_e                                                                             e
# matches_group_id                                                                2435
# e_coll_info                        [['61624504590001701', 'Elsevier ScienceDirect...
# portfolio_info                     [['53624687270001701', 'Progress in nuclear ma...
# Coverage Information Combined                      [ Available from 1966 volume: 1;]
# PCAD?                                                                          [Yes]
# Vendor_key                                                                [Elsevier]
# Title 1 (Print)_BTAA-SPR                                                         NaN
# Title 2 (Print)_BTAA-SPR                                                         NaN
# Match?_BTAA-SPR                                                                  NaN
# SPR Holdings_BTAA-SPR                                                            NaN
# Title (Complete)_PORTICO                                                         NaN
# Portico Match_PORTICO                                                            NaN
# Portico Title_PORTICO                                                            NaN
# PCA_PORTICO                                                                      NaN
# Status_PORTICO                                                                   NaN
# Earliest Year Preserved_PORTICO                                                  NaN
# Latest Year Preserved_PORTICO                                                    NaN
# curr-lib-loc_x                                                                   NaN
# all_item_count                                                                   NaN
# chron                                                                            NaN
# curr-lib-loc_ALL                                                                 NaN
# chron_as_list                             [1966, 1967, 1969, 1970, 1971, 1972, 1973]
# chron_ranges_calc                                                                NaN
# pcad-range                         [1966, 1967, 1968, 1969, 1970, 1971, 1972, 197...
# SPR-yrs                            [1965, 1966, 1970, 1971, 1972, 1973, 1974, 197...
# Portico-years                                                                    NaN
# repo-coverage                      [1965, 1966, 1970, 1971, 1972, 1973, 1974, 197...
# p2e_no_pcad                                                                       []
# ct_chron                                                                           7
# ct_pcad                                                                           54
# ct_p_no_match                                                                      0
# p2e-percent                                                                        1
# p2e_has_pcad                              {1966, 1967, 1969, 1970, 1971, 1972, 1973}
# pcad-repo                                             {1966, 1970, 1971, 1972, 1973}
# pcad-repo-percent                                                               0.71
# total-to-remove                                                                 0.71
# potential volumes to withdraw                                                    NaN
# Name: 12, dtype: object

# %% [markdown]
# #### Normalize group IDs

# %%
def new_group_ids ( df, identifier_column, group_name ):

    df2 = pd.DataFrame()
    df2 = df.groupby([identifier_column]).ngroup()
    print('grouped')

    groups = df2.to_frame()
    groups.rename(columns={0: group_name + '_group_id' },inplace=True)
    print(groups.columns)
    
    eg = pd.merge(df,groups,left_index=True,right_index=True, how="inner")
    
    return eg

# %%
df1 = new_group_ids(df, 'matches_group_id','final')
df1
# Out:
# grouped
# Index(['final_group_id'], dtype='object')
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 4     9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 3239  9931018220001701                                          Ophelia
# 3240  9967674080001701                 South African journal of zoology
# 3241  9942687740001701                 South African journal of zoology
# 3242  9968947900001701  International journal of adhesion and adhesives
# 3243  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  matches_group_id  \
# 0     [0893-6706, 2162-1373]      e                 5
# 1                [0893-6706]      p                 5
# 2     [0020-2681, 2058-1009]      e                12
# 3                [0020-2681]      p                12
# 4     [1532-2785, 0143-4179]      e               744
# ...                      ...    ...               ...
# 3239             [0078-5326]      p            101035
# 3240             [0254-1858]      e            101036
# 3241             [0254-1858]      p            101036
# 3242  [0143-7496, 1879-0127]      e            101582
# 3243             [0143-7496]      p            101582
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3239                                                NaN
# 3240  [['61808506700001701', 'Taylor & Francis Biolo...
# 3241                                                NaN
# 3242  [['61624504590001701', 'Elsevier ScienceDirect...
# 3243                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4             [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 3239                                                NaN
# 3240  [['53815442650001701', 'South African journal ...
# 3241                                                NaN
# 3242  [['53624617390001701', 'International journal ...
# 3243                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 4     [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 3239                                                NaN    NaN
# 3240  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 3241                                                NaN    NaN
# 3242     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 3243                                                NaN    NaN
#
#               Vendor_key  ... ct_chron ct_pcad ct_p_no_match p2e-percent  \
# 0                [other]  ...        4       1             3        0.25
# 1                    NaN  ...        4       1             3        0.25
# 2                [JSTOR]  ...       13     110             0        1.00
# 3                    NaN  ...       13     110             0        1.00
# 4             [Elsevier]  ...       24      10            15        0.38
# ...                  ...  ...      ...     ...           ...         ...
# 3239                 NaN  ...       31      41             0        1.00
# 3240  [Taylor & Francis]  ...       21      21             0        1.00
# 3241                 NaN  ...       21      21             0        1.00
# 3242          [Elsevier]  ...       11      40             0        1.00
# 3243                 NaN  ...       11      40             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 4     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3240  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3242  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 4                                                    {}              0.00
# ...                                                 ...               ...
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3240                           {1992, 1989, 1990, 1991}              0.19
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3242                                             {1990}              0.09
# 3243                                             {1990}              0.09
#
#      total-to-remove potential volumes to withdraw  final_group_id
# 0               0.25                           NaN               0
# 1               0.25                           0.0               0
# 2               0.46                           NaN               1
# 3               0.46                          21.0               1
# 4               0.00                           NaN               2
# ...              ...                           ...             ...
# 3239            0.29                           5.0            1619
# 3240            0.19                           NaN            1620
# 3241            0.19                           2.0            1620
# 3242            0.09                           NaN            1621
# 3243            0.09                           0.0            1621
#
# [3244 rows x 42 columns]

# %%
#check counts
print(df1['matches_group_id'].nunique())
print(df1['final_group_id'].max())
print(df1['final_group_id'].min())
print(df1['final_group_id'].nunique())
# Out:
# 1622
# 1621
# 0
# 1622

# %%
df1.columns
# Out:
# Index(['MMS_ID', 'Title_bib', 'ISSN_cluster', 'p_or_e', 'matches_group_id',
#        'e_coll_info', 'portfolio_info', 'Coverage Information Combined',
#        'PCAD?', 'Vendor_key', 'Title 1 (Print)_BTAA-SPR',
#        'Title 2 (Print)_BTAA-SPR', 'Match?_BTAA-SPR', 'SPR Holdings_BTAA-SPR',
#        'Title (Complete)_PORTICO', 'Portico Match_PORTICO',
#        'Portico Title_PORTICO', 'PCA_PORTICO', 'Status_PORTICO',
#        'Earliest Year Preserved_PORTICO', 'Latest Year Preserved_PORTICO',
#        'curr-lib-loc_x', 'all_item_count', 'chron', 'curr-lib-loc_ALL',
#        'chron_as_list', 'chron_ranges_calc', 'pcad-range', 'SPR-yrs',
#        'Portico-years', 'repo-coverage', 'p2e_no_pcad', 'ct_chron', 'ct_pcad',
#        'ct_p_no_match', 'p2e-percent', 'p2e_has_pcad', 'pcad-repo',
#        'pcad-repo-percent', 'total-to-remove', 'potential volumes to withdraw',
#        'final_group_id'],
#       dtype='object')

# %%
df1.drop(columns=['matches_group_id'],inplace=True)
df1
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 4     9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 3239  9931018220001701                                          Ophelia
# 3240  9967674080001701                 South African journal of zoology
# 3241  9942687740001701                 South African journal of zoology
# 3242  9968947900001701  International journal of adhesion and adhesives
# 3243  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  \
# 0     [0893-6706, 2162-1373]      e
# 1                [0893-6706]      p
# 2     [0020-2681, 2058-1009]      e
# 3                [0020-2681]      p
# 4     [1532-2785, 0143-4179]      e
# ...                      ...    ...
# 3239             [0078-5326]      p
# 3240             [0254-1858]      e
# 3241             [0254-1858]      p
# 3242  [0143-7496, 1879-0127]      e
# 3243             [0143-7496]      p
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3239                                                NaN
# 3240  [['61808506700001701', 'Taylor & Francis Biolo...
# 3241                                                NaN
# 3242  [['61624504590001701', 'Elsevier ScienceDirect...
# 3243                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4             [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 3239                                                NaN
# 3240  [['53815442650001701', 'South African journal ...
# 3241                                                NaN
# 3242  [['53624617390001701', 'International journal ...
# 3243                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 4     [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 3239                                                NaN    NaN
# 3240  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 3241                                                NaN    NaN
# 3242     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 3243                                                NaN    NaN
#
#               Vendor_key                          Title 1 (Print)_BTAA-SPR  \
# 0                [other]                                               NaN
# 1                    NaN     IEEE transactions on ultrasonics engineering.
# 2                [JSTOR]                                               NaN
# 3                    NaN            Journal of the Institute of Actuaries.
# 4             [Elsevier]                                               NaN
# ...                  ...                                               ...
# 3239                 NaN                                               NaN
# 3240  [Taylor & Francis]                                               NaN
# 3241                 NaN                                               NaN
# 3242          [Elsevier]                                               NaN
# 3243                 NaN  International journal of adhesion and adhesives.
#
#       ... ct_chron ct_pcad ct_p_no_match p2e-percent  \
# 0     ...        4       1             3        0.25
# 1     ...        4       1             3        0.25
# 2     ...       13     110             0        1.00
# 3     ...       13     110             0        1.00
# 4     ...       24      10            15        0.38
# ...   ...      ...     ...           ...         ...
# 3239  ...       31      41             0        1.00
# 3240  ...       21      21             0        1.00
# 3241  ...       21      21             0        1.00
# 3242  ...       11      40             0        1.00
# 3243  ...       11      40             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 4     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3240  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3242  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 4                                                    {}              0.00
# ...                                                 ...               ...
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3240                           {1992, 1989, 1990, 1991}              0.19
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3242                                             {1990}              0.09
# 3243                                             {1990}              0.09
#
#      total-to-remove  potential volumes to withdraw  final_group_id
# 0               0.25                            NaN               0
# 1               0.25                            0.0               0
# 2               0.46                            NaN               1
# 3               0.46                           21.0               1
# 4               0.00                            NaN               2
# ...              ...                            ...             ...
# 3239            0.29                            5.0            1619
# 3240            0.19                            NaN            1620
# 3241            0.19                            2.0            1620
# 3242            0.09                            NaN            1621
# 3243            0.09                            0.0            1621
#
# [3244 rows x 41 columns]

# %% [markdown]
# #### Sort out single vs. multiple locations

# %%
p2 = df1[df1['curr-lib-loc_ALL'].notnull()]
p2['curr-lib-loc_ALL'] = p2['curr-lib-loc_ALL'].apply(lambda x: ast.literal_eval(x))
p2
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 MMS_ID                                         Title_bib  \
# 1     9963550760001701      IEEE transactions on ultrasonics engineering
# 3     9939481760001701             Journal of the Institute of Actuaries
# 5     9931084310001701                                     Neuropeptides
# 6     9918228280001701                   Annals of agricultural science.
# 9     9975846880001701  Journal für praktische Chemie, Chemiker-Zeitung
# ...                ...                                               ...
# 3235  9913415620001701     Journal of muscle research and cell motility.
# 3237  9952125650001701                 Journal of the Franklin Institute
# 3239  9931018220001701                                           Ophelia
# 3241  9942687740001701                  South African journal of zoology
# 3243  9957960200001701   International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e e_coll_info portfolio_info  \
# 1                [0893-6706]      p         NaN            NaN
# 3                [0020-2681]      p         NaN            NaN
# 5                [0143-4179]      p         NaN            NaN
# 6     [1110-0249, 0570-1783]      p         NaN            NaN
# 9                [0941-1216]      p         NaN            NaN
# ...                      ...    ...         ...            ...
# 3235             [0142-4319]      p         NaN            NaN
# 3237             [0016-0032]      p         NaN            NaN
# 3239             [0078-5326]      p         NaN            NaN
# 3241             [0254-1858]      p         NaN            NaN
# 3243             [0143-7496]      p         NaN            NaN
#
#      Coverage Information Combined PCAD? Vendor_key  \
# 1                              NaN   NaN        NaN
# 3                              NaN   NaN        NaN
# 5                              NaN   NaN        NaN
# 6                              NaN   NaN        NaN
# 9                              NaN   NaN        NaN
# ...                            ...   ...        ...
# 3235                           NaN   NaN        NaN
# 3237                           NaN   NaN        NaN
# 3239                           NaN   NaN        NaN
# 3241                           NaN   NaN        NaN
# 3243                           NaN   NaN        NaN
#
#                               Title 1 (Print)_BTAA-SPR  ... ct_chron ct_pcad  \
# 1        IEEE transactions on ultrasonics engineering.  ...        4       1
# 3               Journal of the Institute of Actuaries.  ...       13     110
# 5                                       Neuropeptides.  ...       24      10
# 6                                                  NaN  ...        7       9
# 9                                                  NaN  ...        5       7
# ...                                                ...  ...      ...     ...
# 3235     Journal of muscle research and cell motility.  ...       25      17
# 3237                Journal of the Franklin Institute.  ...      178     194
# 3239                                               NaN  ...       31      41
# 3241                                               NaN  ...       21      21
# 3243  International journal of adhesion and adhesives.  ...       11      40
#
#      ct_p_no_match p2e-percent  \
# 1                3        0.25
# 3                0        1.00
# 5               15        0.38
# 6                7        0.00
# 9                0        1.00
# ...            ...         ...
# 3235             8        0.68
# 3237             0        1.00
# 3239             0        1.00
# 3241             0        1.00
# 3243             0        1.00
#
#                                            p2e_has_pcad  \
# 1                                                {1963}
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 5     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 6                                                    {}
# 9                        {1992, 1993, 1994, 1995, 1996}
# ...                                                 ...
# 3235  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 3237  {1826, 1827, 1828, 1829, 1830, 1831, 1832, 183...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 1                                                {1963}              1.00
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 5                                                    {}              0.00
# 6                                                    {}              0.00
# 9                                                    {}              0.00
# ...                                                 ...               ...
# 3235  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...              1.00
# 3237  {1829, 1830, 1831, 1832, 1833, 1834, 1835, 183...              0.84
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3243                                             {1990}              0.09
#
#      total-to-remove  potential volumes to withdraw  final_group_id
# 1               0.25                            0.0               0
# 3               0.46                           21.0               1
# 5               0.00                            0.0               2
# 6               0.00                            0.0               3
# 9               0.00                            0.0               4
# ...              ...                            ...             ...
# 3235            0.68                           25.0            1617
# 3237            0.84                          262.0            1618
# 3239            0.29                            5.0            1619
# 3241            0.19                            2.0            1620
# 3243            0.09                            0.0            1621
#
# [1622 rows x 41 columns]

# %%
p2['curr-lib-loc_ALL']
# Out:
# 1         [TZDS GEN]
# 3        [TWILS CLS]
# 5       [TBIOM PERS]
# 6        [ZMLAC OWL]
# 9        [ZMLAC OWL]
#             ...
# 3235    [TBIOM PERS]
# 3237      [TSCI PER]
# 3239     [TMAGR PER]
# 3241     [TMAGR PER]
# 3243      [TSCI PER]
# Name: curr-lib-loc_ALL, Length: 1622, dtype: object

# %%
p2['loc_count'] = ''
p2['locs'] = ''
for index, row in p2.iterrows():
    locs = [x for x in row['curr-lib-loc_ALL'] if ('WDN' not in x)]
    p2.set_value(index, 'loc_count', len(locs))
    p2.set_value(index, 'locs', locs)
    
p2
# Out:
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#                 MMS_ID                                         Title_bib  \
# 1     9963550760001701      IEEE transactions on ultrasonics engineering
# 3     9939481760001701             Journal of the Institute of Actuaries
# 5     9931084310001701                                     Neuropeptides
# 6     9918228280001701                   Annals of agricultural science.
# 9     9975846880001701  Journal für praktische Chemie, Chemiker-Zeitung
# ...                ...                                               ...
# 3235  9913415620001701     Journal of muscle research and cell motility.
# 3237  9952125650001701                 Journal of the Franklin Institute
# 3239  9931018220001701                                           Ophelia
# 3241  9942687740001701                  South African journal of zoology
# 3243  9957960200001701   International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e e_coll_info portfolio_info  \
# 1                [0893-6706]      p         NaN            NaN
# 3                [0020-2681]      p         NaN            NaN
# 5                [0143-4179]      p         NaN            NaN
# 6     [1110-0249, 0570-1783]      p         NaN            NaN
# 9                [0941-1216]      p         NaN            NaN
# ...                      ...    ...         ...            ...
# 3235             [0142-4319]      p         NaN            NaN
# 3237             [0016-0032]      p         NaN            NaN
# 3239             [0078-5326]      p         NaN            NaN
# 3241             [0254-1858]      p         NaN            NaN
# 3243             [0143-7496]      p         NaN            NaN
#
#      Coverage Information Combined PCAD? Vendor_key  \
# 1                              NaN   NaN        NaN
# 3                              NaN   NaN        NaN
# 5                              NaN   NaN        NaN
# 6                              NaN   NaN        NaN
# 9                              NaN   NaN        NaN
# ...                            ...   ...        ...
# 3235                           NaN   NaN        NaN
# 3237                           NaN   NaN        NaN
# 3239                           NaN   NaN        NaN
# 3241                           NaN   NaN        NaN
# 3243                           NaN   NaN        NaN
#
#                               Title 1 (Print)_BTAA-SPR  ... ct_p_no_match  \
# 1        IEEE transactions on ultrasonics engineering.  ...             3
# 3               Journal of the Institute of Actuaries.  ...             0
# 5                                       Neuropeptides.  ...            15
# 6                                                  NaN  ...             7
# 9                                                  NaN  ...             0
# ...                                                ...  ...           ...
# 3235     Journal of muscle research and cell motility.  ...             8
# 3237                Journal of the Franklin Institute.  ...             0
# 3239                                               NaN  ...             0
# 3241                                               NaN  ...             0
# 3243  International journal of adhesion and adhesives.  ...             0
#
#      p2e-percent                                       p2e_has_pcad  \
# 1           0.25                                             {1963}
# 3           1.00  {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 5           0.38  {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 6           0.00                                                 {}
# 9           1.00                     {1992, 1993, 1994, 1995, 1996}
# ...          ...                                                ...
# 3235        0.68  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 3237        1.00  {1826, 1827, 1828, 1829, 1830, 1831, 1832, 183...
# 3239        1.00  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3241        1.00  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3243        1.00  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 1                                                {1963}              1.00
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 5                                                    {}              0.00
# 6                                                    {}              0.00
# 9                                                    {}              0.00
# ...                                                 ...               ...
# 3235  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...              1.00
# 3237  {1829, 1830, 1831, 1832, 1833, 1834, 1835, 183...              0.84
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3243                                             {1990}              0.09
#
#      total-to-remove potential volumes to withdraw final_group_id  loc_count  \
# 1               0.25                           0.0              0          1
# 3               0.46                          21.0              1          1
# 5               0.00                           0.0              2          1
# 6               0.00                           0.0              3          1
# 9               0.00                           0.0              4          1
# ...              ...                           ...            ...        ...
# 3235            0.68                          25.0           1617          1
# 3237            0.84                         262.0           1618          1
# 3239            0.29                           5.0           1619          1
# 3241            0.19                           2.0           1620          1
# 3243            0.09                           0.0           1621          1
#
#               locs
# 1       [TZDS GEN]
# 3      [TWILS CLS]
# 5     [TBIOM PERS]
# 6      [ZMLAC OWL]
# 9      [ZMLAC OWL]
# ...            ...
# 3235  [TBIOM PERS]
# 3237    [TSCI PER]
# 3239   [TMAGR PER]
# 3241   [TMAGR PER]
# 3243    [TSCI PER]
#
# [1622 rows x 43 columns]

# %%
p2[['curr-lib-loc_ALL','locs','loc_count']]
# Out:
#      curr-lib-loc_ALL          locs loc_count
# 1          [TZDS GEN]    [TZDS GEN]         1
# 3         [TWILS CLS]   [TWILS CLS]         1
# 5        [TBIOM PERS]  [TBIOM PERS]         1
# 6         [ZMLAC OWL]   [ZMLAC OWL]         1
# 9         [ZMLAC OWL]   [ZMLAC OWL]         1
# ...               ...           ...       ...
# 3235     [TBIOM PERS]  [TBIOM PERS]         1
# 3237       [TSCI PER]    [TSCI PER]         1
# 3239      [TMAGR PER]   [TMAGR PER]         1
# 3241      [TMAGR PER]   [TMAGR PER]         1
# 3243       [TSCI PER]    [TSCI PER]         1
#
# [1622 rows x 3 columns]

# %%
p3 = pd.merge(df1, p2[['locs','loc_count']], how='left',left_index=True, right_index=True)
p3
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 4     9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 3239  9931018220001701                                          Ophelia
# 3240  9967674080001701                 South African journal of zoology
# 3241  9942687740001701                 South African journal of zoology
# 3242  9968947900001701  International journal of adhesion and adhesives
# 3243  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  \
# 0     [0893-6706, 2162-1373]      e
# 1                [0893-6706]      p
# 2     [0020-2681, 2058-1009]      e
# 3                [0020-2681]      p
# 4     [1532-2785, 0143-4179]      e
# ...                      ...    ...
# 3239             [0078-5326]      p
# 3240             [0254-1858]      e
# 3241             [0254-1858]      p
# 3242  [0143-7496, 1879-0127]      e
# 3243             [0143-7496]      p
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3239                                                NaN
# 3240  [['61808506700001701', 'Taylor & Francis Biolo...
# 3241                                                NaN
# 3242  [['61624504590001701', 'Elsevier ScienceDirect...
# 3243                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4             [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 3239                                                NaN
# 3240  [['53815442650001701', 'South African journal ...
# 3241                                                NaN
# 3242  [['53624617390001701', 'International journal ...
# 3243                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 4     [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 3239                                                NaN    NaN
# 3240  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 3241                                                NaN    NaN
# 3242     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 3243                                                NaN    NaN
#
#               Vendor_key                          Title 1 (Print)_BTAA-SPR  \
# 0                [other]                                               NaN
# 1                    NaN     IEEE transactions on ultrasonics engineering.
# 2                [JSTOR]                                               NaN
# 3                    NaN            Journal of the Institute of Actuaries.
# 4             [Elsevier]                                               NaN
# ...                  ...                                               ...
# 3239                 NaN                                               NaN
# 3240  [Taylor & Francis]                                               NaN
# 3241                 NaN                                               NaN
# 3242          [Elsevier]                                               NaN
# 3243                 NaN  International journal of adhesion and adhesives.
#
#       ... ct_p_no_match p2e-percent  \
# 0     ...             3        0.25
# 1     ...             3        0.25
# 2     ...             0        1.00
# 3     ...             0        1.00
# 4     ...            15        0.38
# ...   ...           ...         ...
# 3239  ...             0        1.00
# 3240  ...             0        1.00
# 3241  ...             0        1.00
# 3242  ...             0        1.00
# 3243  ...             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 4     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3240  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3242  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 4                                                    {}              0.00
# ...                                                 ...               ...
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3240                           {1992, 1989, 1990, 1991}              0.19
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3242                                             {1990}              0.09
# 3243                                             {1990}              0.09
#
#      total-to-remove potential volumes to withdraw final_group_id  \
# 0               0.25                           NaN              0
# 1               0.25                           0.0              0
# 2               0.46                           NaN              1
# 3               0.46                          21.0              1
# 4               0.00                           NaN              2
# ...              ...                           ...            ...
# 3239            0.29                           5.0           1619
# 3240            0.19                           NaN           1620
# 3241            0.19                           2.0           1620
# 3242            0.09                           NaN           1621
# 3243            0.09                           0.0           1621
#
#              locs  loc_count
# 0             NaN        NaN
# 1      [TZDS GEN]          1
# 2             NaN        NaN
# 3     [TWILS CLS]          1
# 4             NaN        NaN
# ...           ...        ...
# 3239  [TMAGR PER]          1
# 3240          NaN        NaN
# 3241  [TMAGR PER]          1
# 3242          NaN        NaN
# 3243   [TSCI PER]          1
#
# [3244 rows x 43 columns]

# %%
p3['loc_count'].fillna(0,inplace=True)
p3
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 4     9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 3239  9931018220001701                                          Ophelia
# 3240  9967674080001701                 South African journal of zoology
# 3241  9942687740001701                 South African journal of zoology
# 3242  9968947900001701  International journal of adhesion and adhesives
# 3243  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  \
# 0     [0893-6706, 2162-1373]      e
# 1                [0893-6706]      p
# 2     [0020-2681, 2058-1009]      e
# 3                [0020-2681]      p
# 4     [1532-2785, 0143-4179]      e
# ...                      ...    ...
# 3239             [0078-5326]      p
# 3240             [0254-1858]      e
# 3241             [0254-1858]      p
# 3242  [0143-7496, 1879-0127]      e
# 3243             [0143-7496]      p
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3239                                                NaN
# 3240  [['61808506700001701', 'Taylor & Francis Biolo...
# 3241                                                NaN
# 3242  [['61624504590001701', 'Elsevier ScienceDirect...
# 3243                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4             [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 3239                                                NaN
# 3240  [['53815442650001701', 'South African journal ...
# 3241                                                NaN
# 3242  [['53624617390001701', 'International journal ...
# 3243                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 4     [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 3239                                                NaN    NaN
# 3240  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 3241                                                NaN    NaN
# 3242     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 3243                                                NaN    NaN
#
#               Vendor_key                          Title 1 (Print)_BTAA-SPR  \
# 0                [other]                                               NaN
# 1                    NaN     IEEE transactions on ultrasonics engineering.
# 2                [JSTOR]                                               NaN
# 3                    NaN            Journal of the Institute of Actuaries.
# 4             [Elsevier]                                               NaN
# ...                  ...                                               ...
# 3239                 NaN                                               NaN
# 3240  [Taylor & Francis]                                               NaN
# 3241                 NaN                                               NaN
# 3242          [Elsevier]                                               NaN
# 3243                 NaN  International journal of adhesion and adhesives.
#
#       ... ct_p_no_match p2e-percent  \
# 0     ...             3        0.25
# 1     ...             3        0.25
# 2     ...             0        1.00
# 3     ...             0        1.00
# 4     ...            15        0.38
# ...   ...           ...         ...
# 3239  ...             0        1.00
# 3240  ...             0        1.00
# 3241  ...             0        1.00
# 3242  ...             0        1.00
# 3243  ...             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 4     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3240  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3242  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 4                                                    {}              0.00
# ...                                                 ...               ...
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3240                           {1992, 1989, 1990, 1991}              0.19
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3242                                             {1990}              0.09
# 3243                                             {1990}              0.09
#
#      total-to-remove potential volumes to withdraw final_group_id  \
# 0               0.25                           NaN              0
# 1               0.25                           0.0              0
# 2               0.46                           NaN              1
# 3               0.46                          21.0              1
# 4               0.00                           NaN              2
# ...              ...                           ...            ...
# 3239            0.29                           5.0           1619
# 3240            0.19                           NaN           1620
# 3241            0.19                           2.0           1620
# 3242            0.09                           NaN           1621
# 3243            0.09                           0.0           1621
#
#              locs  loc_count
# 0             NaN          0
# 1      [TZDS GEN]          1
# 2             NaN          0
# 3     [TWILS CLS]          1
# 4             NaN          0
# ...           ...        ...
# 3239  [TMAGR PER]          1
# 3240          NaN          0
# 3241  [TMAGR PER]          1
# 3242          NaN          0
# 3243   [TSCI PER]          1
#
# [3244 rows x 43 columns]

# %%
multi_locs = p3[p3['loc_count'] > 1]
multi_locs_ids = list(multi_locs['final_group_id'])
multi_loc_data = p3[p3['final_group_id'].isin(multi_locs_ids)]
multi_loc_data
# Out:
#                 MMS_ID                                       Title_bib  \
# 10    9968016560001701  Annals of the Entomological Society of America
# 11    9925898310001701  Annals of the Entomological Society of America
# 30    9966977060001701                          Sociology of education
# 31    9926013400001701                          Sociology of education
# 40    9967040110001701       Journal of mathematical behavior (Online)
# ...                ...                                             ...
# 3181  9942475030001701                 Journal of lightwave technology
# 3184  9949962250001701             IEEE robotics & automation magazine
# 3185  9966891010001701    IEEE robotics & automation magazine (Online)
# 3202  9963163570001701        I.R.E. transactions on automatic control
# 3203  9968437690001701           IRE transactions on automatic control
#
#                 ISSN_cluster p_or_e  \
# 10    [0013-8746, 1938-2901]      e
# 11    [0013-8746, 1938-2901]      p
# 30    [0038-0407, 1939-8573]      e
# 31               [0038-0407]      p
# 40    [0732-3123, 1873-8028]      e
# ...                      ...    ...
# 3181             [0733-8724]      p
# 3184  [1558-223X, 1070-9932]      p
# 3185             [1070-9932]      e
# 3202             [0096-199X]      p
# 3203  [0096-199X, 1558-3651]      e
#
#                                             e_coll_info  \
# 10    [['61640618310001701', 'Oxford University Pres...
# 11                                                  NaN
# 30    [['61786968900001701', 'SAGE Premier 2020', ''...
# 31                                                  NaN
# 40    [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3181                                                NaN
# 3184                                                NaN
# 3185  [['61619505660001701', 'IEEE/IET Electronic Li...
# 3202                                                NaN
# 3203  [['61619505660001701', 'IEEE/IET Electronic Li...
#
#                                          portfolio_info  \
# 10    [['53640944640001701', 'Annals of the Entomolo...
# 11                                                  NaN
# 30    [['53787025550001701', 'Sociology of education...
# 31                                                  NaN
# 40    [['53624646450001701', 'The journal of mathema...
# ...                                                 ...
# 3181                                                NaN
# 3184                                                NaN
# 3185  [['53620436290001701', 'IEEE robotics & automa...
# 3202                                                NaN
# 3203  [['53620436030001701', 'IRE transactions on au...
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 10    [ Available from 1908 volume: 1 issue: 1 until...  [Yes]     [other]
# 11                                                  NaN    NaN         NaN
# 30    [ Available from 2004 until 2009;,  Available ...  [Yes]      [SAGE]
# 31                                                  NaN    NaN         NaN
# 40      [ Available from 1994-03- volume: 13 issue: 1;]  [Yes]  [Elsevier]
# ...                                                 ...    ...         ...
# 3181                                                NaN    NaN         NaN
# 3184                                                NaN    NaN         NaN
# 3185                 [ Available from 1994 until 1999;]  [Yes]     [other]
# 3202                                                NaN    NaN         NaN
# 3203  [ Available from 1956 volume: 1 issue: 1 until...  [Yes]     [other]
#
#                                Title 1 (Print)_BTAA-SPR  ... ct_p_no_match  \
# 10                                                  NaN  ...            17
# 11      Annals of the Entomological Society of America.  ...            17
# 30                                                  NaN  ...            41
# 31                              Sociology of education.  ...            41
# 40                                                  NaN  ...             3
# ...                                                 ...  ...           ...
# 3181  Journal of lightwave technology : a joint IEEE...  ...             4
# 3184               IEEE robotics & automation magazine.  ...             4
# 3185                                                NaN  ...             4
# 3202             IRE transactions on automatic control.  ...             0
# 3203                                                NaN  ...             0
#
#      p2e-percent                                       p2e_has_pcad  \
# 10          0.83  {1908, 1909, 1910, 1911, 1912, 1913, 1914, 191...
# 11          0.83  {1908, 1909, 1910, 1911, 1912, 1913, 1914, 191...
# 30          0.13               {2004, 2005, 2006, 2007, 2008, 2009}
# 31          0.13               {2004, 2005, 2006, 2007, 2008, 2009}
# 40          0.73   {1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001}
# ...          ...                                                ...
# 3181        0.81  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 3184        0.60               {1994, 1995, 1996, 1997, 1998, 1999}
# 3185        0.60               {1994, 1995, 1996, 1997, 1998, 1999}
# 3202        1.00         {1956, 1957, 1958, 1959, 1960, 1961, 1962}
# 3203        1.00         {1956, 1957, 1958, 1959, 1960, 1961, 1962}
#
#                                               pcad-repo pcad-repo-percent  \
# 10    {1908, 1909, 1910, 1911, 1912, 1913, 1914, 191...              0.96
# 11    {1908, 1909, 1910, 1911, 1912, 1913, 1914, 191...              0.96
# 30                 {2004, 2005, 2006, 2007, 2008, 2009}              1.00
# 31                 {2004, 2005, 2006, 2007, 2008, 2009}              1.00
# 40           {1994, 1995, 1996, 1997, 1998, 1999, 2001}              0.88
# ...                                                 ...               ...
# 3181  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...              1.00
# 3184               {1994, 1995, 1996, 1997, 1998, 1999}              1.00
# 3185               {1994, 1995, 1996, 1997, 1998, 1999}              1.00
# 3202                                 {1956, 1957, 1958}              0.43
# 3203                                 {1956, 1957, 1958}              0.43
#
#      total-to-remove potential volumes to withdraw final_group_id  \
# 10              0.80                           NaN              5
# 11              0.80                         120.0              5
# 30              0.13                           NaN             15
# 31              0.13                           5.0             15
# 40              0.64                           NaN             20
# ...              ...                           ...            ...
# 3181            0.81                          63.0           1590
# 3184            0.60                          13.0           1592
# 3185            0.60                           NaN           1592
# 3202            0.43                           3.0           1601
# 3203            0.43                           NaN           1601
#
#                          locs  loc_count
# 10                        NaN          0
# 11      [TNRL GEN, ZMLAC OWL]          2
# 30                        NaN          0
# 31     [ZMLAC OWL, TWILS PER]          2
# 40                        NaN          0
# ...                       ...        ...
# 3181   [ZMLAC UMDN, TSCI PER]          2
# 3184   [ZMLAC UMDN, TSCI PER]          2
# 3185                      NaN          0
# 3202  [ZMLAC UMDN, ZMLAC OWL]          2
# 3203                      NaN          0
#
# [622 rows x 43 columns]

# %%
single_loc_data = p3[~p3['final_group_id'].isin(multi_locs_ids)]
single_loc_data
# Out:
#                 MMS_ID                                        Title_bib  \
# 0     9968441380001701     IEEE transactions on ultrasonics engineering
# 1     9963550760001701     IEEE transactions on ultrasonics engineering
# 2     9968429800001701            Journal of the Institute of Actuaries
# 3     9939481760001701            Journal of the Institute of Actuaries
# 4     9966907990001701                                    Neuropeptides
# ...                ...                                              ...
# 3239  9931018220001701                                          Ophelia
# 3240  9967674080001701                 South African journal of zoology
# 3241  9942687740001701                 South African journal of zoology
# 3242  9968947900001701  International journal of adhesion and adhesives
# 3243  9957960200001701  International journal of adhesion and adhesives
#
#                 ISSN_cluster p_or_e  \
# 0     [0893-6706, 2162-1373]      e
# 1                [0893-6706]      p
# 2     [0020-2681, 2058-1009]      e
# 3                [0020-2681]      p
# 4     [1532-2785, 0143-4179]      e
# ...                      ...    ...
# 3239             [0078-5326]      p
# 3240             [0254-1858]      e
# 3241             [0254-1858]      p
# 3242  [0143-7496, 1879-0127]      e
# 3243             [0143-7496]      p
#
#                                             e_coll_info  \
# 0     [['61619505660001701', 'IEEE/IET Electronic Li...
# 1                                                   NaN
# 2     [['61535216140001701', 'JSTOR Business III Col...
# 3                                                   NaN
# 4     [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 3239                                                NaN
# 3240  [['61808506700001701', 'Taylor & Francis Biolo...
# 3241                                                NaN
# 3242  [['61624504590001701', 'Elsevier ScienceDirect...
# 3243                                                NaN
#
#                                          portfolio_info  \
# 0     [['53620359120001701', 'IEEE transactions on u...
# 1                                                   NaN
# 2     [['53540140170001701', 'Journal of the Institu...
# 3                                                   NaN
# 4             [['53624660480001701', 'Neuropeptides.']]
# ...                                                 ...
# 3239                                                NaN
# 3240  [['53815442650001701', 'South African journal ...
# 3241                                                NaN
# 3242  [['53624617390001701', 'International journal ...
# 3243                                                NaN
#
#                           Coverage Information Combined  PCAD?  \
# 0     [ Available from 1963 volume: 10 issue: 1 unti...  [Yes]
# 1                                                   NaN    NaN
# 2     [ Available from 1886 volume: 25 issue: 5 unti...  [Yes]
# 3                                                   NaN    NaN
# 4     [ Available from 1995-01- volume: 28 issue: 1 ...  [Yes]
# ...                                                 ...    ...
# 3239                                                NaN    NaN
# 3240  [ Available from 1979 volume: 14 issue: 1 unti...  [Yes]
# 3241                                                NaN    NaN
# 3242     [ Available from 1980-07- volume: 1 issue: 1;]  [Yes]
# 3243                                                NaN    NaN
#
#               Vendor_key                          Title 1 (Print)_BTAA-SPR  \
# 0                [other]                                               NaN
# 1                    NaN     IEEE transactions on ultrasonics engineering.
# 2                [JSTOR]                                               NaN
# 3                    NaN            Journal of the Institute of Actuaries.
# 4             [Elsevier]                                               NaN
# ...                  ...                                               ...
# 3239                 NaN                                               NaN
# 3240  [Taylor & Francis]                                               NaN
# 3241                 NaN                                               NaN
# 3242          [Elsevier]                                               NaN
# 3243                 NaN  International journal of adhesion and adhesives.
#
#       ... ct_p_no_match p2e-percent  \
# 0     ...             3        0.25
# 1     ...             3        0.25
# 2     ...             0        1.00
# 3     ...             0        1.00
# 4     ...            15        0.38
# ...   ...           ...         ...
# 3239  ...             0        1.00
# 3240  ...             0        1.00
# 3241  ...             0        1.00
# 3242  ...             0        1.00
# 3243  ...             0        1.00
#
#                                            p2e_has_pcad  \
# 0                                                {1963}
# 1                                                {1963}
# 2     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 3     {1890, 1951, 1892, 1947, 1895, 1939, 1943, 191...
# 4     {1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# ...                                                 ...
# 3239  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 3240  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3241  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 3242  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
# 3243  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 198...
#
#                                               pcad-repo pcad-repo-percent  \
# 0                                                {1963}              1.00
# 1                                                {1963}              1.00
# 2                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 3                  {1939, 1943, 1946, 1947, 1948, 1951}              0.46
# 4                                                    {}              0.00
# ...                                                 ...               ...
# 3239  {1986, 1987, 1988, 1989, 1990, 1991, 1992, 199...              0.29
# 3240                           {1992, 1989, 1990, 1991}              0.19
# 3241                           {1992, 1989, 1990, 1991}              0.19
# 3242                                             {1990}              0.09
# 3243                                             {1990}              0.09
#
#      total-to-remove potential volumes to withdraw final_group_id  \
# 0               0.25                           NaN              0
# 1               0.25                           0.0              0
# 2               0.46                           NaN              1
# 3               0.46                          21.0              1
# 4               0.00                           NaN              2
# ...              ...                           ...            ...
# 3239            0.29                           5.0           1619
# 3240            0.19                           NaN           1620
# 3241            0.19                           2.0           1620
# 3242            0.09                           NaN           1621
# 3243            0.09                           0.0           1621
#
#              locs  loc_count
# 0             NaN          0
# 1      [TZDS GEN]          1
# 2             NaN          0
# 3     [TWILS CLS]          1
# 4             NaN          0
# ...           ...        ...
# 3239  [TMAGR PER]          1
# 3240          NaN          0
# 3241  [TMAGR PER]          1
# 3242          NaN          0
# 3243   [TSCI PER]          1
#
# [2622 rows x 43 columns]

# %%
multi_loc_data.to_pickle('multi_loc_data_' + today + '.pkl')
single_loc_data.to_pickle('single_loc_data_' + today + '.pkl')

# %%
print(multi_loc_data['final_group_id'].nunique())
print(single_loc_data['final_group_id'].nunique())
# Out:
# 311
# 1311

# %% [markdown]
# #### Split multi-loc and single-loc into coverage groups

# %%
def split_by_coverage(df, df_name):
    
    base = df_name
    base_100 = base + '_100'
    base_100_df = base_100 + '_df'
    base_0_100 = base + '_gt0_lt100'
    base_0_100_df = base_0_100 + '_df'
    base_0 = base + '_0'
    base_0_df = base_0 + '_df'
    
    base_100_df = df.groupby('final_group_id').filter(lambda x: x['total-to-remove'].mean() == 1)
    base_100_df.to_pickle(base_100 + '.pkl')
    base_100_df.to_csv(base_100 + '.txt',sep='\t')
    
    base_0_df = df.groupby('final_group_id').filter(lambda x: x['total-to-remove'].mean() == 0)
    base_0_df.to_pickle(base_0 + '.pkl')
    base_0_df.to_csv(base_0 + '.txt',sep='\t')
    
    base_0_100_df = df.groupby('final_group_id').filter(lambda x: 0 < x['total-to-remove'].mean() < 1)
    base_0_100_df.to_pickle(base_0_100 + '.pkl')
    base_0_100_df.to_csv(base_0_100 + '.txt',sep='\t')
    
    return base_100_df, base_0_100_df, base_0_df

# %%
multi_loc_100, multi_loc_0_100, multi_loc_0 = split_by_coverage(multi_loc_data,'multi_loc_data')
single_loc_100, single_loc_0_100, single_loc_0 = split_by_coverage(single_loc_data,'single_loc_data')

# %%
print(multi_loc_100.shape)
print(multi_loc_0_100.shape)
print(multi_loc_0.shape)
print(single_loc_100.shape)
print(single_loc_0_100.shape)
print(single_loc_0.shape)
# Out:
# (126, 43)
# (474, 43)
# (22, 43)
# (566, 43)
# (1722, 43)
# (334, 43)

# %% [markdown]
# #### Split coverage groups by single or multi vendor

# %%
def split_by_vendor_ct (df, df_name):
    
    df_has_vendors = df[df['Vendor_key'].notnull()]
    has_vendor_groups = list(df_has_vendors['final_group_id'])
    has_vendor_data = df[df['final_group_id'].isin(has_vendor_groups)]
    
    no_vendor_data = df[~df['final_group_id'].isin(has_vendor_groups)]
    print('no_vendor')
    print(no_vendor_data.shape)
    no_vendor_data.to_pickle(df_name + 'no_vendor_data.pkl')
    no_vendor_data.to_csv(df_name +'no_vendor_data.txt',sep='\t')
    
    df_has_vendors['num_of_vend'] = df_has_vendors['Vendor_key'].apply(lambda x: len(x))
    df_has_one_vendor = df_has_vendors[df_has_vendors['num_of_vend'] == 1]
    
    df_has_multiple_vendors = df_has_vendors[df_has_vendors['num_of_vend'] > 1]
    multi_vendor_groups = list(df_has_multiple_vendors['final_group_id'])
    multi_vendor_data = has_vendor_data[has_vendor_data['final_group_id'].isin(multi_vendor_groups)]
    
    print('has multiple vendors')
    print(multi_vendor_data.shape)
    multi_vendor_data.to_pickle(df_name + 'multi-vendor-data.pkl')
    multi_vendor_data.to_csv(df_name + 'multi-vendor-data.txt',sep='\t', index=False)
    
    single_vendor_data = has_vendor_data[~has_vendor_data['final_group_id'].isin(multi_vendor_groups)]
    print('has single vendor')
    print(single_vendor_data.shape)
    single_vendor_data.to_pickle(df_name +'single-vendor-data.pkl')
    single_vendor_data.to_csv(df_name +'single-vendor-data.txt',sep='\t', index=False)
    
    return single_vendor_data

# %%
multi_loc_100_vendor = split_by_vendor_ct(multi_loc_100, 'multi_loc_100')
multi_loc_100_vendor
# Out:
# no_vendor
# (0, 43)
# has multiple vendors
# (6, 43)
# has single vendor
# (120, 43)
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                 MMS_ID                                          Title_bib  \
# 68    9966748700001701                                   Behavior therapy
# 69    9956703420001701                                   Behavior therapy
# 200   9968110510001701  Journal of Comparative Pathology and Therapeutics
# 201   9965015360001701  Journal of Comparative Pathology and Therapeutics
# 212   9966893360001701                                 Brain and language
# ...                ...                                                ...
# 2855  9926256870001701                         Progress in lipid research
# 3076  9968437680001701         IRE transactions on communications systems
# 3077  9946180690001701         IRE transactions on communications systems
# 3166  9955333930001701                 Journal of ultrastructure research
# 3167  9967295640001701        Journal of ultrastructure research (Online)
#
#                 ISSN_cluster p_or_e  \
# 68    [1878-1888, 0005-7894]      e
# 69               [0005-7894]      p
# 200              [0368-1742]      e
# 201              [0368-1742]      p
# 212   [1090-2155, 0093-934X]      e
# ...                      ...    ...
# 2855             [0163-7827]      p
# 3076  [0096-2244, 2162-2132]      e
# 3077             [0096-2244]      p
# 3166             [0022-5320]      p
# 3167  [0022-5320, 1878-2345]      e
#
#                                             e_coll_info  \
# 68    [['61624504590001701', 'Elsevier ScienceDirect...
# 69                                                  NaN
# 200   [['61624504590001701', 'Elsevier ScienceDirect...
# 201                                                 NaN
# 212   [['61624504590001701', 'Elsevier ScienceDirect...
# ...                                                 ...
# 2855                                                NaN
# 3076  [['61619505660001701', 'IEEE/IET Electronic Li...
# 3077                                                NaN
# 3166                                                NaN
# 3167  [['61535211230001701', 'Elsevier SD Backfile B...
#
#                                          portfolio_info  \
# 68          [['53624565280001701', 'Behavior therapy']]
# 69                                                  NaN
# 200   [['53624638360001701', 'Journal of Comparative...
# 201                                                 NaN
# 212      [['53624562670001701', 'Brain and language.']]
# ...                                                 ...
# 2855                                                NaN
# 3076  [['53620358750001701', 'IRE transactions on co...
# 3077                                                NaN
# 3166                                                NaN
# 3167  [['53537613440001701', 'Journal of ultrastruct...
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 68       [ Available from 1970-03- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# 69                                                  NaN    NaN         NaN
# 200   [ Available from 1888 volume: 1 until 1964 vol...  [Yes]  [Elsevier]
# 201                                                 NaN    NaN         NaN
# 212      [ Available from 1974-01- volume: 1 issue: 1;]  [Yes]  [Elsevier]
# ...                                                 ...    ...         ...
# 2855                                                NaN    NaN         NaN
# 3076  [ Available from 1956 volume: 4 issue: 1 until...  [Yes]     [other]
# 3077                                                NaN    NaN         NaN
# 3166                                                NaN    NaN         NaN
# 3167  [ Available from 1957-11- volume: 1 issue: 1 u...  [Yes]  [Elsevier]
#
#                                Title 1 (Print)_BTAA-SPR  ... ct_p_no_match  \
# 68                                                  NaN  ...             0
# 69                                    Behavior therapy.  ...             0
# 200   Journal of comparative pathology and therapeut...  ...             0
# 201   Journal of comparative pathology and therapeut...  ...             0
# 212                                                 NaN  ...             0
# ...                                                 ...  ...           ...
# 2855                        Progress in lipid research.  ...             0
# 3076                                                NaN  ...             0
# 3077        IRE transactions on communications systems.  ...             0
# 3166                Journal of ultrastructure research.  ...             0
# 3167                                                NaN  ...             0
#
#      p2e-percent                                       p2e_has_pcad  \
# 68           1.0  {1970, 1971, 1972, 1973, 1974, 1975, 1976, 197...
# 69           1.0  {1970, 1971, 1972, 1973, 1974, 1975, 1976, 197...
# 200          1.0  {1920, 1921, 1922, 1923, 1924, 1925, 1926, 192...
# 201          1.0  {1920, 1921, 1922, 1923, 1924, 1925, 1926, 192...
# 212          1.0  {1974, 1975, 1976, 1977, 1978, 1979, 1980, 198...
# ...          ...                                                ...
# 2855         1.0  {1978, 1979, 1980, 1981, 1982, 1983, 1984, 198...
# 3076         1.0                           {1960, 1961, 1962, 1959}
# 3077         1.0                           {1960, 1961, 1962, 1959}
# 3166         1.0  {1957, 1958, 1959, 1960, 1961, 1962, 1963, 196...
# 3167         1.0  {1957, 1958, 1959, 1960, 1961, 1962, 1963, 196...
#
#                                               pcad-repo pcad-repo-percent  \
# 68    {1970, 1971, 1972, 1973, 1974, 1975, 1976, 197...               1.0
# 69    {1970, 1971, 1972, 1973, 1974, 1975, 1976, 197...               1.0
# 200   {1920, 1921, 1922, 1923, 1924, 1925, 1926, 192...               1.0
# 201   {1920, 1921, 1922, 1923, 1924, 1925, 1926, 192...               1.0
# 212   {1974, 1975, 1976, 1977, 1978, 1979, 1980, 198...               1.0
# ...                                                 ...               ...
# 2855  {1978, 1979, 1980, 1981, 1982, 1983, 1984, 198...               1.0
# 3076                           {1960, 1961, 1962, 1959}               1.0
# 3077                           {1960, 1961, 1962, 1959}               1.0
# 3166  {1957, 1958, 1959, 1960, 1961, 1962, 1963, 196...               1.0
# 3167  {1957, 1958, 1959, 1960, 1961, 1962, 1963, 196...               1.0
#
#      total-to-remove potential volumes to withdraw final_group_id  \
# 68               1.0                           NaN             34
# 69               1.0                          30.0             34
# 200              1.0                           NaN            100
# 201              1.0                          43.0            100
# 212              1.0                           NaN            106
# ...              ...                           ...            ...
# 2855             1.0                          32.0           1427
# 3076             1.0                           NaN           1538
# 3077             1.0                           6.0           1538
# 3166             1.0                         158.0           1583
# 3167             1.0                           NaN           1583
#
#                                      locs  loc_count
# 68                                    NaN          0
# 69                [TBIOM PERS, ZMLAC OWL]          2
# 200                                   NaN          0
# 201                 [ZMLAC NON, TVET PER]          2
# 212                                   NaN          0
# ...                                   ...        ...
# 2855                 [TCOS SN1, TZDS GEN]          2
# 3076                                  NaN          0
# 3077              [ZMLAC UMDN, ZMLAC OWL]          2
# 3166  [TBIOM PERS, ZMLAC UMDN, ZMLAC OWL]          3
# 3167                                  NaN          0
#
# [120 rows x 43 columns]

# %%
single_loc_100_vendor = split_by_vendor_ct(single_loc_100, 'single_loc_100')
single_loc_100_vendor
# Out:
# no_vendor
# (0, 43)
# has multiple vendors
# (30, 43)
# has single vendor
# (536, 43)
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                 MMS_ID                                          Title_bib  \
# 16    9967030990001701                  Progress in solid state chemistry
# 17    9916137210001701                  Progress in solid state chemistry
# 18    9967833530001701  Progress in the chemistry of fats and other li...
# 19    9930545140001701  Progress in the chemistry of fats and other li...
# 20    9968670150001701  Journal of the Royal Institute of Internationa...
# ...                ...                                                ...
# 3219  9915270740001701                    Journal of virological methods.
# 3220  9968725470001701                                 IEEE ASSP magazine
# 3221  9937260310001701                                 IEEE ASSP magazine
# 3224  9966662330001701  SIAM journal on scientific and statistical com...
# 3225  9946102070001701  SIAM journal on scientific and statistical com...
#
#                            ISSN_cluster p_or_e  \
# 16               [1873-1643, 0079-6786]      e
# 17                          [0079-6786]      p
# 18               [0079-6832, 1878-3198]      e
# 19                          [0079-6832]      p
# 20                          [1473-799X]      e
# ...                                 ...    ...
# 3219                        [0166-0934]      p
# 3220  [1558-1284, 2168-3050, 0740-7467]      e
# 3221                        [0740-7467]      p
# 3224             [2168-3417, 0196-5204]      e
# 3225                        [0196-5204]      p
#
#                                             e_coll_info  \
# 16    [['61624504590001701', 'Elsevier ScienceDirect...
# 17                                                  NaN
# 18    [['61535212360001701', 'Elsevier SD Backfile B...
# 19                                                  NaN
# 20    [['61535212310001701', 'JSTOR Arts and Science...
# ...                                                 ...
# 3219                                                NaN
# 3220  [['61619505660001701', 'IEEE/IET Electronic Li...
# 3221                                                NaN
# 3224  [['61535215690001701', "LOCUS - SIAM''s Online...
# 3225                                                NaN
#
#                                          portfolio_info  \
# 16    [['53624686980001701', 'Progress in solid stat...
# 17                                                  NaN
# 18    [['53611930190001701', 'Progress in the chemis...
# 19                                                  NaN
# 20    [['53540678550001701', 'Journal of the Royal I...
# ...                                                 ...
# 3219                                                NaN
# 3220  [['53620358530001701', 'IEEE ASSP magazine : a...
# 3221                                                NaN
# 3224  [['53536196430001701', 'SIAM journal on scient...
# 3225                                                NaN
#
#                           Coverage Information Combined  PCAD?  Vendor_key  \
# 16                    [ Available from 1964 volume: 1;]  [Yes]  [Elsevier]
# 17                                                  NaN    NaN         NaN
# 18    [ Available from 1952 volume: 1 until 1978 vol...  [Yes]  [Elsevier]
# 19                                                  NaN    NaN         NaN
# 20    [ Available from 1926 volume: 5 issue: 3 until...  [Yes]     [JSTOR]
# ...                                                 ...    ...         ...
# 3219                                                NaN    NaN         NaN
# 3220  [ Available from 1984 volume: 1 issue: 1 until...  [Yes]     [other]
# 3221                                                NaN    NaN         NaN
# 3224  [ Available from 1980 volume: 1 issue: 1 until...  [Yes]     [other]
# 3225                                                NaN    NaN         NaN
#
#                                Title 1 (Print)_BTAA-SPR  ... ct_p_no_match  \
# 16                                                  NaN  ...             0
# 17                   Progress in solid state chemistry.  ...             0
# 18                                                  NaN  ...             0
# 19    Progress in the chemistry of fats and other li...  ...             0
# 20                                                  NaN  ...             0
# ...                                                 ...  ...           ...
# 3219                    Journal of virological methods.  ...             0
# 3220                                                NaN  ...             0
# 3221                                IEEE ASSP magazine.  ...             0
# 3224                                                NaN  ...             0
# 3225  SIAM journal on scientific and statistical com...  ...             0
#
#      p2e-percent                                       p2e_has_pcad  \
# 16           1.0                     {1964, 1965, 1967, 1971, 1973}
# 17           1.0                     {1964, 1965, 1967, 1971, 1973}
# 18           1.0  {1952, 1954, 1955, 1957, 1958, 1963, 1964, 196...
# 19           1.0  {1952, 1954, 1955, 1957, 1958, 1963, 1964, 196...
# 20           1.0                                 {1928, 1929, 1930}
# ...          ...                                                ...
# 3219         1.0  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 3220         1.0         {1984, 1985, 1986, 1987, 1988, 1989, 1990}
# 3221         1.0         {1984, 1985, 1986, 1987, 1988, 1989, 1990}
# 3224         1.0  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
# 3225         1.0  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...
#
#                                               pcad-repo pcad-repo-percent  \
# 16                       {1964, 1965, 1967, 1971, 1973}               1.0
# 17                       {1964, 1965, 1967, 1971, 1973}               1.0
# 18    {1952, 1954, 1955, 1957, 1958, 1963, 1964, 196...               1.0
# 19    {1952, 1954, 1955, 1957, 1958, 1963, 1964, 196...               1.0
# 20                                   {1928, 1929, 1930}               1.0
# ...                                                 ...               ...
# 3219  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...               1.0
# 3220         {1984, 1985, 1986, 1987, 1988, 1989, 1990}               1.0
# 3221         {1984, 1985, 1986, 1987, 1988, 1989, 1990}               1.0
# 3224  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...               1.0
# 3225  {1984, 1985, 1986, 1987, 1988, 1989, 1990, 199...               1.0
#
#      total-to-remove potential volumes to withdraw final_group_id  \
# 16               1.0                           NaN              8
# 17               1.0                           7.0              8
# 18               1.0                           NaN              9
# 19               1.0                          13.0              9
# 20               1.0                           NaN             10
# ...              ...                           ...            ...
# 3219             1.0                          46.0           1609
# 3220             1.0                           NaN           1610
# 3221             1.0                           3.0           1610
# 3224             1.0                           NaN           1612
# 3225             1.0                          22.0           1612
#
#              locs  loc_count
# 16            NaN          0
# 17    [ZMLAC GEN]          1
# 18            NaN          0
# 19    [ZMLAC OWL]          1
# 20            NaN          0
# ...           ...        ...
# 3219   [TVET PER]          1
# 3220          NaN          0
# 3221  [ZMLAC OWL]          1
# 3224          NaN          0
# 3225  [ZMLAC OWL]          1
#
# [536 rows x 43 columns]

# %% [markdown]
# #### Split out single vendor groups by vendor

# %%
def split_by_vendor(df, df_name):
    vends = df[df['Vendor_key'].notnull() == True]
    vends['vendor'] = vends['Vendor_key'].apply(lambda x: x[0])
    
    vendor_list = ['Wiley', 'Elsevier','SAGE','Springer','Taylor & Francis']
    for x in vendor_list:
        print(x)
        group_list = list(vends[vends['vendor'] == x]['final_group_id'])
        data = df[df['final_group_id'].isin(group_list)]
        print(data.shape)
        data.to_pickle(df_name + '_' + x + '.pkl')
        data.to_csv(df_name + '_' + x + '.txt', sep='\t', index=False)
        
    other_groups = list(vends[(vends['vendor'] == 'JSTOR') | (vends['vendor'] == 'other')]['final_group_id'])
    print('other + JSTOR')
    other = df[df['final_group_id'].isin(other_groups)]
    print(other.shape)
    other.to_pickle(df_name + '_other_and_JSTOR.pkl')
    other.to_csv(df_name + '_other_and_JSTOR.txt', sep='\t',index=False)

# %%
split_by_vendor(multi_loc_100_vendor, 'multi_loc_100_vendor')
split_by_vendor(single_loc_100_vendor, 'single_loc_100_vendor')
# Out:
# Wiley
# (6, 43)
# Elsevier
# (80, 43)
# SAGE
# (2, 43)
# Springer
# (4, 43)
# Taylor & Francis
# (2, 43)
# other + JSTOR
# (26, 43)
# Wiley
# (60, 43)
# Elsevier
# (256, 43)
# SAGE
# (14, 43)
# Springer
# (66, 43)
# Taylor & Francis
# (14, 43)
# other + JSTOR
# (126, 43)
# C:\Users\trail001\AppData\Local\Continuum\anaconda3\envs\isbnhld\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
